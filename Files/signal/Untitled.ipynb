# %%
import glob
import re
import pandas as pd

# %%
file_direc = glob.glob('*')
file_direc
# Out:
# ['corr',
#  'pt_daedalus.csv',
#  'pt_template_A_clustering_result.csv',
#  'pt_template_C_clustering_results.csv',
#  'pt_template_D_clustering_results.csv',
#  'Untitled.ipynb']

# %%
for i in range(1,5):
    name = file_direc[i]
    temp = pd.read_csv(name)
    print(temp)
    #temp['expression'].to_csv(f'{i}_cg.csv')
# Out:
#     Unnamed: 0       pnl  book_size  long_count  short_count  turnover  \
# 0            0  40088586   20000000         950         1996    0.0608
# 1            1  98104133   20000000          18            0    0.4555
# 2            2  83627711   20000000          20            0    0.3601
# 3            3  84451589   20000000          19            0    0.4377
# 4            4  28800644   20000000         984          110    0.0285
# 5            5  22442324   20000000         572            0    0.1406
# 6            6  51944043   20000000        1724         1089    0.1699
# 7            7  12026489   20000000        1055         1244    0.0718
# 8            8  91947096   20000000          59            3    0.7774
# 9            9  66361119   20000000        1362          373    1.0349
# 10          10  16967348   20000000           9          138    0.1057
# 11          11  83607519   20000000          30           18    0.4848
# ...
