# %% [markdown]
# ### Import library

# %%
import os
os.chdir('../../')
os.getcwd()
# Out:
# 'C:\\Users\\csia7\\OneDrive\\문서\\GitHub\\WQBrain_2024_API'

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px
import pygwalker as pyg
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_JR8Ht1KsNMXhFNhwLcDborZQNe6w

# %% [markdown]
# ## Global TOP3000 region Alpha Template

# %%
expression_template = f'''
signal1 = ts_zscore (ts_backfill (vec_avg(mdl139_score), 252), 252)
signal2 = ts_zscore (ts_backfill (vec_avg(oth193_shield2), 252), 252)
group = pv13_6l_scibr
group_zscore(signal1, signal2, group)

'''

# %% [markdown]
# #### Step 1. Download datsets

# %%
datasets_df = hf.get_datasets(s, region = 'GLB', universe = 'MINVOL1M') # by default we load all datasets USA TOP3000 delay 1    , region='GLB', universe='MINVOL1M'
datasets_df # DataFrame.head() shows first 5 rows of the dataframe
# Out:
#                 id                             name  \
# 0        analyst11                       ESG scores
# 1        analyst14  Estimations of Key Fundamentals
# 2        analyst15               Earnings forecasts
# 3        analyst16              Real Time Estimates
# 4        analyst35                        ESG Model
# ..             ...                              ...
# 83  shortinterest6              SmartHoldings Model
# 84  shortinterest7              Short Selling Model
# 85   socialmedia12        Sentiment Data for Equity
# 86    socialmedia5           Lexical Breakdown Data
# 87           univ1                 Universe Dataset
#
#                                           description  \
# 0   Environmental Social Governance scores that ex...
# 1   This dataset reports many items from financial...
# 2   This dataset provides bottom-up forecast data ...
# 3   This dataset provides real-time access to the ...
# 4   The dataset provide ESG related information ba...
# ..                                                ...
# 83  This dataset is a global stock selection model...
# 84  The dataset combines features obtained from sh...
# 85  This dataset provides sentiment data with diff...
# 86  Sentiment scores derived from social media. So...
# 87                             No dataset description
#
#                                              category  \
# 0                {'id': 'analyst', 'name': 'Analyst'}
# 1                {'id': 'analyst', 'name': 'Analyst'}
# 2                {'id': 'analyst', 'name': 'Analyst'}
# 3                {'id': 'analyst', 'name': 'Analyst'}
# 4                {'id': 'analyst', 'name': 'Analyst'}
# ..                                                ...
# 83  {'id': 'shortinterest', 'name': 'Short Interest'}
# 84  {'id': 'shortinterest', 'name': 'Short Interest'}
# 85      {'id': 'socialmedia', 'name': 'Social Media'}
# 86      {'id': 'socialmedia', 'name': 'Social Media'}
# 87               {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 0                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  MINVOL1M
# 1   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  MINVOL1M
# 2   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  MINVOL1M
# 3   {'id': 'analyst-crowdsourced-estimates', 'name...    GLB      1  MINVOL1M
# 4                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  MINVOL1M
# ..                                                ...    ...    ...       ...
# 83  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  MINVOL1M
# 84  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  MINVOL1M
# 85  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  MINVOL1M
# 86  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  MINVOL1M
# 87  {'id': 'pv-price-volume', 'name': 'Price Volume'}    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 0     0.7917     None         4.0         66         304         197     []
# 1     0.5186     None         3.0        101         589         926     []
# 2     0.9929     None         2.0        158        1497         288     []
# 3     0.9013     None         2.0        134         821          42     []
# 4     0.4375     None         3.0         63         202          23     []
# ..       ...      ...         ...        ...         ...         ...    ...
# 83    0.9711     None         2.0         92         389          11     []
# 84    1.0000     None         2.0         73         331          16     []
# 85    0.6731     None         3.0         17          25           2     []
# 86    0.3753     None         5.0          2           3          12     []
# 87    1.0000     None         3.0          3           5           2     []
#
#                                        researchPapers
# 0   [{'title': 'Research Paper 19: ESG Preference,...
# 1   [{'title': 'Research Paper 10: Investor Learni...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 83                                                 []
# 84  [{'title': 'Research Paper 04: Strategic Rebal...
# 85  [{'title': 'Research Paper 01: Textual Sentime...
# 86                                                 []
# 87                                                 []
#
# [88 rows x 16 columns]

# %%
# select needed datasets
selected_datasets_df_1 = datasets_df[
    (datasets_df["name"].str.contains('inflation', case=False))
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df_1
# Out:
#           id                                   name  \
# 35  model139  Inflation based stock selection model
#
#                                           description  \
# 35  The model is expected to generate signal in an...
#
#                             category  \
# 35  {'id': 'model', 'name': 'Model'}
#
#                                           subcategory region  delay  universe  \
# 35  {'id': 'model-risk-based-models', 'name': 'Ris...    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 35    0.5965     None         1.0        121         891           2     []
#
#    researchPapers
# 35             []

# %%
# select needed datasets
selected_datasets_df_2 = datasets_df[
    (datasets_df["name"].str.contains('systematic hedging', case=False))
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df_2
# Out:
#           id                                               name  \
# 61  other193  Systematic Hedging for Investors to Evade Larg...
#
#                                           description  \
# 61  Machine learning based stock selection model. ...
#
#                             category  \
# 61  {'id': 'other', 'name': 'Other'}
#
#                                         subcategory region  delay  universe  \
# 61  {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 61    0.5667     None         2.0        125         609           3     []
#
#    researchPapers
# 61             []

# %%
# select needed datasets
selected_datasets_df_3 = datasets_df[
    (datasets_df["name"].str.contains('relationship data for equity', case=False))
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df_3
# Out:
#       id                          name  \
# 73  pv13  Relationship Data for Equity
#
#                                           description  \
# 73  The dataset outputs various classifications an...
#
#                                 category  \
# 73  {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 73  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 73    0.9152     None         1.0        130        1964          29     []
#
#    researchPapers
# 73             []

# %% [markdown]
# #### Step 2. Select the needed datafields

# %% [markdown]
# ### Data 1

# %%
dataset_id_1 = selected_datasets_df_1.id.values.tolist()[0] # create a list of selected datasets ids, our list has only one element
dataset_id_1
# Out:
# 'model139'

# %%
datafields_df_1 = hf.get_datafields(s, region = 'GLB', universe = 'MINVOL1M', dataset_id=dataset_id_1) # download all fields of dataset news
datafields_df_1
# Out:
#               id                              description  \
# 0  mdl139_mktcap                               Market Cap
# 1   mdl139_score  Composite Score (value between 0 and 1)
#
#                                              dataset  \
# 0  {'id': 'model139', 'name': 'Inflation based st...
# 1  {'id': 'model139', 'name': 'Inflation based st...
#
#                            category  \
# 0  {'id': 'model', 'name': 'Model'}
# 1  {'id': 'model', 'name': 'Model'}
#
#                                          subcategory region  delay  universe  \
# 0  {'id': 'model-risk-based-models', 'name': 'Ris...    GLB      1  MINVOL1M
# 1  {'id': 'model-risk-based-models', 'name': 'Ris...    GLB      1  MINVOL1M
#
#      type  coverage turnover  userCount  alphaCount themes
# 0  VECTOR    0.5965     None          7          18     []
# 1  VECTOR    0.5965     None        119         888     []

# %%
selected_datafields_df_1_id = datafields_df_1.id.values.tolist()
selected_datafields_df_1_id
# Out:
# ['mdl139_mktcap', 'mdl139_score']

# %% [markdown]
# ### Data 2

# %%
dataset_id_2 = selected_datasets_df_2.id.values.tolist()[0] # create a list of selected datasets ids, our list has only one element
dataset_id_2
# Out:
# 'other193'

# %%
datafields_df_2 = hf.get_datafields(s, region = 'GLB', universe = 'MINVOL1M', dataset_id=dataset_id_2) # download all fields of dataset news
datafields_df_2
# Out:
#                                   id  \
# 0                      oth193_shield
# 1                     oth193_shield2
# 2  oth193_wolfe_shield_global_mktcap
#
#                                          description  \
# 0  The field gives the score which comes from the...
# 1  The field gives the score which comes from a m...
# 2                       Martket cap values in dollar
#
#                                              dataset  \
# 0  {'id': 'other193', 'name': 'Systematic Hedging...
# 1  {'id': 'other193', 'name': 'Systematic Hedging...
# 2  {'id': 'other193', 'name': 'Systematic Hedging...
#
#                            category  \
# 0  {'id': 'other', 'name': 'Other'}
# 1  {'id': 'other', 'name': 'Other'}
# 2  {'id': 'other', 'name': 'Other'}
#
#                                        subcategory region  delay  universe  \
# 0  {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    GLB      1  MINVOL1M
# 1  {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    GLB      1  MINVOL1M
# 2  {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    GLB      1  MINVOL1M
#
#      type  coverage turnover  userCount  alphaCount themes
# 0  VECTOR    0.5667     None         59         223     []
# 1  VECTOR    0.5667     None        109         431     []
# 2  VECTOR    0.5667     None         29          52     []

# %%
selected_datafields_df_2_id = datafields_df_2.id.values.tolist()
selected_datafields_df_2_id
# Out:
# ['oth193_shield', 'oth193_shield2', 'oth193_wolfe_shield_global_mktcap']

# %% [markdown]
# ### Data 3

# %%
dataset_id_3 = selected_datasets_df_3.id.values.tolist()[0] # create a list of selected datasets ids, our list has only one element
dataset_id_3
# Out:
# 'pv13'

# %%
datafields_df_3 = hf.get_datafields(s, region = 'GLB', universe = 'MINVOL1M', dataset_id=dataset_id_3) # download all fields of dataset news
datafields_df_3
# Out:
#                                       id  \
# 0         pv13_10_f2_g3_minvol_1m_sector
# 1         pv13_10_f2_g4_minvol_1m_sector
# 2         pv13_10_f3_g2_minvol_1m_sector
# 3               pv13_10_minvol_1m_sector
# 4                         pv13_10_sector
# 5                          pv13_1l_scibr
# 6               pv13_20_minvol_1m_sector
# 7          pv13_2_f3_g2_minvol_1m_sector
# 8          pv13_2_f4_g3_minvol_1m_sector
# 9    pv13_2_minvol_1m_all_delay_1_sector
# 10               pv13_2_minvol_1m_sector
# 11                         pv13_2_sector
# 12                         pv13_2l_scibr
# 13                         pv13_3l_scibr
# 14                         pv13_4l_scibr
# 15  pv13_52_minvol_1m_all_delay_1_sector
# 16              pv13_52_minvol_1m_sector
# 17         pv13_5_f3_g2_minvol_1m_sector
# 18                   pv13_5_f3_g2_sector
# 19               pv13_5_minvol_1m_sector
# 20                         pv13_5l_scibr
# 21                         pv13_6l_scibr
# 22    pv13_ompetitor_graphrank_auth_rank
# 23     pv13_ompetitor_graphrank_hub_rank
# 24    pv13_ompetitor_graphrank_page_rank
# 25                        pv13_reveremap
# 26      pv13_ustomer_graphrank_auth_rank
# 27       pv13_ustomer_graphrank_hub_rank
# 28      pv13_ustomer_graphrank_page_rank
#
#                                 description  \
# 0                           grouping fields
# 1                           grouping fields
# 2                           grouping fields
# 3                           grouping fields
# 4                           grouping fields
# 5                           grouping fields
# 6                           grouping fields
# 7                           grouping fields
# 8                           grouping fields
# 9                           grouping fields
# 10                          grouping fields
# 11                          grouping fields
# 12                          grouping fields
# 13                          grouping fields
# 14                          grouping fields
# 15                          grouping fields
# 16                          grouping fields
# 17                          grouping fields
# 18                          grouping fields
# 19                          grouping fields
# 20                          grouping fields
# 21                          grouping fields
# 22  the HITS authority score of competitors
# 23        the HITS hub score of competitors
# 24        the PageRank score of competitors
# 25                             Mapping data
# 26    the HITS authority score of customers
# 27          the HITS hub score of customers
# 28          the PageRank score of customers
#
#                                               dataset  \
# 0   {'id': 'pv13', 'name': 'Relationship Data for ...
# 1   {'id': 'pv13', 'name': 'Relationship Data for ...
# 2   {'id': 'pv13', 'name': 'Relationship Data for ...
# 3   {'id': 'pv13', 'name': 'Relationship Data for ...
# 4   {'id': 'pv13', 'name': 'Relationship Data for ...
# 5   {'id': 'pv13', 'name': 'Relationship Data for ...
# 6   {'id': 'pv13', 'name': 'Relationship Data for ...
# 7   {'id': 'pv13', 'name': 'Relationship Data for ...
# 8   {'id': 'pv13', 'name': 'Relationship Data for ...
# 9   {'id': 'pv13', 'name': 'Relationship Data for ...
# 10  {'id': 'pv13', 'name': 'Relationship Data for ...
# 11  {'id': 'pv13', 'name': 'Relationship Data for ...
# 12  {'id': 'pv13', 'name': 'Relationship Data for ...
# 13  {'id': 'pv13', 'name': 'Relationship Data for ...
# 14  {'id': 'pv13', 'name': 'Relationship Data for ...
# 15  {'id': 'pv13', 'name': 'Relationship Data for ...
# 16  {'id': 'pv13', 'name': 'Relationship Data for ...
# 17  {'id': 'pv13', 'name': 'Relationship Data for ...
# 18  {'id': 'pv13', 'name': 'Relationship Data for ...
# 19  {'id': 'pv13', 'name': 'Relationship Data for ...
# 20  {'id': 'pv13', 'name': 'Relationship Data for ...
# 21  {'id': 'pv13', 'name': 'Relationship Data for ...
# 22  {'id': 'pv13', 'name': 'Relationship Data for ...
# 23  {'id': 'pv13', 'name': 'Relationship Data for ...
# 24  {'id': 'pv13', 'name': 'Relationship Data for ...
# 25  {'id': 'pv13', 'name': 'Relationship Data for ...
# 26  {'id': 'pv13', 'name': 'Relationship Data for ...
# 27  {'id': 'pv13', 'name': 'Relationship Data for ...
# 28  {'id': 'pv13', 'name': 'Relationship Data for ...
#
#                                 category  \
# 0   {'id': 'pv', 'name': 'Price Volume'}
# 1   {'id': 'pv', 'name': 'Price Volume'}
# 2   {'id': 'pv', 'name': 'Price Volume'}
# 3   {'id': 'pv', 'name': 'Price Volume'}
# 4   {'id': 'pv', 'name': 'Price Volume'}
# 5   {'id': 'pv', 'name': 'Price Volume'}
# 6   {'id': 'pv', 'name': 'Price Volume'}
# 7   {'id': 'pv', 'name': 'Price Volume'}
# 8   {'id': 'pv', 'name': 'Price Volume'}
# 9   {'id': 'pv', 'name': 'Price Volume'}
# 10  {'id': 'pv', 'name': 'Price Volume'}
# 11  {'id': 'pv', 'name': 'Price Volume'}
# 12  {'id': 'pv', 'name': 'Price Volume'}
# 13  {'id': 'pv', 'name': 'Price Volume'}
# 14  {'id': 'pv', 'name': 'Price Volume'}
# 15  {'id': 'pv', 'name': 'Price Volume'}
# 16  {'id': 'pv', 'name': 'Price Volume'}
# 17  {'id': 'pv', 'name': 'Price Volume'}
# 18  {'id': 'pv', 'name': 'Price Volume'}
# 19  {'id': 'pv', 'name': 'Price Volume'}
# 20  {'id': 'pv', 'name': 'Price Volume'}
# 21  {'id': 'pv', 'name': 'Price Volume'}
# 22  {'id': 'pv', 'name': 'Price Volume'}
# 23  {'id': 'pv', 'name': 'Price Volume'}
# 24  {'id': 'pv', 'name': 'Price Volume'}
# 25  {'id': 'pv', 'name': 'Price Volume'}
# 26  {'id': 'pv', 'name': 'Price Volume'}
# 27  {'id': 'pv', 'name': 'Price Volume'}
# 28  {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 0   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 1   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 2   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 3   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 4   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 5   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 6   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 7   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 8   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 9   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 10  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 11  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 12  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 13  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 14  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 15  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 16  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 17  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 18  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 19  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 20  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 21  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 22  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 23  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 24  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 25  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 26  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 27  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 28  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
#
#       type  coverage turnover  userCount  alphaCount themes
# 0    GROUP    1.0000     None         27         147     []
# 1    GROUP    1.0000     None         16         102     []
# 2    GROUP    1.0000     None         17          99     []
# 3    GROUP    1.0000     None         36         124     []
# 4    GROUP    1.0000     None          4          10     []
# 5    GROUP    0.8770     None         31         120     []
# 6    GROUP    1.0000     None         38         247     []
# 7    GROUP    1.0000     None         19          78     []
# 8    GROUP    1.0000     None         21          89     []
# 9    GROUP    1.0000     None         26          94     []
# 10   GROUP    1.0000     None         21         132     []
# 11   GROUP    1.0000     None          5           6     []
# 12   GROUP    0.9238     None         23         128     []
# 13   GROUP    0.9238     None         25          60     []
# 14   GROUP    0.9238     None         20          73     []
# 15   GROUP    1.0000     None         23         132     []
# 16   GROUP    1.0000     None         23         104     []
# 17   GROUP    1.0000     None         19         151     []
# 18   GROUP    1.0000     None          3           3     []
# 19   GROUP    1.0000     None         14          66     []
# 20   GROUP    0.9238     None         34         291     []
# 21   GROUP    0.9238     None         40         377     []
# 22  MATRIX    0.7318     None          6          14     []
# 23  MATRIX    0.3809     None          7          12     []
# 24  MATRIX    0.7700     None          7          10     []
# 25  MATRIX    1.0000     None          6          10     []
# 26  MATRIX    0.7959     None          7           9     []
# 27  MATRIX    0.4791     None          3           8     []
# 28  MATRIX    0.8858     None          9          15     []

# %%
selected_datafields_df_3 = datafields_df_3[
    (datafields_df_3['type'].str.contains('group', case=False))
].sort_values(by=['userCount'], ascending=False)
selected_datafields_df_3
# Out:
#                                       id      description  \
# 21                         pv13_6l_scibr  grouping fields
# 6               pv13_20_minvol_1m_sector  grouping fields
# 3               pv13_10_minvol_1m_sector  grouping fields
# 20                         pv13_5l_scibr  grouping fields
# 5                          pv13_1l_scibr  grouping fields
# 0         pv13_10_f2_g3_minvol_1m_sector  grouping fields
# 9    pv13_2_minvol_1m_all_delay_1_sector  grouping fields
# 13                         pv13_3l_scibr  grouping fields
# 12                         pv13_2l_scibr  grouping fields
# 15  pv13_52_minvol_1m_all_delay_1_sector  grouping fields
# 16              pv13_52_minvol_1m_sector  grouping fields
# 8          pv13_2_f4_g3_minvol_1m_sector  grouping fields
# 10               pv13_2_minvol_1m_sector  grouping fields
# 14                         pv13_4l_scibr  grouping fields
# 7          pv13_2_f3_g2_minvol_1m_sector  grouping fields
# 17         pv13_5_f3_g2_minvol_1m_sector  grouping fields
# 2         pv13_10_f3_g2_minvol_1m_sector  grouping fields
# 1         pv13_10_f2_g4_minvol_1m_sector  grouping fields
# 19               pv13_5_minvol_1m_sector  grouping fields
# 11                         pv13_2_sector  grouping fields
# 4                         pv13_10_sector  grouping fields
# 18                   pv13_5_f3_g2_sector  grouping fields
#
#                                               dataset  \
# 21  {'id': 'pv13', 'name': 'Relationship Data for ...
# 6   {'id': 'pv13', 'name': 'Relationship Data for ...
# 3   {'id': 'pv13', 'name': 'Relationship Data for ...
# 20  {'id': 'pv13', 'name': 'Relationship Data for ...
# 5   {'id': 'pv13', 'name': 'Relationship Data for ...
# 0   {'id': 'pv13', 'name': 'Relationship Data for ...
# 9   {'id': 'pv13', 'name': 'Relationship Data for ...
# 13  {'id': 'pv13', 'name': 'Relationship Data for ...
# 12  {'id': 'pv13', 'name': 'Relationship Data for ...
# 15  {'id': 'pv13', 'name': 'Relationship Data for ...
# 16  {'id': 'pv13', 'name': 'Relationship Data for ...
# 8   {'id': 'pv13', 'name': 'Relationship Data for ...
# 10  {'id': 'pv13', 'name': 'Relationship Data for ...
# 14  {'id': 'pv13', 'name': 'Relationship Data for ...
# 7   {'id': 'pv13', 'name': 'Relationship Data for ...
# 17  {'id': 'pv13', 'name': 'Relationship Data for ...
# 2   {'id': 'pv13', 'name': 'Relationship Data for ...
# 1   {'id': 'pv13', 'name': 'Relationship Data for ...
# 19  {'id': 'pv13', 'name': 'Relationship Data for ...
# 11  {'id': 'pv13', 'name': 'Relationship Data for ...
# 4   {'id': 'pv13', 'name': 'Relationship Data for ...
# 18  {'id': 'pv13', 'name': 'Relationship Data for ...
#
#                                 category  \
# 21  {'id': 'pv', 'name': 'Price Volume'}
# 6   {'id': 'pv', 'name': 'Price Volume'}
# 3   {'id': 'pv', 'name': 'Price Volume'}
# 20  {'id': 'pv', 'name': 'Price Volume'}
# 5   {'id': 'pv', 'name': 'Price Volume'}
# 0   {'id': 'pv', 'name': 'Price Volume'}
# 9   {'id': 'pv', 'name': 'Price Volume'}
# 13  {'id': 'pv', 'name': 'Price Volume'}
# 12  {'id': 'pv', 'name': 'Price Volume'}
# 15  {'id': 'pv', 'name': 'Price Volume'}
# 16  {'id': 'pv', 'name': 'Price Volume'}
# 8   {'id': 'pv', 'name': 'Price Volume'}
# 10  {'id': 'pv', 'name': 'Price Volume'}
# 14  {'id': 'pv', 'name': 'Price Volume'}
# 7   {'id': 'pv', 'name': 'Price Volume'}
# 17  {'id': 'pv', 'name': 'Price Volume'}
# 2   {'id': 'pv', 'name': 'Price Volume'}
# 1   {'id': 'pv', 'name': 'Price Volume'}
# 19  {'id': 'pv', 'name': 'Price Volume'}
# 11  {'id': 'pv', 'name': 'Price Volume'}
# 4   {'id': 'pv', 'name': 'Price Volume'}
# 18  {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 21  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 6   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 3   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 20  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 5   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 0   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 9   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 13  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 12  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 15  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 16  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 8   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 10  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 14  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 7   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 17  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 2   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 1   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 19  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 11  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 4   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 18  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
#
#      type  coverage turnover  userCount  alphaCount themes
# 21  GROUP    0.9238     None         40         377     []
# 6   GROUP    1.0000     None         38         247     []
# 3   GROUP    1.0000     None         36         124     []
# 20  GROUP    0.9238     None         34         291     []
# 5   GROUP    0.8770     None         31         120     []
# 0   GROUP    1.0000     None         27         147     []
# 9   GROUP    1.0000     None         26          94     []
# 13  GROUP    0.9238     None         25          60     []
# 12  GROUP    0.9238     None         23         128     []
# 15  GROUP    1.0000     None         23         132     []
# 16  GROUP    1.0000     None         23         104     []
# 8   GROUP    1.0000     None         21          89     []
# 10  GROUP    1.0000     None         21         132     []
# 14  GROUP    0.9238     None         20          73     []
# 7   GROUP    1.0000     None         19          78     []
# 17  GROUP    1.0000     None         19         151     []
# 2   GROUP    1.0000     None         17          99     []
# 1   GROUP    1.0000     None         16         102     []
# 19  GROUP    1.0000     None         14          66     []
# 11  GROUP    1.0000     None          5           6     []
# 4   GROUP    1.0000     None          4          10     []
# 18  GROUP    1.0000     None          3           3     []

# %%
selected_datafields_df_3_id = selected_datafields_df_3.id.values.tolist()
# Out:
# ['pv13_6l_scibr',
#  'pv13_20_minvol_1m_sector',
#  'pv13_10_minvol_1m_sector',
#  'pv13_5l_scibr',
#  'pv13_1l_scibr',
#  'pv13_10_f2_g3_minvol_1m_sector',
#  'pv13_2_minvol_1m_all_delay_1_sector',
#  'pv13_3l_scibr',
#  'pv13_2l_scibr',
#  'pv13_52_minvol_1m_all_delay_1_sector',
#  'pv13_52_minvol_1m_sector',
#  'pv13_2_f4_g3_minvol_1m_sector',
#  'pv13_2_minvol_1m_sector',
#  'pv13_4l_scibr',
#  'pv13_2_f3_g2_minvol_1m_sector',
#  'pv13_5_f3_g2_minvol_1m_sector',
#  'pv13_10_f3_g2_minvol_1m_sector',
#  'pv13_10_f2_g4_minvol_1m_sector',
#  'pv13_5_minvol_1m_sector',
#  'pv13_2_sector',
#  'pv13_10_sector',
#  'pv13_5_f3_g2_sector']

# %% [markdown]
# #### Step 4. Apply generate_alpha function to the expression list
# In generate alpha function you can specify region, universe, decay, delay and other simulation settings

# %% [markdown]
# 이제 만들어둔 expressions 을 사용해 alpha simulation 을 해줍니다.

# %%
#?ace.generate_alpha

# %%
# parameters
data1, data2, data3 = 0, 0, 0

expression_template = f'''
s1 = ts_zscore (ts_backfill (vec_avg({data1}), 252), 252)
s2 = ts_zscore (ts_backfill (vec_avg({data2}), 252), 252)
group = {data3}
group_zscore(s1, s2, group)
'''

# %%
parameters = []
for a in selected_datafields_df_1_id:
    for b in selected_datafields_df_2_id:
        for c in selected_datafields_df_3_id[:5]:
            parameters.append([a, b, c])
parameters[:5]
# Out:
# [['mdl139_mktcap', 'oth193_shield', 'pv13_6l_scibr'],
#  ['mdl139_mktcap', 'oth193_shield', 'pv13_20_minvol_1m_sector'],
#  ['mdl139_mktcap', 'oth193_shield', 'pv13_10_minvol_1m_sector'],
#  ['mdl139_mktcap', 'oth193_shield', 'pv13_5l_scibr'],
#  ['mdl139_mktcap', 'oth193_shield', 'pv13_1l_scibr']]

# %%
expressions = []
for data1, data2, data3 in parameters:
    expressions.append(f's1 = ts_zscore (ts_backfill (vec_avg({data1}), 252), 252);s2 = ts_zscore (ts_backfill (vec_avg({data2}), 252), 252);group = {data3};group_zscore(s1+s2, group)')
    
expressions[:5]
# Out:
# ['s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mktcap), 252), 252);s2 = ts_zscore (ts_backfill (vec_avg(oth193_shield), 252), 252);group = pv13_6l_scibr;group_zscore(s1+s2, group)',
#  's1 = ts_zscore (ts_backfill (vec_avg(mdl139_mktcap), 252), 252);s2 = ts_zscore (ts_backfill (vec_avg(oth193_shield), 252), 252);group = pv13_20_minvol_1m_sector;group_zscore(s1+s2, group)',
#  's1 = ts_zscore (ts_backfill (vec_avg(mdl139_mktcap), 252), 252);s2 = ts_zscore (ts_backfill (vec_avg(oth193_shield), 252), 252);group = pv13_10_minvol_1m_sector;group_zscore(s1+s2, group)',
#  's1 = ts_zscore (ts_backfill (vec_avg(mdl139_mktcap), 252), 252);s2 = ts_zscore (ts_backfill (vec_avg(oth193_shield), 252), 252);group = pv13_5l_scibr;group_zscore(s1+s2, group)',
#  's1 = ts_zscore (ts_backfill (vec_avg(mdl139_mktcap), 252), 252);s2 = ts_zscore (ts_backfill (vec_avg(oth193_shield), 252), 252);group = pv13_1l_scibr;group_zscore(s1+s2, group)']

# %%
len(expressions)
# Out:
# 30

# %%
#when you send multiple alphas for simulation, please make sure all alphas of a single list should have common settings
#alphas with different settings should be sent in a different list, for instance below list has all alphas with same settings

alpha_list = [ace.generate_alpha(x, region= "GLB", universe = "MINVOL1M", neutralization = 'COUNTRY', truncation = 0.01, delay = 1, decay = 2) for x in expressions]
alpha_list[0]
# Out:
# {'type': 'REGULAR',
#  'settings': {'instrumentType': 'EQUITY',
#   'region': 'GLB',
#   'universe': 'MINVOL1M',
#   'delay': 1,
#   'decay': 2,
#   'neutralization': 'COUNTRY',
#   'truncation': 0.01,
#   'pasteurization': 'ON',
#   'testPeriod': 'P0Y0M0D',
#   'unitHandling': 'VERIFY',
#   'nanHandling': 'OFF',
#   'language': 'FASTEXPR',
#   'visualization': False},
#  'regular': 's1 = ts_zscore (ts_backfill (vec_avg(mdl139_mktcap), 252), 252);s2 = ts_zscore (ts_backfill (vec_avg(oth193_shield), 252), 252);group = pv13_6l_scibr;group_zscore(s1+s2, group)'}

# %% [markdown]
# ### Simulate alpha list, get simulation result
#
# simulate_alpha_list_multi will do a multi-simulation if list of alphas is greater than 10, which is the case here
#
# the returned object will contain simulation results for all alphas as a list

# %%
#alpha expressions are sliced to first 10 for demonstration purpose

result = ace.simulate_alpha_list_multi(s, alpha_list)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [25:21<00:00, 152.20s/it]

# %% [markdown]
# 위 코드를 실행하면 시뮬레이션이 시작됩니다. 100개의 알파에 대략 1시간 정도 소요되니, 인터넷 연결이 끊기지 않게 주의하시고, 너무 많은 알파를 한 번에 돌리기보다는 몇개씩 끊어서 돌려도 좋습니다.

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#          pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0    8746509   20000000        3493         3487    0.1848   0.0845    0.0090
# 1    9120942   20000000        3336         3329    0.1790   0.0881    0.0103
# 2    8483961   20000000        3490         3487    0.1865   0.0819    0.0100
# 3    8584940   20000000        3493         3485    0.1853   0.0829    0.0082
# 4    8292249   20000000        3493         3488    0.1871   0.0801    0.0092
# 5    9005648   20000000        3337         3328    0.1792   0.0870    0.0143
# 6    7801164   20000000        3168         3167    0.1846   0.0753    0.0087
# 7    7708870   20000000        3169         3167    0.1849   0.0744    0.0090
# 8    7708024   20000000        3227         3226    0.1847   0.0744    0.0104
# 9    7597359   20000000        3227         3226    0.1850   0.0734    0.0105
# 10  10001488   20000000        3361         3303    0.1394   0.0966    0.1013
# 11   8237887   20000000        3519         3457    0.1483   0.0795    0.0686
# 12   7769358   20000000        3518         3461    0.1505   0.0750    0.0652
# 13   7102245   20000000        3249         3202    0.1495   0.0686    0.0558
# 14   6849943   20000000        3191         3144    0.1501   0.0661    0.0529
# 15   7967614   20000000        3330         3336    0.1491   0.0769    0.1094
# 16   7844751   20000000        3333         3331    0.1486   0.0758    0.1148
# 17   6332711   20000000        3491         3487    0.1569   0.0612    0.0841
# 18   6132163   20000000        3493         3485    0.1571   0.0592    0.0888
# 19   5892650   20000000        3492         3486    0.1591   0.0569    0.0800
# 20   5690289   20000000        3493         3484    0.1592   0.0549    0.0845
# 21   4909882   20000000        3174         3163    0.1589   0.0474    0.0672
# 22   4956407   20000000        3229         3222    0.1586   0.0479    0.0694
# 23   4771174   20000000        3174         3162    0.1587   0.0461    0.0704
# 24   4843658   20000000        3231         3222    0.1584   0.0468    0.0726
# 25   4795183   20000000        3365         3300    0.0950   0.0463    0.1743
# 26   2262006   20000000        3519         3460    0.1027   0.0218    0.1577
# 27   1798872   20000000        3515         3462    0.1043   0.0174    0.1540
# 28   1165469   20000000        3248         3203    0.1048   0.0113    0.1403
# 29    870027   20000000        3189         3146    0.1055   0.0084    0.1447
#
#       margin  fitness  sharpe  start_date alpha_id  \
# 0   0.000914     3.71    5.49  2012-01-22  9rvZRVK
# 1   0.000984     3.62    5.16  2012-01-22  d0Xkx1J
# 2   0.000878     3.60    5.44  2012-01-22  XnrmKWz
# 3   0.000895     3.54    5.30  2012-01-22  VP91YGJ
# 4   0.000856     3.43    5.24  2012-01-22  zmMKJNG
# 5   0.000971     3.41    4.90  2012-01-22  1d9k7RQ
# 6   0.000816     3.31    5.18  2012-01-22  vlqwLbQ
# 7   0.000805     3.22    5.08  2012-01-22  mb3wxV5
# 8   0.000806     3.21    5.05  2012-01-22  OZYQ9N7
# 9   0.000793     3.11    4.93  2012-01-22  GLa1w7Q
# 10  0.001385     1.57    1.88  2012-01-22  5Obnz1n
# 11  0.001073     1.48    2.02  2012-01-22  bqkGL86
# 12  0.000997     1.41    2.00  2012-01-22  P3WQ2AJ
# 13  0.000917     1.35    2.00  2012-01-22  APWjN2l
# 14  0.000881     1.33    2.00  2012-01-22  e0pkO6d
# 15  0.001032     1.10    1.53  2012-01-22  xk6OzMp
# 16  0.001019     1.05    1.47  2012-01-22  XnrmErX
# 17  0.000779     1.00    1.60  2012-01-22  Zn5PZ8Q
# 18  0.000754     0.93    1.51  2012-01-22  QVJZLxG
# 19  0.000715     0.93    1.56  2012-01-22  2L08EYP
# 20  0.000690     0.86    1.47  2012-01-22  0ElO0Jq
# 21  0.000597     0.82    1.50  2012-01-22  0ElOW3q
# 22  0.000604     0.80    1.46  2012-01-22  gMAkv2g
# 23  0.000581     0.77    1.43  2012-01-22  698mv6G
# 24  0.000591     0.76    1.39  2012-01-22  R83jLMe
# 25  0.000975     0.41    0.67  2012-01-22  ql19dzK
# 26  0.000425     0.16    0.39  2012-01-22  71A7Xg5
# 27  0.000333     0.12    0.32  2012-01-22  EE7ObYP
# 28  0.000215     0.07    0.23  2012-01-22  VP91EE8
# 29  0.000159     0.05    0.18  2012-01-22  3RbQ6g6
#
#                                            expression concentrated_weight  \
# 0   s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 1   s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 2   s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 3   s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 4   s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 5   s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 6   s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 7   s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 8   s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 9   s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 10  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 11  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 12  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 13  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 14  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_sc...                PASS
# 15  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 16  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 17  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 18  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 19  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 20  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 21  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 22  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 23  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 24  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 25  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 26  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 27  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 28  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
# 29  s1 = ts_zscore (ts_backfill (vec_avg(mdl139_mk...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             PASS        PASS       PASS
# 1           PASS             PASS        PASS       PASS
# 2           PASS             PASS        PASS       PASS
# 3           PASS             PASS        PASS       PASS
# 4           PASS             PASS        PASS       PASS
# 5           PASS             PASS        PASS       PASS
# 6           PASS             PASS        PASS       PASS
# 7           PASS             PASS        PASS       PASS
# 8           PASS             PASS        PASS       PASS
# 9           PASS             PASS        PASS       PASS
# 10          PASS             FAIL        PASS       PASS
# 11          PASS             FAIL        PASS       PASS
# 12          PASS             FAIL        PASS       PASS
# 13          PASS             FAIL        PASS       PASS
# 14          PASS             FAIL        PASS       PASS
# 15          PASS             FAIL        PASS       FAIL
# 16          PASS             FAIL        PASS       FAIL
# 17          PASS             FAIL        PASS       PASS
# 18          PASS             FAIL        FAIL       FAIL
# 19          PASS             FAIL        FAIL       FAIL
# 20          PASS             FAIL        FAIL       FAIL
# 21          PASS             FAIL        FAIL       FAIL
# 22          PASS             FAIL        FAIL       FAIL
# 23          PASS             FAIL        FAIL       FAIL
# 24          PASS             FAIL        FAIL       FAIL
# 25          PASS             FAIL        FAIL       FAIL
# 26          PASS             FAIL        FAIL       FAIL
# 27          PASS             FAIL        FAIL       FAIL
# 28          PASS             FAIL        FAIL       FAIL
# 29          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover
# 0                     FAIL         PASS
# 1                     FAIL         PASS
# 2                     FAIL         PASS
# 3                     FAIL         PASS
# 4                     FAIL         PASS
# 5                     FAIL         PASS
# 6                     FAIL         PASS
# 7                     FAIL         PASS
# 8                     FAIL         PASS
# 9                     FAIL         PASS
# 10                    PASS         PASS
# 11                    PASS         PASS
# 12                    PASS         PASS
# 13                    PASS         PASS
# 14                    PASS         PASS
# 15                    PASS         PASS
# 16                    PASS         PASS
# 17                    PASS         PASS
# 18                    PASS         PASS
# 19                    PASS         PASS
# 20                    PASS         PASS
# 21                    PASS         PASS
# 22                    PASS         PASS
# 23                    PASS         PASS
# 24                    PASS         PASS
# 25                    PASS         PASS
# 26                    PASS         PASS
# 27                    FAIL         PASS
# 28                    FAIL         PASS
# 29                    FAIL         PASS

# %% [markdown]
# prettify 함수를 이용해 dataframe 형식으로 변환하면 결과를 보기 더 편합니다.

# %%
result_st1.to_csv('2024_09_13_GLBTOP3000.csv')

# %% [markdown]
# ### How to submit?
#
# Create a list of submittable alphas - alphas that have no FAIL in is_tests

# %% [markdown]
# 시뮬레이션을 마친 알파 중 제출 가능한 알파들을 제출해 봅시다.

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df
# Out:
#     alpha_id     endDate  limit                 name   result   startDate  \
# 0    698mv6G         NaN   1.58           LOW_SHARPE     FAIL         NaN
# 1    698mv6G         NaN   1.00          LOW_FITNESS     FAIL         NaN
# 2    698mv6G         NaN   0.01         LOW_TURNOVER     PASS         NaN
# 3    698mv6G         NaN   0.70        HIGH_TURNOVER     PASS         NaN
# 4    698mv6G         NaN    NaN  CONCENTRATED_WEIGHT     PASS         NaN
# ..       ...         ...    ...                  ...      ...         ...
# 355  5Obnz1n         NaN    NaN       DATA_DIVERSITY  PENDING         NaN
# 356  5Obnz1n         NaN    NaN     PROD_CORRELATION  PENDING         NaN
# 357  5Obnz1n         NaN    NaN   REGULAR_SUBMISSION  PENDING         NaN
# 358  5Obnz1n  2020-01-25   1.58     IS_LADDER_SHARPE     FAIL  2022-01-24
# 359  5Obnz1n         NaN    NaN       MATCHES_THEMES  WARNING         NaN
#
#                                                 themes   value  year
# 0                                                  NaN  1.4300   NaN
# 1                                                  NaN  0.7700   NaN
# 2                                                  NaN  0.1587   NaN
# 3                                                  NaN  0.1587   NaN
# 4                                                  NaN     NaN   NaN
# ..                                                 ...     ...   ...
# 355                                                NaN     NaN   NaN
# 356                                                NaN     NaN   NaN
# 357                                                NaN     NaN   NaN
# 358                                                NaN  0.8600   2.0
# 359  [{'id': 'WBlNe4R', 'multiplier': 3.0, 'name': ...     NaN   NaN
#
# [360 rows x 9 columns]

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['698mv6G' 'QVJZLxG' '0ElO0Jq' 'R83jLMe' 'XnrmErX' '0ElOW3q' 'Zn5PZ8Q'
#  '2L08EYP' 'gMAkv2g' 'EE7ObYP' 'VP91EE8' 'ql19dzK' 'xk6OzMp' '3RbQ6g6'
#  '71A7Xg5' 'mb3wxV5' 'VP91YGJ' 'zmMKJNG' '9rvZRVK' 'XnrmKWz' 'OZYQ9N7'
#  'd0Xkx1J' 'e0pkO6d' 'bqkGL86' 'GLa1w7Q' '1d9k7RQ' 'vlqwLbQ' 'P3WQ2AJ'
#  'APWjN2l' '5Obnz1n']
# Passed alphas:[]

# %%
for alpha_id in ['ad59v2O', 'k3z6qqk', 'Lp0YPva', '9wNOzNr', '7weR901', '6w5Ln6E', 'QawpLe5', '17rAQ6m', '273obEY', 'xxJpKLg', 'Wpv2EZo', 'm8EWMk1']:
    hf.set_alpha_properties(s, alpha_id, tags = ['pass_Sep07_mixing'])

# %%
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['Sep07_GLB'])

# %% [markdown]
# ## Temp

# %%
passed_alphas = ['3RQeOx0', 'Xnm8ObX', 'zmKRARo', 'VP1Gdn0', 'Xnm8OJX', '1dkzRmX', 'Y0LgRZo', 'wlKake6', 'vlwNR83', 'ql9656v', 'Y0LvopW', '2L8pN9P', 'EEOGRwG', 'L1VGOEe', '0EOMaXq', '5OnkGk1', 'k0EPrOg', '1dkp7YJ', 'vlwNmYz', 'K9lE7oj', '2L8prr5', 'ql9NrPE', 'GL1GAzQ', 'OZQGP5J', 'QVZ9wmG', 'plYK9Jq', 'Y0Lvqqo', 'JOMGP0E', '8Q5pxpa', 'mbwVjGK', 'anjE5N5', 'QVZ97RW', 'APj7LPg', 'd0kRPOK', 'VP137L5', 'Xnm8Npz', 'EEOe2pR', 'MQML7E8', 'GL1el7Z', '1dkzGdX', 'P3QOAgJ', 'GL1elRG', 'gMk8wnv', 'k0EPqxk', 'llpWXZn', '69mpoPE', 'Xnm8N8m', 'n2xNr1w', 'P3QOkn7', 'vlwNPRG', 'vlwNap3', '3RQelNQ', 'ZnPK71n', 'ZnPKXKQ', 'EEOe9qJ', '5OnkGO1', '717znG8', 'j0z6Wqe']

# %%
len(passed_alphas)
# Out:
# 58

# %% [markdown]
# 위 함수로 통과한 알파들에 태그를 붙일 수 있습니다.

# %% [markdown]
# When you got a list of submittable alphas, you can call function submit_alpha()

# %%
#calling submit_alpha on all alphas that have passed the submission tests

submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas[40:]}

# %% [markdown]
# 위 함수로 알파를 제출할 수 있습니다.

# %% [markdown]
# 알파의 id 로 제출하는 것이기 때문에, 그 알파를 시뮬레이션 한 날짜가 중요합니다. 가령, 1주일 전에 시뮬레이션 해 결과를 저장해 두었던 alpha id로 제출을 한다면 제출 날짜가 1주일 전이 됩니다. 그러니 오늘 제출하고 싶은 alpha 가 있다면 시뮬레이션을 다시 돌려 새로 생긴 alpha id 를 이용해야 합니다. 이 과정은 alpha 에 특정 태그를 달아 Brain 플랫폼에서 직접 하는게 훨씬 수월합니다. (다만, 플랫폼에서는 alpha id 로 알파를 검색할 수 없습니다.)

# %%
#submit_result will have return values from the submit_result function

submit_result
# Out:
# {'P3QOAgJ': False,
#  'GL1elRG': False,
#  'gMk8wnv': False,
#  'k0EPqxk': False,
#  'llpWXZn': False,
#  '69mpoPE': False,
#  'Xnm8N8m': False,
#  'n2xNr1w': False,
#  'P3QOkn7': False,
#  'vlwNPRG': False,
#  'vlwNap3': False,
#  '3RQelNQ': False,
#  'ZnPK71n': False,
#  'ZnPKXKQ': False,
#  'EEOe9qJ': False,
#  '5OnkGO1': False,
#  '717znG8': False,
#  'j0z6Wqe': False}

# %% [markdown]
# 주의하셔야 하실 점은, 하루 최대 알파 제출 한도인 4개를 루프중에 이미 넘기면 그 뒤의 알파들이 제출 가능하더라도 자동으로 제출에 실패하게 됩니다.

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance

# %% [markdown]
# 유용한 추가 함수들입니다. prod correlation 혹은 self correlation 만을 확인하고 싶을 때, 혹은 알파의 pnl 을 확인하고 싶을때 유용히 쓰입니다.
