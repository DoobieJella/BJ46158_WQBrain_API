# %% [markdown]
# ### Import library

# %%
import os
os.chdir('../../')
os.getcwd()
# Out:
# 'C:\\Users\\csia7\\OneDrive\\문서\\GitHub\\WQBrain_2024_API'

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px
import pygwalker as pyg
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_8sprG6tDj7L4UcduisqWJk5k5gBJ

# %% [markdown]
# ## Global region Alpha Template

# %%
expression_template = f'''
group = (country+1)*group_max(pv13_52_minvol_1m_all_delay_1_sector, market) + pv13_52_minvol_1m_all_delay_1_sector;
group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_ecns, industry, 252, std=1), 252), densify(group))
'''

# %% [markdown]
# #### Step 1. Download datsets

# %%
datasets_df = hf.get_datasets(s, region = 'GLB', universe = 'MINVOL1M') # by default we load all datasets USA TOP3000 delay 1    , region='GLB', universe='MINVOL1M'
datasets_df # DataFrame.head() shows first 5 rows of the dataframe
# Out:
#                 id                             name  \
# 0        analyst11                       ESG scores
# 1        analyst14  Estimations of Key Fundamentals
# 2        analyst15               Earnings forecasts
# 3        analyst16              Real Time Estimates
# 4        analyst35                        ESG Model
# ..             ...                              ...
# 83  shortinterest6              SmartHoldings Model
# 84  shortinterest7              Short Selling Model
# 85   socialmedia12        Sentiment Data for Equity
# 86    socialmedia5           Lexical Breakdown Data
# 87           univ1                 Universe Dataset
#
#                                           description  \
# 0   Environmental Social Governance scores that ex...
# 1   This dataset reports many items from financial...
# 2   This dataset provides bottom-up forecast data ...
# 3   This dataset provides real-time access to the ...
# 4   The dataset provide ESG related information ba...
# ..                                                ...
# 83  This dataset is a global stock selection model...
# 84  The dataset combines features obtained from sh...
# 85  This dataset provides sentiment data with diff...
# 86  Sentiment scores derived from social media. So...
# 87                             No dataset description
#
#                                              category  \
# 0                {'id': 'analyst', 'name': 'Analyst'}
# 1                {'id': 'analyst', 'name': 'Analyst'}
# 2                {'id': 'analyst', 'name': 'Analyst'}
# 3                {'id': 'analyst', 'name': 'Analyst'}
# 4                {'id': 'analyst', 'name': 'Analyst'}
# ..                                                ...
# 83  {'id': 'shortinterest', 'name': 'Short Interest'}
# 84  {'id': 'shortinterest', 'name': 'Short Interest'}
# 85      {'id': 'socialmedia', 'name': 'Social Media'}
# 86      {'id': 'socialmedia', 'name': 'Social Media'}
# 87               {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 0                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  MINVOL1M
# 1   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  MINVOL1M
# 2   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  MINVOL1M
# 3   {'id': 'analyst-crowdsourced-estimates', 'name...    GLB      1  MINVOL1M
# 4                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  MINVOL1M
# ..                                                ...    ...    ...       ...
# 83  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  MINVOL1M
# 84  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  MINVOL1M
# 85  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  MINVOL1M
# 86  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  MINVOL1M
# 87  {'id': 'pv-price-volume', 'name': 'Price Volume'}    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 0     0.7917     None         4.0         66         299         197     []
# 1     0.5186     None         3.0        101         584         926     []
# 2     0.9929     None         2.0        157        1489         288     []
# 3     0.9013     None         2.0        134         807          42     []
# 4     0.4375     None         3.0         63         201          23     []
# ..       ...      ...         ...        ...         ...         ...    ...
# 83    0.9711     None         2.0         91         382          11     []
# 84    1.0000     None         2.0         73         331          16     []
# 85    0.6731     None         3.0         17          25           2     []
# 86    0.3753     None         5.0          2           3          12     []
# 87    1.0000     None         3.0          3           5           2     []
#
#                                        researchPapers
# 0   [{'title': 'Research Paper 19: ESG Preference,...
# 1   [{'title': 'Research Paper 10: Investor Learni...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 83                                                 []
# 84  [{'title': 'Research Paper 04: Strategic Rebal...
# 85  [{'title': 'Research Paper 01: Textual Sentime...
# 86                                                 []
# 87                                                 []
#
# [88 rows x 16 columns]

# %%
# select needed datasets
selected_datasets_df_1 = datasets_df[
    (datasets_df["name"].str.contains('relationship data for equity', case=False))
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df_1
# Out:
#       id                          name  \
# 73  pv13  Relationship Data for Equity
#
#                                           description  \
# 73  The dataset outputs various classifications an...
#
#                                 category  \
# 73  {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 73  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 73    0.9152     None         1.0        127        1924          29     []
#
#    researchPapers
# 73             []

# %%
# select needed datasets
selected_datasets_df_2 = datasets_df[
    (datasets_df["name"].str.contains('fundamental point in time', case=False))
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df_2
# Out:
#                id                            name  \
# 21  fundamental23  Fundamental Point in Time Data
#
#                                           description  \
# 21  This dataset gives point in time access to fun...
#
#                                         category  \
# 21  {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                           subcategory region  delay  universe  \
# 21  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 21    0.6704     None         2.0        257        2041         886     []
#
#                                        researchPapers
# 21  [{'title': 'Research Paper 01: Textual Sentime...

# %% [markdown]
# #### Step 2. Select the needed datafields

# %% [markdown]
# ##### Step 2-1. equity relationship datafield extraction

# %%
dataset_id_1 = selected_datasets_df_1.id.values.tolist()[0] # create a list of selected datasets ids, our list has only one element
dataset_id_1
# Out:
# 'pv13'

# %%
datafields_df_1 = hf.get_datafields(s, region = 'GLB', universe = 'MINVOL1M', dataset_id=dataset_id_1) # download all fields of dataset news
datafields_df_1
# Out:
#                                       id  \
# 0         pv13_10_f2_g3_minvol_1m_sector
# 1         pv13_10_f2_g4_minvol_1m_sector
# 2         pv13_10_f3_g2_minvol_1m_sector
# 3               pv13_10_minvol_1m_sector
# 4                         pv13_10_sector
# 5                          pv13_1l_scibr
# 6               pv13_20_minvol_1m_sector
# 7          pv13_2_f3_g2_minvol_1m_sector
# 8          pv13_2_f4_g3_minvol_1m_sector
# 9    pv13_2_minvol_1m_all_delay_1_sector
# 10               pv13_2_minvol_1m_sector
# 11                         pv13_2_sector
# 12                         pv13_2l_scibr
# 13                         pv13_3l_scibr
# 14                         pv13_4l_scibr
# 15  pv13_52_minvol_1m_all_delay_1_sector
# 16              pv13_52_minvol_1m_sector
# 17         pv13_5_f3_g2_minvol_1m_sector
# 18                   pv13_5_f3_g2_sector
# 19               pv13_5_minvol_1m_sector
# 20                         pv13_5l_scibr
# 21                         pv13_6l_scibr
# 22    pv13_ompetitor_graphrank_auth_rank
# 23     pv13_ompetitor_graphrank_hub_rank
# 24    pv13_ompetitor_graphrank_page_rank
# 25                        pv13_reveremap
# 26      pv13_ustomer_graphrank_auth_rank
# 27       pv13_ustomer_graphrank_hub_rank
# 28      pv13_ustomer_graphrank_page_rank
#
#                                 description  \
# 0                           grouping fields
# 1                           grouping fields
# 2                           grouping fields
# 3                           grouping fields
# 4                           grouping fields
# 5                           grouping fields
# 6                           grouping fields
# 7                           grouping fields
# 8                           grouping fields
# 9                           grouping fields
# 10                          grouping fields
# 11                          grouping fields
# 12                          grouping fields
# 13                          grouping fields
# 14                          grouping fields
# 15                          grouping fields
# 16                          grouping fields
# 17                          grouping fields
# 18                          grouping fields
# 19                          grouping fields
# 20                          grouping fields
# 21                          grouping fields
# 22  the HITS authority score of competitors
# 23        the HITS hub score of competitors
# 24        the PageRank score of competitors
# 25                             Mapping data
# 26    the HITS authority score of customers
# 27          the HITS hub score of customers
# 28          the PageRank score of customers
#
#                                               dataset  \
# 0   {'id': 'pv13', 'name': 'Relationship Data for ...
# 1   {'id': 'pv13', 'name': 'Relationship Data for ...
# 2   {'id': 'pv13', 'name': 'Relationship Data for ...
# 3   {'id': 'pv13', 'name': 'Relationship Data for ...
# 4   {'id': 'pv13', 'name': 'Relationship Data for ...
# 5   {'id': 'pv13', 'name': 'Relationship Data for ...
# 6   {'id': 'pv13', 'name': 'Relationship Data for ...
# 7   {'id': 'pv13', 'name': 'Relationship Data for ...
# 8   {'id': 'pv13', 'name': 'Relationship Data for ...
# 9   {'id': 'pv13', 'name': 'Relationship Data for ...
# 10  {'id': 'pv13', 'name': 'Relationship Data for ...
# 11  {'id': 'pv13', 'name': 'Relationship Data for ...
# 12  {'id': 'pv13', 'name': 'Relationship Data for ...
# 13  {'id': 'pv13', 'name': 'Relationship Data for ...
# 14  {'id': 'pv13', 'name': 'Relationship Data for ...
# 15  {'id': 'pv13', 'name': 'Relationship Data for ...
# 16  {'id': 'pv13', 'name': 'Relationship Data for ...
# 17  {'id': 'pv13', 'name': 'Relationship Data for ...
# 18  {'id': 'pv13', 'name': 'Relationship Data for ...
# 19  {'id': 'pv13', 'name': 'Relationship Data for ...
# 20  {'id': 'pv13', 'name': 'Relationship Data for ...
# 21  {'id': 'pv13', 'name': 'Relationship Data for ...
# 22  {'id': 'pv13', 'name': 'Relationship Data for ...
# 23  {'id': 'pv13', 'name': 'Relationship Data for ...
# 24  {'id': 'pv13', 'name': 'Relationship Data for ...
# 25  {'id': 'pv13', 'name': 'Relationship Data for ...
# 26  {'id': 'pv13', 'name': 'Relationship Data for ...
# 27  {'id': 'pv13', 'name': 'Relationship Data for ...
# 28  {'id': 'pv13', 'name': 'Relationship Data for ...
#
#                                 category  \
# 0   {'id': 'pv', 'name': 'Price Volume'}
# 1   {'id': 'pv', 'name': 'Price Volume'}
# 2   {'id': 'pv', 'name': 'Price Volume'}
# 3   {'id': 'pv', 'name': 'Price Volume'}
# 4   {'id': 'pv', 'name': 'Price Volume'}
# 5   {'id': 'pv', 'name': 'Price Volume'}
# 6   {'id': 'pv', 'name': 'Price Volume'}
# 7   {'id': 'pv', 'name': 'Price Volume'}
# 8   {'id': 'pv', 'name': 'Price Volume'}
# 9   {'id': 'pv', 'name': 'Price Volume'}
# 10  {'id': 'pv', 'name': 'Price Volume'}
# 11  {'id': 'pv', 'name': 'Price Volume'}
# 12  {'id': 'pv', 'name': 'Price Volume'}
# 13  {'id': 'pv', 'name': 'Price Volume'}
# 14  {'id': 'pv', 'name': 'Price Volume'}
# 15  {'id': 'pv', 'name': 'Price Volume'}
# 16  {'id': 'pv', 'name': 'Price Volume'}
# 17  {'id': 'pv', 'name': 'Price Volume'}
# 18  {'id': 'pv', 'name': 'Price Volume'}
# 19  {'id': 'pv', 'name': 'Price Volume'}
# 20  {'id': 'pv', 'name': 'Price Volume'}
# 21  {'id': 'pv', 'name': 'Price Volume'}
# 22  {'id': 'pv', 'name': 'Price Volume'}
# 23  {'id': 'pv', 'name': 'Price Volume'}
# 24  {'id': 'pv', 'name': 'Price Volume'}
# 25  {'id': 'pv', 'name': 'Price Volume'}
# 26  {'id': 'pv', 'name': 'Price Volume'}
# 27  {'id': 'pv', 'name': 'Price Volume'}
# 28  {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 0   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 1   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 2   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 3   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 4   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 5   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 6   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 7   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 8   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 9   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 10  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 11  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 12  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 13  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 14  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 15  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 16  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 17  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 18  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 19  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 20  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 21  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 22  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 23  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 24  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 25  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 26  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 27  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 28  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
#
#       type  coverage turnover  userCount  alphaCount themes
# 0    GROUP    1.0000     None         27         146     []
# 1    GROUP    1.0000     None         16         102     []
# 2    GROUP    1.0000     None         17          98     []
# 3    GROUP    1.0000     None         36         120     []
# 4    GROUP    1.0000     None          4          10     []
# 5    GROUP    0.8770     None         31         120     []
# 6    GROUP    1.0000     None         36         234     []
# 7    GROUP    1.0000     None         19          75     []
# 8    GROUP    1.0000     None         21          88     []
# 9    GROUP    1.0000     None         26          88     []
# 10   GROUP    1.0000     None         21         132     []
# 11   GROUP    1.0000     None          5           6     []
# 12   GROUP    0.9238     None         23         125     []
# 13   GROUP    0.9238     None         25          59     []
# 14   GROUP    0.9238     None         20          68     []
# 15   GROUP    1.0000     None         22         125     []
# 16   GROUP    1.0000     None         23         104     []
# 17   GROUP    1.0000     None         19         150     []
# 18   GROUP    1.0000     None          3           3     []
# 19   GROUP    1.0000     None         14          65     []
# 20   GROUP    0.9238     None         34         288     []
# 21   GROUP    0.9238     None         39         372     []
# 22  MATRIX    0.7318     None          6          14     []
# 23  MATRIX    0.3809     None          7          12     []
# 24  MATRIX    0.7700     None          7          10     []
# 25  MATRIX    1.0000     None          6          10     []
# 26  MATRIX    0.7959     None          7           9     []
# 27  MATRIX    0.4791     None          3           8     []
# 28  MATRIX    0.8858     None          9          15     []

# %%
selected_datafields_df_1 = datafields_df_1[
    (datafields_df_1['type'] == 'GROUP') & 
    (datafields_df_1['userCount'] > 5) &
    (datafields_df_1['id'].str.contains('pv13_52_minvol_1m_all_delay_1_sector', case = False))
].sort_values(by=['userCount'], ascending=False)
selected_datafields_df_1
# Out:
#                                       id      description  \
# 15  pv13_52_minvol_1m_all_delay_1_sector  grouping fields
#
#                                               dataset  \
# 15  {'id': 'pv13', 'name': 'Relationship Data for ...
#
#                                 category  \
# 15  {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 15  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
#
#      type  coverage turnover  userCount  alphaCount themes
# 15  GROUP       1.0     None         22         125     []

# %%
len(selected_datafields_df_1)
# Out:
# 1

# %%
selected_datafields_df_1_id = selected_datafields_df_1.id.values.tolist()
selected_datafields_df_1_id
# Out:
# ['pv13_52_minvol_1m_all_delay_1_sector']

# %% [markdown]
# ##### Step 2-2. fundamental time datafields extraction

# %%
dataset_id_2 = selected_datasets_df_2.id.values.tolist()[0] # create a list of selected datasets ids, our list has only one element
dataset_id_2
# Out:
# 'fundamental23'

# %%
datafields_df_2 = hf.get_datafields(s, region = 'GLB', universe = 'MINVOL1M', dataset_id=dataset_id_2) # download all fields of dataset news
datafields_df_2
# Out:
#                        id                                        description  \
# 0       fnd23_acc_payable                                   accounts payable
# 1        fnd23_annfv_item  integer index of the item description field. Y...
# 2       fnd23_annfv_value                           annual financial values.
# 3    fnd23_annfvmfm2_acta  total current assets. Sum of cash and short te...
# 4    fnd23_annfvmfm2_amao                  Amortization of Acquisition Costs
# ..                    ...                                                ...
# 881          fnd23_topic3           third tier topic mapped to parent topic.
# 882      fnd23_tot_assets                                      total assets.
# 883   fnd23_tot_inventory                                   total inventory.
# 884     fnd23_tot_revenue                                     total revenue.
# 885              fnd23_ve                                   enterprise value
#
#                                                dataset  \
# 0    {'id': 'fundamental23', 'name': 'Fundamental P...
# 1    {'id': 'fundamental23', 'name': 'Fundamental P...
# 2    {'id': 'fundamental23', 'name': 'Fundamental P...
# 3    {'id': 'fundamental23', 'name': 'Fundamental P...
# 4    {'id': 'fundamental23', 'name': 'Fundamental P...
# ..                                                 ...
# 881  {'id': 'fundamental23', 'name': 'Fundamental P...
# 882  {'id': 'fundamental23', 'name': 'Fundamental P...
# 883  {'id': 'fundamental23', 'name': 'Fundamental P...
# 884  {'id': 'fundamental23', 'name': 'Fundamental P...
# 885  {'id': 'fundamental23', 'name': 'Fundamental P...
#
#                                          category  \
# 0    {'id': 'fundamental', 'name': 'Fundamental'}
# 1    {'id': 'fundamental', 'name': 'Fundamental'}
# 2    {'id': 'fundamental', 'name': 'Fundamental'}
# 3    {'id': 'fundamental', 'name': 'Fundamental'}
# 4    {'id': 'fundamental', 'name': 'Fundamental'}
# ..                                            ...
# 881  {'id': 'fundamental', 'name': 'Fundamental'}
# 882  {'id': 'fundamental', 'name': 'Fundamental'}
# 883  {'id': 'fundamental', 'name': 'Fundamental'}
# 884  {'id': 'fundamental', 'name': 'Fundamental'}
# 885  {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                            subcategory region  delay  \
# 0    {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 1    {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 2    {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 3    {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 4    {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# ..                                                 ...    ...    ...
# 881  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 882  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 883  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 884  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 885  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
#
#      universe    type  coverage turnover  userCount  alphaCount themes
# 0    MINVOL1M  MATRIX    0.8848     None         11          30     []
# 1    MINVOL1M  VECTOR    0.4969     None          1           1     []
# 2    MINVOL1M  VECTOR    0.4969     None          2           2     []
# 3    MINVOL1M  MATRIX    0.9223     None         16          30     []
# 4    MINVOL1M  MATRIX    0.3231     None          1           2     []
# ..        ...     ...       ...      ...        ...         ...    ...
# 881  MINVOL1M  VECTOR    0.7647     None          0           0     []
# 882  MINVOL1M  MATRIX    1.0000     None         31          84     []
# 883  MINVOL1M  MATRIX    0.9832     None          6           8     []
# 884  MINVOL1M  MATRIX    0.9928     None         12          18     []
# 885  MINVOL1M  MATRIX    0.9619     None         18          38     []
#
# [886 rows x 14 columns]

# %%
selected_datafields_df_2 = datafields_df_2[
    (datafields_df_2['type'] == 'MATRIX') &
    (datafields_df_2["userCount"] > 5)
].sort_values(by=['userCount'], ascending=False)
selected_datafields_df_2
# Out:
#                         id                                        description  \
# 14    fnd23_annfvmfm2_fcos                         Changes in Working Capital
# 23    fnd23_annfvmfm2_olto  includes diverse cash flows that are reported ...
# 882       fnd23_tot_assets                                      total assets.
# 875              fnd23_roe                                   return on equity
# 870       fnd23_net_income                                         net income
# ..                     ...                                                ...
# 19    fnd23_annfvmfm2_lctl  represents current liabilities for industrial ...
# 302  fnd23_intfvalld1_ipos                                  Operating Income.
# 883    fnd23_tot_inventory                                   total inventory.
# 132  fnd23_intfvalld1_cdav                         Deferred Revenue - Current
# 284  fnd23_intfvalld1_iads  Diluted EPS Including Extraordinary Items repr...
#
#                                                dataset  \
# 14   {'id': 'fundamental23', 'name': 'Fundamental P...
# 23   {'id': 'fundamental23', 'name': 'Fundamental P...
# 882  {'id': 'fundamental23', 'name': 'Fundamental P...
# 875  {'id': 'fundamental23', 'name': 'Fundamental P...
# 870  {'id': 'fundamental23', 'name': 'Fundamental P...
# ..                                                 ...
# 19   {'id': 'fundamental23', 'name': 'Fundamental P...
# 302  {'id': 'fundamental23', 'name': 'Fundamental P...
# 883  {'id': 'fundamental23', 'name': 'Fundamental P...
# 132  {'id': 'fundamental23', 'name': 'Fundamental P...
# 284  {'id': 'fundamental23', 'name': 'Fundamental P...
#
#                                          category  \
# 14   {'id': 'fundamental', 'name': 'Fundamental'}
# 23   {'id': 'fundamental', 'name': 'Fundamental'}
# 882  {'id': 'fundamental', 'name': 'Fundamental'}
# 875  {'id': 'fundamental', 'name': 'Fundamental'}
# 870  {'id': 'fundamental', 'name': 'Fundamental'}
# ..                                            ...
# 19   {'id': 'fundamental', 'name': 'Fundamental'}
# 302  {'id': 'fundamental', 'name': 'Fundamental'}
# 883  {'id': 'fundamental', 'name': 'Fundamental'}
# 132  {'id': 'fundamental', 'name': 'Fundamental'}
# 284  {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                            subcategory region  delay  \
# 14   {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 23   {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 882  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 875  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 870  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# ..                                                 ...    ...    ...
# 19   {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 302  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 883  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 132  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 284  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
#
#      universe    type  coverage turnover  userCount  alphaCount themes
# 14   MINVOL1M  MATRIX    1.0000     None         70         167     []
# 23   MINVOL1M  MATRIX    1.0000     None         41         101     []
# 882  MINVOL1M  MATRIX    1.0000     None         31          84     []
# 875  MINVOL1M  MATRIX    1.0000     None         29          47     []
# 870  MINVOL1M  MATRIX    1.0000     None         28          74     []
# ..        ...     ...       ...      ...        ...         ...    ...
# 19   MINVOL1M  MATRIX    0.9225     None          6           8     []
# 302  MINVOL1M  MATRIX    0.9922     None          6          13     []
# 883  MINVOL1M  MATRIX    0.9832     None          6           8     []
# 132  MINVOL1M  MATRIX    0.3804     None          6          15     []
# 284  MINVOL1M  MATRIX    1.0000     None          6           8     []
#
# [65 rows x 14 columns]

# %%
selected_datafields_df_2_id = selected_datafields_df_2.id.values.tolist()
selected_datafields_df_2_id
# Out:
# ['fnd23_annfvmfm2_fcos',
#  'fnd23_annfvmfm2_olto',
#  'fnd23_tot_assets',
#  'fnd23_roe',
#  'fnd23_net_income',
#  'fnd23_intfvalld1_iscs',
#  'fnd23_cash_n_equivalents',
#  'fnd23_aor',
#  'fnd23_ebitda',
#  'fnd23_intfvmfm2_olto',
#  'fnd23_net_debt',
#  'fnd23_ofc',
#  'fnd23_intfvalld1_dtns',
#  'fnd23_annfvmfm2_iscs',
#  'fnd23_intfvmfm_olto',
#  'fnd23_ve',
#  'fnd23_capex',
#  'fnd23_curr_assets',
#  'fnd23_annfvmfm2_acta',
#  'fnd23_annfvmfm2_cnin',
#  'fnd23_intfvalld1_ecns',
#  'fnd23_intfvmalld1_olto',
#  'fnd23_ebit',
#  'fnd23_annfvmfm2_bpao',
#  'fnd23_intfvmalld1_sedv',
#  'fnd23_annfvmfm_olto',
#  'fnd23_tot_revenue',
#  'fnd23_annfvmfm2_bloo',
#  'fnd23_acc_payable',
#  'fnd23_curr_liabilities',
#  'fnd23_ffcf',
#  'fnd23_intfvalld1_fbds',
#  'fnd23_intfvalld1_ccns',
#  'fnd23_annfvmfm2_ltio',
#  'fnd23_debt_issuance',
#  'fnd23_intfvmfm2_fcos',
#  'fnd23_intfvmalld1_xbin',
#  'fnd23_intfvmalld1_ipos',
#  'fnd23_intfvalld1_fcos',
#  'fnd23_annfvmfm2_eltq',
#  'fnd23_annfvmfm2_inds',
#  'fnd23_cogs',
#  'fnd23_lt_debt',
#  'fnd23_intfvmalld1_ccns',
#  'fnd23_intfvalld1_eaca',
#  'fnd23_intfvmalld1_ppos',
#  'fnd23_intfvalld1_ndlf',
#  'fnd23_intfvmalld1_iscs',
#  'fnd23_intfvalld1_sebv',
#  'fnd23_intfvalld1_iucs',
#  'fnd23_annfvmfm2_xecs',
#  'fnd23_intfvalld1_lcos',
#  'fnd23_intfvalld1_caiv',
#  'fnd23_intfvmfm2_inds',
#  'fnd23_intfvmalld1_ecns',
#  'fnd23_intfvmfm2_tibs',
#  'fnd23_intfvmfm_eltq',
#  'fnd23_intfvalld1_mpns',
#  'fnd23_intfvalld1_tbie',
#  'fnd23_intfvmalld1_inds',
#  'fnd23_annfvmfm2_lctl',
#  'fnd23_intfvalld1_ipos',
#  'fnd23_tot_inventory',
#  'fnd23_intfvalld1_cdav',
#  'fnd23_intfvalld1_iads']

# %% [markdown]
# #### Step 4. Apply generate_alpha function to the expression list
# In generate alpha function you can specify region, universe, decay, delay and other simulation settings

# %% [markdown]
# 이제 만들어둔 expressions 을 사용해 alpha simulation 을 해줍니다.

# %%
#?ace.generate_alpha

# %%
equity, time = ' ', ' '

expression_template = f'''
group = (country+1)*group_max({equity}, market) + {equity};
group_neutralize(ts_scale(group_backfill({time}, industry, 252, std=1), 252), densify(group))
'''

# %%
expressions = []
equity = selected_datafields_df_1_id[0]
for time in selected_datafields_df_2_id:
    expressions.append(f'group = (country+1)*group_max({equity}, market) + {equity};group_neutralize(ts_scale(group_backfill({time}, industry, 252, std=1), 252), densify(group))')

# %%
len(expressions)
# Out:
# 65

# %%
#when you send multiple alphas for simulation, please make sure all alphas of a single list should have common settings
#alphas with different settings should be sent in a different list, for instance below list has all alphas with same settings

alpha_list = [ace.generate_alpha(x, region= "GLB", universe = "MINVOL1M", neutralization = 'COUNTRY', truncation = 0.01, delay = 1, decay = 0) for x in expressions]
alpha_list[0]
# Out:
# {'type': 'REGULAR',
#  'settings': {'instrumentType': 'EQUITY',
#   'region': 'GLB',
#   'universe': 'MINVOL1M',
#   'delay': 1,
#   'decay': 0,
#   'neutralization': 'COUNTRY',
#   'truncation': 0.01,
#   'pasteurization': 'ON',
#   'testPeriod': 'P0Y0M0D',
#   'unitHandling': 'VERIFY',
#   'nanHandling': 'OFF',
#   'language': 'FASTEXPR',
#   'visualization': False},
#  'regular': 'group = (country+1)*group_max(pv13_52_minvol_1m_all_delay_1_sector, market) + pv13_52_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))'}

# %% [markdown]
# ### Simulate alpha list, get simulation result
#
# simulate_alpha_list_multi will do a multi-simulation if list of alphas is greater than 10, which is the case here
#
# the returned object will contain simulation results for all alphas as a list

# %%
#alpha expressions are sliced to first 10 for demonstration purpose

result = ace.simulate_alpha_list_multi(s, alpha_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 22/22 [1:23:55<00:00, 228.89s/it]

# %% [markdown]
# 위 코드를 실행하면 시뮬레이션이 시작됩니다. 100개의 알파에 대략 1시간 정도 소요되니, 인터넷 연결이 끊기지 않게 주의하시고, 너무 많은 알파를 한 번에 돌리기보다는 몇개씩 끊어서 돌려도 좋습니다.

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   5312939   20000000        4041         4022    0.0319   0.0513    0.0751
# 1   5281117   20000000        4062         3999    0.0313   0.0510    0.0704
# 2   5508931   20000000        4056         4001    0.0300   0.0532    0.0827
# 3   3622137   20000000        4074         3938    0.0266   0.0350    0.0260
# 4   3622137   20000000        4074         3938    0.0266   0.0350    0.0260
# ..      ...        ...         ...          ...       ...      ...       ...
# 60  -844398   20000000        4238         3688    0.0400  -0.0082    0.1156
# 61  -905431   20000000        3718         3808    0.0259  -0.0087    0.1512
# 62  -899515   20000000        3578         3661    0.0250  -0.0087    0.1213
# 63 -3259252   20000000        4119         3936    0.0248  -0.0315    0.3724
# 64 -3347334   20000000        4096         3915    0.0247  -0.0323    0.3770
#
#       margin  fitness  sharpe  start_date alpha_id  \
# 0   0.003220     1.26    1.96  2012-01-22  AwopJ9d
# 1   0.003263     1.26    1.98  2012-01-22  xxJLwqb
# 2   0.003548     1.22    1.87  2012-01-22  273gaOP
# 3   0.002626     1.21    2.29  2012-01-22  EwjlvM9
# 4   0.002626     1.21    2.29  2012-01-22  5wPmal1
# ..       ...      ...     ...         ...      ...
# 60 -0.000408    -0.11   -0.43  2012-01-22  8zMxdvv
# 61 -0.000676    -0.15   -0.58  2012-01-22  VpAb6kM
# 62 -0.000696    -0.16   -0.60  2012-01-22  5wPd2M6
# 63 -0.002537    -0.69   -1.38  2012-01-22  MpJNW6L
# 64 -0.002612    -0.72   -1.41  2012-01-22  jZqKbno
#
#                                            expression concentrated_weight  \
# 0   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 1   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 2   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 3   \ngroup = (country+1)*group_max(pv13_52_minvol...                PASS
# 4   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# ..                                                ...                 ...
# 60  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 61  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 62  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 63  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 64  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        PASS       PASS
# 1           PASS             FAIL        PASS       PASS
# 2           PASS             FAIL        PASS       PASS
# 3           PASS             PASS        PASS       PASS
# 4           PASS             PASS        PASS       PASS
# ..           ...              ...         ...        ...
# 60          PASS             FAIL        FAIL       FAIL
# 61          PASS             FAIL        FAIL       FAIL
# 62          PASS             FAIL        FAIL       FAIL
# 63          PASS             FAIL        FAIL       FAIL
# 64          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover
# 0                     PASS         PASS
# 1                     PASS         PASS
# 2                     PASS         PASS
# 3                     PASS         PASS
# 4                     PASS         PASS
# ..                     ...          ...
# 60                    PASS         PASS
# 61                    FAIL         PASS
# 62                    PASS         PASS
# 63                    FAIL         PASS
# 64                    FAIL         PASS
#
# [65 rows x 20 columns]

# %% [markdown]
# prettify 함수를 이용해 dataframe 형식으로 변환하면 결과를 보기 더 편합니다.

# %%
result_st1.to_csv('2024_09_07_GLB.csv')

# %% [markdown]
# ### How to submit?
#
# Create a list of submittable alphas - alphas that have no FAIL in is_tests

# %% [markdown]
# 시뮬레이션을 마친 알파 중 제출 가능한 알파들을 제출해 봅시다.

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df
# Out:
#     alpha_id     endDate  limit message                 name   result  \
# 0    RpGox8g         NaN   1.58     NaN           LOW_SHARPE     PASS
# 1    RpGox8g         NaN   1.00     NaN          LOW_FITNESS     FAIL
# 2    RpGox8g         NaN   0.01     NaN         LOW_TURNOVER     PASS
# 3    RpGox8g         NaN   0.70     NaN        HIGH_TURNOVER     PASS
# 4    RpGox8g         NaN    NaN     NaN  CONCENTRATED_WEIGHT     PASS
# ..       ...         ...    ...     ...                  ...      ...
# 840  Ew9jG3r         NaN    NaN     NaN       DATA_DIVERSITY  PENDING
# 841  Ew9jG3r         NaN    NaN     NaN     PROD_CORRELATION  PENDING
# 842  Ew9jG3r         NaN    NaN     NaN   REGULAR_SUBMISSION  PENDING
# 843  Ew9jG3r  2020-01-25   1.58     NaN     IS_LADDER_SHARPE     FAIL
# 844  Ew9jG3r         NaN    NaN     NaN       MATCHES_THEMES  WARNING
#
#       startDate                                             themes   value  \
# 0           NaN                                                NaN  1.6800
# 1           NaN                                                NaN  0.8000
# 2           NaN                                                NaN  0.0307
# 3           NaN                                                NaN  0.0307
# 4           NaN                                                NaN     NaN
# ..          ...                                                ...     ...
# 840         NaN                                                NaN     NaN
# 841         NaN                                                NaN     NaN
# 842         NaN                                                NaN     NaN
# 843  2022-01-24                                                NaN  1.5800
# 844         NaN  [{'id': 'WBlNe4R', 'multiplier': 3.0, 'name': ...     NaN
#
#      year
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 840   NaN
# 841   NaN
# 842   NaN
# 843   2.0
# 844   NaN
#
# [845 rows x 10 columns]

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['RpGox8g' 'WpvRrVd' '273xVN5' 'ad58ma1' 'xxJo7vW' 'dxN6J92' 'Lp0wodv'
#  'WpvRrAd' 'g1nVEmK' 'jZqKbno' '9wNOLJ1' 'MpJNW6L' 'dxNrX92' 'OplXY6b'
#  'jZqKbeE' '8zMxdvv' 'jZqKbYE' 'Awo8Jzl' 'g1nVqGl' 'XpdAYw8' 'VpAbYqJ'
#  'qAQJmvO' '7weRK9O' '8zMxK1v' 'Ew9PrAr' 'Awo8wJY' 'Ppkmprx' '7weRw0O'
#  'KbWMO8k' 'jZqK3wO' '378v9n6' 'ad59Lk2' 'VpAb6kM' 'k3z6VEd' 'Jp6J3al'
#  'qAQJ52j' 'Ew9Pmn9' 'NpYl2Ap' 'm8EWlZ1' 'Lp0Yrxe' 'g1nVdzM' 'XpdAeEz'
#  'roZMnA3' '5wPd2M6' 'RpGOnO1' 'RpGOnOz' '071V0Jv' 'xxJLwOm' 'AwopJ9d'
#  'xxJLwqb' '273gaOP' 'dxNMEOx' 'lVon7m7' 'AwopnAe' '8zM0OMo' 'p6926l3'
#  'vLWELv3' 'Qawxa95' 'PpkRGEx' 'Ew9jG3r']
# Passed alphas:['EwjlvM9', '273o2J5', '378v2AZ', '5wPmal1', 'lVoYwWl']

# %%
for alpha_id in ['ad59v2O', 'k3z6qqk', 'Lp0YPva', '9wNOzNr', '7weR901', '6w5Ln6E', 'QawpLe5', '17rAQ6m', '273obEY', 'xxJpKLg', 'Wpv2EZo', 'm8EWMk1']:
    hf.set_alpha_properties(s, alpha_id, tags = ['pass_Sep07_mixing'])

# %%
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['Sep07_GLB'])

# %% [markdown]
# 위 함수로 통과한 알파들에 태그를 붙일 수 있습니다.

# %% [markdown]
# When you got a list of submittable alphas, you can call function submit_alpha()

# %%
#calling submit_alpha on all alphas that have passed the submission tests

submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas}

# %% [markdown]
# 위 함수로 알파를 제출할 수 있습니다.

# %% [markdown]
# 알파의 id 로 제출하는 것이기 때문에, 그 알파를 시뮬레이션 한 날짜가 중요합니다. 가령, 1주일 전에 시뮬레이션 해 결과를 저장해 두었던 alpha id로 제출을 한다면 제출 날짜가 1주일 전이 됩니다. 그러니 오늘 제출하고 싶은 alpha 가 있다면 시뮬레이션을 다시 돌려 새로 생긴 alpha id 를 이용해야 합니다. 이 과정은 alpha 에 특정 태그를 달아 Brain 플랫폼에서 직접 하는게 훨씬 수월합니다. (다만, 플랫폼에서는 alpha id 로 알파를 검색할 수 없습니다.)

# %%
#submit_result will have return values from the submit_result function

submit_result
# Out:
# {'ZpO36rQ': False}

# %% [markdown]
# 주의하셔야 하실 점은, 하루 최대 알파 제출 한도인 4개를 루프중에 이미 넘기면 그 뒤의 알파들이 제출 가능하더라도 자동으로 제출에 실패하게 됩니다.

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance

# %% [markdown]
# 유용한 추가 함수들입니다. prod correlation 혹은 self correlation 만을 확인하고 싶을 때, 혹은 알파의 pnl 을 확인하고 싶을때 유용히 쓰입니다.
