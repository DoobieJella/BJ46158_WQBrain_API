# %% [markdown]
# ### Import library

# %%
import os
os.chdir('../../')
os.getcwd()
# Out:
# 'C:\\Users\\csia7\\OneDrive\\문서\\GitHub\\WQBrain_2024_API'

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px
import pygwalker as pyg
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_wRbJSB8KavfDKU41fara2NHzDBBQ

# %% [markdown]
# ## Global region Alpha Template

# %%
expression_template = f'''
group = (country+1)*group_max(pv13_52_minvol_1m_all_delay_1_sector, market) + pv13_52_minvol_1m_all_delay_1_sector;
group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_ecns, industry, 252, std=1), 252), densify(group))
'''

# %% [markdown]
# #### Step 1. Download datsets

# %%
datasets_df = hf.get_datasets(s, region = 'GLB', universe = 'MINVOL1M') # by default we load all datasets USA TOP3000 delay 1    , region='GLB', universe='MINVOL1M'
datasets_df # DataFrame.head() shows first 5 rows of the dataframe
# Out:
#                 id                             name  \
# 0        analyst11                       ESG scores
# 1        analyst14  Estimations of Key Fundamentals
# 2        analyst15               Earnings forecasts
# 3        analyst16              Real Time Estimates
# 4        analyst35                        ESG Model
# ..             ...                              ...
# 83  shortinterest6              SmartHoldings Model
# 84  shortinterest7              Short Selling Model
# 85   socialmedia12        Sentiment Data for Equity
# 86    socialmedia5           Lexical Breakdown Data
# 87           univ1                 Universe Dataset
#
#                                           description  \
# 0   Environmental Social Governance scores that ex...
# 1   This dataset reports many items from financial...
# 2   This dataset provides bottom-up forecast data ...
# 3   This dataset provides real-time access to the ...
# 4   The dataset provide ESG related information ba...
# ..                                                ...
# 83  This dataset is a global stock selection model...
# 84  The dataset combines features obtained from sh...
# 85  This dataset provides sentiment data with diff...
# 86  Sentiment scores derived from social media. So...
# 87                             No dataset description
#
#                                              category  \
# 0                {'id': 'analyst', 'name': 'Analyst'}
# 1                {'id': 'analyst', 'name': 'Analyst'}
# 2                {'id': 'analyst', 'name': 'Analyst'}
# 3                {'id': 'analyst', 'name': 'Analyst'}
# 4                {'id': 'analyst', 'name': 'Analyst'}
# ..                                                ...
# 83  {'id': 'shortinterest', 'name': 'Short Interest'}
# 84  {'id': 'shortinterest', 'name': 'Short Interest'}
# 85      {'id': 'socialmedia', 'name': 'Social Media'}
# 86      {'id': 'socialmedia', 'name': 'Social Media'}
# 87               {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 0                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  MINVOL1M
# 1   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  MINVOL1M
# 2   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  MINVOL1M
# 3   {'id': 'analyst-crowdsourced-estimates', 'name...    GLB      1  MINVOL1M
# 4                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  MINVOL1M
# ..                                                ...    ...    ...       ...
# 83  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  MINVOL1M
# 84  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  MINVOL1M
# 85  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  MINVOL1M
# 86  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  MINVOL1M
# 87  {'id': 'pv-price-volume', 'name': 'Price Volume'}    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 0     0.7917     None         4.0         66         299         197     []
# 1     0.5186     None         3.0        101         584         926     []
# 2     0.9929     None         2.0        157        1489         288     []
# 3     0.9013     None         2.0        134         807          42     []
# 4     0.4375     None         3.0         63         201          23     []
# ..       ...      ...         ...        ...         ...         ...    ...
# 83    0.9711     None         2.0         91         382          11     []
# 84    1.0000     None         2.0         73         331          16     []
# 85    0.6731     None         3.0         17          25           2     []
# 86    0.3753     None         5.0          2           3          12     []
# 87    1.0000     None         3.0          3           5           2     []
#
#                                        researchPapers
# 0   [{'title': 'Research Paper 19: ESG Preference,...
# 1   [{'title': 'Research Paper 10: Investor Learni...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 83                                                 []
# 84  [{'title': 'Research Paper 04: Strategic Rebal...
# 85  [{'title': 'Research Paper 01: Textual Sentime...
# 86                                                 []
# 87                                                 []
#
# [88 rows x 16 columns]

# %%
# select needed datasets
selected_datasets_df_1 = datasets_df[
    (datasets_df["name"].str.contains('relationship data for equity', case=False))
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df_1
# Out:
#       id                          name  \
# 73  pv13  Relationship Data for Equity
#
#                                           description  \
# 73  The dataset outputs various classifications an...
#
#                                 category  \
# 73  {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 73  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 73    0.9152     None         1.0        127        1924          29     []
#
#    researchPapers
# 73             []

# %%
# select needed datasets
selected_datasets_df_2 = datasets_df[
    (datasets_df["name"].str.contains('fundamental point in time', case=False))
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df_2
# Out:
#                id                            name  \
# 21  fundamental23  Fundamental Point in Time Data
#
#                                           description  \
# 21  This dataset gives point in time access to fun...
#
#                                         category  \
# 21  {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                           subcategory region  delay  universe  \
# 21  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 21    0.6704     None         2.0        257        2041         886     []
#
#                                        researchPapers
# 21  [{'title': 'Research Paper 01: Textual Sentime...

# %% [markdown]
# #### Step 2. Select the needed datafields

# %% [markdown]
# ##### Step 2-1. equity relationship datafield extraction

# %%
dataset_id_1 = selected_datasets_df_1.id.values.tolist()[0] # create a list of selected datasets ids, our list has only one element
dataset_id_1
# Out:
# 'pv13'

# %%
datafields_df_1 = hf.get_datafields(s, region = 'GLB', universe = 'MINVOL1M', dataset_id=dataset_id_1) # download all fields of dataset news
datafields_df_1
# Out:
#                                       id  \
# 0         pv13_10_f2_g3_minvol_1m_sector
# 1         pv13_10_f2_g4_minvol_1m_sector
# 2         pv13_10_f3_g2_minvol_1m_sector
# 3               pv13_10_minvol_1m_sector
# 4                         pv13_10_sector
# 5                          pv13_1l_scibr
# 6               pv13_20_minvol_1m_sector
# 7          pv13_2_f3_g2_minvol_1m_sector
# 8          pv13_2_f4_g3_minvol_1m_sector
# 9    pv13_2_minvol_1m_all_delay_1_sector
# 10               pv13_2_minvol_1m_sector
# 11                         pv13_2_sector
# 12                         pv13_2l_scibr
# 13                         pv13_3l_scibr
# 14                         pv13_4l_scibr
# 15  pv13_52_minvol_1m_all_delay_1_sector
# 16              pv13_52_minvol_1m_sector
# 17         pv13_5_f3_g2_minvol_1m_sector
# 18                   pv13_5_f3_g2_sector
# 19               pv13_5_minvol_1m_sector
# 20                         pv13_5l_scibr
# 21                         pv13_6l_scibr
# 22    pv13_ompetitor_graphrank_auth_rank
# 23     pv13_ompetitor_graphrank_hub_rank
# 24    pv13_ompetitor_graphrank_page_rank
# 25                        pv13_reveremap
# 26      pv13_ustomer_graphrank_auth_rank
# 27       pv13_ustomer_graphrank_hub_rank
# 28      pv13_ustomer_graphrank_page_rank
#
#                                 description  \
# 0                           grouping fields
# 1                           grouping fields
# 2                           grouping fields
# 3                           grouping fields
# 4                           grouping fields
# 5                           grouping fields
# 6                           grouping fields
# 7                           grouping fields
# 8                           grouping fields
# 9                           grouping fields
# 10                          grouping fields
# 11                          grouping fields
# 12                          grouping fields
# 13                          grouping fields
# 14                          grouping fields
# 15                          grouping fields
# 16                          grouping fields
# 17                          grouping fields
# 18                          grouping fields
# 19                          grouping fields
# 20                          grouping fields
# 21                          grouping fields
# 22  the HITS authority score of competitors
# 23        the HITS hub score of competitors
# 24        the PageRank score of competitors
# 25                             Mapping data
# 26    the HITS authority score of customers
# 27          the HITS hub score of customers
# 28          the PageRank score of customers
#
#                                               dataset  \
# 0   {'id': 'pv13', 'name': 'Relationship Data for ...
# 1   {'id': 'pv13', 'name': 'Relationship Data for ...
# 2   {'id': 'pv13', 'name': 'Relationship Data for ...
# 3   {'id': 'pv13', 'name': 'Relationship Data for ...
# 4   {'id': 'pv13', 'name': 'Relationship Data for ...
# 5   {'id': 'pv13', 'name': 'Relationship Data for ...
# 6   {'id': 'pv13', 'name': 'Relationship Data for ...
# 7   {'id': 'pv13', 'name': 'Relationship Data for ...
# 8   {'id': 'pv13', 'name': 'Relationship Data for ...
# 9   {'id': 'pv13', 'name': 'Relationship Data for ...
# 10  {'id': 'pv13', 'name': 'Relationship Data for ...
# 11  {'id': 'pv13', 'name': 'Relationship Data for ...
# 12  {'id': 'pv13', 'name': 'Relationship Data for ...
# 13  {'id': 'pv13', 'name': 'Relationship Data for ...
# 14  {'id': 'pv13', 'name': 'Relationship Data for ...
# 15  {'id': 'pv13', 'name': 'Relationship Data for ...
# 16  {'id': 'pv13', 'name': 'Relationship Data for ...
# 17  {'id': 'pv13', 'name': 'Relationship Data for ...
# 18  {'id': 'pv13', 'name': 'Relationship Data for ...
# 19  {'id': 'pv13', 'name': 'Relationship Data for ...
# 20  {'id': 'pv13', 'name': 'Relationship Data for ...
# 21  {'id': 'pv13', 'name': 'Relationship Data for ...
# 22  {'id': 'pv13', 'name': 'Relationship Data for ...
# 23  {'id': 'pv13', 'name': 'Relationship Data for ...
# 24  {'id': 'pv13', 'name': 'Relationship Data for ...
# 25  {'id': 'pv13', 'name': 'Relationship Data for ...
# 26  {'id': 'pv13', 'name': 'Relationship Data for ...
# 27  {'id': 'pv13', 'name': 'Relationship Data for ...
# 28  {'id': 'pv13', 'name': 'Relationship Data for ...
#
#                                 category  \
# 0   {'id': 'pv', 'name': 'Price Volume'}
# 1   {'id': 'pv', 'name': 'Price Volume'}
# 2   {'id': 'pv', 'name': 'Price Volume'}
# 3   {'id': 'pv', 'name': 'Price Volume'}
# 4   {'id': 'pv', 'name': 'Price Volume'}
# 5   {'id': 'pv', 'name': 'Price Volume'}
# 6   {'id': 'pv', 'name': 'Price Volume'}
# 7   {'id': 'pv', 'name': 'Price Volume'}
# 8   {'id': 'pv', 'name': 'Price Volume'}
# 9   {'id': 'pv', 'name': 'Price Volume'}
# 10  {'id': 'pv', 'name': 'Price Volume'}
# 11  {'id': 'pv', 'name': 'Price Volume'}
# 12  {'id': 'pv', 'name': 'Price Volume'}
# 13  {'id': 'pv', 'name': 'Price Volume'}
# 14  {'id': 'pv', 'name': 'Price Volume'}
# 15  {'id': 'pv', 'name': 'Price Volume'}
# 16  {'id': 'pv', 'name': 'Price Volume'}
# 17  {'id': 'pv', 'name': 'Price Volume'}
# 18  {'id': 'pv', 'name': 'Price Volume'}
# 19  {'id': 'pv', 'name': 'Price Volume'}
# 20  {'id': 'pv', 'name': 'Price Volume'}
# 21  {'id': 'pv', 'name': 'Price Volume'}
# 22  {'id': 'pv', 'name': 'Price Volume'}
# 23  {'id': 'pv', 'name': 'Price Volume'}
# 24  {'id': 'pv', 'name': 'Price Volume'}
# 25  {'id': 'pv', 'name': 'Price Volume'}
# 26  {'id': 'pv', 'name': 'Price Volume'}
# 27  {'id': 'pv', 'name': 'Price Volume'}
# 28  {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 0   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 1   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 2   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 3   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 4   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 5   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 6   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 7   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 8   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 9   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 10  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 11  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 12  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 13  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 14  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 15  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 16  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 17  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 18  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 19  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 20  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 21  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 22  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 23  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 24  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 25  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 26  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 27  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 28  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
#
#       type  coverage turnover  userCount  alphaCount themes
# 0    GROUP    1.0000     None         27         146     []
# 1    GROUP    1.0000     None         16         102     []
# 2    GROUP    1.0000     None         17          98     []
# 3    GROUP    1.0000     None         36         120     []
# 4    GROUP    1.0000     None          4          10     []
# 5    GROUP    0.8770     None         31         120     []
# 6    GROUP    1.0000     None         36         234     []
# 7    GROUP    1.0000     None         19          75     []
# 8    GROUP    1.0000     None         21          88     []
# 9    GROUP    1.0000     None         26          88     []
# 10   GROUP    1.0000     None         21         132     []
# 11   GROUP    1.0000     None          5           6     []
# 12   GROUP    0.9238     None         23         125     []
# 13   GROUP    0.9238     None         25          59     []
# 14   GROUP    0.9238     None         20          68     []
# 15   GROUP    1.0000     None         22         125     []
# 16   GROUP    1.0000     None         23         104     []
# 17   GROUP    1.0000     None         19         150     []
# 18   GROUP    1.0000     None          3           3     []
# 19   GROUP    1.0000     None         14          65     []
# 20   GROUP    0.9238     None         34         288     []
# 21   GROUP    0.9238     None         39         372     []
# 22  MATRIX    0.7318     None          6          14     []
# 23  MATRIX    0.3809     None          7          12     []
# 24  MATRIX    0.7700     None          7          10     []
# 25  MATRIX    1.0000     None          6          10     []
# 26  MATRIX    0.7959     None          7           9     []
# 27  MATRIX    0.4791     None          3           8     []
# 28  MATRIX    0.8858     None          9          15     []

# %%
selected_datafields_df_1 = datafields_df_1[
    (datafields_df_1['type'] == 'GROUP') & 
    (datafields_df_1['userCount'] > 5)
].sort_values(by=['userCount'], ascending=False)
selected_datafields_df_1
# Out:
#                                       id      description  \
# 21                         pv13_6l_scibr  grouping fields
# 6               pv13_20_minvol_1m_sector  grouping fields
# 3               pv13_10_minvol_1m_sector  grouping fields
# 20                         pv13_5l_scibr  grouping fields
# 5                          pv13_1l_scibr  grouping fields
# 0         pv13_10_f2_g3_minvol_1m_sector  grouping fields
# 9    pv13_2_minvol_1m_all_delay_1_sector  grouping fields
# 13                         pv13_3l_scibr  grouping fields
# 12                         pv13_2l_scibr  grouping fields
# 16              pv13_52_minvol_1m_sector  grouping fields
# 15  pv13_52_minvol_1m_all_delay_1_sector  grouping fields
# 8          pv13_2_f4_g3_minvol_1m_sector  grouping fields
# 10               pv13_2_minvol_1m_sector  grouping fields
# 14                         pv13_4l_scibr  grouping fields
# 7          pv13_2_f3_g2_minvol_1m_sector  grouping fields
# 17         pv13_5_f3_g2_minvol_1m_sector  grouping fields
# 2         pv13_10_f3_g2_minvol_1m_sector  grouping fields
# 1         pv13_10_f2_g4_minvol_1m_sector  grouping fields
# 19               pv13_5_minvol_1m_sector  grouping fields
#
#                                               dataset  \
# 21  {'id': 'pv13', 'name': 'Relationship Data for ...
# 6   {'id': 'pv13', 'name': 'Relationship Data for ...
# 3   {'id': 'pv13', 'name': 'Relationship Data for ...
# 20  {'id': 'pv13', 'name': 'Relationship Data for ...
# 5   {'id': 'pv13', 'name': 'Relationship Data for ...
# 0   {'id': 'pv13', 'name': 'Relationship Data for ...
# 9   {'id': 'pv13', 'name': 'Relationship Data for ...
# 13  {'id': 'pv13', 'name': 'Relationship Data for ...
# 12  {'id': 'pv13', 'name': 'Relationship Data for ...
# 16  {'id': 'pv13', 'name': 'Relationship Data for ...
# 15  {'id': 'pv13', 'name': 'Relationship Data for ...
# 8   {'id': 'pv13', 'name': 'Relationship Data for ...
# 10  {'id': 'pv13', 'name': 'Relationship Data for ...
# 14  {'id': 'pv13', 'name': 'Relationship Data for ...
# 7   {'id': 'pv13', 'name': 'Relationship Data for ...
# 17  {'id': 'pv13', 'name': 'Relationship Data for ...
# 2   {'id': 'pv13', 'name': 'Relationship Data for ...
# 1   {'id': 'pv13', 'name': 'Relationship Data for ...
# 19  {'id': 'pv13', 'name': 'Relationship Data for ...
#
#                                 category  \
# 21  {'id': 'pv', 'name': 'Price Volume'}
# 6   {'id': 'pv', 'name': 'Price Volume'}
# 3   {'id': 'pv', 'name': 'Price Volume'}
# 20  {'id': 'pv', 'name': 'Price Volume'}
# 5   {'id': 'pv', 'name': 'Price Volume'}
# 0   {'id': 'pv', 'name': 'Price Volume'}
# 9   {'id': 'pv', 'name': 'Price Volume'}
# 13  {'id': 'pv', 'name': 'Price Volume'}
# 12  {'id': 'pv', 'name': 'Price Volume'}
# 16  {'id': 'pv', 'name': 'Price Volume'}
# 15  {'id': 'pv', 'name': 'Price Volume'}
# 8   {'id': 'pv', 'name': 'Price Volume'}
# 10  {'id': 'pv', 'name': 'Price Volume'}
# 14  {'id': 'pv', 'name': 'Price Volume'}
# 7   {'id': 'pv', 'name': 'Price Volume'}
# 17  {'id': 'pv', 'name': 'Price Volume'}
# 2   {'id': 'pv', 'name': 'Price Volume'}
# 1   {'id': 'pv', 'name': 'Price Volume'}
# 19  {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 21  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 6   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 3   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 20  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 5   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 0   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 9   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 13  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 12  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 16  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 15  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 8   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 10  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 14  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 7   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 17  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 2   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 1   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 19  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
#
#      type  coverage turnover  userCount  alphaCount themes
# 21  GROUP    0.9238     None         39         372     []
# 6   GROUP    1.0000     None         36         234     []
# 3   GROUP    1.0000     None         36         120     []
# 20  GROUP    0.9238     None         34         288     []
# 5   GROUP    0.8770     None         31         120     []
# 0   GROUP    1.0000     None         27         146     []
# 9   GROUP    1.0000     None         26          88     []
# 13  GROUP    0.9238     None         25          59     []
# 12  GROUP    0.9238     None         23         125     []
# 16  GROUP    1.0000     None         23         104     []
# 15  GROUP    1.0000     None         22         125     []
# 8   GROUP    1.0000     None         21          88     []
# 10  GROUP    1.0000     None         21         132     []
# 14  GROUP    0.9238     None         20          68     []
# 7   GROUP    1.0000     None         19          75     []
# 17  GROUP    1.0000     None         19         150     []
# 2   GROUP    1.0000     None         17          98     []
# 1   GROUP    1.0000     None         16         102     []
# 19  GROUP    1.0000     None         14          65     []

# %%
len(selected_datafields_df_1)
# Out:
# 19

# %%
selected_datafields_df_1_id = selected_datafields_df_1.id.values.tolist()
selected_datafields_df_1_id
# Out:
# ['pv13_6l_scibr',
#  'pv13_20_minvol_1m_sector',
#  'pv13_10_minvol_1m_sector',
#  'pv13_5l_scibr',
#  'pv13_1l_scibr',
#  'pv13_10_f2_g3_minvol_1m_sector',
#  'pv13_2_minvol_1m_all_delay_1_sector',
#  'pv13_3l_scibr',
#  'pv13_2l_scibr',
#  'pv13_52_minvol_1m_sector',
#  'pv13_52_minvol_1m_all_delay_1_sector',
#  'pv13_2_f4_g3_minvol_1m_sector',
#  'pv13_2_minvol_1m_sector',
#  'pv13_4l_scibr',
#  'pv13_2_f3_g2_minvol_1m_sector',
#  'pv13_5_f3_g2_minvol_1m_sector',
#  'pv13_10_f3_g2_minvol_1m_sector',
#  'pv13_10_f2_g4_minvol_1m_sector',
#  'pv13_5_minvol_1m_sector']

# %% [markdown]
# ##### Step 2-2. fundamental time datafields extraction

# %%
dataset_id_2 = selected_datasets_df_2.id.values.tolist()[0] # create a list of selected datasets ids, our list has only one element
dataset_id_2
# Out:
# 'fundamental23'

# %%
datafields_df_2 = hf.get_datafields(s, region = 'GLB', universe = 'MINVOL1M', dataset_id=dataset_id_2) # download all fields of dataset news
datafields_df_2
# Out:
#                        id                                        description  \
# 0       fnd23_acc_payable                                   accounts payable
# 1        fnd23_annfv_item  integer index of the item description field. Y...
# 2       fnd23_annfv_value                           annual financial values.
# 3    fnd23_annfvmfm2_acta  total current assets. Sum of cash and short te...
# 4    fnd23_annfvmfm2_amao                  Amortization of Acquisition Costs
# ..                    ...                                                ...
# 881          fnd23_topic3           third tier topic mapped to parent topic.
# 882      fnd23_tot_assets                                      total assets.
# 883   fnd23_tot_inventory                                   total inventory.
# 884     fnd23_tot_revenue                                     total revenue.
# 885              fnd23_ve                                   enterprise value
#
#                                                dataset  \
# 0    {'id': 'fundamental23', 'name': 'Fundamental P...
# 1    {'id': 'fundamental23', 'name': 'Fundamental P...
# 2    {'id': 'fundamental23', 'name': 'Fundamental P...
# 3    {'id': 'fundamental23', 'name': 'Fundamental P...
# 4    {'id': 'fundamental23', 'name': 'Fundamental P...
# ..                                                 ...
# 881  {'id': 'fundamental23', 'name': 'Fundamental P...
# 882  {'id': 'fundamental23', 'name': 'Fundamental P...
# 883  {'id': 'fundamental23', 'name': 'Fundamental P...
# 884  {'id': 'fundamental23', 'name': 'Fundamental P...
# 885  {'id': 'fundamental23', 'name': 'Fundamental P...
#
#                                          category  \
# 0    {'id': 'fundamental', 'name': 'Fundamental'}
# 1    {'id': 'fundamental', 'name': 'Fundamental'}
# 2    {'id': 'fundamental', 'name': 'Fundamental'}
# 3    {'id': 'fundamental', 'name': 'Fundamental'}
# 4    {'id': 'fundamental', 'name': 'Fundamental'}
# ..                                            ...
# 881  {'id': 'fundamental', 'name': 'Fundamental'}
# 882  {'id': 'fundamental', 'name': 'Fundamental'}
# 883  {'id': 'fundamental', 'name': 'Fundamental'}
# 884  {'id': 'fundamental', 'name': 'Fundamental'}
# 885  {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                            subcategory region  delay  \
# 0    {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 1    {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 2    {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 3    {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 4    {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# ..                                                 ...    ...    ...
# 881  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 882  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 883  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 884  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 885  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
#
#      universe    type  coverage turnover  userCount  alphaCount themes
# 0    MINVOL1M  MATRIX    0.8848     None         11          30     []
# 1    MINVOL1M  VECTOR    0.4969     None          1           1     []
# 2    MINVOL1M  VECTOR    0.4969     None          2           2     []
# 3    MINVOL1M  MATRIX    0.9223     None         16          30     []
# 4    MINVOL1M  MATRIX    0.3231     None          1           2     []
# ..        ...     ...       ...      ...        ...         ...    ...
# 881  MINVOL1M  VECTOR    0.7647     None          0           0     []
# 882  MINVOL1M  MATRIX    1.0000     None         31          84     []
# 883  MINVOL1M  MATRIX    0.9832     None          6           8     []
# 884  MINVOL1M  MATRIX    0.9928     None         12          18     []
# 885  MINVOL1M  MATRIX    0.9619     None         18          38     []
#
# [886 rows x 14 columns]

# %%
selected_datafields_df_2 = datafields_df_2[
    (datafields_df_2['type'] == 'MATRIX') &
    (datafields_df_2["userCount"] > 5)
].sort_values(by=['userCount'], ascending=False)
selected_datafields_df_2
# Out:
#                         id                                        description  \
# 14    fnd23_annfvmfm2_fcos                         Changes in Working Capital
# 23    fnd23_annfvmfm2_olto  includes diverse cash flows that are reported ...
# 882       fnd23_tot_assets                                      total assets.
# 875              fnd23_roe                                   return on equity
# 870       fnd23_net_income                                         net income
# ..                     ...                                                ...
# 19    fnd23_annfvmfm2_lctl  represents current liabilities for industrial ...
# 302  fnd23_intfvalld1_ipos                                  Operating Income.
# 883    fnd23_tot_inventory                                   total inventory.
# 132  fnd23_intfvalld1_cdav                         Deferred Revenue - Current
# 284  fnd23_intfvalld1_iads  Diluted EPS Including Extraordinary Items repr...
#
#                                                dataset  \
# 14   {'id': 'fundamental23', 'name': 'Fundamental P...
# 23   {'id': 'fundamental23', 'name': 'Fundamental P...
# 882  {'id': 'fundamental23', 'name': 'Fundamental P...
# 875  {'id': 'fundamental23', 'name': 'Fundamental P...
# 870  {'id': 'fundamental23', 'name': 'Fundamental P...
# ..                                                 ...
# 19   {'id': 'fundamental23', 'name': 'Fundamental P...
# 302  {'id': 'fundamental23', 'name': 'Fundamental P...
# 883  {'id': 'fundamental23', 'name': 'Fundamental P...
# 132  {'id': 'fundamental23', 'name': 'Fundamental P...
# 284  {'id': 'fundamental23', 'name': 'Fundamental P...
#
#                                          category  \
# 14   {'id': 'fundamental', 'name': 'Fundamental'}
# 23   {'id': 'fundamental', 'name': 'Fundamental'}
# 882  {'id': 'fundamental', 'name': 'Fundamental'}
# 875  {'id': 'fundamental', 'name': 'Fundamental'}
# 870  {'id': 'fundamental', 'name': 'Fundamental'}
# ..                                            ...
# 19   {'id': 'fundamental', 'name': 'Fundamental'}
# 302  {'id': 'fundamental', 'name': 'Fundamental'}
# 883  {'id': 'fundamental', 'name': 'Fundamental'}
# 132  {'id': 'fundamental', 'name': 'Fundamental'}
# 284  {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                            subcategory region  delay  \
# 14   {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 23   {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 882  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 875  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 870  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# ..                                                 ...    ...    ...
# 19   {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 302  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 883  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 132  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
# 284  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1
#
#      universe    type  coverage turnover  userCount  alphaCount themes
# 14   MINVOL1M  MATRIX    1.0000     None         70         167     []
# 23   MINVOL1M  MATRIX    1.0000     None         41         101     []
# 882  MINVOL1M  MATRIX    1.0000     None         31          84     []
# 875  MINVOL1M  MATRIX    1.0000     None         29          47     []
# 870  MINVOL1M  MATRIX    1.0000     None         28          74     []
# ..        ...     ...       ...      ...        ...         ...    ...
# 19   MINVOL1M  MATRIX    0.9225     None          6           8     []
# 302  MINVOL1M  MATRIX    0.9922     None          6          13     []
# 883  MINVOL1M  MATRIX    0.9832     None          6           8     []
# 132  MINVOL1M  MATRIX    0.3804     None          6          15     []
# 284  MINVOL1M  MATRIX    1.0000     None          6           8     []
#
# [65 rows x 14 columns]

# %%
selected_datafields_df_2_id = selected_datafields_df_2.id.values.tolist()
selected_datafields_df_2_id
# Out:
# ['fnd23_annfvmfm2_fcos',
#  'fnd23_annfvmfm2_olto',
#  'fnd23_tot_assets',
#  'fnd23_roe',
#  'fnd23_net_income',
#  'fnd23_intfvalld1_iscs',
#  'fnd23_cash_n_equivalents',
#  'fnd23_aor',
#  'fnd23_ebitda',
#  'fnd23_intfvmfm2_olto',
#  'fnd23_net_debt',
#  'fnd23_ofc',
#  'fnd23_intfvalld1_dtns',
#  'fnd23_annfvmfm2_iscs',
#  'fnd23_intfvmfm_olto',
#  'fnd23_ve',
#  'fnd23_capex',
#  'fnd23_curr_assets',
#  'fnd23_annfvmfm2_acta',
#  'fnd23_annfvmfm2_cnin',
#  'fnd23_intfvalld1_ecns',
#  'fnd23_intfvmalld1_olto',
#  'fnd23_ebit',
#  'fnd23_annfvmfm2_bpao',
#  'fnd23_intfvmalld1_sedv',
#  'fnd23_annfvmfm_olto',
#  'fnd23_tot_revenue',
#  'fnd23_annfvmfm2_bloo',
#  'fnd23_acc_payable',
#  'fnd23_curr_liabilities',
#  'fnd23_ffcf',
#  'fnd23_intfvalld1_fbds',
#  'fnd23_intfvalld1_ccns',
#  'fnd23_annfvmfm2_ltio',
#  'fnd23_debt_issuance',
#  'fnd23_intfvmfm2_fcos',
#  'fnd23_intfvmalld1_xbin',
#  'fnd23_intfvmalld1_ipos',
#  'fnd23_intfvalld1_fcos',
#  'fnd23_annfvmfm2_eltq',
#  'fnd23_annfvmfm2_inds',
#  'fnd23_cogs',
#  'fnd23_lt_debt',
#  'fnd23_intfvmalld1_ccns',
#  'fnd23_intfvalld1_eaca',
#  'fnd23_intfvmalld1_ppos',
#  'fnd23_intfvalld1_ndlf',
#  'fnd23_intfvmalld1_iscs',
#  'fnd23_intfvalld1_sebv',
#  'fnd23_intfvalld1_iucs',
#  'fnd23_annfvmfm2_xecs',
#  'fnd23_intfvalld1_lcos',
#  'fnd23_intfvalld1_caiv',
#  'fnd23_intfvmfm2_inds',
#  'fnd23_intfvmalld1_ecns',
#  'fnd23_intfvmfm2_tibs',
#  'fnd23_intfvmfm_eltq',
#  'fnd23_intfvalld1_mpns',
#  'fnd23_intfvalld1_tbie',
#  'fnd23_intfvmalld1_inds',
#  'fnd23_annfvmfm2_lctl',
#  'fnd23_intfvalld1_ipos',
#  'fnd23_tot_inventory',
#  'fnd23_intfvalld1_cdav',
#  'fnd23_intfvalld1_iads']

# %% [markdown]
# #### Step 4. Apply generate_alpha function to the expression list
# In generate alpha function you can specify region, universe, decay, delay and other simulation settings

# %% [markdown]
# 이제 만들어둔 expressions 을 사용해 alpha simulation 을 해줍니다.

# %%
#?ace.generate_alpha

# %%
equity, time = ' ', ' '

expression_template = f'''
group = (country+1)*group_max({equity}, market) + {equity};
group_neutralize(ts_scale(group_backfill({time}, industry, 252, std=1), 252), densify(group))
'''

# %%
selected_datafields_df_1
# Out:
#                                       id      description  \
# 21                         pv13_6l_scibr  grouping fields
# 6               pv13_20_minvol_1m_sector  grouping fields
# 3               pv13_10_minvol_1m_sector  grouping fields
# 20                         pv13_5l_scibr  grouping fields
# 5                          pv13_1l_scibr  grouping fields
# 0         pv13_10_f2_g3_minvol_1m_sector  grouping fields
# 9    pv13_2_minvol_1m_all_delay_1_sector  grouping fields
# 13                         pv13_3l_scibr  grouping fields
# 12                         pv13_2l_scibr  grouping fields
# 16              pv13_52_minvol_1m_sector  grouping fields
# 15  pv13_52_minvol_1m_all_delay_1_sector  grouping fields
# 8          pv13_2_f4_g3_minvol_1m_sector  grouping fields
# 10               pv13_2_minvol_1m_sector  grouping fields
# 14                         pv13_4l_scibr  grouping fields
# 7          pv13_2_f3_g2_minvol_1m_sector  grouping fields
# 17         pv13_5_f3_g2_minvol_1m_sector  grouping fields
# 2         pv13_10_f3_g2_minvol_1m_sector  grouping fields
# 1         pv13_10_f2_g4_minvol_1m_sector  grouping fields
# 19               pv13_5_minvol_1m_sector  grouping fields
#
#                                               dataset  \
# 21  {'id': 'pv13', 'name': 'Relationship Data for ...
# 6   {'id': 'pv13', 'name': 'Relationship Data for ...
# 3   {'id': 'pv13', 'name': 'Relationship Data for ...
# 20  {'id': 'pv13', 'name': 'Relationship Data for ...
# 5   {'id': 'pv13', 'name': 'Relationship Data for ...
# 0   {'id': 'pv13', 'name': 'Relationship Data for ...
# 9   {'id': 'pv13', 'name': 'Relationship Data for ...
# 13  {'id': 'pv13', 'name': 'Relationship Data for ...
# 12  {'id': 'pv13', 'name': 'Relationship Data for ...
# 16  {'id': 'pv13', 'name': 'Relationship Data for ...
# 15  {'id': 'pv13', 'name': 'Relationship Data for ...
# 8   {'id': 'pv13', 'name': 'Relationship Data for ...
# 10  {'id': 'pv13', 'name': 'Relationship Data for ...
# 14  {'id': 'pv13', 'name': 'Relationship Data for ...
# 7   {'id': 'pv13', 'name': 'Relationship Data for ...
# 17  {'id': 'pv13', 'name': 'Relationship Data for ...
# 2   {'id': 'pv13', 'name': 'Relationship Data for ...
# 1   {'id': 'pv13', 'name': 'Relationship Data for ...
# 19  {'id': 'pv13', 'name': 'Relationship Data for ...
#
#                                 category  \
# 21  {'id': 'pv', 'name': 'Price Volume'}
# 6   {'id': 'pv', 'name': 'Price Volume'}
# 3   {'id': 'pv', 'name': 'Price Volume'}
# 20  {'id': 'pv', 'name': 'Price Volume'}
# 5   {'id': 'pv', 'name': 'Price Volume'}
# 0   {'id': 'pv', 'name': 'Price Volume'}
# 9   {'id': 'pv', 'name': 'Price Volume'}
# 13  {'id': 'pv', 'name': 'Price Volume'}
# 12  {'id': 'pv', 'name': 'Price Volume'}
# 16  {'id': 'pv', 'name': 'Price Volume'}
# 15  {'id': 'pv', 'name': 'Price Volume'}
# 8   {'id': 'pv', 'name': 'Price Volume'}
# 10  {'id': 'pv', 'name': 'Price Volume'}
# 14  {'id': 'pv', 'name': 'Price Volume'}
# 7   {'id': 'pv', 'name': 'Price Volume'}
# 17  {'id': 'pv', 'name': 'Price Volume'}
# 2   {'id': 'pv', 'name': 'Price Volume'}
# 1   {'id': 'pv', 'name': 'Price Volume'}
# 19  {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 21  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 6   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 3   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 20  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 5   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 0   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 9   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 13  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 12  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 16  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 15  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 8   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 10  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 14  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 7   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 17  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 2   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 1   {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
# 19  {'id': 'pv-relationship', 'name': 'Relationship'}    GLB      1  MINVOL1M
#
#      type  coverage turnover  userCount  alphaCount themes
# 21  GROUP    0.9238     None         39         372     []
# 6   GROUP    1.0000     None         36         234     []
# 3   GROUP    1.0000     None         36         120     []
# 20  GROUP    0.9238     None         34         288     []
# 5   GROUP    0.8770     None         31         120     []
# 0   GROUP    1.0000     None         27         146     []
# 9   GROUP    1.0000     None         26          88     []
# 13  GROUP    0.9238     None         25          59     []
# 12  GROUP    0.9238     None         23         125     []
# 16  GROUP    1.0000     None         23         104     []
# 15  GROUP    1.0000     None         22         125     []
# 8   GROUP    1.0000     None         21          88     []
# 10  GROUP    1.0000     None         21         132     []
# 14  GROUP    0.9238     None         20          68     []
# 7   GROUP    1.0000     None         19          75     []
# 17  GROUP    1.0000     None         19         150     []
# 2   GROUP    1.0000     None         17          98     []
# 1   GROUP    1.0000     None         16         102     []
# 19  GROUP    1.0000     None         14          65     []

# %%
parameters = []
for i in range(10):
    for j in range(10):
        parameters.append([selected_datafields_df_1_id[i], selected_datafields_df_2_id[j]])
parameters
# Out:
# [['pv13_6l_scibr', 'fnd23_annfvmfm2_fcos'],
#  ['pv13_6l_scibr', 'fnd23_annfvmfm2_olto'],
#  ['pv13_6l_scibr', 'fnd23_tot_assets'],
#  ['pv13_6l_scibr', 'fnd23_roe'],
#  ['pv13_6l_scibr', 'fnd23_net_income'],
#  ['pv13_6l_scibr', 'fnd23_intfvalld1_iscs'],
#  ['pv13_6l_scibr', 'fnd23_cash_n_equivalents'],
#  ['pv13_6l_scibr', 'fnd23_aor'],
#  ['pv13_6l_scibr', 'fnd23_ebitda'],
#  ['pv13_6l_scibr', 'fnd23_intfvmfm2_olto'],
#  ['pv13_20_minvol_1m_sector', 'fnd23_annfvmfm2_fcos'],
#  ['pv13_20_minvol_1m_sector', 'fnd23_annfvmfm2_olto'],
#  ['pv13_20_minvol_1m_sector', 'fnd23_tot_assets'],
#  ['pv13_20_minvol_1m_sector', 'fnd23_roe'],
#  ['pv13_20_minvol_1m_sector', 'fnd23_net_income'],
#  ['pv13_20_minvol_1m_sector', 'fnd23_intfvalld1_iscs'],
#  ['pv13_20_minvol_1m_sector', 'fnd23_cash_n_equivalents'],
#  ['pv13_20_minvol_1m_sector', 'fnd23_aor'],
#  ['pv13_20_minvol_1m_sector', 'fnd23_ebitda'],
#  ['pv13_20_minvol_1m_sector', 'fnd23_intfvmfm2_olto'],
#  ['pv13_10_minvol_1m_sector', 'fnd23_annfvmfm2_fcos'],
#  ['pv13_10_minvol_1m_sector', 'fnd23_annfvmfm2_olto'],
#  ['pv13_10_minvol_1m_sector', 'fnd23_tot_assets'],
#  ['pv13_10_minvol_1m_sector', 'fnd23_roe'],
#  ['pv13_10_minvol_1m_sector', 'fnd23_net_income'],
#  ['pv13_10_minvol_1m_sector', 'fnd23_intfvalld1_iscs'],
#  ['pv13_10_minvol_1m_sector', 'fnd23_cash_n_equivalents'],
#  ['pv13_10_minvol_1m_sector', 'fnd23_aor'],
#  ['pv13_10_minvol_1m_sector', 'fnd23_ebitda'],
#  ['pv13_10_minvol_1m_sector', 'fnd23_intfvmfm2_olto'],
#  ['pv13_5l_scibr', 'fnd23_annfvmfm2_fcos'],
#  ['pv13_5l_scibr', 'fnd23_annfvmfm2_olto'],
#  ['pv13_5l_scibr', 'fnd23_tot_assets'],
#  ['pv13_5l_scibr', 'fnd23_roe'],
#  ['pv13_5l_scibr', 'fnd23_net_income'],
#  ['pv13_5l_scibr', 'fnd23_intfvalld1_iscs'],
#  ['pv13_5l_scibr', 'fnd23_cash_n_equivalents'],
#  ['pv13_5l_scibr', 'fnd23_aor'],
#  ['pv13_5l_scibr', 'fnd23_ebitda'],
#  ['pv13_5l_scibr', 'fnd23_intfvmfm2_olto'],
#  ['pv13_1l_scibr', 'fnd23_annfvmfm2_fcos'],
#  ['pv13_1l_scibr', 'fnd23_annfvmfm2_olto'],
#  ['pv13_1l_scibr', 'fnd23_tot_assets'],
#  ['pv13_1l_scibr', 'fnd23_roe'],
#  ['pv13_1l_scibr', 'fnd23_net_income'],
#  ['pv13_1l_scibr', 'fnd23_intfvalld1_iscs'],
#  ['pv13_1l_scibr', 'fnd23_cash_n_equivalents'],
#  ['pv13_1l_scibr', 'fnd23_aor'],
#  ['pv13_1l_scibr', 'fnd23_ebitda'],
#  ['pv13_1l_scibr', 'fnd23_intfvmfm2_olto'],
#  ['pv13_10_f2_g3_minvol_1m_sector', 'fnd23_annfvmfm2_fcos'],
#  ['pv13_10_f2_g3_minvol_1m_sector', 'fnd23_annfvmfm2_olto'],
#  ['pv13_10_f2_g3_minvol_1m_sector', 'fnd23_tot_assets'],
#  ['pv13_10_f2_g3_minvol_1m_sector', 'fnd23_roe'],
#  ['pv13_10_f2_g3_minvol_1m_sector', 'fnd23_net_income'],
#  ['pv13_10_f2_g3_minvol_1m_sector', 'fnd23_intfvalld1_iscs'],
#  ['pv13_10_f2_g3_minvol_1m_sector', 'fnd23_cash_n_equivalents'],
#  ['pv13_10_f2_g3_minvol_1m_sector', 'fnd23_aor'],
#  ['pv13_10_f2_g3_minvol_1m_sector', 'fnd23_ebitda'],
#  ['pv13_10_f2_g3_minvol_1m_sector', 'fnd23_intfvmfm2_olto'],
#  ['pv13_2_minvol_1m_all_delay_1_sector', 'fnd23_annfvmfm2_fcos'],
#  ['pv13_2_minvol_1m_all_delay_1_sector', 'fnd23_annfvmfm2_olto'],
#  ['pv13_2_minvol_1m_all_delay_1_sector', 'fnd23_tot_assets'],
#  ['pv13_2_minvol_1m_all_delay_1_sector', 'fnd23_roe'],
#  ['pv13_2_minvol_1m_all_delay_1_sector', 'fnd23_net_income'],
#  ['pv13_2_minvol_1m_all_delay_1_sector', 'fnd23_intfvalld1_iscs'],
#  ['pv13_2_minvol_1m_all_delay_1_sector', 'fnd23_cash_n_equivalents'],
#  ['pv13_2_minvol_1m_all_delay_1_sector', 'fnd23_aor'],
#  ['pv13_2_minvol_1m_all_delay_1_sector', 'fnd23_ebitda'],
#  ['pv13_2_minvol_1m_all_delay_1_sector', 'fnd23_intfvmfm2_olto'],
#  ['pv13_3l_scibr', 'fnd23_annfvmfm2_fcos'],
#  ['pv13_3l_scibr', 'fnd23_annfvmfm2_olto'],
#  ['pv13_3l_scibr', 'fnd23_tot_assets'],
#  ['pv13_3l_scibr', 'fnd23_roe'],
#  ['pv13_3l_scibr', 'fnd23_net_income'],
#  ['pv13_3l_scibr', 'fnd23_intfvalld1_iscs'],
#  ['pv13_3l_scibr', 'fnd23_cash_n_equivalents'],
#  ['pv13_3l_scibr', 'fnd23_aor'],
#  ['pv13_3l_scibr', 'fnd23_ebitda'],
#  ['pv13_3l_scibr', 'fnd23_intfvmfm2_olto'],
#  ['pv13_2l_scibr', 'fnd23_annfvmfm2_fcos'],
#  ['pv13_2l_scibr', 'fnd23_annfvmfm2_olto'],
#  ['pv13_2l_scibr', 'fnd23_tot_assets'],
#  ['pv13_2l_scibr', 'fnd23_roe'],
#  ['pv13_2l_scibr', 'fnd23_net_income'],
#  ['pv13_2l_scibr', 'fnd23_intfvalld1_iscs'],
#  ['pv13_2l_scibr', 'fnd23_cash_n_equivalents'],
#  ['pv13_2l_scibr', 'fnd23_aor'],
#  ['pv13_2l_scibr', 'fnd23_ebitda'],
#  ['pv13_2l_scibr', 'fnd23_intfvmfm2_olto'],
#  ['pv13_52_minvol_1m_sector', 'fnd23_annfvmfm2_fcos'],
#  ['pv13_52_minvol_1m_sector', 'fnd23_annfvmfm2_olto'],
#  ['pv13_52_minvol_1m_sector', 'fnd23_tot_assets'],
#  ['pv13_52_minvol_1m_sector', 'fnd23_roe'],
#  ['pv13_52_minvol_1m_sector', 'fnd23_net_income'],
#  ['pv13_52_minvol_1m_sector', 'fnd23_intfvalld1_iscs'],
#  ['pv13_52_minvol_1m_sector', 'fnd23_cash_n_equivalents'],
#  ['pv13_52_minvol_1m_sector', 'fnd23_aor'],
#  ['pv13_52_minvol_1m_sector', 'fnd23_ebitda'],
#  ['pv13_52_minvol_1m_sector', 'fnd23_intfvmfm2_olto']]

# %%
expressions = []
for params in parameters:
    equity = params[0]
    time = params[1]
    expressions.append(f'group = (country+1)*group_max({equity}, market) + {equity};group_neutralize(ts_scale(group_backfill({time}, industry, 252, std=1), 252), densify(group))')

# %%
expressions
# Out:
# ['group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_tot_assets, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_roe, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_net_income, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_iscs, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_cash_n_equivalents, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_aor, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_ebitda, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_intfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_20_minvol_1m_sector, market) + pv13_20_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_20_minvol_1m_sector, market) + pv13_20_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_20_minvol_1m_sector, market) + pv13_20_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_tot_assets, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_20_minvol_1m_sector, market) + pv13_20_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_roe, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_20_minvol_1m_sector, market) + pv13_20_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_net_income, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_20_minvol_1m_sector, market) + pv13_20_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_iscs, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_20_minvol_1m_sector, market) + pv13_20_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_cash_n_equivalents, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_20_minvol_1m_sector, market) + pv13_20_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_aor, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_20_minvol_1m_sector, market) + pv13_20_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_ebitda, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_20_minvol_1m_sector, market) + pv13_20_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_intfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_minvol_1m_sector, market) + pv13_10_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_minvol_1m_sector, market) + pv13_10_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_minvol_1m_sector, market) + pv13_10_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_tot_assets, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_minvol_1m_sector, market) + pv13_10_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_roe, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_minvol_1m_sector, market) + pv13_10_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_net_income, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_minvol_1m_sector, market) + pv13_10_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_iscs, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_minvol_1m_sector, market) + pv13_10_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_cash_n_equivalents, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_minvol_1m_sector, market) + pv13_10_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_aor, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_minvol_1m_sector, market) + pv13_10_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_ebitda, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_minvol_1m_sector, market) + pv13_10_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_intfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_5l_scibr, market) + pv13_5l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_5l_scibr, market) + pv13_5l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_5l_scibr, market) + pv13_5l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_tot_assets, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_5l_scibr, market) + pv13_5l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_roe, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_5l_scibr, market) + pv13_5l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_net_income, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_5l_scibr, market) + pv13_5l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_iscs, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_5l_scibr, market) + pv13_5l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_cash_n_equivalents, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_5l_scibr, market) + pv13_5l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_aor, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_5l_scibr, market) + pv13_5l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_ebitda, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_5l_scibr, market) + pv13_5l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_intfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_1l_scibr, market) + pv13_1l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_1l_scibr, market) + pv13_1l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_1l_scibr, market) + pv13_1l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_tot_assets, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_1l_scibr, market) + pv13_1l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_roe, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_1l_scibr, market) + pv13_1l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_net_income, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_1l_scibr, market) + pv13_1l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_iscs, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_1l_scibr, market) + pv13_1l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_cash_n_equivalents, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_1l_scibr, market) + pv13_1l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_aor, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_1l_scibr, market) + pv13_1l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_ebitda, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_1l_scibr, market) + pv13_1l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_intfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_f2_g3_minvol_1m_sector, market) + pv13_10_f2_g3_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_f2_g3_minvol_1m_sector, market) + pv13_10_f2_g3_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_f2_g3_minvol_1m_sector, market) + pv13_10_f2_g3_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_tot_assets, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_f2_g3_minvol_1m_sector, market) + pv13_10_f2_g3_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_roe, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_f2_g3_minvol_1m_sector, market) + pv13_10_f2_g3_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_net_income, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_f2_g3_minvol_1m_sector, market) + pv13_10_f2_g3_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_iscs, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_f2_g3_minvol_1m_sector, market) + pv13_10_f2_g3_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_cash_n_equivalents, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_f2_g3_minvol_1m_sector, market) + pv13_10_f2_g3_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_aor, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_f2_g3_minvol_1m_sector, market) + pv13_10_f2_g3_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_ebitda, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_10_f2_g3_minvol_1m_sector, market) + pv13_10_f2_g3_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_intfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2_minvol_1m_all_delay_1_sector, market) + pv13_2_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2_minvol_1m_all_delay_1_sector, market) + pv13_2_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2_minvol_1m_all_delay_1_sector, market) + pv13_2_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_tot_assets, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2_minvol_1m_all_delay_1_sector, market) + pv13_2_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_roe, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2_minvol_1m_all_delay_1_sector, market) + pv13_2_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_net_income, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2_minvol_1m_all_delay_1_sector, market) + pv13_2_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_iscs, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2_minvol_1m_all_delay_1_sector, market) + pv13_2_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_cash_n_equivalents, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2_minvol_1m_all_delay_1_sector, market) + pv13_2_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_aor, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2_minvol_1m_all_delay_1_sector, market) + pv13_2_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_ebitda, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2_minvol_1m_all_delay_1_sector, market) + pv13_2_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(fnd23_intfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_3l_scibr, market) + pv13_3l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_3l_scibr, market) + pv13_3l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_3l_scibr, market) + pv13_3l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_tot_assets, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_3l_scibr, market) + pv13_3l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_roe, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_3l_scibr, market) + pv13_3l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_net_income, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_3l_scibr, market) + pv13_3l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_iscs, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_3l_scibr, market) + pv13_3l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_cash_n_equivalents, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_3l_scibr, market) + pv13_3l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_aor, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_3l_scibr, market) + pv13_3l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_ebitda, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_3l_scibr, market) + pv13_3l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_intfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2l_scibr, market) + pv13_2l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2l_scibr, market) + pv13_2l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2l_scibr, market) + pv13_2l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_tot_assets, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2l_scibr, market) + pv13_2l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_roe, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2l_scibr, market) + pv13_2l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_net_income, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2l_scibr, market) + pv13_2l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_iscs, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2l_scibr, market) + pv13_2l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_cash_n_equivalents, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2l_scibr, market) + pv13_2l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_aor, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2l_scibr, market) + pv13_2l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_ebitda, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_2l_scibr, market) + pv13_2l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_intfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_52_minvol_1m_sector, market) + pv13_52_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_52_minvol_1m_sector, market) + pv13_52_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_olto, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_52_minvol_1m_sector, market) + pv13_52_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_tot_assets, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_52_minvol_1m_sector, market) + pv13_52_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_roe, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_52_minvol_1m_sector, market) + pv13_52_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_net_income, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_52_minvol_1m_sector, market) + pv13_52_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_iscs, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_52_minvol_1m_sector, market) + pv13_52_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_cash_n_equivalents, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_52_minvol_1m_sector, market) + pv13_52_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_aor, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_52_minvol_1m_sector, market) + pv13_52_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_ebitda, industry, 252, std=1), 252), densify(group))',
#  'group = (country+1)*group_max(pv13_52_minvol_1m_sector, market) + pv13_52_minvol_1m_sector;group_neutralize(ts_scale(group_backfill(fnd23_intfvmfm2_olto, industry, 252, std=1), 252), densify(group))']

# %%
#when you send multiple alphas for simulation, please make sure all alphas of a single list should have common settings
#alphas with different settings should be sent in a different list, for instance below list has all alphas with same settings

alpha_list = [ace.generate_alpha(x, region= "GLB", universe = "MINVOL1M", neutralization = 'COUNTRY', truncation = 0.01, delay = 1, decay = 0) for x in expressions]
alpha_list[0]
# Out:
# {'type': 'REGULAR',
#  'settings': {'instrumentType': 'EQUITY',
#   'region': 'GLB',
#   'universe': 'MINVOL1M',
#   'delay': 1,
#   'decay': 0,
#   'neutralization': 'COUNTRY',
#   'truncation': 0.01,
#   'pasteurization': 'ON',
#   'testPeriod': 'P0Y0M0D',
#   'unitHandling': 'VERIFY',
#   'nanHandling': 'OFF',
#   'language': 'FASTEXPR',
#   'visualization': False},
#  'regular': 'group = (country+1)*group_max(pv13_6l_scibr, market) + pv13_6l_scibr;group_neutralize(ts_scale(group_backfill(fnd23_annfvmfm2_fcos, industry, 252, std=1), 252), densify(group))'}

# %% [markdown]
# ### Simulate alpha list, get simulation result
#
# simulate_alpha_list_multi will do a multi-simulation if list of alphas is greater than 10, which is the case here
#
# the returned object will contain simulation results for all alphas as a list

# %%
#alpha expressions are sliced to first 10 for demonstration purpose

result = ace.simulate_alpha_list_multi(s, alpha_list[:50])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 17/17 [1:14:59<00:00, 264.67s/it]

# %% [markdown]
# 위 코드를 실행하면 시뮬레이션이 시작됩니다. 100개의 알파에 대략 1시간 정도 소요되니, 인터넷 연결이 끊기지 않게 주의하시고, 너무 많은 알파를 한 번에 돌리기보다는 몇개씩 끊어서 돌려도 좋습니다.

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   4142182   20000000        4013         3967    0.0469   0.0400    0.0361
# 1   4122365   20000000        3988         3989    0.0474   0.0398    0.0362
# 2   4350382   20000000        4019         3911    0.0481   0.0420    0.0612
# 3   4631670   20000000        3825         3617    0.0374   0.0447    0.0690
# 4   4333680   20000000        3758         3722    0.0375   0.0418    0.0601
# 5   4074932   20000000        4029         3898    0.0486   0.0393    0.0559
# 6   3493294   20000000        3936         4085    0.0485   0.0337    0.0726
# 7   3178647   20000000        3854         3679    0.0319   0.0307    0.0271
# 8   3246982   20000000        3994         4098    0.0483   0.0314    0.0219
# 9   3950050   20000000        3633         3891    0.0411   0.0381    0.0911
# 10  3274107   20000000        3980         4107    0.0488   0.0316    0.0227
# 11  3023163   20000000        4118         3907    0.0405   0.0292    0.0336
# 12  3406822   20000000        3936         4079    0.0485   0.0329    0.0729
# 13  3401673   20000000        3724         3862    0.0390   0.0328    0.0392
# 14  3210686   20000000        3800         3571    0.0448   0.0310    0.0338
# 15  2931831   20000000        3987         4105    0.0497   0.0283    0.0245
# 16  3143649   20000000        3705         3651    0.0452   0.0304    0.0315
# 17  2951310   20000000        3969         4122    0.0502   0.0285    0.0255
# 18  2759196   20000000        4155         3870    0.0409   0.0266    0.0424
# 19  3163001   20000000        3739         3555    0.0467   0.0305    0.0405
# 20  2864375   20000000        3724         3692    0.0459   0.0277    0.0420
# 21  3127918   20000000        3734         3534    0.0471   0.0302    0.0416
# 22  2649423   20000000        3489         3680    0.0361   0.0256    0.0462
# 23  2783104   20000000        3754         3741    0.0462   0.0269    0.0239
# 24  2507696   20000000        3820         3831    0.0442   0.0242    0.0442
# 25  2647610   20000000        3766         3627    0.0461   0.0256    0.0465
# 26  2834924   20000000        3711         3875    0.0399   0.0274    0.0400
# 27  2708672   20000000        3683         3796    0.0466   0.0262    0.0301
# 28  2536446   20000000        4081         3525    0.0313   0.0245    0.0533
# 29  2347064   20000000        3831         3817    0.0448   0.0227    0.0527
# 30  2450748   20000000        3726         3765    0.0470   0.0237    0.0232
# 31  2381727   20000000        3662         3818    0.0475   0.0230    0.0231
# 32  2367887   20000000        3873         3255    0.0243   0.0229    0.0768
# 33  2184285   20000000        3837         3544    0.0388   0.0211    0.0451
# 34  1991488   20000000        4078         3524    0.0316   0.0192    0.0555
# 35  2003956   20000000        3579         3407    0.0425   0.0194    0.0315
# 36  1973662   20000000        3841         3560    0.0383   0.0191    0.0562
# 37  1890034   20000000        3535         3477    0.0420   0.0183    0.0479
# 38  1845199   20000000        4068         2851    0.0286   0.0178    0.0382
# 39  1810470   20000000        4156         2727    0.0289   0.0175    0.0390
# 40  1939768   20000000        4767         3239    0.0369   0.0187    0.0773
# 41  1839119   20000000        4739         3261    0.0371   0.0178    0.0816
# 42  1126063   20000000        3464         3694    0.0261   0.0109    0.0187
# 43  1469164   20000000        4712         2801    0.0293   0.0142    0.1005
# 44  1236167   20000000        4140         3207    0.0352   0.0119    0.0647
# 45  1108279   20000000        4095         3269    0.0347   0.0107    0.0682
# 46   747236   20000000        3848         3788    0.0332   0.0072    0.0242
# 47   671490   20000000        3899         3731    0.0334   0.0065    0.0250
# 48   399319   20000000        3825         3133    0.0309   0.0039    0.0264
# 49   332570   20000000        3702         3276    0.0307   0.0032    0.0305
#
#       margin  fitness  sharpe  start_date alpha_id  \
# 0   0.001704     1.28    2.26  2012-01-22  ZpO36rQ
# 1   0.001679     1.25    2.21  2012-01-22  g1nOo3K
# 2   0.001745     1.24    2.14  2012-01-22  ZpO3lOd
# 3   0.002389     1.20    2.01  2012-01-22  9wN15bq
# 4   0.002233     1.17    2.03  2012-01-22  p69rxkj
# 5   0.001618     1.15    2.05  2012-01-22  WpvQAeG
# 6   0.001390     1.03    1.98  2012-01-22  WpvQXvZ
# 7   0.001926     1.02    2.06  2012-01-22  dxNA2EY
# 8   0.001297     1.01    2.01  2012-01-22  AwoZM1Y
# 9   0.001855     1.01    1.83  2012-01-22  ZpO3Vqj
# 10  0.001296     1.00    1.99  2012-01-22  7webzN5
# 11  0.001443     0.99    2.04  2012-01-22  KbWdjKk
# 12  0.001356     0.98    1.91  2012-01-22  ad5Z1x9
# 13  0.001685     0.92    1.79  2012-01-22  Lp0APkL
# 14  0.001383     0.91    1.82  2012-01-22  OplP7L1
# 15  0.001140     0.88    1.84  2012-01-22  RpGQMN1
# 16  0.001342     0.87    1.76  2012-01-22  bLekgAm
# 17  0.001136     0.87    1.82  2012-01-22  AwoZgjd
# 18  0.001303     0.86    1.86  2012-01-22  wR0xJeQ
# 19  0.001309     0.82    1.65  2012-01-22  ZpO3XNQ
# 20  0.001206     0.81    1.72  2012-01-22  Ew9WzgL
# 21  0.001283     0.80    1.62  2012-01-22  m8E3N6E
# 22  0.001418     0.77    1.71  2012-01-22  k3z2xnL
# 23  0.001163     0.76    1.63  2012-01-22  GwZAQ9J
# 24  0.001095     0.75    1.71  2012-01-22  273zb1x
# 25  0.001108     0.72    1.58  2012-01-22  VpAj9rb
# 26  0.001372     0.71    1.52  2012-01-22  VpAjZLJ
# 27  0.001122     0.71    1.56  2012-01-22  2730xmx
# 28  0.001564     0.70    1.57  2012-01-22  NpYmwYo
# 29  0.001013     0.67    1.58  2012-01-22  OplP5pY
# 30  0.001007     0.66    1.51  2012-01-22  ngLR75d
# 31  0.000969     0.62    1.45  2012-01-22  5wPb1Yz
# 32  0.001882     0.58    1.36  2012-01-22  ngLRqnq
# 33  0.001088     0.54    1.32  2012-01-22  9wNv32K
# 34  0.001219     0.48    1.23  2012-01-22  Jp6EgjO
# 35  0.000911     0.47    1.20  2012-01-22  PpkWbgp
# 36  0.000995     0.47    1.21  2012-01-22  g1nOjlM
# 37  0.000868     0.44    1.15  2012-01-22  17rbGPX
# 38  0.001246     0.43    1.13  2012-01-22  0713Rqv
# 39  0.001212     0.40    1.08  2012-01-22  bLekmpq
# 40  0.001015     0.35    0.90  2012-01-22  m8ERpqp
# 41  0.000958     0.32    0.86  2012-01-22  z9l6PqE
# 42  0.000832     0.28    0.96  2012-01-22  Qawkznr
# 43  0.000968     0.20    0.59  2012-01-22  GwZAX7O
# 44  0.000679     0.18    0.58  2012-01-22  Lp0jvem
# 45  0.000617     0.16    0.53  2012-01-22  Lp0a9Wm
# 46  0.000434     0.14    0.60  2012-01-22  7webAp1
# 47  0.000388     0.12    0.53  2012-01-22  jZqRd5W
# 48  0.000249     0.05    0.27  2012-01-22  NpYwdMq
# 49  0.000209     0.04    0.23  2012-01-22  m8ERgw6
#
#                                            expression concentrated_weight  \
# 0   group = (country+1)*group_max(pv13_20_minvol_1...                PASS
# 1   group = (country+1)*group_max(pv13_10_minvol_1...                PASS
# 2   group = (country+1)*group_max(pv13_20_minvol_1...                PASS
# 3   group = (country+1)*group_max(pv13_1l_scibr, m...                PASS
# 4   group = (country+1)*group_max(pv13_1l_scibr, m...                PASS
# 5   group = (country+1)*group_max(pv13_10_minvol_1...                PASS
# 6   group = (country+1)*group_max(pv13_20_minvol_1...                PASS
# 7   group = (country+1)*group_max(pv13_1l_scibr, m...                PASS
# 8   group = (country+1)*group_max(pv13_20_minvol_1...                PASS
# 9   group = (country+1)*group_max(pv13_1l_scibr, m...                PASS
# 10  group = (country+1)*group_max(pv13_10_minvol_1...                PASS
# 11  group = (country+1)*group_max(pv13_20_minvol_1...                PASS
# 12  group = (country+1)*group_max(pv13_10_minvol_1...                PASS
# 13  group = (country+1)*group_max(pv13_1l_scibr, m...                PASS
# 14  group = (country+1)*group_max(pv13_5l_scibr, m...                PASS
# 15  group = (country+1)*group_max(pv13_20_minvol_1...                PASS
# 16  group = (country+1)*group_max(pv13_6l_scibr, m...                PASS
# 17  group = (country+1)*group_max(pv13_10_minvol_1...                PASS
# 18  group = (country+1)*group_max(pv13_10_minvol_1...                PASS
# 19  group = (country+1)*group_max(pv13_5l_scibr, m...                PASS
# 20  group = (country+1)*group_max(pv13_5l_scibr, m...                PASS
# 21  group = (country+1)*group_max(pv13_6l_scibr, m...                PASS
# 22  group = (country+1)*group_max(pv13_1l_scibr, m...                PASS
# 23  group = (country+1)*group_max(pv13_5l_scibr, m...                PASS
# 24  group = (country+1)*group_max(pv13_20_minvol_1...                PASS
# 25  group = (country+1)*group_max(pv13_6l_scibr, m...                PASS
# 26  group = (country+1)*group_max(pv13_1l_scibr, m...                PASS
# 27  group = (country+1)*group_max(pv13_6l_scibr, m...                PASS
# 28  group = (country+1)*group_max(pv13_20_minvol_1...                PASS
# 29  group = (country+1)*group_max(pv13_10_minvol_1...                PASS
# 30  group = (country+1)*group_max(pv13_5l_scibr, m...                PASS
# 31  group = (country+1)*group_max(pv13_6l_scibr, m...                PASS
# 32  group = (country+1)*group_max(pv13_1l_scibr, m...                PASS
# 33  group = (country+1)*group_max(pv13_6l_scibr, m...                PASS
# 34  group = (country+1)*group_max(pv13_10_minvol_1...                PASS
# 35  group = (country+1)*group_max(pv13_6l_scibr, m...                PASS
# 36  group = (country+1)*group_max(pv13_5l_scibr, m...                PASS
# 37  group = (country+1)*group_max(pv13_5l_scibr, m...                PASS
# 38  group = (country+1)*group_max(pv13_5l_scibr, m...                PASS
# 39  group = (country+1)*group_max(pv13_6l_scibr, m...                PASS
# 40  group = (country+1)*group_max(pv13_20_minvol_1...                PASS
# 41  group = (country+1)*group_max(pv13_10_minvol_1...                PASS
# 42  group = (country+1)*group_max(pv13_1l_scibr, m...                PASS
# 43  group = (country+1)*group_max(pv13_1l_scibr, m...                PASS
# 44  group = (country+1)*group_max(pv13_6l_scibr, m...                PASS
# 45  group = (country+1)*group_max(pv13_5l_scibr, m...                PASS
# 46  group = (country+1)*group_max(pv13_20_minvol_1...                PASS
# 47  group = (country+1)*group_max(pv13_10_minvol_1...                PASS
# 48  group = (country+1)*group_max(pv13_6l_scibr, m...                PASS
# 49  group = (country+1)*group_max(pv13_5l_scibr, m...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             PASS        PASS       PASS
# 1           PASS             FAIL        PASS       PASS
# 2           PASS             FAIL        PASS       PASS
# 3           PASS             FAIL        PASS       PASS
# 4           PASS             FAIL        PASS       PASS
# 5           PASS             FAIL        PASS       PASS
# 6           PASS             FAIL        PASS       PASS
# 7           PASS             FAIL        PASS       PASS
# 8           PASS             FAIL        PASS       PASS
# 9           PASS             FAIL        PASS       PASS
# 10          PASS             FAIL        PASS       PASS
# 11          PASS             FAIL        FAIL       PASS
# 12          PASS             FAIL        FAIL       PASS
# 13          PASS             FAIL        FAIL       PASS
# 14          PASS             FAIL        FAIL       PASS
# 15          PASS             FAIL        FAIL       PASS
# 16          PASS             FAIL        FAIL       PASS
# 17          PASS             FAIL        FAIL       PASS
# 18          PASS             FAIL        FAIL       PASS
# 19          PASS             FAIL        FAIL       PASS
# 20          PASS             FAIL        FAIL       PASS
# 21          PASS             FAIL        FAIL       PASS
# 22          PASS             FAIL        FAIL       PASS
# 23          PASS             FAIL        FAIL       PASS
# 24          PASS             FAIL        FAIL       PASS
# 25          PASS             FAIL        FAIL       PASS
# 26          PASS             FAIL        FAIL       FAIL
# 27          PASS             FAIL        FAIL       FAIL
# 28          PASS             FAIL        FAIL       FAIL
# 29          PASS             FAIL        FAIL       PASS
# 30          PASS             FAIL        FAIL       FAIL
# 31          PASS             FAIL        FAIL       FAIL
# 32          PASS             FAIL        FAIL       FAIL
# 33          PASS             FAIL        FAIL       FAIL
# 34          PASS             FAIL        FAIL       FAIL
# 35          PASS             FAIL        FAIL       FAIL
# 36          PASS             FAIL        FAIL       FAIL
# 37          PASS             FAIL        FAIL       FAIL
# 38          PASS             FAIL        FAIL       FAIL
# 39          PASS             FAIL        FAIL       FAIL
# 40          PASS             FAIL        FAIL       FAIL
# 41          PASS             FAIL        FAIL       FAIL
# 42          PASS             FAIL        FAIL       FAIL
# 43          PASS             FAIL        FAIL       FAIL
# 44          PASS             FAIL        FAIL       FAIL
# 45          PASS             FAIL        FAIL       FAIL
# 46          PASS             FAIL        FAIL       FAIL
# 47          PASS             FAIL        FAIL       FAIL
# 48          PASS             FAIL        FAIL       FAIL
# 49          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover
# 0                     PASS         PASS
# 1                     PASS         PASS
# 2                     PASS         PASS
# 3                     PASS         PASS
# 4                     PASS         PASS
# 5                     PASS         PASS
# 6                     PASS         PASS
# 7                     PASS         PASS
# 8                     PASS         PASS
# 9                     PASS         PASS
# 10                    PASS         PASS
# 11                    FAIL         PASS
# 12                    PASS         PASS
# 13                    PASS         PASS
# 14                    PASS         PASS
# 15                    PASS         PASS
# 16                    PASS         PASS
# 17                    PASS         PASS
# 18                    FAIL         PASS
# 19                    PASS         PASS
# 20                    PASS         PASS
# 21                    PASS         PASS
# 22                    PASS         PASS
# 23                    PASS         PASS
# 24                    FAIL         PASS
# 25                    PASS         PASS
# 26                    PASS         PASS
# 27                    PASS         PASS
# 28                    FAIL         PASS
# 29                    PASS         PASS
# 30                    PASS         PASS
# 31                    PASS         PASS
# 32                    FAIL         PASS
# 33                    PASS         PASS
# 34                    FAIL         PASS
# 35                    PASS         PASS
# 36                    PASS         PASS
# 37                    PASS         PASS
# 38                    PASS         PASS
# 39                    PASS         PASS
# 40                    PASS         PASS
# 41                    PASS         PASS
# 42                    PASS         PASS
# 43                    PASS         PASS
# 44                    PASS         PASS
# 45                    PASS         PASS
# 46                    FAIL         PASS
# 47                    FAIL         PASS
# 48                    PASS         PASS
# 49                    PASS         PASS

# %% [markdown]
# prettify 함수를 이용해 dataframe 형식으로 변환하면 결과를 보기 더 편합니다.

# %%
result_st1.to_csv('2024_09_06_GLB.csv')

# %% [markdown]
# ### How to submit?
#
# Create a list of submittable alphas - alphas that have no FAIL in is_tests

# %% [markdown]
# 시뮬레이션을 마친 알파 중 제출 가능한 알파들을 제출해 봅시다.

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df
# Out:
#     alpha_id     endDate  limit message                 name   result  \
# 0    PpkWbgp         NaN   1.58     NaN           LOW_SHARPE     FAIL
# 1    PpkWbgp         NaN   1.00     NaN          LOW_FITNESS     FAIL
# 2    PpkWbgp         NaN   0.01     NaN         LOW_TURNOVER     PASS
# 3    PpkWbgp         NaN   0.70     NaN        HIGH_TURNOVER     PASS
# 4    PpkWbgp         NaN    NaN     NaN  CONCENTRATED_WEIGHT     PASS
# ..       ...         ...    ...     ...                  ...      ...
# 645  Lp0APkL         NaN    NaN     NaN       DATA_DIVERSITY  PENDING
# 646  Lp0APkL         NaN    NaN     NaN     PROD_CORRELATION  PENDING
# 647  Lp0APkL         NaN    NaN     NaN   REGULAR_SUBMISSION  PENDING
# 648  Lp0APkL  2020-01-25   1.58     NaN     IS_LADDER_SHARPE     FAIL
# 649  Lp0APkL         NaN    NaN     NaN       MATCHES_THEMES  WARNING
#
#       startDate                                             themes   value  \
# 0           NaN                                                NaN  1.2000
# 1           NaN                                                NaN  0.4700
# 2           NaN                                                NaN  0.0425
# 3           NaN                                                NaN  0.0425
# 4           NaN                                                NaN     NaN
# ..          ...                                                ...     ...
# 645         NaN                                                NaN     NaN
# 646         NaN                                                NaN     NaN
# 647         NaN                                                NaN     NaN
# 648  2022-01-24                                                NaN  1.4700
# 649         NaN  [{'id': 'WBlNe4R', 'multiplier': 3.0, 'name': ...     NaN
#
#      year
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 645   NaN
# 646   NaN
# 647   NaN
# 648   2.0
# 649   NaN
#
# [650 rows x 10 columns]

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['PpkWbgp' '2730xmx' 'm8E3N6E' '5wPb1Yz' 'bLekgAm' '9wNv32K' 'NpYwdMq'
#  'bLekmpq' 'Lp0jvem' 'm8ERpqp' 'RpGQMN1' 'VpAj9rb' '7webAp1' 'NpYmwYo'
#  'KbWdjKk' '273zb1x' 'AwoZM1Y' 'ZpO3lOd' 'WpvQXvZ' 'jZqRd5W' 'g1nOo3K'
#  'wR0xJeQ' 'OplP5pY' 'Jp6EgjO' 'z9l6PqE' 'AwoZgjd' '7webzN5' 'WpvQAeG'
#  'ad5Z1x9' 'ngLR75d' 'OplP7L1' 'g1nOjlM' 'm8ERgw6' '0713Rqv' 'Lp0a9Wm'
#  '17rbGPX' 'GwZAQ9J' 'ZpO3XNQ' 'GwZAX7O' 'VpAjZLJ' 'p69rxkj' 'Ew9WzgL'
#  'Qawkznr' 'ngLRqnq' '9wN15bq' 'ZpO3Vqj' 'dxNA2EY' 'k3z2xnL' 'Lp0APkL']
# Passed alphas:['ZpO36rQ']

# %% [markdown]
# 위 함수들을 이용해 All Pass (correlation 제외) 가 나온 알파들의 id 를 쉽게 구별해 낼 수 있습니다. 주의하셔야 할 점은 is_test 함수에 넣는 input 값은 prettify 하지 않은, alpha simulation 을 마쳤을 때 출력되는 원본 형태를 입력해야 된다는 겁니다.

# %%
ace.get_check_submission(s, passed_alphas[0])
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4211, in DataFrame._set_value(self, index, col, value, takeable)
#    4210     icol = self.columns.get_loc(col)
# -> 4211     iindex = self.index.get_loc(index)
#    4212 self._mgr.column_setitem(icol, iindex, value, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:394, in RangeIndex.get_loc(self, key, method, tolerance)
#     393         raise KeyError(key) from err
# --> 394 self._check_indexing_error(key)
#     395 raise KeyError(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5925, in Index._check_indexing_error(self, key)
#    5922 if not is_scalar(key):
#    5923     # if key is not a scalar, directly raise an error (the code below
#    5924     # would convert to numpy arrays and raise later any way) - GH29926
# -> 5925     raise InvalidIndexError(key)
#
# InvalidIndexError: Int64Index([11], dtype='int64')
#
# The above exception was the direct cause of the following exception:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ace.get_check_submission(s, passed_alphas[0])
#
# File ~\OneDrive\문서\GitHub\WQBrain_2024_API\ace_lib.py:399, in get_check_submission(s, alpha_id)
#     397 if 'year' in checks_df:
#     398     ladder_dict = [checks_df.loc[checks_df.index[checks_df['name']=='IS_LADDER_SHARPE']][['value', 'year']].iloc[0].to_dict()]
# --> 399     checks_df.at[checks_df.index[checks_df['name']=='IS_LADDER_SHARPE'], 'value'] = ladder_dict
#     400     checks_df.drop(['endDate', 'startDate', 'year'], axis=1, inplace=True)
#     402 return checks_df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2442, in _AtIndexer.__setitem__(self, key, value)
#    2439     self.obj.loc[key] = value
#    2440     return
# -> 2442 return super().__setitem__(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2397, in _ScalarAccessIndexer.__setitem__(self, key, value)
#    2394 if len(key) != self.ndim:
#    2395     raise ValueError("Not enough indexers for scalar access (setting)!")
# -> 2397 self.obj._set_value(*key, value=value, takeable=self._takeable)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4230, in DataFrame._set_value(self, index, col, value, takeable)
#    4225     self._item_cache.pop(col, None)
#    4227 except InvalidIndexError as ii_err:
#    4228     # GH48729: Seems like you are trying to assign a value to a
#    4229     # row when only scalar options are permitted
# -> 4230     raise InvalidIndexError(
#    4231         f"You can only assign a scalar value not a {type(value)}"
#    4232     ) from ii_err
#
# InvalidIndexError: You can only assign a scalar value not a <class 'list'>

# %% [markdown]
# 위 함수로 각 알파가 correlation 을 포함한 모든 기준에서 통과를 했는지 확인 해 볼 수 있습니다.

# %%
for alpha_id in passed_alphas:
    print(ace.get_check_submission(s, alpha_id))
# Out:
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.1700
# 1              LOW_FITNESS   PASS   1.00  1.1900
# 2             LOW_TURNOVER   PASS   0.01  0.3861
# 3            HIGH_TURNOVER   PASS   0.70  0.3861
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.76  0.9300
# 6         SELF_CORRELATION   PASS   0.70  0.5198
# 7         PROD_CORRELATION   FAIL   0.70  0.7659
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  z92n2P8
# 1                                         NaN  z92n2P8
# 2                                         NaN  z92n2P8
# 3                                         NaN  z92n2P8
# 4                                         NaN  z92n2P8
# 5                                         NaN  z92n2P8
# 6                                         NaN  z92n2P8
# 7                                         NaN  z92n2P8
# 8                                         NaN  z92n2P8
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  z92n2P8
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.7900
# 1              LOW_FITNESS   PASS   1.00  1.7900
# 2             LOW_TURNOVER   PASS   0.01  0.3496
# 3            HIGH_TURNOVER   PASS   0.70  0.3496
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.98  1.3700
# 6         SELF_CORRELATION   PASS   0.70  0.3836
# 7         PROD_CORRELATION   FAIL   0.70  0.7858
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  Jp3oAxE
# 1                                         NaN  Jp3oAxE
# 2                                         NaN  Jp3oAxE
# 3                                         NaN  Jp3oAxE
# 4                                         NaN  Jp3oAxE
# 5                                         NaN  Jp3oAxE
# 6                                         NaN  Jp3oAxE
# 7                                         NaN  Jp3oAxE
# 8                                         NaN  Jp3oAxE
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  Jp3oAxE
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.6600
# 1              LOW_FITNESS   PASS   1.00  1.5600
# 2             LOW_TURNOVER   PASS   0.01  0.3978
# 3            HIGH_TURNOVER   PASS   0.70  0.3978
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.93  1.4000
# 6         SELF_CORRELATION   PASS   0.70  0.3758
# 7         PROD_CORRELATION   FAIL   0.70  0.8155
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  Xpz5Zwm
# 1                                         NaN  Xpz5Zwm
# 2                                         NaN  Xpz5Zwm
# 3                                         NaN  Xpz5Zwm
# 4                                         NaN  Xpz5Zwm
# 5                                         NaN  Xpz5Zwm
# 6                                         NaN  Xpz5Zwm
# 7                                         NaN  Xpz5Zwm
# 8                                         NaN  Xpz5Zwm
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  Xpz5Zwm
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.2500
# 1              LOW_FITNESS   PASS   1.00  1.2100
# 2             LOW_TURNOVER   PASS   0.01  0.4356
# 3            HIGH_TURNOVER   PASS   0.70  0.4356
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.79  0.9300
# 6         SELF_CORRELATION   PASS   0.70  0.3567
# 7         PROD_CORRELATION   FAIL   0.70  0.8235
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  lVGb3QA
# 1                                         NaN  lVGb3QA
# 2                                         NaN  lVGb3QA
# 3                                         NaN  lVGb3QA
# 4                                         NaN  lVGb3QA
# 5                                         NaN  lVGb3QA
# 6                                         NaN  lVGb3QA
# 7                                         NaN  lVGb3QA
# 8                                         NaN  lVGb3QA
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  lVGb3QA
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.0800
# 1              LOW_FITNESS   PASS   1.00  1.1400
# 2             LOW_TURNOVER   PASS   0.01  0.3579
# 3            HIGH_TURNOVER   PASS   0.70  0.3579
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.73  0.8900
# 6         SELF_CORRELATION   PASS   0.70  0.5093
# 7         PROD_CORRELATION   FAIL   0.70  0.8071
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  LpzJJKL
# 1                                         NaN  LpzJJKL
# 2                                         NaN  LpzJJKL
# 3                                         NaN  LpzJJKL
# 4                                         NaN  LpzJJKL
# 5                                         NaN  LpzJJKL
# 6                                         NaN  LpzJJKL
# 7                                         NaN  LpzJJKL
# 8                                         NaN  LpzJJKL
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  LpzJJKL
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.7700
# 1              LOW_FITNESS   PASS   1.00  1.8000
# 2             LOW_TURNOVER   PASS   0.01  0.3328
# 3            HIGH_TURNOVER   PASS   0.70  0.3328
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.97  1.2700
# 6         SELF_CORRELATION   PASS   0.70  0.4018
# 7         PROD_CORRELATION   FAIL   0.70  0.8494
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  5wGAbp1
# 1                                         NaN  5wGAbp1
# 2                                         NaN  5wGAbp1
# 3                                         NaN  5wGAbp1
# 4                                         NaN  5wGAbp1
# 5                                         NaN  5wGAbp1
# 6                                         NaN  5wGAbp1
# 7                                         NaN  5wGAbp1
# 8                                         NaN  5wGAbp1
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  5wGAbp1
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.1300
# 1              LOW_FITNESS   PASS   1.00  1.1500
# 2             LOW_TURNOVER   PASS   0.01  0.3854
# 3            HIGH_TURNOVER   PASS   0.70  0.3854
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.75  0.9800
# 6         SELF_CORRELATION   PASS   0.70  0.5274
# 7         PROD_CORRELATION   FAIL   0.70  0.7635
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  KbzjAvE
# 1                                         NaN  KbzjAvE
# 2                                         NaN  KbzjAvE
# 3                                         NaN  KbzjAvE
# 4                                         NaN  KbzjAvE
# 5                                         NaN  KbzjAvE
# 6                                         NaN  KbzjAvE
# 7                                         NaN  KbzjAvE
# 8                                         NaN  KbzjAvE
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  KbzjAvE
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.4700
# 1              LOW_FITNESS   PASS   1.00  1.3400
# 2             LOW_TURNOVER   PASS   0.01  0.4417
# 3            HIGH_TURNOVER   PASS   0.70  0.4417
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.86  1.0800
# 6         SELF_CORRELATION   PASS   0.70  0.3222
# 7         PROD_CORRELATION   FAIL   0.70  0.7670
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  xxG0den
# 1                                         NaN  xxG0den
# 2                                         NaN  xxG0den
# 3                                         NaN  xxG0den
# 4                                         NaN  xxG0den
# 5                                         NaN  xxG0den
# 6                                         NaN  xxG0den
# 7                                         NaN  xxG0den
# 8                                         NaN  xxG0den
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  xxG0den
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.8000
# 1              LOW_FITNESS   PASS   1.00  1.6400
# 2             LOW_TURNOVER   PASS   0.01  0.4388
# 3            HIGH_TURNOVER   PASS   0.70  0.4388
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.98  1.4300
# 6         SELF_CORRELATION   PASS   0.70  0.3480
# 7         PROD_CORRELATION   FAIL   0.70  0.7862
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  37PZ3vz
# 1                                         NaN  37PZ3vz
# 2                                         NaN  37PZ3vz
# 3                                         NaN  37PZ3vz
# 4                                         NaN  37PZ3vz
# 5                                         NaN  37PZ3vz
# 6                                         NaN  37PZ3vz
# 7                                         NaN  37PZ3vz
# 8                                         NaN  37PZ3vz
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  37PZ3vz
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  1.9900
# 1              LOW_FITNESS   PASS   1.00  1.0700
# 2             LOW_TURNOVER   PASS   0.01  0.3659
# 3            HIGH_TURNOVER   PASS   0.70  0.3659
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.70  0.7500
# 6         SELF_CORRELATION   PASS   0.70  0.5120
# 7         PROD_CORRELATION   FAIL   0.70  0.7916
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  m879JN9
# 1                                         NaN  m879JN9
# 2                                         NaN  m879JN9
# 3                                         NaN  m879JN9
# 4                                         NaN  m879JN9
# 5                                         NaN  m879JN9
# 6                                         NaN  m879JN9
# 7                                         NaN  m879JN9
# 8                                         NaN  m879JN9
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  m879JN9
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.5000
# 1              LOW_FITNESS   PASS   1.00  1.4900
# 2             LOW_TURNOVER   PASS   0.01  0.3888
# 3            HIGH_TURNOVER   PASS   0.70  0.3888
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.88  1.2900
# 6         SELF_CORRELATION   PASS   0.70  0.4053
# 7         PROD_CORRELATION   FAIL   0.70  0.8508
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  oKGMjGn
# 1                                         NaN  oKGMjGn
# 2                                         NaN  oKGMjGn
# 3                                         NaN  oKGMjGn
# 4                                         NaN  oKGMjGn
# 5                                         NaN  oKGMjGn
# 6                                         NaN  oKGMjGn
# 7                                         NaN  oKGMjGn
# 8                                         NaN  oKGMjGn
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  oKGMjGn
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.5600
# 1              LOW_FITNESS   PASS   1.00  1.6800
# 2             LOW_TURNOVER   PASS   0.01  0.3231
# 3            HIGH_TURNOVER   PASS   0.70  0.3231
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.90  1.1600
# 6         SELF_CORRELATION   PASS   0.70  0.4289
# 7         PROD_CORRELATION   FAIL   0.70  0.8844
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  wRN2mEv
# 1                                         NaN  wRN2mEv
# 2                                         NaN  wRN2mEv
# 3                                         NaN  wRN2mEv
# 4                                         NaN  wRN2mEv
# 5                                         NaN  wRN2mEv
# 6                                         NaN  wRN2mEv
# 7                                         NaN  wRN2mEv
# 8                                         NaN  wRN2mEv
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  wRN2mEv
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.1500
# 1              LOW_FITNESS   PASS   1.00  1.1500
# 2             LOW_TURNOVER   PASS   0.01  0.3730
# 3            HIGH_TURNOVER   PASS   0.70  0.3730
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.75  0.8500
# 6         SELF_CORRELATION   PASS   0.70  0.4998
# 7         PROD_CORRELATION   FAIL   0.70  0.7646
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  qAGqPLK
# 1                                         NaN  qAGqPLK
# 2                                         NaN  qAGqPLK
# 3                                         NaN  qAGqPLK
# 4                                         NaN  qAGqPLK
# 5                                         NaN  qAGqPLK
# 6                                         NaN  qAGqPLK
# 7                                         NaN  qAGqPLK
# 8                                         NaN  qAGqPLK
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  qAGqPLK
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.5400
# 1              LOW_FITNESS   PASS   1.00  1.5200
# 2             LOW_TURNOVER   PASS   0.01  0.3896
# 3            HIGH_TURNOVER   PASS   0.70  0.3896
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.89  1.1700
# 6         SELF_CORRELATION   PASS   0.70  0.4052
# 7         PROD_CORRELATION   FAIL   0.70  0.8503
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  JpzZege
# 1                                         NaN  JpzZege
# 2                                         NaN  JpzZege
# 3                                         NaN  JpzZege
# 4                                         NaN  JpzZege
# 5                                         NaN  JpzZege
# 6                                         NaN  JpzZege
# 7                                         NaN  JpzZege
# 8                                         NaN  JpzZege
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  JpzZege
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.3300
# 1              LOW_FITNESS   PASS   1.00  1.3900
# 2             LOW_TURNOVER   PASS   0.01  0.3689
# 3            HIGH_TURNOVER   PASS   0.70  0.3689
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.82  1.0300
# 6         SELF_CORRELATION   PASS   0.70  0.3848
# 7         PROD_CORRELATION   FAIL   0.70  0.8931
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  8zJ1aRV
# 1                                         NaN  8zJ1aRV
# 2                                         NaN  8zJ1aRV
# 3                                         NaN  8zJ1aRV
# 4                                         NaN  8zJ1aRV
# 5                                         NaN  8zJ1aRV
# 6                                         NaN  8zJ1aRV
# 7                                         NaN  8zJ1aRV
# 8                                         NaN  8zJ1aRV
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  8zJ1aRV
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.5100
# 1              LOW_FITNESS   PASS   1.00  1.4900
# 2             LOW_TURNOVER   PASS   0.01  0.3269
# 3            HIGH_TURNOVER   PASS   0.70  0.3269
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.88  1.0900
# 6         SELF_CORRELATION   PASS   0.70  0.5402
# 7         PROD_CORRELATION   FAIL   0.70  0.7620
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  MpgeWQ6
# 1                                         NaN  MpgeWQ6
# 2                                         NaN  MpgeWQ6
# 3                                         NaN  MpgeWQ6
# 4                                         NaN  MpgeWQ6
# 5                                         NaN  MpgeWQ6
# 6                                         NaN  MpgeWQ6
# 7                                         NaN  MpgeWQ6
# 8                                         NaN  MpgeWQ6
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  MpgeWQ6
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.2400
# 1              LOW_FITNESS   PASS   1.00  1.2200
# 2             LOW_TURNOVER   PASS   0.01  0.3651
# 3            HIGH_TURNOVER   PASS   0.70  0.3651
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.78  0.9800
# 6         SELF_CORRELATION   PASS   0.70  0.4966
# 7         PROD_CORRELATION   FAIL   0.70  0.7746
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  AwzKKxX
# 1                                         NaN  AwzKKxX
# 2                                         NaN  AwzKKxX
# 3                                         NaN  AwzKKxX
# 4                                         NaN  AwzKKxX
# 5                                         NaN  AwzKKxX
# 6                                         NaN  AwzKKxX
# 7                                         NaN  AwzKKxX
# 8                                         NaN  AwzKKxX
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  AwzKKxX
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.7100
# 1              LOW_FITNESS   PASS   1.00  1.6000
# 2             LOW_TURNOVER   PASS   0.01  0.3986
# 3            HIGH_TURNOVER   PASS   0.70  0.3986
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.95  1.2700
# 6         SELF_CORRELATION   PASS   0.70  0.3764
# 7         PROD_CORRELATION   FAIL   0.70  0.8162
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  LpzAMne
# 1                                         NaN  LpzAMne
# 2                                         NaN  LpzAMne
# 3                                         NaN  LpzAMne
# 4                                         NaN  LpzAMne
# 5                                         NaN  LpzAMne
# 6                                         NaN  LpzAMne
# 7                                         NaN  LpzAMne
# 8                                         NaN  LpzAMne
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  LpzAMne
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.5400
# 1              LOW_FITNESS   PASS   1.00  1.5100
# 2             LOW_TURNOVER   PASS   0.01  0.3777
# 3            HIGH_TURNOVER   PASS   0.70  0.3777
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.89  1.1600
# 6         SELF_CORRELATION   PASS   0.70  0.3609
# 7         PROD_CORRELATION   FAIL   0.70  0.8652
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  xxGgPvN
# 1                                         NaN  xxGgPvN
# 2                                         NaN  xxGgPvN
# 3                                         NaN  xxGgPvN
# 4                                         NaN  xxGgPvN
# 5                                         NaN  xxGgPvN
# 6                                         NaN  xxGgPvN
# 7                                         NaN  xxGgPvN
# 8                                         NaN  xxGgPvN
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  xxGgPvN
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.4500
# 1              LOW_FITNESS   PASS   1.00  1.4400
# 2             LOW_TURNOVER   PASS   0.01  0.3450
# 3            HIGH_TURNOVER   PASS   0.70  0.3450
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.86  1.1900
# 6         SELF_CORRELATION   PASS   0.70  0.5098
# 7         PROD_CORRELATION   PASS   0.70  0.7194
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  z9Agxgo
# 1                                         NaN  z9Agxgo
# 2                                         NaN  z9Agxgo
# 3                                         NaN  z9Agxgo
# 4                                         NaN  z9Agxgo
# 5                                         NaN  z9Agxgo
# 6                                         NaN  z9Agxgo
# 7                                         NaN  z9Agxgo
# 8                                         NaN  z9Agxgo
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  z9Agxgo
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.6400
# 1              LOW_FITNESS   PASS   1.00  1.4900
# 2             LOW_TURNOVER   PASS   0.01  0.4249
# 3            HIGH_TURNOVER   PASS   0.70  0.4249
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.92  1.3000
# 6         SELF_CORRELATION   PASS   0.70  0.5286
# 7         PROD_CORRELATION   FAIL   0.70  0.7371
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  roGvE9j
# 1                                         NaN  roGvE9j
# 2                                         NaN  roGvE9j
# 3                                         NaN  roGvE9j
# 4                                         NaN  roGvE9j
# 5                                         NaN  roGvE9j
# 6                                         NaN  roGvE9j
# 7                                         NaN  roGvE9j
# 8                                         NaN  roGvE9j
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  roGvE9j
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.5800
# 1              LOW_FITNESS   PASS   1.00  1.5600
# 2             LOW_TURNOVER   PASS   0.01  0.3700
# 3            HIGH_TURNOVER   PASS   0.70  0.3700
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.90  1.2600
# 6         SELF_CORRELATION   PASS   0.70  0.3681
# 7         PROD_CORRELATION   FAIL   0.70  0.8606
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  wRGgxYl
# 1                                         NaN  wRGgxYl
# 2                                         NaN  wRGgxYl
# 3                                         NaN  wRGgxYl
# 4                                         NaN  wRGgxYl
# 5                                         NaN  wRGgxYl
# 6                                         NaN  wRGgxYl
# 7                                         NaN  wRGgxYl
# 8                                         NaN  wRGgxYl
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  wRGgxYl
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.7700
# 1              LOW_FITNESS   PASS   1.00  1.5400
# 2             LOW_TURNOVER   PASS   0.01  0.4322
# 3            HIGH_TURNOVER   PASS   0.70  0.4322
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.97  1.3900
# 6         SELF_CORRELATION   PASS   0.70  0.5072
# 7         PROD_CORRELATION   PASS   0.70  0.7028
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  6w0v3oG
# 1                                         NaN  6w0v3oG
# 2                                         NaN  6w0v3oG
# 3                                         NaN  6w0v3oG
# 4                                         NaN  6w0v3oG
# 5                                         NaN  6w0v3oG
# 6                                         NaN  6w0v3oG
# 7                                         NaN  6w0v3oG
# 8                                         NaN  6w0v3oG
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  6w0v3oG
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.6500
# 1              LOW_FITNESS   PASS   1.00  1.5700
# 2             LOW_TURNOVER   PASS   0.01  0.4299
# 3            HIGH_TURNOVER   PASS   0.70  0.4299
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.93  1.3300
# 6         SELF_CORRELATION   PASS   0.70  0.3816
# 7         PROD_CORRELATION   FAIL   0.70  0.8250
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  EwzXYzR
# 1                                         NaN  EwzXYzR
# 2                                         NaN  EwzXYzR
# 3                                         NaN  EwzXYzR
# 4                                         NaN  EwzXYzR
# 5                                         NaN  EwzXYzR
# 6                                         NaN  EwzXYzR
# 7                                         NaN  EwzXYzR
# 8                                         NaN  EwzXYzR
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  EwzXYzR
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.2400
# 1              LOW_FITNESS   PASS   1.00  1.2000
# 2             LOW_TURNOVER   PASS   0.01  0.3927
# 3            HIGH_TURNOVER   PASS   0.70  0.3927
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.78  1.0600
# 6         SELF_CORRELATION   PASS   0.70  0.5140
# 7         PROD_CORRELATION   FAIL   0.70  0.7379
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  dxzAJ3w
# 1                                         NaN  dxzAJ3w
# 2                                         NaN  dxzAJ3w
# 3                                         NaN  dxzAJ3w
# 4                                         NaN  dxzAJ3w
# 5                                         NaN  dxzAJ3w
# 6                                         NaN  dxzAJ3w
# 7                                         NaN  dxzAJ3w
# 8                                         NaN  dxzAJ3w
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  dxzAJ3w
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.3500
# 1              LOW_FITNESS   PASS   1.00  1.4100
# 2             LOW_TURNOVER   PASS   0.01  0.3190
# 3            HIGH_TURNOVER   PASS   0.70  0.3190
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.82  1.0000
# 6         SELF_CORRELATION   PASS   0.70  0.5542
# 7         PROD_CORRELATION   FAIL   0.70  0.7929
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  Lp8mjaL
# 1                                         NaN  Lp8mjaL
# 2                                         NaN  Lp8mjaL
# 3                                         NaN  Lp8mjaL
# 4                                         NaN  Lp8mjaL
# 5                                         NaN  Lp8mjaL
# 6                                         NaN  Lp8mjaL
# 7                                         NaN  Lp8mjaL
# 8                                         NaN  Lp8mjaL
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  Lp8mjaL
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.3200
# 1              LOW_FITNESS   PASS   1.00  1.3700
# 2             LOW_TURNOVER   PASS   0.01  0.3374
# 3            HIGH_TURNOVER   PASS   0.70  0.3374
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.81  1.1000
# 6         SELF_CORRELATION   PASS   0.70  0.5235
# 7         PROD_CORRELATION   FAIL   0.70  0.7533
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  17GO8GX
# 1                                         NaN  17GO8GX
# 2                                         NaN  17GO8GX
# 3                                         NaN  17GO8GX
# 4                                         NaN  17GO8GX
# 5                                         NaN  17GO8GX
# 6                                         NaN  17GO8GX
# 7                                         NaN  17GO8GX
# 8                                         NaN  17GO8GX
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  17GO8GX
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.2900
# 1              LOW_FITNESS   PASS   1.00  1.2400
# 2             LOW_TURNOVER   PASS   0.01  0.3933
# 3            HIGH_TURNOVER   PASS   0.70  0.3933
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.80  1.0100
# 6         SELF_CORRELATION   PASS   0.70  0.5057
# 7         PROD_CORRELATION   FAIL   0.70  0.7402
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  PpYmYnW
# 1                                         NaN  PpYmYnW
# 2                                         NaN  PpYmYnW
# 3                                         NaN  PpYmYnW
# 4                                         NaN  PpYmYnW
# 5                                         NaN  PpYmYnW
# 6                                         NaN  PpYmYnW
# 7                                         NaN  PpYmYnW
# 8                                         NaN  PpYmYnW
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  PpYmYnW
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.6100
# 1              LOW_FITNESS   PASS   1.00  1.6900
# 2             LOW_TURNOVER   PASS   0.01  0.3402
# 3            HIGH_TURNOVER   PASS   0.70  0.3402
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.91  1.2500
# 6         SELF_CORRELATION   PASS   0.70  0.4079
# 7         PROD_CORRELATION   FAIL   0.70  0.8244
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  dx9YMjE
# 1                                         NaN  dx9YMjE
# 2                                         NaN  dx9YMjE
# 3                                         NaN  dx9YMjE
# 4                                         NaN  dx9YMjE
# 5                                         NaN  dx9YMjE
# 6                                         NaN  dx9YMjE
# 7                                         NaN  dx9YMjE
# 8                                         NaN  dx9YMjE
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  dx9YMjE
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.3700
# 1              LOW_FITNESS   PASS   1.00  1.4400
# 2             LOW_TURNOVER   PASS   0.01  0.3613
# 3            HIGH_TURNOVER   PASS   0.70  0.3613
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.83  1.1400
# 6         SELF_CORRELATION   PASS   0.70  0.3930
# 7         PROD_CORRELATION   FAIL   0.70  0.8912
# 8       REGULAR_SUBMISSION   PASS   4.00  0.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  RpzWQ7o
# 1                                         NaN  RpzWQ7o
# 2                                         NaN  RpzWQ7o
# 3                                         NaN  RpzWQ7o
# 4                                         NaN  RpzWQ7o
# 5                                         NaN  RpzWQ7o
# 6                                         NaN  RpzWQ7o
# 7                                         NaN  RpzWQ7o
# 8                                         NaN  RpzWQ7o
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  RpzWQ7o

# %% [markdown]
# 위 함수로 통과한 알파들을 한꺼번에 돌려볼 수 있습니다. 다만 여러개를 돌리면 시간이 꽤 걸리는 점 주의해 주시길 바랍니다.

# %%
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['Sep06_GLB'])

# %% [markdown]
# 위 함수로 통과한 알파들에 태그를 붙일 수 있습니다.

# %% [markdown]
# When you got a list of submittable alphas, you can call function submit_alpha()

# %%
#calling submit_alpha on all alphas that have passed the submission tests

submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas}

# %% [markdown]
# 위 함수로 알파를 제출할 수 있습니다.

# %% [markdown]
# 알파의 id 로 제출하는 것이기 때문에, 그 알파를 시뮬레이션 한 날짜가 중요합니다. 가령, 1주일 전에 시뮬레이션 해 결과를 저장해 두었던 alpha id로 제출을 한다면 제출 날짜가 1주일 전이 됩니다. 그러니 오늘 제출하고 싶은 alpha 가 있다면 시뮬레이션을 다시 돌려 새로 생긴 alpha id 를 이용해야 합니다. 이 과정은 alpha 에 특정 태그를 달아 Brain 플랫폼에서 직접 하는게 훨씬 수월합니다. (다만, 플랫폼에서는 alpha id 로 알파를 검색할 수 없습니다.)

# %%
#submit_result will have return values from the submit_result function

submit_result
# Out:
# {'ZpO36rQ': False}

# %% [markdown]
# 주의하셔야 하실 점은, 하루 최대 알파 제출 한도인 4개를 루프중에 이미 넘기면 그 뒤의 알파들이 제출 가능하더라도 자동으로 제출에 실패하게 됩니다.

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance

# %% [markdown]
# 유용한 추가 함수들입니다. prod correlation 혹은 self correlation 만을 확인하고 싶을 때, 혹은 알파의 pnl 을 확인하고 싶을때 유용히 쓰입니다.
