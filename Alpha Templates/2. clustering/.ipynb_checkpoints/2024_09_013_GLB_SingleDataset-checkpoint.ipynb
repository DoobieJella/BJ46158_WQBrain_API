# %% [markdown]
# ### Import library

# %%
import os
os.chdir('../../')
os.getcwd()
# Out:
# 'C:\\Users\\csia7\\OneDrive\\문서\\GitHub\\WQBrain_2024_API'

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px
import pygwalker as pyg
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_RyTLo2zyNjjwPtYyrQQVyDazqaep

# %% [markdown]
# ## Global region Alpha Template

# %%
expression_template = f'''
group = (country+1)*group_max(pv13_52_minvol_1m_all_delay_1_sector, market) + pv13_52_minvol_1m_all_delay_1_sector;
group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_ecns, industry, 252, std=1), 252), densify(group))
'''

# %% [markdown]
# #### Step 1. Download datsets

# %%
datasets_df = hf.get_datasets(s, region = 'GLB', universe = 'MINVOL1M') # by default we load all datasets USA TOP3000 delay 1    , region='GLB', universe='MINVOL1M'
datasets_df # DataFrame.head() shows first 5 rows of the dataframe
# Out:
#                 id                             name  \
# 0        analyst11                       ESG scores
# 1        analyst14  Estimations of Key Fundamentals
# 2        analyst15               Earnings forecasts
# 3        analyst16              Real Time Estimates
# 4        analyst35                        ESG Model
# ..             ...                              ...
# 83  shortinterest6              SmartHoldings Model
# 84  shortinterest7              Short Selling Model
# 85   socialmedia12        Sentiment Data for Equity
# 86    socialmedia5           Lexical Breakdown Data
# 87           univ1                 Universe Dataset
#
#                                           description  \
# 0   Environmental Social Governance scores that ex...
# 1   This dataset reports many items from financial...
# 2   This dataset provides bottom-up forecast data ...
# 3   This dataset provides real-time access to the ...
# 4   The dataset provide ESG related information ba...
# ..                                                ...
# 83  This dataset is a global stock selection model...
# 84  The dataset combines features obtained from sh...
# 85  This dataset provides sentiment data with diff...
# 86  Sentiment scores derived from social media. So...
# 87                             No dataset description
#
#                                              category  \
# 0                {'id': 'analyst', 'name': 'Analyst'}
# 1                {'id': 'analyst', 'name': 'Analyst'}
# 2                {'id': 'analyst', 'name': 'Analyst'}
# 3                {'id': 'analyst', 'name': 'Analyst'}
# 4                {'id': 'analyst', 'name': 'Analyst'}
# ..                                                ...
# 83  {'id': 'shortinterest', 'name': 'Short Interest'}
# 84  {'id': 'shortinterest', 'name': 'Short Interest'}
# 85      {'id': 'socialmedia', 'name': 'Social Media'}
# 86      {'id': 'socialmedia', 'name': 'Social Media'}
# 87               {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay  universe  \
# 0                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  MINVOL1M
# 1   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  MINVOL1M
# 2   {'id': 'analyst-analyst-estimates', 'name': 'A...    GLB      1  MINVOL1M
# 3   {'id': 'analyst-crowdsourced-estimates', 'name...    GLB      1  MINVOL1M
# 4                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  MINVOL1M
# ..                                                ...    ...    ...       ...
# 83  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  MINVOL1M
# 84  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  MINVOL1M
# 85  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  MINVOL1M
# 86  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  MINVOL1M
# 87  {'id': 'pv-price-volume', 'name': 'Price Volume'}    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 0     0.7917     None         4.0         66         304         197     []
# 1     0.5186     None         3.0        101         589         926     []
# 2     0.9929     None         2.0        158        1497         288     []
# 3     0.9013     None         2.0        134         821          42     []
# 4     0.4375     None         3.0         63         202          23     []
# ..       ...      ...         ...        ...         ...         ...    ...
# 83    0.9711     None         2.0         92         389          11     []
# 84    1.0000     None         2.0         73         331          16     []
# 85    0.6731     None         3.0         17          25           2     []
# 86    0.3753     None         5.0          2           3          12     []
# 87    1.0000     None         3.0          3           5           2     []
#
#                                        researchPapers
# 0   [{'title': 'Research Paper 19: ESG Preference,...
# 1   [{'title': 'Research Paper 10: Investor Learni...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 83                                                 []
# 84  [{'title': 'Research Paper 04: Strategic Rebal...
# 85  [{'title': 'Research Paper 01: Textual Sentime...
# 86                                                 []
# 87                                                 []
#
# [88 rows x 16 columns]

# %%
# select needed datasets
selected_datasets_df = datasets_df[
    (datasets_df["valueScore"] > 3) &
    (datasets_df["valueScore"] < 6) 
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df
# Out:
#                 id                                               name  \
# 86    socialmedia5                             Lexical Breakdown Data
# 58         option2  Implied Volatility and Pricing for Equity Options
# 71         other83                      Insider Transaction Analytics
# 68         other47                              Web Intelligence Data
# 30         macro27                       Job records from job posting
# 31          macro4                           Macroeconomic Indicators
# 51          news23                                     MnA Deals Data
# 65        other452                                  Earnings Tax Data
# 56          news76                             Textual News Feed Data
# 82  shortinterest2                               Short Interest Model
# 77            pv37                               Equity Interval Data
# 74           pv132                               Equity Warrants Data
# 66        other455                   Relationship enhanced with AI/ML
# 64        other450                     Other Multi-Factor Risk Models
# 62        other351         International sentiment analysis NLP model
# 59         option4  Implied Volatility and Pricing for Equity Options
# 0        analyst11                                         ESG scores
# 57          news87              Smart Conference call transcript data
# 7        analyst40                   Information on board of director
# 54          news54                                Newa analystic data
# 53          news52                               Conference call data
# 52           news3                      Dow Jones News Analytics Data
# 39        model211                   Analyst estimate prediction data
# 27    fundamental7                    Comprehensive Fundamentals Data
# 20   fundamental22           Environmental and Social Governance Data
# 19   fundamental21                                    ESG Scores Data
# 16    fundamental1                      Management and Executive Data
# 8        analyst44                                   Broker Estimates
# 55          news66                            Webpage View Statistics
#
#                                           description  \
# 86  Sentiment scores derived from social media. So...
# 58  Dataset based on security type and option pric...
# 71  Data of transactions carried out by the key co...
# 68  This dataset provides  budget expenditure on o...
# 30  This data set contains data found in the descr...
# 31  This dataset encompasses a comprehensive colle...
# 51  The dataset provides information on various tr...
# 65  This dataset comprehensively studies a wide ra...
# 56  The dataset is composed of different subscript...
# 82  This is a model dataset that gives short inter...
# 77  Price Volume related dataset based on assessme...
# 74  The dataset includes globally Equity Warrants ...
# 66  Grouping data. Generated using deep learning m...
# 64  The dataset consists of risk factors which can...
# 62  NLP driven predictive model dataset. GINA scor...
# 59  This dataset provides information of options p...
# 0   Environmental Social Governance scores that ex...
# 57  Conference call transcript data provides mainl...
# 7   This dataset about Boards of Directors has fou...
# 54  This dataset provides access to events & news ...
# 53  Information on company's conference call, such...
# 52  The Sentiment Analysis Engine (SAE) is a softw...
# 39  Machine learning driven predictive dataset for...
# 27  The dataset holds fundamental items included i...
# 20  This dataset provides objective, relevant and ...
# 19  This dataset has ESG scores for different ESG ...
# 16  The dataset contains information about company...
# 8   This dataset integrates the detail estimates f...
# 55  The dataset is a collection of view statistics...
#
#                                              category  \
# 86      {'id': 'socialmedia', 'name': 'Social Media'}
# 58                 {'id': 'option', 'name': 'Option'}
# 71                   {'id': 'other', 'name': 'Other'}
# 68                   {'id': 'other', 'name': 'Other'}
# 30                   {'id': 'macro', 'name': 'Macro'}
# 31                   {'id': 'macro', 'name': 'Macro'}
# 51                     {'id': 'news', 'name': 'News'}
# 65                   {'id': 'other', 'name': 'Other'}
# 56                     {'id': 'news', 'name': 'News'}
# 82  {'id': 'shortinterest', 'name': 'Short Interest'}
# 77               {'id': 'pv', 'name': 'Price Volume'}
# 74               {'id': 'pv', 'name': 'Price Volume'}
# 66                   {'id': 'other', 'name': 'Other'}
# 64                   {'id': 'other', 'name': 'Other'}
# 62                   {'id': 'other', 'name': 'Other'}
# 59                 {'id': 'option', 'name': 'Option'}
# 0                {'id': 'analyst', 'name': 'Analyst'}
# 57                     {'id': 'news', 'name': 'News'}
# 7                {'id': 'analyst', 'name': 'Analyst'}
# 54                     {'id': 'news', 'name': 'News'}
# 53                     {'id': 'news', 'name': 'News'}
# 52                     {'id': 'news', 'name': 'News'}
# 39                   {'id': 'model', 'name': 'Model'}
# 27       {'id': 'fundamental', 'name': 'Fundamental'}
# 20       {'id': 'fundamental', 'name': 'Fundamental'}
# 19       {'id': 'fundamental', 'name': 'Fundamental'}
# 16       {'id': 'fundamental', 'name': 'Fundamental'}
# 8                {'id': 'analyst', 'name': 'Analyst'}
# 55                     {'id': 'news', 'name': 'News'}
#
#                                           subcategory region  delay  universe  \
# 86  {'id': 'socialmedia-social-media', 'name': 'So...    GLB      1  MINVOL1M
# 58  {'id': 'option-option-volatility', 'name': 'Op...    GLB      1  MINVOL1M
# 71   {'id': 'other-event-data', 'name': 'Event Data'}    GLB      1  MINVOL1M
# 68  {'id': 'other-employee-data', 'name': 'Employe...    GLB      1  MINVOL1M
# 30  {'id': 'macro-macroeconomic-activities', 'name...    GLB      1  MINVOL1M
# 31  {'id': 'macro-macroeconomic-activities', 'name...    GLB      1  MINVOL1M
# 51                {'id': 'news-news', 'name': 'News'}    GLB      1  MINVOL1M
# 65  {'id': 'other-dividend-models', 'name': 'Divid...    GLB      1  MINVOL1M
# 56                {'id': 'news-news', 'name': 'News'}    GLB      1  MINVOL1M
# 82  {'id': 'shortinterest-short-sale-models', 'nam...    GLB      1  MINVOL1M
# 77  {'id': 'pv-price-volume', 'name': 'Price Volume'}    GLB      1  MINVOL1M
# 74  {'id': 'pv-price-volume', 'name': 'Price Volume'}    GLB      1  MINVOL1M
# 66    {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    GLB      1  MINVOL1M
# 64    {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    GLB      1  MINVOL1M
# 62    {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    GLB      1  MINVOL1M
# 59          {'id': 'option-option', 'name': 'Option'}    GLB      1  MINVOL1M
# 0                {'id': 'analyst-esg', 'name': 'ESG'}    GLB      1  MINVOL1M
# 57                {'id': 'news-news', 'name': 'News'}    GLB      1  MINVOL1M
# 7   {'id': 'analyst-crowdsourced-estimates', 'name...    GLB      1  MINVOL1M
# 54  {'id': 'news-news-sentiment', 'name': 'News Se...    GLB      1  MINVOL1M
# 53                {'id': 'news-news', 'name': 'News'}    GLB      1  MINVOL1M
# 52  {'id': 'news-news-sentiment', 'name': 'News Se...    GLB      1  MINVOL1M
# 39  {'id': 'model-mlai-models', 'name': 'ML/AI Mod...    GLB      1  MINVOL1M
# 27  {'id': 'fundamental-fundamental-data', 'name':...    GLB      1  MINVOL1M
# 20  {'id': 'fundamental-fundamental-models', 'name...    GLB      1  MINVOL1M
# 19  {'id': 'fundamental-fundamental-models', 'name...    GLB      1  MINVOL1M
# 16  {'id': 'fundamental-fundamental-models', 'name...    GLB      1  MINVOL1M
# 8   {'id': 'analyst-crowdsourced-estimates', 'name...    GLB      1  MINVOL1M
# 55  {'id': 'news-news-sentiment', 'name': 'News Se...    GLB      1  MINVOL1M
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 86    0.3753     None         5.0          2           3          12     []
# 58    0.4789     None         5.0          1           3           1     []
# 71    0.4802     None         5.0          9          15          15     []
# 68    0.6210     None         5.0          7          11           4     []
# 30    0.4335     None         5.0          9          22          23     []
# 31    0.0000     None         5.0          3           5           1     []
# 51    0.3279     None         5.0          3          34          28     []
# 65    0.3273     None         5.0         14          74          23     []
# 56    1.0000     None         5.0          1           6           1     []
# 82    0.3440     None         4.0         15          44           8     []
# 77    1.0000     None         4.0         13          24          80     []
# 74    0.2993     None         4.0         11          36          23     []
# 66    0.8127     None         4.0        141        1229        1500     []
# 64    0.9483     None         4.0         32         147          14     []
# 62    0.5300     None         4.0         15          46           5     []
# 59    0.6148     None         4.0         14          31           9     []
# 0     0.7917     None         4.0         66         304         197     []
# 57    0.3880     None         4.0          4           5         201     []
# 7     0.4134     None         4.0          9          46          11     []
# 54    0.7416     None         4.0          4           4           5     []
# 53    0.4275     None         4.0          4          25          24     []
# 52    0.6982     None         4.0         10          26          19     []
# 39    0.5567     None         4.0         18          98          96     []
# 27    0.3696     None         4.0         10          41         105     []
# 20    0.6312     None         4.0          3           8           1     []
# 19    0.4399     None         4.0         28          64         173     []
# 16    0.2584     None         4.0          4          19          19     []
# 8     0.8173     None         4.0         53         194         115     []
# 55    0.7449     None         4.0          4           7           2     []
#
#                                        researchPapers
# 86                                                 []
# 58                                                 []
# 71                                                 []
# 68                                                 []
# 30  [{'title': 'Research Paper 75: The Stock Marke...
# 31                                                 []
# 51                                                 []
# 65                                                 []
# 56                                                 []
# 82                                                 []
# 77                                                 []
# 74                                                 []
# 66                                                 []
# 64                                                 []
# 62                                                 []
# 59  [{'title': 'Research Paper 26: Bid and Ask Pri...
# 0   [{'title': 'Research Paper 19: ESG Preference,...
# 57                                                 []
# 7                                                  []
# 54                                                 []
# 53                                                 []
# 52                                                 []
# 39                                                 []
# 27                                                 []
# 20                                                 []
# 19                                                 []
# 16                                                 []
# 8                                                  []
# 55                                                 []

# %% [markdown]
# #### Step 2. Select the needed datafields

# %%
dataset_ids = selected_datasets_df.id.values.tolist() # create a list of selected datasets ids, our list has only one element
dataset_ids
# Out:
# ['socialmedia5',
#  'option2',
#  'other83',
#  'other47',
#  'macro27',
#  'macro4',
#  'news23',
#  'other452',
#  'news76',
#  'shortinterest2',
#  'pv37',
#  'pv132',
#  'other455',
#  'other450',
#  'other351',
#  'option4',
#  'analyst11',
#  'news87',
#  'analyst40',
#  'news54',
#  'news52',
#  'news3',
#  'model211',
#  'fundamental7',
#  'fundamental22',
#  'fundamental21',
#  'fundamental1',
#  'analyst44',
#  'news66']

# %%
selected_datafields_full = []
for dataset_id in dataset_ids:
    datafields_df = hf.get_datafields(s, region = 'GLB', universe = 'MINVOL1M', dataset_id=dataset_id)
    selected_datafields_df = datafields_df[
        (datafields_df['type'] == 'MATRIX')
    ].sort_values(by=['userCount'], ascending=False)
    selected_datafields_df_id = selected_datafields_df.id.values.tolist()
    selected_datafields_full += selected_datafields_df_id[:10]
selected_datafields_full
# Out:
# ['opt2_securitymap',
#  'mcr4_value',
#  'oth452_accrualsratio_d1_asset_change',
#  'oth452_deferred_tax_expense_11',
#  'oth452_deferred_tax_expense_31',
#  'oth452_deferred_tax_liability_11',
#  'oth452_deferred_tax_liability_12',
#  'oth452_liability_d1_mean',
#  'oth452_deferred_tax_expense_21',
#  'oth452_deferred_tax_liability_31',
#  'oth452_liability_d1_max',
#  'oth452_liability_d1_length',
#  'star_si_shortsqueeze_rank',
#  'star_si_country_rank_unadj',
#  'star_si_insown_pct',
#  'shrt2_t12m_volatility_rank',
#  'shrt2_t3m_volatility_rank',
#  'star_si_country_rank',
#  'pv37_close_global',
#  'pv37_task_mean',
#  'pv37_low_global30m',
#  'pv37_vwap_13',
#  'pv37_taks_mean',
#  'pv37_lstp_mean',
#  'pv37_volume_global2',
#  'pv37_low_13',
#  'pv37_close_global30m',
#  'pv37_close_global2h',
#  'oth455_relation_roam_w5_pca_fact3_value',
#  'oth455_relation_roam_w1_pca_fact3_value',
#  'oth455_relation_n2v_p10_q200_w1_pca_fact1_value',
#  'oth455_partner_roam_w1_pca_fact2_value',
#  'oth455_partner_n2v_p10_q50_w2_pca_fact1_value',
#  'oth455_customer_n2v_p10_q50_w5_pca_fact2_value',
#  'oth455_partner_n2v_p50_q50_w4_pca_fact3_value',
#  'oth455_competitor_n2v_p10_q200_w1_pca_fact1_value',
#  'oth455_customer_n2v_p50_q200_w4_pca_fact3_value',
#  'oth455_relation_n2v_p50_q50_w4_pca_fact2_value',
#  'oth450_mfm_gem3_dsrt',
#  'oth450_mfm_gem3_ri_earnyield',
#  'oth450_mfm_gem3_ri_momentum',
#  'oth450_mfm_gem3_ri_value',
#  'oth450_mfm_gem3_ri_growth',
#  'oth450_mfm_gem3_ri_leverage',
#  'oth450_mfm_gem3_ri_volatility',
#  'oth450_mfm_gem3_ri_size',
#  'oth450_mfm_gem3_srisk',
#  'oth450_mfm_gem3_ri_beta',
#  'oth351_score',
#  'oth351_lm_nnc',
#  'oth351_sentiment_ml',
#  'oth351_similarity10k',
#  'oth351_similarity10q',
#  'opt4_ask',
#  'opt4_secpr_volume',
#  'opt4_adjfactor',
#  'opt4_bid',
#  'opt4_retfactor',
#  'opt4_return',
#  'opt4_shareoutstanding',
#  'opt4_close',
#  'opt4_open',
#  'anl11_2_1e',
#  'anl11_2_1pme',
#  'anl11_2_gse',
#  'anl11_2_1tic',
#  'anl11_2_1g',
#  'anl11_2_3g',
#  'anl11_2_region',
#  'anl11_2_2g',
#  'anl11_citreg_industryrnk',
#  'anl11_knrtcesgere',
#  'anl40_moveout',
#  'anl40_newcount',
#  'anl40_totalchange',
#  'anl40_oldcount',
#  'anl40_addin',
#  'anl40_brdcount',
#  'anl40_netturnoverrate',
#  'anl40_turnoverrate',
#  'anl40_employmentrate',
#  'mws52_chars_in_presentation',
#  'mws52_corporate_participants',
#  'mws52_paragraphs_in_presentation',
#  'mws52_chars_in_qa',
#  'mws52_starttime',
#  'mws52_sentences_in_qa',
#  'mws52_sentences_in_presentation',
#  'mws52_questions_in_qa',
#  'mws52_questions_in_presentation',
#  'mws52_lastuptime',
#  'mdl211_delta_epsq_q2_madp',
#  'mdl211_delta_saly_y1_predict',
#  'mdl211_delta_epsq_q2_predict',
#  'mdl211_delta_salq_q4_predict',
#  'mdl211_delta_epsq_q3_madp',
#  'mdl211_delta_epsq_q1_predict',
#  'mdl211_delta_saly_y1_mae',
#  'mdl211_salq_q3_madp',
#  'mdl211_netq_q2_predict',
#  'mdl211_delta_epsq_q1_mada',
#  'fnd7_ointfund_qhctsvi',
#  'fnd7_ointfund_qhcvi',
#  'fnd7_ointfund_qqes',
#  'fnd7_ointfund_21fspe',
#  'fnd7_ointfund_qttld',
#  'fnd7_ointfund_qips',
#  'fnd7_ointfund_qtca',
#  'fnd7_ointfund_qbi',
#  'fnd7_ointfund_21speo',
#  'fnd7_ointfund_qohsc']

# %% [markdown]
# #### Step 4. Apply generate_alpha function to the expression list
# In generate alpha function you can specify region, universe, decay, delay and other simulation settings

# %% [markdown]
# 이제 만들어둔 expressions 을 사용해 alpha simulation 을 해줍니다.

# %%
#?ace.generate_alpha

# %%
expression_template = f'''
group = (country+1)*group_max(pv13_52_minvol_1m_all_delay_1_sector, market) + pv13_52_minvol_1m_all_delay_1_sector;
group_neutralize(ts_scale(group_backfill({data}, industry, 252, std=1), 252), densify(group))
'''

# %%
expressions = []
for data in selected_datafields_full:
    expressions.append(f'group = (country+1)*group_max(pv13_52_minvol_1m_all_delay_1_sector, market) + pv13_52_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill({data}, industry, 252, std=1), 252), densify(group))')

# %%
len(expressions)
# Out:
# 111

# %%
#when you send multiple alphas for simulation, please make sure all alphas of a single list should have common settings
#alphas with different settings should be sent in a different list, for instance below list has all alphas with same settings

alpha_list = [ace.generate_alpha(x, region= "GLB", universe = "MINVOL1M", neutralization = 'COUNTRY', truncation = 0.01, delay = 1, decay = 3) for x in expressions]
alpha_list[0]
# Out:
# {'type': 'REGULAR',
#  'settings': {'instrumentType': 'EQUITY',
#   'region': 'GLB',
#   'universe': 'MINVOL1M',
#   'delay': 1,
#   'decay': 3,
#   'neutralization': 'COUNTRY',
#   'truncation': 0.01,
#   'pasteurization': 'ON',
#   'testPeriod': 'P0Y0M0D',
#   'unitHandling': 'VERIFY',
#   'nanHandling': 'OFF',
#   'language': 'FASTEXPR',
#   'visualization': False},
#  'regular': 'group = (country+1)*group_max(pv13_52_minvol_1m_all_delay_1_sector, market) + pv13_52_minvol_1m_all_delay_1_sector;group_neutralize(ts_scale(group_backfill(opt2_securitymap, industry, 252, std=1), 252), densify(group))'}

# %% [markdown]
# ### Simulate alpha list, get simulation result
#
# simulate_alpha_list_multi will do a multi-simulation if list of alphas is greater than 10, which is the case here
#
# the returned object will contain simulation results for all alphas as a list

# %%
#alpha expressions are sliced to first 10 for demonstration purpose

result = ace.simulate_alpha_list_multi(s, alpha_list[20:73])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 18/18 [1:04:38<00:00, 215.49s/it]

# %% [markdown]
# 위 코드를 실행하면 시뮬레이션이 시작됩니다. 100개의 알파에 대략 1시간 정도 소요되니, 인터넷 연결이 끊기지 않게 주의하시고, 너무 많은 알파를 한 번에 돌리기보다는 몇개씩 끊어서 돌려도 좋습니다.

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   4601334   20000000        4066         3941    0.0762   0.0444    0.1188
# 1   5814975   20000000        3133         5255    0.4043   0.0562    0.0690
# 2   4804502   20000000        4073         4292    0.0501   0.0464    0.1519
# 3   4949151   20000000        3525         4866    0.1171   0.0478    0.2145
# 4   4693902   20000000        3452         4941    0.1202   0.0453    0.2135
# 5   4631501   20000000        3439         4951    0.1203   0.0447    0.2115
# 6   4656866   20000000        4037         4357    0.0855   0.0450    0.1322
# 7   2069033   20000000        4205         4184    0.0309   0.0200    0.0678
# 8   1713533   20000000        4075         4295    0.0171   0.0165    0.0661
# 9   2909273   20000000        4516         3875    0.0518   0.0281    0.1392
# 10  1269056   20000000        3404         3752    0.0352   0.0123    0.0395
# 11  2993228   20000000        3320         5071    0.1551   0.0289    0.2054
# 12  2923617   20000000        3336         5056    0.1507   0.0282    0.1983
# 13  2934497   20000000        3334         5059    0.1552   0.0283    0.2064
# 14  1239747   20000000        4250         4140    0.0318   0.0120    0.0607
# 15  2362552   20000000        2186         6201    0.3320   0.0228    0.0707
# 16  1787121   20000000        4584         3799    0.0631   0.0173    0.1400
# 17  1590129   20000000        3962         4407    0.0661   0.0154    0.1285
# 18  1644124   20000000        4658         3726    0.0634   0.0159    0.1408
# 19   997801   20000000        4201         4165    0.0818   0.0096    0.1004
# 20   809977   20000000        3997         4367    0.0184   0.0078    0.0985
# 21   777595   20000000        4307         4057    0.0799   0.0075    0.0413
# 22   717292   20000000        4288         4079    0.0818   0.0069    0.0600
# 23   698857   20000000        4195         4184    0.0236   0.0067    0.0652
# 24   747701   20000000        3625         4687    0.0419   0.0072    0.0827
# 25   371111   20000000        4678         3685    0.0197   0.0036    0.1134
# 26   301251   20000000        3671         4701    0.0444   0.0029    0.0703
# 27   282974   20000000        4232         4139    0.0142   0.0027    0.0743
# 28   397573   20000000        3318         5069    0.0873   0.0038    0.0914
# 29   122308   20000000        3727         4616    0.0576   0.0012    0.1126
# 30   106113   20000000        3922         3875    0.0534   0.0010    0.1484
# 31  -242350   20000000        4121         4246    0.0780  -0.0023    0.1260
# 32  -229674   20000000        4223         4157    0.0341  -0.0022    0.1030
# 33  -266415   20000000        4168         4200    0.0782  -0.0026    0.1250
# 34  -337697   20000000        3981         4383    0.0796  -0.0033    0.1030
# 35  -206706   20000000        4403         3957    0.0175  -0.0020    0.0696
# 36  -544753   20000000        4634         3664    0.0300  -0.0053    0.2718
# 37  -674880   20000000        4068         3729    0.0787  -0.0065    0.1987
# 38  -568900   20000000        3589         4776    0.0309  -0.0055    0.2651
# 39  -932262   20000000        4150         4241    0.0642  -0.0090    0.2487
# 40  -685807   20000000        3941         4420    0.0216  -0.0066    0.1456
# 41  -708917   20000000        4175         4191    0.0770  -0.0068    0.1474
# 42 -1521204   20000000        4179         4212    0.0775  -0.0147    0.2115
# 43  -981706   20000000        4340         4044    0.1057  -0.0095    0.1861
# 44  -830516   20000000        4235         4144    0.0223  -0.0080    0.1226
# 45  -854492   20000000        3898         4466    0.0175  -0.0083    0.1190
# 46 -1101333   20000000        5227         3140    0.0993  -0.0106    0.1846
# 47 -1377490   20000000        3306         4491    0.0827  -0.0133    0.1433
# 48 -1357683   20000000        4810         3559    0.0947  -0.0131    0.1982
# 49 -1561392   20000000        4078         4291    0.0222  -0.0151    0.1841
# 50 -1682272   20000000        4573         3804    0.0631  -0.0162    0.1761
# 51 -3367172   20000000        3968         4424    0.0598  -0.0325    0.3476
# 52 -9821538   20000000        4128         4265    0.4777  -0.0948    0.9956
#
#       margin  fitness  sharpe  start_date alpha_id  \
# 0   0.001166     0.77    1.29  2012-01-22  K90KLRp
# 1   0.000278     0.61    1.63  2012-01-22  gM6nNPJ
# 2   0.001853     0.52    0.86  2012-01-22  71AkdOx
# 3   0.000816     0.46    0.74  2012-01-22  Y06R3mw
# 4   0.000754     0.42    0.70  2012-01-22  xkqJ79N
# 5   0.000743     0.42    0.70  2012-01-22  k0dzpXL
# 6   0.001052     0.38    0.63  2012-01-22  R83J8jd
# 7   0.001294     0.31    0.78  2012-01-22  bqkYO0N
# 8   0.001938     0.28    0.76  2012-01-22  8Qomdvl
# 9   0.001084     0.28    0.60  2012-01-22  APWRXAY
# 10  0.000697     0.20    0.65  2012-01-22  L1jPRQM
# 11  0.000373     0.19    0.45  2012-01-22  an65mVv
# 12  0.000375     0.19    0.44  2012-01-22  R8MGx6d
# 13  0.000365     0.19    0.44  2012-01-22  ol7xjzE
# 14  0.000754     0.16    0.51  2012-01-22  71AkGw8
# 15  0.000137     0.14    0.55  2012-01-22  vl8W7Or
# 16  0.000547     0.14    0.38  2012-01-22  VP9vQr0
# 17  0.000464     0.13    0.36  2012-01-22  e0plM1N
# 18  0.000501     0.12    0.35  2012-01-22  plXqabX
# 19  0.000236     0.12    0.42  2012-01-22  1d9YYnW
# 20  0.000849     0.09    0.35  2012-01-22  j0E5bAo
# 21  0.000188     0.09    0.36  2012-01-22  anYrgpW
# 22  0.000169     0.07    0.28  2012-01-22  Y0rPPW6
# 23  0.000571     0.07    0.32  2012-01-22  P3WJgVq
# 24  0.000345     0.06    0.25  2012-01-22  R83Jx9a
# 25  0.000364     0.03    0.16  2012-01-22  QVJ1LKQ
# 26  0.000131     0.02    0.13  2012-01-22  e0plMME
# 27  0.000384     0.02    0.15  2012-01-22  j0E5be5
# 28  0.000088     0.02    0.14  2012-01-22  e0plaMM
# 29  0.000041     0.00    0.05  2012-01-22  APWRxpQ
# 30  0.000038     0.00    0.03  2012-01-22  wlm8e01
# 31 -0.000060    -0.01   -0.10  2012-01-22  698n2WL
# 32 -0.000130    -0.02   -0.13  2012-01-22  llqLgle
# 33 -0.000066    -0.02   -0.11  2012-01-22  OZY123d
# 34 -0.000082    -0.02   -0.14  2012-01-22  n2Jp9Ol
# 35 -0.000228    -0.02   -0.12  2012-01-22  ql1KoL1
# 36 -0.000351    -0.02   -0.12  2012-01-22  OZY1E8Y
# 37 -0.000166    -0.03   -0.14  2012-01-22  wlm8er1
# 38 -0.000356    -0.03   -0.14  2012-01-22  d0X2wwx
# 39 -0.000281    -0.06   -0.22  2012-01-22  GLaqL1P
# 40 -0.000615    -0.07   -0.30  2012-01-22  QVMwRjp
# 41 -0.000178    -0.07   -0.28  2012-01-22  APW11aw
# 42 -0.000379    -0.10   -0.30  2012-01-22  xk6Klnw
# 43 -0.000179    -0.10   -0.36  2012-01-22  71AkPvb
# 44 -0.000720    -0.11   -0.44  2012-01-22  OZY1831
# 45 -0.000943    -0.11   -0.44  2012-01-22  vlqKV0d
# 46 -0.000214    -0.15   -0.53  2012-01-22  WGMvJnx
# 47 -0.000322    -0.16   -0.49  2012-01-22  rl3KYrJ
# 48 -0.000277    -0.20   -0.62  2012-01-22  AP9oEbg
# 49 -0.001357    -0.22   -0.63  2012-01-22  MQWjAAr
# 50 -0.000515    -0.26   -0.72  2012-01-22  8QbMX6m
# 51 -0.001087    -0.35   -0.68  2012-01-22  5ObZOn5
# 52 -0.000397    -1.24   -2.78  2012-01-22  ql1KXZP
#
#                                            expression concentrated_weight  \
# 0   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 1   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 2   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 3   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 4   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 5   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 6   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 7   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 8   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 9   group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 10  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 11  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 12  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 13  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 14  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 15  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 16  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 17  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 18  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 19  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 20  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 21  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 22  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 23  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 24  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 25  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 26  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 27  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 28  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 29  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 30  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 31  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 32  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 33  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 34  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 35  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 36  group = (country+1)*group_max(pv13_52_minvol_1...                FAIL
# 37  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 38  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 39  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 40  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 41  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 42  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 43  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 44  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 45  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 46  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 47  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 48  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 49  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 50  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 51  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
# 52  group = (country+1)*group_max(pv13_52_minvol_1...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       PASS
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
# 14          PASS             FAIL        FAIL       FAIL
# 15          PASS             FAIL        FAIL       FAIL
# 16          PASS             FAIL        FAIL       FAIL
# 17          PASS             FAIL        FAIL       FAIL
# 18          PASS             FAIL        FAIL       FAIL
# 19          PASS             FAIL        FAIL       FAIL
# 20          PASS             FAIL        FAIL       FAIL
# 21          PASS             FAIL        FAIL       FAIL
# 22          PASS             FAIL        FAIL       FAIL
# 23          PASS             FAIL        FAIL       FAIL
# 24          PASS             FAIL        FAIL       FAIL
# 25          PASS             FAIL        FAIL       FAIL
# 26          PASS             FAIL        FAIL       FAIL
# 27          PASS             FAIL        FAIL       FAIL
# 28          PASS             FAIL        FAIL       FAIL
# 29          PASS             FAIL        FAIL       FAIL
# 30          PASS             FAIL        FAIL       FAIL
# 31          PASS             FAIL        FAIL       FAIL
# 32          PASS             FAIL        FAIL       FAIL
# 33          PASS             FAIL        FAIL       FAIL
# 34          PASS             FAIL        FAIL       FAIL
# 35          PASS             FAIL        FAIL       FAIL
# 36          PASS             FAIL        FAIL       FAIL
# 37          PASS             FAIL        FAIL       FAIL
# 38          PASS             FAIL        FAIL       FAIL
# 39          PASS             FAIL        FAIL       FAIL
# 40          PASS             FAIL        FAIL       FAIL
# 41          PASS             FAIL        FAIL       FAIL
# 42          PASS             FAIL        FAIL       FAIL
# 43          PASS             FAIL        FAIL       FAIL
# 44          PASS             FAIL        FAIL       FAIL
# 45          PASS             FAIL        FAIL       FAIL
# 46          PASS             FAIL        FAIL       FAIL
# 47          PASS             FAIL        FAIL       FAIL
# 48          PASS             FAIL        FAIL       FAIL
# 49          PASS             FAIL        FAIL       FAIL
# 50          PASS             FAIL        FAIL       FAIL
# 51          PASS             FAIL        FAIL       FAIL
# 52          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover
# 0                     PASS         PASS
# 1                     PASS         PASS
# 2                     PASS         PASS
# 3                     FAIL         PASS
# 4                     PASS         PASS
# 5                     PASS         PASS
# 6                     FAIL         PASS
# 7                     PASS         PASS
# 8                     PASS         PASS
# 9                     FAIL         PASS
# 10                    PASS         PASS
# 11                    FAIL         PASS
# 12                    FAIL         PASS
# 13                    FAIL         PASS
# 14                    FAIL         PASS
# 15                    PASS         PASS
# 16                    PASS         PASS
# 17                    FAIL         PASS
# 18                    PASS         PASS
# 19                    PASS         PASS
# 20                    PASS         PASS
# 21                    PASS         PASS
# 22                    PASS         PASS
# 23                    FAIL         PASS
# 24                    PASS         PASS
# 25                    FAIL         PASS
# 26                    FAIL         PASS
# 27                    FAIL         PASS
# 28                    FAIL         PASS
# 29                    FAIL         PASS
# 30                    PASS         PASS
# 31                    FAIL         PASS
# 32                    FAIL         PASS
# 33                    PASS         PASS
# 34                    PASS         PASS
# 35                    FAIL         PASS
# 36                    FAIL         PASS
# 37                    PASS         PASS
# 38                    FAIL         PASS
# 39                    PASS         PASS
# 40                    FAIL         PASS
# 41                    PASS         PASS
# 42                    PASS         PASS
# 43                    FAIL         PASS
# 44                    PASS         PASS
# 45                    FAIL         PASS
# 46                    PASS         PASS
# 47                    FAIL         PASS
# 48                    PASS         PASS
# 49                    FAIL         PASS
# 50                    PASS         PASS
# 51                    PASS         PASS
# 52                    FAIL         PASS

# %% [markdown]
# prettify 함수를 이용해 dataframe 형식으로 변환하면 결과를 보기 더 편합니다.

# %%
result_st1.to_csv('2024_09_013_GLB.csv')

# %% [markdown]
# ### How to submit?
#
# Create a list of submittable alphas - alphas that have no FAIL in is_tests

# %% [markdown]
# 시뮬레이션을 마친 알파 중 제출 가능한 알파들을 제출해 봅시다.

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df
# Out:
#     alpha_id date     endDate  limit message                 name   result  \
# 0    xkqJ79N  NaN         NaN   1.58     NaN           LOW_SHARPE     FAIL
# 1    xkqJ79N  NaN         NaN   1.00     NaN          LOW_FITNESS     FAIL
# 2    xkqJ79N  NaN         NaN   0.01     NaN         LOW_TURNOVER     PASS
# 3    xkqJ79N  NaN         NaN   0.70     NaN        HIGH_TURNOVER     PASS
# 4    xkqJ79N  NaN         NaN    NaN     NaN  CONCENTRATED_WEIGHT     PASS
# ..       ...  ...         ...    ...     ...                  ...      ...
# 691  WGMvJnx  NaN         NaN    NaN     NaN       DATA_DIVERSITY  PENDING
# 692  WGMvJnx  NaN         NaN    NaN     NaN     PROD_CORRELATION  PENDING
# 693  WGMvJnx  NaN         NaN    NaN     NaN   REGULAR_SUBMISSION  PENDING
# 694  WGMvJnx  NaN  2020-01-25   1.58     NaN     IS_LADDER_SHARPE     FAIL
# 695  WGMvJnx  NaN         NaN    NaN     NaN       MATCHES_THEMES  WARNING
#
#       startDate                                             themes   value  \
# 0           NaN                                                NaN  0.7000
# 1           NaN                                                NaN  0.4200
# 2           NaN                                                NaN  0.1202
# 3           NaN                                                NaN  0.1202
# 4           NaN                                                NaN     NaN
# ..          ...                                                ...     ...
# 691         NaN                                                NaN     NaN
# 692         NaN                                                NaN     NaN
# 693         NaN                                                NaN     NaN
# 694  2022-01-24                                                NaN -2.5700
# 695         NaN  [{'id': 'WBlNe4R', 'multiplier': 3.0, 'name': ...     NaN
#
#      year
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 691   NaN
# 692   NaN
# 693   NaN
# 694   2.0
# 695   NaN
#
# [696 rows x 11 columns]

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['xkqJ79N' 'k0dzpXL' 'QVMwRjp' 'Y06R3mw' 'gM6nNPJ' 'ol7xjzE' 'R8MGx6d'
#  'an65mVv' 'vl8W7Or' 'j0E5bAo' 'OZY1E8Y' 'QVJ1LKQ' 'j0E5be5' '8Qomdvl'
#  'ql1KoL1' 'd0X2wwx' 'MQWjAAr' 'vlqKV0d' 'ql1KXZP' 'K90KLRp' '71AkdOx'
#  'wlm8er1' 'L1jPRQM' 'wlm8e01' 'GLaqL1P' 'R83J8jd' '5ObZOn5' 'bqkYO0N'
#  'OZY1831' 'P3WJgVq' 'plXqabX' 'e0plaMM' 'APWRxpQ' 'xk6Klnw' '71AkGw8'
#  'llqLgle' '698n2WL' 'anYrgpW' 'OZY123d' 'e0plM1N' 'R83Jx9a' '71AkPvb'
#  'e0plMME' 'VP9vQr0' 'APWRXAY' 'APW11aw' 'Y0rPPW6' '1d9YYnW' 'AP9oEbg'
#  '8QbMX6m' 'rl3KYrJ' 'n2Jp9Ol' 'WGMvJnx']
# Passed alphas:[]

# %%
for alpha_id in ['ad59v2O', 'k3z6qqk', 'Lp0YPva', '9wNOzNr', '7weR901', '6w5Ln6E', 'QawpLe5', '17rAQ6m', '273obEY', 'xxJpKLg', 'Wpv2EZo', 'm8EWMk1']:
    hf.set_alpha_properties(s, alpha_id, tags = ['pass_Sep07_mixing'])

# %%
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['Sep07_GLB'])

# %% [markdown]
# 위 함수로 통과한 알파들에 태그를 붙일 수 있습니다.

# %% [markdown]
# When you got a list of submittable alphas, you can call function submit_alpha()

# %%
#calling submit_alpha on all alphas that have passed the submission tests

submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas}

# %% [markdown]
# 위 함수로 알파를 제출할 수 있습니다.

# %% [markdown]
# 알파의 id 로 제출하는 것이기 때문에, 그 알파를 시뮬레이션 한 날짜가 중요합니다. 가령, 1주일 전에 시뮬레이션 해 결과를 저장해 두었던 alpha id로 제출을 한다면 제출 날짜가 1주일 전이 됩니다. 그러니 오늘 제출하고 싶은 alpha 가 있다면 시뮬레이션을 다시 돌려 새로 생긴 alpha id 를 이용해야 합니다. 이 과정은 alpha 에 특정 태그를 달아 Brain 플랫폼에서 직접 하는게 훨씬 수월합니다. (다만, 플랫폼에서는 alpha id 로 알파를 검색할 수 없습니다.)

# %%
#submit_result will have return values from the submit_result function

submit_result
# Out:
# {'ZpO36rQ': False}

# %% [markdown]
# 주의하셔야 하실 점은, 하루 최대 알파 제출 한도인 4개를 루프중에 이미 넘기면 그 뒤의 알파들이 제출 가능하더라도 자동으로 제출에 실패하게 됩니다.

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance

# %% [markdown]
# 유용한 추가 함수들입니다. prod correlation 혹은 self correlation 만을 확인하고 싶을 때, 혹은 알파의 pnl 을 확인하고 싶을때 유용히 쓰입니다.
