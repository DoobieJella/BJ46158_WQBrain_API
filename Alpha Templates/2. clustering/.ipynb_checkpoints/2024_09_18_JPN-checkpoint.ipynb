# %% [markdown]
# ### Import library

# %%
import os
os.chdir('../../')
os.getcwd()
# Out:
# 'C:\\Users\\csia7\\OneDrive\\문서\\GitHub\\BJ46158_WQBrain_API'

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px
import pygwalker as pyg
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_TiBtqVA8fP7UszQzKkoJ1v28tZUm

# %% [markdown]
# ## Global region Alpha Template

# %%
expression_template = f'''
group = (country+1)*group_max(pv13_52_minvol_1m_all_delay_1_sector, market) + pv13_52_minvol_1m_all_delay_1_sector;
group_neutralize(ts_scale(group_backfill(fnd23_intfvalld1_ecns, industry, 252, std=1), 252), densify(group))
'''

# %% [markdown]
# #### Step 1. Download datsets

# %%
datasets_df = hf.get_datasets(s, region = 'JPN', universe = 'TOP1600') # by default we load all datasets USA TOP3000 delay 1    , region='GLB', universe='MINVOL1M'
datasets_df # DataFrame.head() shows first 5 rows of the dataframe
# Out:
#                 id                                  name  \
# 0        analyst14       Estimations of Key Fundamentals
# 1        analyst15                    Earnings forecasts
# 2        analyst16                   Real Time Estimates
# 3        analyst39  Analyst estimates & financial ratios
# 4         analyst4      Analyst Estimate Data for Equity
# ..             ...                                   ...
# 95          risk60       Securities Lending Insight Data
# 96          risk70                    Multi-Factor Model
# 97  shortinterest3         Securities Lending Files Data
# 98  shortinterest6                   SmartHoldings Model
# 99           univ1                      Universe Dataset
#
#                                           description  \
# 0   This dataset reports many items from financial...
# 1   This dataset provides bottom-up forecast data ...
# 2   This dataset provides real-time access to the ...
# 3   This dataset provides a lot of information on ...
# 4   This dataset provides details and aggregations...
# ..                                                ...
# 95  The dataset provides list of metrics, covering...
# 96  The dataset publishes risk factors which can b...
# 97  The data consists of loans of securities by le...
# 98  This dataset is a global stock selection model...
# 99                             No dataset description
#
#                                              category  \
# 0                {'id': 'analyst', 'name': 'Analyst'}
# 1                {'id': 'analyst', 'name': 'Analyst'}
# 2                {'id': 'analyst', 'name': 'Analyst'}
# 3                {'id': 'analyst', 'name': 'Analyst'}
# 4                {'id': 'analyst', 'name': 'Analyst'}
# ..                                                ...
# 95                     {'id': 'risk', 'name': 'Risk'}
# 96                     {'id': 'risk', 'name': 'Risk'}
# 97  {'id': 'shortinterest', 'name': 'Short Interest'}
# 98  {'id': 'shortinterest', 'name': 'Short Interest'}
# 99               {'id': 'pv', 'name': 'Price Volume'}
#
#                                           subcategory region  delay universe  \
# 0   {'id': 'analyst-analyst-estimates', 'name': 'A...    JPN      1  TOP1600
# 1   {'id': 'analyst-analyst-estimates', 'name': 'A...    JPN      1  TOP1600
# 2   {'id': 'analyst-crowdsourced-estimates', 'name...    JPN      1  TOP1600
# 3                {'id': 'analyst-esg', 'name': 'ESG'}    JPN      1  TOP1600
# 4   {'id': 'analyst-analyst-estimates', 'name': 'A...    JPN      1  TOP1600
# ..                                                ...    ...    ...      ...
# 95  {'id': 'risk-risk-models', 'name': 'Risk Models'}    JPN      1  TOP1600
# 96  {'id': 'risk-risk-factors', 'name': 'Risk Fact...    JPN      1  TOP1600
# 97  {'id': 'shortinterest-short-sale-models', 'nam...    JPN      1  TOP1600
# 98  {'id': 'shortinterest-short-sale-models', 'nam...    JPN      1  TOP1600
# 99  {'id': 'pv-price-volume', 'name': 'Price Volume'}    JPN      1  TOP1600
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 0     0.4792     None         4.0         34         144         167     []
# 1     0.8486     None         3.0         80         728         288     []
# 2     0.6375     None         5.0          9          62          71     []
# 3     0.7532     None         4.0         41         118          18     []
# 4     0.5812     None         4.0         48         168         112     []
# ..       ...      ...         ...        ...         ...         ...    ...
# 95    0.9727     None         6.0          1           1           4     []
# 96    0.8948     None         5.0         15          51          58     []
# 97    0.9537     None         5.0          2           2           2     []
# 98    0.8210     None         5.0          4          17          11     []
# 99    0.8750     None         7.0          0           0           2     []
#
#                                        researchPapers
# 0   [{'title': 'Research Paper 10: Investor Learni...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [{'title': 'Research Paper 46: Time-Series and...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
# [100 rows x 16 columns]

# %%
# select needed datasets
selected_datasets_df = datasets_df[
    (datasets_df["valueScore"] > 4) &
    (datasets_df["userCount"] > 3) 
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df
# Out:
#                 id                                         name  \
# 83          other7                            Archive News Data
# 12         broker1                                      Broker1
# 79        other455             Relationship enhanced with AI/ML
# 78        other452                            Earnings Tax Data
# 2        analyst16                          Real Time Estimates
# 58          news48                       Global Media News Data
# 96          risk70                           Multi-Factor Model
# 85         other78            Earnings and conference call data
# 81        other515                      Fund Short Selling Data
# 75        other428                                     Other428
# 71        other395                 Accrual based Earnings Model
# 69        other323                 Global Equity Premarket Data
# 63           news7                     Real Time News Feed Data
# 60          news54                        Key Developments Data
# 59          news50                      Web News Analytics Data
# 56          news38                     News Analytic Model Data
# 5        analyst44                  Integrated Broker Estimates
# 53          news31                   News Analytics on Equities
# 52           news3                Dow Jones News Analytics Data
# 48          news20              Web Sources News Sentiment Data
# 47          news18                          Ravenpack News Data
# 46          news17                              PR Edition Data
# 39         model33                       Revenue Estimate Model
# 30        model176                  Non-Financial Metric Models
# 29         model16                           Fundamental Scores
# 25        model106                        Analysts rating model
# 11        analyst9                  Analyst Estimate Daily Data
# 8        analyst47  Alternative Analyst Investment Insight Data
# 6        analyst45                          Analyst Trade Ideas
# 98  shortinterest6                          SmartHoldings Model
#
#                                           description  \
# 83  New streaming and archive data for Benzinga, M...
# 12                             No dataset description
# 79  Grouping data. Generated using deep learning m...
# 78  This dataset comprehensively studies a wide ra...
# 2   This dataset provides real-time access to the ...
# 58  The dataset provides news and information from...
# 96  The dataset publishes risk factors which can b...
# 85  Contains records of questions and answers from...
# 81  The dataset provides fund-by-fund short sellin...
# 75                             No dataset description
# 71  Uses an accrual based approach in analyzing th...
# 69  The dataset captures company information, mark...
# 63  Combines various text new feeds from multiple ...
# 60  This dataset provides access to events & news ...
# 59  Analyze articles/news from leading publishers ...
# 56  The dataset provides datafields from news anal...
# 5   This dataset integrates the detail estimates f...
# 53  This dataset provides real-time news and its n...
# 52  The Sentiment Analysis Engine (SAE) is a softw...
# 48  This dataset provides real-time structured sen...
# 47  This dataset provides news sentiment and other...
# 46  Dataset which analyzes news and information fr...
# 39  Revenue is the money generated from normal bus...
# 30  Ratings that quantify non-financial statement ...
# 29  This dataset ranks stocks based on fundamental...
# 25  The dataset provides ratings and evaluations r...
# 11                            estimation from analyst
# 8   The dataset incorporates the investment insigh...
# 6   This dataset contains analyst trade ideas. Tra...
# 98  This dataset is a global stock selection model...
#
#                                              category  \
# 83                   {'id': 'other', 'name': 'Other'}
# 12                 {'id': 'broker', 'name': 'Broker'}
# 79                   {'id': 'other', 'name': 'Other'}
# 78                   {'id': 'other', 'name': 'Other'}
# 2                {'id': 'analyst', 'name': 'Analyst'}
# 58                     {'id': 'news', 'name': 'News'}
# 96                     {'id': 'risk', 'name': 'Risk'}
# 85                   {'id': 'other', 'name': 'Other'}
# 81                   {'id': 'other', 'name': 'Other'}
# 75                   {'id': 'other', 'name': 'Other'}
# 71                   {'id': 'other', 'name': 'Other'}
# 69                   {'id': 'other', 'name': 'Other'}
# 63                     {'id': 'news', 'name': 'News'}
# 60                     {'id': 'news', 'name': 'News'}
# 59                     {'id': 'news', 'name': 'News'}
# 56                     {'id': 'news', 'name': 'News'}
# 5                {'id': 'analyst', 'name': 'Analyst'}
# 53                     {'id': 'news', 'name': 'News'}
# 52                     {'id': 'news', 'name': 'News'}
# 48                     {'id': 'news', 'name': 'News'}
# 47                     {'id': 'news', 'name': 'News'}
# 46                     {'id': 'news', 'name': 'News'}
# 39                   {'id': 'model', 'name': 'Model'}
# 30                   {'id': 'model', 'name': 'Model'}
# 29                   {'id': 'model', 'name': 'Model'}
# 25                   {'id': 'model', 'name': 'Model'}
# 11               {'id': 'analyst', 'name': 'Analyst'}
# 8                {'id': 'analyst', 'name': 'Analyst'}
# 6                {'id': 'analyst', 'name': 'Analyst'}
# 98  {'id': 'shortinterest', 'name': 'Short Interest'}
#
#                                           subcategory region  delay universe  \
# 83   {'id': 'other-event-data', 'name': 'Event Data'}    JPN      1  TOP1600
# 12  {'id': 'broker-broker-estimates', 'name': 'Bro...    JPN      1  TOP1600
# 79    {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    JPN      1  TOP1600
# 78  {'id': 'other-dividend-models', 'name': 'Divid...    JPN      1  TOP1600
# 2   {'id': 'analyst-crowdsourced-estimates', 'name...    JPN      1  TOP1600
# 58  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 96  {'id': 'risk-risk-factors', 'name': 'Risk Fact...    JPN      1  TOP1600
# 85   {'id': 'other-event-data', 'name': 'Event Data'}    JPN      1  TOP1600
# 81    {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    JPN      1  TOP1600
# 75   {'id': 'other-event-data', 'name': 'Event Data'}    JPN      1  TOP1600
# 71  {'id': 'other-dividend-models', 'name': 'Divid...    JPN      1  TOP1600
# 69  {'id': 'other-dividend-models', 'name': 'Divid...    JPN      1  TOP1600
# 63                {'id': 'news-news', 'name': 'News'}    JPN      1  TOP1600
# 60  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 59  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 56                {'id': 'news-news', 'name': 'News'}    JPN      1  TOP1600
# 5   {'id': 'analyst-crowdsourced-estimates', 'name...    JPN      1  TOP1600
# 53                {'id': 'news-news', 'name': 'News'}    JPN      1  TOP1600
# 52  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 48  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 47  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 46                {'id': 'news-news', 'name': 'News'}    JPN      1  TOP1600
# 39  {'id': 'model-estimates-models', 'name': 'Esti...    JPN      1  TOP1600
# 30  {'id': 'model-consumer-models', 'name': 'Consu...    JPN      1  TOP1600
# 29  {'id': 'model-valuation-models', 'name': 'Valu...    JPN      1  TOP1600
# 25  {'id': 'model-estimates-models', 'name': 'Esti...    JPN      1  TOP1600
# 11  {'id': 'analyst-analyst-estimates', 'name': 'A...    JPN      1  TOP1600
# 8   {'id': 'analyst-crowdsourced-estimates', 'name...    JPN      1  TOP1600
# 6   {'id': 'analyst-analyst-estimates', 'name': 'A...    JPN      1  TOP1600
# 98  {'id': 'shortinterest-short-sale-models', 'nam...    JPN      1  TOP1600
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 83    0.7530     None         6.0          4           7          11     []
# 12    0.5841     None         6.0          4           8           4     []
# 79    0.4670     None         6.0         14         125        1125     []
# 78    0.5283     None         6.0          4          16          36     []
# 2     0.6375     None         5.0          9          62          71     []
# 58    0.4880     None         5.0          4           9          15     []
# 96    0.8948     None         5.0         15          51          58     []
# 85    0.5068     None         5.0          8          18           9     []
# 81    0.2803     None         5.0          6          17          24     []
# 75    0.5851     None         5.0         11          47          13     []
# 71    0.5008     None         5.0         22         145         343     []
# 69    1.0000     None         5.0         12          32           6     []
# 63    0.8253     None         5.0          7          23          30     []
# 60    0.5239     None         5.0          4           6          14     []
# 59    0.7977     None         5.0          5          26          37     []
# 56    0.7966     None         5.0          4          14          34     []
# 5     0.6457     None         5.0         12         138         175     []
# 53    0.7835     None         5.0          4          11          25     []
# 52    0.7685     None         5.0          4           6          19     []
# 48    0.5631     None         5.0          4           8          20     []
# 47    0.6115     None         5.0          9          46          35     []
# 46    0.5143     None         5.0          4           8          17     []
# 39    0.5578     None         5.0          6          12          14     []
# 30    0.4350     None         5.0          7          62          39     []
# 29    0.4295     None         5.0          4           7           8     []
# 25    0.3758     None         5.0          4           6          14     []
# 11    0.7107     None         5.0          5          14          36     []
# 8     0.5449     None         5.0          5           7          10     []
# 6     0.5265     None         5.0          6          64          82     []
# 98    0.8210     None         5.0          4          17          11     []
#
#                                        researchPapers
# 83                                                 []
# 12                                                 []
# 79                                                 []
# 78                                                 []
# 2                                                  []
# 58                                                 []
# 96                                                 []
# 85                                                 []
# 81                                                 []
# 75                                                 []
# 71                                                 []
# 69                                                 []
# 63  [{'title': 'Research Paper 25: The Momentum of...
# 60                                                 []
# 59                                                 []
# 56                                                 []
# 5                                                  []
# 53                                                 []
# 52                                                 []
# 48                                                 []
# 47  [{'title': 'Research Paper 55: Implied Equity ...
# 46                                                 []
# 39                                                 []
# 30                                                 []
# 29  [{'title': 'Research Paper 01: The Momentum of...
# 25  [{'title': 'Research Paper 03: Currency and St...
# 11  [{'title': 'Research Paper 33: Using Abnormal ...
# 8                                                  []
# 6                                                  []
# 98                                                 []

# %%
# select needed datasets
selected_datasets_df_group = datasets_df[
    (datasets_df["valueScore"] > 4) &
    (datasets_df["userCount"] > 3) 
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df_group
# Out:
#                 id                                         name  \
# 83          other7                            Archive News Data
# 12         broker1                                      Broker1
# 79        other455             Relationship enhanced with AI/ML
# 78        other452                            Earnings Tax Data
# 2        analyst16                          Real Time Estimates
# 58          news48                       Global Media News Data
# 96          risk70                           Multi-Factor Model
# 85         other78            Earnings and conference call data
# 81        other515                      Fund Short Selling Data
# 75        other428                                     Other428
# 71        other395                 Accrual based Earnings Model
# 69        other323                 Global Equity Premarket Data
# 63           news7                     Real Time News Feed Data
# 60          news54                        Key Developments Data
# 59          news50                      Web News Analytics Data
# 56          news38                     News Analytic Model Data
# 5        analyst44                  Integrated Broker Estimates
# 53          news31                   News Analytics on Equities
# 52           news3                Dow Jones News Analytics Data
# 48          news20              Web Sources News Sentiment Data
# 47          news18                          Ravenpack News Data
# 46          news17                              PR Edition Data
# 39         model33                       Revenue Estimate Model
# 30        model176                  Non-Financial Metric Models
# 29         model16                           Fundamental Scores
# 25        model106                        Analysts rating model
# 11        analyst9                  Analyst Estimate Daily Data
# 8        analyst47  Alternative Analyst Investment Insight Data
# 6        analyst45                          Analyst Trade Ideas
# 98  shortinterest6                          SmartHoldings Model
#
#                                           description  \
# 83  New streaming and archive data for Benzinga, M...
# 12                             No dataset description
# 79  Grouping data. Generated using deep learning m...
# 78  This dataset comprehensively studies a wide ra...
# 2   This dataset provides real-time access to the ...
# 58  The dataset provides news and information from...
# 96  The dataset publishes risk factors which can b...
# 85  Contains records of questions and answers from...
# 81  The dataset provides fund-by-fund short sellin...
# 75                             No dataset description
# 71  Uses an accrual based approach in analyzing th...
# 69  The dataset captures company information, mark...
# 63  Combines various text new feeds from multiple ...
# 60  This dataset provides access to events & news ...
# 59  Analyze articles/news from leading publishers ...
# 56  The dataset provides datafields from news anal...
# 5   This dataset integrates the detail estimates f...
# 53  This dataset provides real-time news and its n...
# 52  The Sentiment Analysis Engine (SAE) is a softw...
# 48  This dataset provides real-time structured sen...
# 47  This dataset provides news sentiment and other...
# 46  Dataset which analyzes news and information fr...
# 39  Revenue is the money generated from normal bus...
# 30  Ratings that quantify non-financial statement ...
# 29  This dataset ranks stocks based on fundamental...
# 25  The dataset provides ratings and evaluations r...
# 11                            estimation from analyst
# 8   The dataset incorporates the investment insigh...
# 6   This dataset contains analyst trade ideas. Tra...
# 98  This dataset is a global stock selection model...
#
#                                              category  \
# 83                   {'id': 'other', 'name': 'Other'}
# 12                 {'id': 'broker', 'name': 'Broker'}
# 79                   {'id': 'other', 'name': 'Other'}
# 78                   {'id': 'other', 'name': 'Other'}
# 2                {'id': 'analyst', 'name': 'Analyst'}
# 58                     {'id': 'news', 'name': 'News'}
# 96                     {'id': 'risk', 'name': 'Risk'}
# 85                   {'id': 'other', 'name': 'Other'}
# 81                   {'id': 'other', 'name': 'Other'}
# 75                   {'id': 'other', 'name': 'Other'}
# 71                   {'id': 'other', 'name': 'Other'}
# 69                   {'id': 'other', 'name': 'Other'}
# 63                     {'id': 'news', 'name': 'News'}
# 60                     {'id': 'news', 'name': 'News'}
# 59                     {'id': 'news', 'name': 'News'}
# 56                     {'id': 'news', 'name': 'News'}
# 5                {'id': 'analyst', 'name': 'Analyst'}
# 53                     {'id': 'news', 'name': 'News'}
# 52                     {'id': 'news', 'name': 'News'}
# 48                     {'id': 'news', 'name': 'News'}
# 47                     {'id': 'news', 'name': 'News'}
# 46                     {'id': 'news', 'name': 'News'}
# 39                   {'id': 'model', 'name': 'Model'}
# 30                   {'id': 'model', 'name': 'Model'}
# 29                   {'id': 'model', 'name': 'Model'}
# 25                   {'id': 'model', 'name': 'Model'}
# 11               {'id': 'analyst', 'name': 'Analyst'}
# 8                {'id': 'analyst', 'name': 'Analyst'}
# 6                {'id': 'analyst', 'name': 'Analyst'}
# 98  {'id': 'shortinterest', 'name': 'Short Interest'}
#
#                                           subcategory region  delay universe  \
# 83   {'id': 'other-event-data', 'name': 'Event Data'}    JPN      1  TOP1600
# 12  {'id': 'broker-broker-estimates', 'name': 'Bro...    JPN      1  TOP1600
# 79    {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    JPN      1  TOP1600
# 78  {'id': 'other-dividend-models', 'name': 'Divid...    JPN      1  TOP1600
# 2   {'id': 'analyst-crowdsourced-estimates', 'name...    JPN      1  TOP1600
# 58  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 96  {'id': 'risk-risk-factors', 'name': 'Risk Fact...    JPN      1  TOP1600
# 85   {'id': 'other-event-data', 'name': 'Event Data'}    JPN      1  TOP1600
# 81    {'id': 'other-aiml-data', 'name': 'AI/ML Data'}    JPN      1  TOP1600
# 75   {'id': 'other-event-data', 'name': 'Event Data'}    JPN      1  TOP1600
# 71  {'id': 'other-dividend-models', 'name': 'Divid...    JPN      1  TOP1600
# 69  {'id': 'other-dividend-models', 'name': 'Divid...    JPN      1  TOP1600
# 63                {'id': 'news-news', 'name': 'News'}    JPN      1  TOP1600
# 60  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 59  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 56                {'id': 'news-news', 'name': 'News'}    JPN      1  TOP1600
# 5   {'id': 'analyst-crowdsourced-estimates', 'name...    JPN      1  TOP1600
# 53                {'id': 'news-news', 'name': 'News'}    JPN      1  TOP1600
# 52  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 48  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 47  {'id': 'news-news-sentiment', 'name': 'News Se...    JPN      1  TOP1600
# 46                {'id': 'news-news', 'name': 'News'}    JPN      1  TOP1600
# 39  {'id': 'model-estimates-models', 'name': 'Esti...    JPN      1  TOP1600
# 30  {'id': 'model-consumer-models', 'name': 'Consu...    JPN      1  TOP1600
# 29  {'id': 'model-valuation-models', 'name': 'Valu...    JPN      1  TOP1600
# 25  {'id': 'model-estimates-models', 'name': 'Esti...    JPN      1  TOP1600
# 11  {'id': 'analyst-analyst-estimates', 'name': 'A...    JPN      1  TOP1600
# 8   {'id': 'analyst-crowdsourced-estimates', 'name...    JPN      1  TOP1600
# 6   {'id': 'analyst-analyst-estimates', 'name': 'A...    JPN      1  TOP1600
# 98  {'id': 'shortinterest-short-sale-models', 'nam...    JPN      1  TOP1600
#
#     coverage turnover  valueScore  userCount  alphaCount  fieldCount themes  \
# 83    0.7530     None         6.0          4           7          11     []
# 12    0.5841     None         6.0          4           8           4     []
# 79    0.4670     None         6.0         14         125        1125     []
# 78    0.5283     None         6.0          4          16          36     []
# 2     0.6375     None         5.0          9          62          71     []
# 58    0.4880     None         5.0          4           9          15     []
# 96    0.8948     None         5.0         15          51          58     []
# 85    0.5068     None         5.0          8          18           9     []
# 81    0.2803     None         5.0          6          17          24     []
# 75    0.5851     None         5.0         11          47          13     []
# 71    0.5008     None         5.0         22         145         343     []
# 69    1.0000     None         5.0         12          32           6     []
# 63    0.8253     None         5.0          7          23          30     []
# 60    0.5239     None         5.0          4           6          14     []
# 59    0.7977     None         5.0          5          26          37     []
# 56    0.7966     None         5.0          4          14          34     []
# 5     0.6457     None         5.0         12         138         175     []
# 53    0.7835     None         5.0          4          11          25     []
# 52    0.7685     None         5.0          4           6          19     []
# 48    0.5631     None         5.0          4           8          20     []
# 47    0.6115     None         5.0          9          46          35     []
# 46    0.5143     None         5.0          4           8          17     []
# 39    0.5578     None         5.0          6          12          14     []
# 30    0.4350     None         5.0          7          62          39     []
# 29    0.4295     None         5.0          4           7           8     []
# 25    0.3758     None         5.0          4           6          14     []
# 11    0.7107     None         5.0          5          14          36     []
# 8     0.5449     None         5.0          5           7          10     []
# 6     0.5265     None         5.0          6          64          82     []
# 98    0.8210     None         5.0          4          17          11     []
#
#                                        researchPapers
# 83                                                 []
# 12                                                 []
# 79                                                 []
# 78                                                 []
# 2                                                  []
# 58                                                 []
# 96                                                 []
# 85                                                 []
# 81                                                 []
# 75                                                 []
# 71                                                 []
# 69                                                 []
# 63  [{'title': 'Research Paper 25: The Momentum of...
# 60                                                 []
# 59                                                 []
# 56                                                 []
# 5                                                  []
# 53                                                 []
# 52                                                 []
# 48                                                 []
# 47  [{'title': 'Research Paper 55: Implied Equity ...
# 46                                                 []
# 39                                                 []
# 30                                                 []
# 29  [{'title': 'Research Paper 01: The Momentum of...
# 25  [{'title': 'Research Paper 03: Currency and St...
# 11  [{'title': 'Research Paper 33: Using Abnormal ...
# 8                                                  []
# 6                                                  []
# 98                                                 []

# %% [markdown]
# #### Step 2. Select the needed datafields

# %%
dataset_ids = selected_datasets_df.id.values.tolist() # create a list of selected datasets ids, our list has only one element
dataset_ids
# Out:
# ['other7',
#  'broker1',
#  'other455',
#  'other452',
#  'analyst16',
#  'news48',
#  'risk70',
#  'other78',
#  'other515',
#  'other428',
#  'other395',
#  'other323',
#  'news7',
#  'news54',
#  'news50',
#  'news38',
#  'analyst44',
#  'news31',
#  'news3',
#  'news20',
#  'news18',
#  'news17',
#  'model33',
#  'model176',
#  'model16',
#  'model106',
#  'analyst9',
#  'analyst47',
#  'analyst45',
#  'shortinterest6']

# %%
selected_datafields_full = []
for dataset_id in dataset_ids:
    datafields_df = hf.get_datafields(s, region = 'JPN', universe = 'TOP1600', dataset_id=dataset_id)
    selected_datafields_df = datafields_df[
        (datafields_df['type'] == 'MATRIX')
    ].sort_values(by=['userCount'], ascending=False)
    selected_datafields_df_id = selected_datafields_df.id.values.tolist()
    selected_datafields_full += selected_datafields_df_id[:10]
selected_datafields_full
# Out:
# ['oth455_relation_roam_w5_pca_fact3_value',
#  'oth455_relation_roam_w4_pca_fact2_value',
#  'oth455_partner_roam_w1_pca_fact1_value',
#  'oth455_relation_n2v_p10_q50_w2_pca_fact2_value',
#  'oth455_relation_n2v_p10_q50_w5_pca_fact3_value',
#  'oth455_customer_n2v_p10_q50_w5_pca_fact1_value',
#  'oth455_customer_n2v_p10_q200_w1_pca_fact3_value',
#  'oth455_relation_n2v_p10_q200_w5_pca_fact3_value',
#  'oth455_relation_n2v_p50_q50_w2_pca_fact2_value',
#  'oth455_customer_n2v_p50_q200_w1_pca_fact3_value',
#  'oth452_accruals_d1_min',
#  'oth452_liability_d1_length',
#  'oth452_accruals_d1_length',
#  'oth452_deferred_tax_expense_51',
#  'oth452_liability_d1_asset_change',
#  'oth452_expense_d1_asset_change',
#  'oth452_deferred_tax_liability_51',
#  'oth452_deferred_tax_liability_41',
#  'oth452_expense_d1_mean',
#  'oth452_deferred_tax_liability_13',
#  'rsk70_mfm2_asetrd_season',
#  'rsk70_mfm2_asetrd_dsrt',
#  'rsk70_mfm2_asetrd_shortint',
#  'rsk70_mfm2_asetrd_anlystsn',
#  'rsk70_mfm2_asetrd_cntadj',
#  'rsk70_mfm2_asetrd_momentum',
#  'rsk70_mfm2_asetrd_semicond',
#  'rsk70_mfm2_asetrd_srisk',
#  'rsk70_mfm2_asetrd_utility',
#  'rsk70_mfm2_asetrd_transprt',
#  'oth428_net_profit',
#  'oth428_dividend_per_share_fiscal_year_end',
#  'oth428_recurring_profit',
#  'oth428_operating_profit',
#  'oth428_spe',
#  'oth428_z_2q_recurring_profit',
#  'oth428_dividend_per_share_yearly_total',
#  'oth428_total_sales',
#  'oth428_z_2q_net_profit',
#  'oth428_z_2q_operating_profit',
#  'oth395_asset_41_13',
#  'oth395_best11_d1_length',
#  'oth395_asset_43_12',
#  'oth395_asset_43_23',
#  'oth395_asset_43_31',
#  'oth395_asset_58_13',
#  'oth395_jones_accrual_pct_other_14',
#  'oth395_fixed1313_d1_min',
#  'oth395_csjonesindustryother11_d1_dts',
#  'oth395_csjonesindustrymajor13_d1_length',
#  'nws7_2_d1_negative_score',
#  'nws7_newsfreq_1_d1_qerf',
#  'nws7_2_d1_negative_freq',
#  'nws7_2_d1_news_freq',
#  'nws7_2_d1_positive_freq',
#  'nws7_2_d1_positive_score',
#  'nws7_2_d1_tone_score',
#  'nws7_news_freq_qerf',
#  'rp_nip_business',
#  'rp_css_business',
#  'rp_nip_earnings',
#  'rp_ess_revenue',
#  'rp_css_earnings',
#  'rp_css_product',
#  'rp_css_revenue',
#  'rp_ess_business',
#  'rp_nip_dividends',
#  'rp_nip_product',
#  'star_rev_surprise_prediction_fy2',
#  'star_rev_analyst_number_fy1',
#  'star_rev_analyst_number_fy2',
#  'star_rev_smart_estimate_fy1',
#  'star_rev_smart_estimate_fy2',
#  'star_rev_surprise_prediction_12m',
#  'star_rev_surprise_prediction_fq1',
#  'star_rev_surprise_prediction_fy1',
#  'star_rev_analyst_number_fq1',
#  'star_rev_analyst_number_fq2',
#  'fscore_quality',
#  'fscore_growth',
#  'fscore_value',
#  'fscore_momentum',
#  'fscore_profitability',
#  'fscore_surface',
#  'fscore_surface_accel',
#  'fscore_total',
#  'mdl106_country',
#  'mdl106_rv',
#  'mdl106_stars',
#  'mdl106_dividend',
#  'mdl106_fmb',
#  'mdl106_fnb',
#  'mdl106_global_evaluation',
#  'mdl106_mkt_cap',
#  'mdl106_pr',
#  'mdl106_price',
#  'anl47_japan_d1_indicator',
#  'anl47_japan_d1_totalrawsignal',
#  'anl47_d1_indicator',
#  'anl47_d1_rawalphadecay',
#  'anl47_d1_totalrawsignal',
#  'anl47_japan_d1_rawsentiment',
#  'anl47_d1_rawexperts',
#  'anl47_d1_rawsentiment',
#  'anl47_japan_d1_rawalphadecay',
#  'anl47_japan_d1_rawexperts',
#  'star_hold_country_rank',
#  'star_hold_global_owner_rank',
#  'star_hold_global_rank',
#  'star_hold_global_screening_rank',
#  'star_hold_region_owner_rank',
#  'star_hold_global_change_rank',
#  'star_hold_industry_rank',
#  'star_hold_region_change_rank',
#  'star_hold_region_rank',
#  'star_hold_region_screening_rank']

# %%
dataset_group_ids = selected_datasets_df_group.id.values.tolist() # create a list of selected datasets ids, our list has only one element
dataset_group_ids
# Out:
# ['other7',
#  'broker1',
#  'other455',
#  'other452',
#  'analyst16',
#  'news48',
#  'risk70',
#  'other78',
#  'other515',
#  'other428',
#  'other395',
#  'other323',
#  'news7',
#  'news54',
#  'news50',
#  'news38',
#  'analyst44',
#  'news31',
#  'news3',
#  'news20',
#  'news18',
#  'news17',
#  'model33',
#  'model176',
#  'model16',
#  'model106',
#  'analyst9',
#  'analyst47',
#  'analyst45',
#  'shortinterest6']

# %%
selected_datafields_group_full = []
for dataset_id in dataset_group_ids:
    datafields_group_df = hf.get_datafields(s, region = 'JPN', universe = 'TOP1600', dataset_id=dataset_id)
    selected_datafields_group_df = datafields_group_df[
        (datafields_group_df['type'] == 'GROUP')
    ].sort_values(by=['userCount'], ascending=False)
    selected_datafields_group_df_id = selected_datafields_group_df.id.values.tolist()
    selected_datafields_group_full += selected_datafields_group_df_id[:10]
selected_datafields_group_full
# Out:
# ['oth455_relation_n2v_p10_q50_w2_kmeans_cluster_20',
#  'oth455_partner_roam_w5_pca_fact2_cluster_10',
#  'oth455_customer_n2v_p10_q200_w1_pca_fact3_cluster_5',
#  'oth455_partner_n2v_p10_q200_w2_kmeans_cluster_20',
#  'oth455_partner_n2v_p10_q50_w2_pca_fact2_cluster_20',
#  'oth455_customer_roam_w3_pca_fact3_cluster_10',
#  'oth455_relation_n2v_p10_q50_w5_pca_fact2_cluster_10',
#  'oth455_customer_n2v_p50_q50_w4_pca_fact3_cluster_20',
#  'oth455_customer_roam_w2_pca_fact1_cluster_10',
#  'oth455_partner_n2v_p50_q50_w4_kmeans_cluster_10']

# %% [markdown]
# #### Step 4. Apply generate_alpha function to the expression list
# In generate alpha function you can specify region, universe, decay, delay and other simulation settings

# %% [markdown]
# 이제 만들어둔 expressions 을 사용해 alpha simulation 을 해줍니다.

# %%
#?ace.generate_alpha

# %%
expression_template = f'''
group = (country+1)*group_max({grp}, market) + {grp};
group_neutralize(ts_scale(group_backfill(rsk70_mfm2_asetrd_season, industry, 252, std=1), 252), densify(group))
'''

# %%
expressions = []
for grp in selected_datafields_group_full:
    expressions.append(f'group = (country+1)*group_max({grp}, market) + {grp};group_neutralize(ts_scale(group_backfill(rsk70_mfm2_asetrd_season, industry, 252, std=1), 252), densify(group))')

# %%
len(expressions)
# Out:
# 10

# %%
#when you send multiple alphas for simulation, please make sure all alphas of a single list should have common settings
#alphas with different settings should be sent in a different list, for instance below list has all alphas with same settings

alpha_list = [ace.generate_alpha(x, region= "JPN", universe = "TOP1600", truncation = 0.01, delay = 1, decay = 3) for x in expressions]
alpha_list[0]
# Out:
# {'type': 'REGULAR',
#  'settings': {'instrumentType': 'EQUITY',
#   'region': 'JPN',
#   'universe': 'TOP1600',
#   'delay': 1,
#   'decay': 3,
#   'neutralization': 'INDUSTRY',
#   'truncation': 0.01,
#   'pasteurization': 'ON',
#   'testPeriod': 'P0Y0M0D',
#   'unitHandling': 'VERIFY',
#   'nanHandling': 'OFF',
#   'language': 'FASTEXPR',
#   'visualization': False},
#  'regular': 'group = (country+1)*group_max(oth455_relation_n2v_p10_q50_w2_kmeans_cluster_20, market) + oth455_relation_n2v_p10_q50_w2_kmeans_cluster_20;group_neutralize(ts_scale(group_backfill(rsk70_mfm2_asetrd_season, industry, 252, std=1), 252), densify(group))'}

# %% [markdown]
# ### Simulate alpha list, get simulation result
#
# simulate_alpha_list_multi will do a multi-simulation if list of alphas is greater than 10, which is the case here
#
# the returned object will contain simulation results for all alphas as a list

# %%
#alpha expressions are sliced to first 10 for demonstration purpose

result = ace.simulate_alpha_list_multi(s, alpha_list)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [04:51<00:00, 72.92s/it]

# %% [markdown]
# 위 코드를 실행하면 시뮬레이션이 시작됩니다. 100개의 알파에 대략 1시간 정도 소요되니, 인터넷 연결이 끊기지 않게 주의하시고, 너무 많은 알파를 한 번에 돌리기보다는 몇개씩 끊어서 돌려도 좋습니다.

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  5257119   20000000         615          614    0.2534   0.0508    0.1483
# 1  5118475   20000000         615          614    0.2536   0.0494    0.1480
# 2  4796056   20000000         595          593    0.2528   0.0463    0.1381
# 3  4657658   20000000         595          593    0.2539   0.0450    0.1426
# 4  4658416   20000000         595          593    0.2524   0.0450    0.1419
# 5  4546217   20000000         595          593    0.2528   0.0439    0.1447
# 6  3160180   20000000         475          474    0.2517   0.0305    0.1444
# 7  3091945   20000000         475          474    0.2510   0.0299    0.1427
# 8  2819425   20000000         475          474    0.2521   0.0272    0.1378
# 9  2636785   20000000         475          474    0.2535   0.0255    0.1397
#
#      margin  fitness  sharpe  start_date alpha_id  \
# 0  0.000401     0.77    1.72  2012-01-22  rlXL5EJ
# 1  0.000390     0.75    1.71  2012-01-22  3RLx93z
# 2  0.000366     0.66    1.55  2012-01-22  2LdROQY
# 3  0.000354     0.64    1.51  2012-01-22  APKb0bW
# 4  0.000356     0.64    1.52  2012-01-22  anvlxGW
# 5  0.000347     0.62    1.49  2012-01-22  K9a6OqE
# 6  0.000242     0.31    0.88  2012-01-22  bqEMRMm
# 7  0.000238     0.29    0.84  2012-01-22  5OW9Q9z
# 8  0.000216     0.25    0.77  2012-01-22  8Q1r3rz
# 9  0.000201     0.23    0.72  2012-01-22  Xn6LWPz
#
#                                           expression concentrated_weight  \
# 0  group = (country+1)*group_max(oth455_relation_...                PASS
# 1  group = (country+1)*group_max(oth455_relation_...                PASS
# 2  group = (country+1)*group_max(oth455_partner_r...                PASS
# 3  group = (country+1)*group_max(oth455_partner_n...                PASS
# 4  group = (country+1)*group_max(oth455_partner_n...                PASS
# 5  group = (country+1)*group_max(oth455_partner_n...                PASS
# 6  group = (country+1)*group_max(oth455_customer_...                PASS
# 7  group = (country+1)*group_max(oth455_customer_...                PASS
# 8  group = (country+1)*group_max(oth455_customer_...                PASS
# 9  group = (country+1)*group_max(oth455_customer_...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             PASS        FAIL       PASS
# 1          PASS             PASS        FAIL       PASS
# 2          PASS             PASS        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             PASS        FAIL       FAIL
# 5          PASS             PASS        FAIL       FAIL
# 6          PASS             FAIL        FAIL       FAIL
# 7          PASS             FAIL        FAIL       FAIL
# 8          PASS             FAIL        FAIL       FAIL
# 9          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover
# 0                    FAIL         PASS
# 1                    FAIL         PASS
# 2                    FAIL         PASS
# 3                    FAIL         PASS
# 4                    FAIL         PASS
# 5                    FAIL         PASS
# 6                    FAIL         PASS
# 7                    FAIL         PASS
# 8                    FAIL         PASS
# 9                    FAIL         PASS

# %%
result_st1['expression'][0]
# Out:
# 'group_neutralize(ts_scale(group_backfill(rsk70_mfm2_asetrd_season, industry, 252, std=1), 252), densify(country))'

# %% [markdown]
# prettify 함수를 이용해 dataframe 형식으로 변환하면 결과를 보기 더 편합니다.

# %%
result_st1.to_csv('2024_09_018_JPN_2.csv')

# %% [markdown]
# ### How to submit?
#
# Create a list of submittable alphas - alphas that have no FAIL in is_tests

# %% [markdown]
# 시뮬레이션을 마친 알파 중 제출 가능한 알파들을 제출해 봅시다.

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df
# Out:
#     alpha_id     endDate  limit message                 name   result  \
# 0    rlXL5EJ         NaN   1.58     NaN           LOW_SHARPE     PASS
# 1    rlXL5EJ         NaN   1.00     NaN          LOW_FITNESS     FAIL
# 2    rlXL5EJ         NaN   0.01     NaN         LOW_TURNOVER     PASS
# 3    rlXL5EJ         NaN   0.70     NaN        HIGH_TURNOVER     PASS
# 4    rlXL5EJ         NaN    NaN     NaN  CONCENTRATED_WEIGHT     PASS
# ..       ...         ...    ...     ...                  ...      ...
# 115  anvlxGW         NaN    NaN     NaN     SELF_CORRELATION  PENDING
# 116  anvlxGW         NaN    NaN     NaN       DATA_DIVERSITY  PENDING
# 117  anvlxGW         NaN    NaN     NaN     PROD_CORRELATION  PENDING
# 118  anvlxGW         NaN    NaN     NaN   REGULAR_SUBMISSION  PENDING
# 119  anvlxGW  2020-01-25   2.02     NaN     IS_LADDER_SHARPE     PASS
#
#       startDate   value  year
# 0           NaN  1.7200   NaN
# 1           NaN  0.7700   NaN
# 2           NaN  0.2534   NaN
# 3           NaN  0.2534   NaN
# 4           NaN     NaN   NaN
# ..          ...     ...   ...
# 115         NaN     NaN   NaN
# 116         NaN     NaN   NaN
# 117         NaN     NaN   NaN
# 118         NaN     NaN   NaN
# 119  2022-01-24  2.1300   2.0
#
# [120 rows x 9 columns]

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['rlXL5EJ' 'Xn6LWPz' '8Q1r3rz' 'K9a6OqE' 'APKb0bW' 'bqEMRMm' '3RLx93z'
#  '2LdROQY' '5OW9Q9z' 'anvlxGW']
# Passed alphas:[]

# %%
for alpha_id in ['ad59v2O', 'k3z6qqk', 'Lp0YPva', '9wNOzNr', '7weR901', '6w5Ln6E', 'QawpLe5', '17rAQ6m', '273obEY', 'xxJpKLg', 'Wpv2EZo', 'm8EWMk1']:
    hf.set_alpha_properties(s, alpha_id, tags = ['pass_Sep07_mixing'])

# %%
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['Sep07_GLB'])

# %% [markdown]
# 위 함수로 통과한 알파들에 태그를 붙일 수 있습니다.

# %% [markdown]
# When you got a list of submittable alphas, you can call function submit_alpha()

# %%
#calling submit_alpha on all alphas that have passed the submission tests

submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas}

# %% [markdown]
# 위 함수로 알파를 제출할 수 있습니다.

# %% [markdown]
# 알파의 id 로 제출하는 것이기 때문에, 그 알파를 시뮬레이션 한 날짜가 중요합니다. 가령, 1주일 전에 시뮬레이션 해 결과를 저장해 두었던 alpha id로 제출을 한다면 제출 날짜가 1주일 전이 됩니다. 그러니 오늘 제출하고 싶은 alpha 가 있다면 시뮬레이션을 다시 돌려 새로 생긴 alpha id 를 이용해야 합니다. 이 과정은 alpha 에 특정 태그를 달아 Brain 플랫폼에서 직접 하는게 훨씬 수월합니다. (다만, 플랫폼에서는 alpha id 로 알파를 검색할 수 없습니다.)

# %%
#submit_result will have return values from the submit_result function

submit_result
# Out:
# {'ZpO36rQ': False}

# %% [markdown]
# 주의하셔야 하실 점은, 하루 최대 알파 제출 한도인 4개를 루프중에 이미 넘기면 그 뒤의 알파들이 제출 가능하더라도 자동으로 제출에 실패하게 됩니다.

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance

# %% [markdown]
# 유용한 추가 함수들입니다. prod correlation 혹은 self correlation 만을 확인하고 싶을 때, 혹은 알파의 pnl 을 확인하고 싶을때 유용히 쓰입니다.
