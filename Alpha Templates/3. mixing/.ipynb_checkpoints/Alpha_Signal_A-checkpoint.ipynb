# %% [markdown]
# ### Import library

# %%
import os
os.chdir('../..')
os.getcwd()
# Out:
# 'C:\\Users\\csia7\\OneDrive\\문서\\GitHub\\WQBrain_2024_API'

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px
import pygwalker as pyg
import glob
import re

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_JLf6tBJgw8a3vWphnqkmNG3NVs2M

# %%
ace.check_session_timeout(s)
# Out:
# 14393.752114

# %% [markdown]
# ## Scoring

# %%
def score(raw_data):
    score_data = raw_data[['turnover', 'returns', 'drawdown']]
    score = pd.DataFrame()
    score = 1.3673 + 0.1757*score_data['turnover'] + 0.6150*score_data['returns'] - 1.0816*score_data['drawdown']
    return score

# %% [markdown]
# ## Alpha Mixing Templates

# %%
'''
signal1 = scale_down(<cs_operator>(ts_backfill(<data1>,126)));

signal2 = scale_down(<cs_operator>(ts_backfill(<data2>,126)));

signal1 * (1 + signal2)
'''
# Out:
# '\nsignal1 = scale_down(<cs_operator>(ts_backfill(<data1>,126)));\n\nsignal2 = scale_down(<cs_operator>(ts_backfill(<data2>,126)));\n\nsignal1 * (1 + signal2)\n'

# %%
'''
signal1 = oth176_lmt_close_eq_score ;
signal2 = oth176_malta_eq_score ;
k = ts_corr(signal1, signal2, 30) ;
k*regression_neut(signal1, signal2)

[아이디어]
경향성이 비슷한 알파 활용하여 corr로 weight를 부여
'''
# Out:
# '\nsignal1 = oth176_lmt_close_eq_score ;\nsignal2 = oth176_malta_eq_score ;\nk = ts_corr(signal1, signal2, 30) ;\nk*regression_neut(signal1, signal2)\n\n[아이디어]\n경향성이 비슷한 알파 활용하여 corr로 weight를 부여\n'

# %% [markdown]
# ## Read all passed alphas

# %%
file_direc = glob.glob('Results/signal/*')
file_direc
# Out:
# ['Results/signal\\A_signalform.csv',
#  'Results/signal\\B_signalform.csv',
#  'Results/signal\\C_signalform.csv',
#  'Results/signal\\D_signalform.csv']

# %%
expressions = {}
expressions['A'] = pd.read_csv(file_direc[0])['expression']
expressions['B'] = pd.read_csv(file_direc[1])['expression']
expressions['C'] = pd.read_csv(file_direc[2])['expression']
expressions['D'] = pd.read_csv(file_direc[3])['expression']

# %% [markdown]
# ## Template A mixing
# use top 32 results

# %%
#region= "GLB", universe = "MINVOL1M", neutralization = 'MARKET', truncation = 0.01

# %%
a = expressions['A'][:32]
b = expressions['B'][:24]
c = expressions['C'][:3]

# %%
'''
signal1 = scale_down(<cs_operator>(ts_backfill(<data1>,126)));

signal2 = scale_down(<cs_operator>(ts_backfill(<data2>,126)));

signal1 * (1 + signal2)
'''
# Out:
# '\nsignal1 = scale_down(<cs_operator>(ts_backfill(<data1>,126)));\n\nsignal2 = scale_down(<cs_operator>(ts_backfill(<data2>,126)));\n\nsignal1 * (1 + signal2)\n'

# %% [markdown]
# ### add

# %%
alpha_list_AB = []

for i in range(25, 30):
    for j in range(20, 23):
        alpha_list_AB.append(ace.generate_alpha(f'{a[i]};{b[j]};add(scale_down(signal_A_{i}), scale_down(signal_B_{j}), filter = false)', region= "GLB", universe = "MINVOL1M", neutralization = 'MARKET', truncation = 0.01, decay = 12))

alpha_list_AB
# Out:
# [{'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_25 = oth460_1l_fbds;stock_A_25 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_25 = group_zscore(ts_ir(returns, 252), industry);alpha_A_25 = vector_neut(stock_A_25, factor_A_25);signal_A_25 = trade_when(pro_A_25<=0.5, alpha_A_25, pro_A_25>0.5);entry_B_20 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_20 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_20 = entry_B_20 < 0.5;signal_B_20 =  trade_when(entry_B_20>0.55, maintenance_B_20, quit_B_20);add(scale_down(signal_A_25), scale_down(signal_B_20), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_25 = oth460_1l_fbds;stock_A_25 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_25 = group_zscore(ts_ir(returns, 252), industry);alpha_A_25 = vector_neut(stock_A_25, factor_A_25);signal_A_25 = trade_when(pro_A_25<=0.5, alpha_A_25, pro_A_25>0.5);entry_B_21 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_21 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_21 = entry_B_21 < 0.5;signal_B_21 =  trade_when(entry_B_21>0.55, maintenance_B_21, quit_B_21);add(scale_down(signal_A_25), scale_down(signal_B_21), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_25 = oth460_1l_fbds;stock_A_25 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_25 = group_zscore(ts_ir(returns, 252), industry);alpha_A_25 = vector_neut(stock_A_25, factor_A_25);signal_A_25 = trade_when(pro_A_25<=0.5, alpha_A_25, pro_A_25>0.5);entry_B_22 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_22 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_22 = entry_B_22 < 0.5;signal_B_22 =  trade_when(entry_B_22>0.55, maintenance_B_22, quit_B_22);add(scale_down(signal_A_25), scale_down(signal_B_22), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_26 = oth460_1l_fbbs;stock_A_26 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_26 = group_zscore(ts_ir(returns, 252), industry);alpha_A_26 = vector_neut(stock_A_26, factor_A_26);signal_A_26 = trade_when(pro_A_26<=0.5, alpha_A_26, pro_A_26>0.5);entry_B_20 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_20 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_20 = entry_B_20 < 0.5;signal_B_20 =  trade_when(entry_B_20>0.55, maintenance_B_20, quit_B_20);add(scale_down(signal_A_26), scale_down(signal_B_20), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_26 = oth460_1l_fbbs;stock_A_26 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_26 = group_zscore(ts_ir(returns, 252), industry);alpha_A_26 = vector_neut(stock_A_26, factor_A_26);signal_A_26 = trade_when(pro_A_26<=0.5, alpha_A_26, pro_A_26>0.5);entry_B_21 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_21 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_21 = entry_B_21 < 0.5;signal_B_21 =  trade_when(entry_B_21>0.55, maintenance_B_21, quit_B_21);add(scale_down(signal_A_26), scale_down(signal_B_21), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_26 = oth460_1l_fbbs;stock_A_26 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_26 = group_zscore(ts_ir(returns, 252), industry);alpha_A_26 = vector_neut(stock_A_26, factor_A_26);signal_A_26 = trade_when(pro_A_26<=0.5, alpha_A_26, pro_A_26>0.5);entry_B_22 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_22 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_22 = entry_B_22 < 0.5;signal_B_22 =  trade_when(entry_B_22>0.55, maintenance_B_22, quit_B_22);add(scale_down(signal_A_26), scale_down(signal_B_22), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_27 = oth460_es_roe_fy1_d1m_l1;stock_A_27 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_27 = group_zscore(ts_ir(returns, 252), industry);alpha_A_27 = regression_neut(stock_A_27, factor_A_27);signal_A_27 = trade_when(pro_A_27<=0.5, alpha_A_27, pro_A_27>0.5);entry_B_20 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_20 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_20 = entry_B_20 < 0.5;signal_B_20 =  trade_when(entry_B_20>0.55, maintenance_B_20, quit_B_20);add(scale_down(signal_A_27), scale_down(signal_B_20), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_27 = oth460_es_roe_fy1_d1m_l1;stock_A_27 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_27 = group_zscore(ts_ir(returns, 252), industry);alpha_A_27 = regression_neut(stock_A_27, factor_A_27);signal_A_27 = trade_when(pro_A_27<=0.5, alpha_A_27, pro_A_27>0.5);entry_B_21 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_21 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_21 = entry_B_21 < 0.5;signal_B_21 =  trade_when(entry_B_21>0.55, maintenance_B_21, quit_B_21);add(scale_down(signal_A_27), scale_down(signal_B_21), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_27 = oth460_es_roe_fy1_d1m_l1;stock_A_27 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_27 = group_zscore(ts_ir(returns, 252), industry);alpha_A_27 = regression_neut(stock_A_27, factor_A_27);signal_A_27 = trade_when(pro_A_27<=0.5, alpha_A_27, pro_A_27>0.5);entry_B_22 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_22 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_22 = entry_B_22 < 0.5;signal_B_22 =  trade_when(entry_B_22>0.55, maintenance_B_22, quit_B_22);add(scale_down(signal_A_27), scale_down(signal_B_22), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_28 = oth460_es_ebit_fy1_d1m_l1;stock_A_28 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_28 = group_zscore(ts_ir(returns, 252), industry);alpha_A_28 = vector_neut(stock_A_28, factor_A_28);signal_A_28 = trade_when(pro_A_28<=0.5, alpha_A_28, pro_A_28>0.5);entry_B_20 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_20 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_20 = entry_B_20 < 0.5;signal_B_20 =  trade_when(entry_B_20>0.55, maintenance_B_20, quit_B_20);add(scale_down(signal_A_28), scale_down(signal_B_20), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_28 = oth460_es_ebit_fy1_d1m_l1;stock_A_28 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_28 = group_zscore(ts_ir(returns, 252), industry);alpha_A_28 = vector_neut(stock_A_28, factor_A_28);signal_A_28 = trade_when(pro_A_28<=0.5, alpha_A_28, pro_A_28>0.5);entry_B_21 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_21 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_21 = entry_B_21 < 0.5;signal_B_21 =  trade_when(entry_B_21>0.55, maintenance_B_21, quit_B_21);add(scale_down(signal_A_28), scale_down(signal_B_21), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_28 = oth460_es_ebit_fy1_d1m_l1;stock_A_28 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_28 = group_zscore(ts_ir(returns, 252), industry);alpha_A_28 = vector_neut(stock_A_28, factor_A_28);signal_A_28 = trade_when(pro_A_28<=0.5, alpha_A_28, pro_A_28>0.5);entry_B_22 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_22 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_22 = entry_B_22 < 0.5;signal_B_22 =  trade_when(entry_B_22>0.55, maintenance_B_22, quit_B_22);add(scale_down(signal_A_28), scale_down(signal_B_22), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_29 = oth460_es_roe_fy1_d1m_l1;stock_A_29 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_29 = group_zscore(ts_ir(returns, 252), industry);alpha_A_29 = vector_neut(stock_A_29, factor_A_29);signal_A_29 = trade_when(pro_A_29<=0.5, alpha_A_29, pro_A_29>0.5);entry_B_20 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_20 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_20 = entry_B_20 < 0.5;signal_B_20 =  trade_when(entry_B_20>0.55, maintenance_B_20, quit_B_20);add(scale_down(signal_A_29), scale_down(signal_B_20), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_29 = oth460_es_roe_fy1_d1m_l1;stock_A_29 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_29 = group_zscore(ts_ir(returns, 252), industry);alpha_A_29 = vector_neut(stock_A_29, factor_A_29);signal_A_29 = trade_when(pro_A_29<=0.5, alpha_A_29, pro_A_29>0.5);entry_B_21 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_21 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_21 = entry_B_21 < 0.5;signal_B_21 =  trade_when(entry_B_21>0.55, maintenance_B_21, quit_B_21);add(scale_down(signal_A_29), scale_down(signal_B_21), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 12,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_29 = oth460_es_roe_fy1_d1m_l1;stock_A_29 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_29 = group_zscore(ts_ir(returns, 252), industry);alpha_A_29 = vector_neut(stock_A_29, factor_A_29);signal_A_29 = trade_when(pro_A_29<=0.5, alpha_A_29, pro_A_29>0.5);entry_B_22 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_22 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_22 = entry_B_22 < 0.5;signal_B_22 =  trade_when(entry_B_22>0.55, maintenance_B_22, quit_B_22);add(scale_down(signal_A_29), scale_down(signal_B_22), filter = false)'}]

# %%
result = ace.simulate_alpha_list_multi(s, alpha_list_AB)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [14:59<00:00, 179.94s/it]

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#          pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   14990838   20000000         899          927    0.4065   0.1448    0.0864
# 1   15560946   20000000         762          803    0.5623   0.1503    0.0606
# 2   16007770   20000000         465          481    0.3972   0.1546    0.0937
# 3   16257181   20000000         460          474    0.4234   0.1570    0.1071
# 4   14944028   20000000         888          915    0.4340   0.1443    0.0844
# 5   15939527   20000000         459          476    0.4105   0.1539    0.1125
# 6   15252992   20000000         733          712    0.4471   0.1473    0.1227
# 7   16391414   20000000         391          380    0.4353   0.1583    0.1212
# 8   15354033   20000000         755          792    0.5893   0.1483    0.0658
# 9   16097403   20000000         387          379    0.4349   0.1554    0.1124
# 10  15189385   20000000         751          796    0.5748   0.1467    0.0707
# 11  14593421   20000000         887          919    0.4206   0.1409    0.0974
# 12  15289990   20000000         620          626    0.5916   0.1476    0.0876
# 13  14682886   20000000         723          708    0.4473   0.1418    0.1207
# 14  15214607   20000000         628          631    0.5913   0.1469    0.0827
#
#       margin  fitness  sharpe  start_date alpha_id  \
# 0   0.000712     1.29    2.16  2012-01-22  Gw21ljO
# 1   0.000534     1.28    2.48  2012-01-22  EwjOlPP
# 2   0.000778     1.28    2.05  2012-01-22  6wWmlWP
# 3   0.000741     1.25    2.05  2012-01-22  xxLOewb
# 4   0.000665     1.23    2.13  2012-01-22  lVnp7JN
# 5   0.000750     1.22    2.00  2012-01-22  MpEMG26
# 6   0.000659     1.20    2.09  2012-01-22  7w57a18
# 7   0.000727     1.20    1.99  2012-01-22  WpZ1aGx
# 8   0.000503     1.20    2.40  2012-01-22  5wmnLRJ
# 9   0.000715     1.19    1.99  2012-01-22  xxLOPxw
# 10  0.000510     1.17    2.31  2012-01-22  jZpz6xe
# 11  0.000670     1.17    2.03  2012-01-22  Npdxb8L
# 12  0.000499     1.15    2.30  2012-01-22  LpvVgkv
# 13  0.000634     1.15    2.04  2012-01-22  PpRQw17
# 14  0.000497     1.14    2.29  2012-01-22  oKb83K5
#
#                                            expression concentrated_weight  \
# 0   pro_A_28 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
# 1   pro_A_28 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
# 2   pro_A_28 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
# 3   pro_A_27 = oth460_es_roe_fy1_d1m_l1;stock_A_27...                PASS
# 4   pro_A_27 = oth460_es_roe_fy1_d1m_l1;stock_A_27...                PASS
# 5   pro_A_29 = oth460_es_roe_fy1_d1m_l1;stock_A_29...                PASS
# 6   pro_A_25 = oth460_1l_fbds;stock_A_25 = ts_zsco...                PASS
# 7   pro_A_25 = oth460_1l_fbds;stock_A_25 = ts_zsco...                PASS
# 8   pro_A_27 = oth460_es_roe_fy1_d1m_l1;stock_A_27...                PASS
# 9   pro_A_26 = oth460_1l_fbbs;stock_A_26 = ts_zsco...                PASS
# 10  pro_A_29 = oth460_es_roe_fy1_d1m_l1;stock_A_29...                PASS
# 11  pro_A_29 = oth460_es_roe_fy1_d1m_l1;stock_A_29...                PASS
# 12  pro_A_26 = oth460_1l_fbbs;stock_A_26 = ts_zsco...                PASS
# 13  pro_A_26 = oth460_1l_fbbs;stock_A_26 = ts_zsco...                PASS
# 14  pro_A_25 = oth460_1l_fbds;stock_A_25 = ts_zsco...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        PASS       PASS
# 1           PASS             PASS        PASS       PASS
# 2           PASS             FAIL        PASS       PASS
# 3           PASS             FAIL        PASS       PASS
# 4           PASS             FAIL        PASS       PASS
# 5           PASS             FAIL        PASS       PASS
# 6           PASS             FAIL        PASS       PASS
# 7           PASS             FAIL        PASS       PASS
# 8           PASS             PASS        PASS       PASS
# 9           PASS             PASS        PASS       PASS
# 10          PASS             PASS        PASS       PASS
# 11          PASS             FAIL        PASS       PASS
# 12          PASS             FAIL        PASS       PASS
# 13          PASS             FAIL        PASS       PASS
# 14          PASS             FAIL        PASS       PASS
#
#    low_sub_universe_sharpe low_turnover
# 0                     PASS         PASS
# 1                     PASS         PASS
# 2                     PASS         PASS
# 3                     PASS         PASS
# 4                     PASS         PASS
# 5                     PASS         PASS
# 6                     PASS         PASS
# 7                     PASS         PASS
# 8                     PASS         PASS
# 9                     PASS         PASS
# 10                    PASS         PASS
# 11                    PASS         PASS
# 12                    PASS         PASS
# 13                    PASS         PASS
# 14                    PASS         PASS

# %%
result_st1.to_csv('AB_mixing_add_5.csv')

# %%
result = pd.read_csv('Results/mixing/AB_mixing_add_4.csv')
result
# Out:
#     Unnamed: 0       pnl  book_size  long_count  short_count  turnover  \
# 0            0  21775775   20000000         462          517    0.5681
# 1            1  18639785   20000000         826          863    0.4747
# 2            2  20836271   20000000         635          720    0.5603
# 3            3  21178514   20000000         456          522    0.5530
# 4            4  17900897   20000000         938          961    0.4719
# 5            5  20244071   20000000         628          728    0.5452
# 6            6  20152186   20000000         583          653    0.5648
# 7            7  19637020   20000000         576          660    0.5502
# 8            8  18460438   20000000         662          663    0.5110
# 9            9  17786432   20000000         789          821    0.6118
# 10          10  20640891   20000000         436          487    0.5782
# 11          11  17862957   20000000         638          666    0.4865
# 12          12  17867552   20000000         655          658    0.5100
# 13          13  19920988   20000000         431          492    0.5633
# 14          14  18687864   20000000         524          592    0.7055
# 15          15  16790076   20000000         761          744    0.5045
# 16          16  16979151   20000000         640          643    0.6358
# 17          17  16923591   20000000         647          648    0.6355
# 18          18  16185473   20000000         753          741    0.5048
# 19          19  18145674   20000000         518          599    0.6913
# 20          20  17101609   20000000         609          634    0.4909
# 21          21  16598889   20000000         515          516    0.5163
# 22          22  16306838   20000000         509          511    0.5157
# 23          23  15501872   20000000         490          489    0.5249
# 24          24  14994604   20000000         484          485    0.5242
#
#     returns  drawdown    margin  fitness  ...  start_date alpha_id  \
# 0    0.2103    0.0632  0.000740     1.85  ...  2012-01-22  ZpVprx1
# 1    0.1800    0.0633  0.000758     1.80  ...  2012-01-22  wR7RjR2
# 2    0.2012    0.0702  0.000718     1.77  ...  2012-01-22  PpLpvXq
# 3    0.2045    0.0678  0.000740     1.75  ...  2012-01-22  ZpVp0NQ
# 4    0.1729    0.0599  0.000733     1.68  ...  2012-01-22  jZkZjEk
# 5    0.1955    0.0759  0.000717     1.68  ...  2012-01-22  RpxpVv1
# 6    0.1946    0.0622  0.000689     1.67  ...  2012-01-22  1737Jak
# 7    0.1896    0.0686  0.000689     1.59  ...  2012-01-22  lVwV8Ye
# 8    0.1783    0.0907  0.000698     1.59  ...  2012-01-22  oKjKnl2
# 9    0.1718    0.0476  0.000561     1.58  ...  2012-01-22  xx7xjkn
# 10   0.1993    0.0689  0.000689     1.57  ...  2012-01-22  6w6wzxE
# 11   0.1725    0.0905  0.000709     1.57  ...  2012-01-22  z979kMK
# 12   0.1725    0.0755  0.000677     1.54  ...  2012-01-22  z979deR
# 13   0.1924    0.0725  0.000683     1.48  ...  2012-01-22  z979gzE
# 14   0.1805    0.0678  0.000512     1.46  ...  2012-01-22  jZkZ1mj
# 15   0.1621    0.0986  0.000643     1.45  ...  2012-01-22  WprpNpO
# 16   0.1640    0.0652  0.000516     1.40  ...  2012-01-22  NpEpP2p
# 17   0.1634    0.0636  0.000514     1.39  ...  2012-01-22  eOMOn0N
# 18   0.1563    0.0913  0.000619     1.38  ...  2012-01-22  RpxpeKe
# 19   0.1752    0.0688  0.000507     1.38  ...  2012-01-22  QaRaOdX
# 20   0.1651    0.0864  0.000673     1.37  ...  2012-01-22  Lpop7dn
# 21   0.1603    0.1159  0.000621     1.31  ...  2012-01-22  OpdpoKv
# 22   0.1575    0.1044  0.000611     1.28  ...  2012-01-22  p6b6x0v
# 23   0.1497    0.1143  0.000570     1.07  ...  2012-01-22  AwXwl9W
# 24   0.1448    0.1183  0.000552     1.02  ...  2012-01-22  ZpVpQMQ
#
#                                            expression concentrated_weight  \
# 0   pro_A_20 = oth460_1l_m1r_1yf_spe_se;stock_A_20...                PASS
# 1   pro_A_22 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
# 2   pro_A_20 = oth460_1l_m1r_1yf_spe_se;stock_A_20...                PASS
# 3   pro_A_23 = oth460_1l_m1r_1yf_spe_se;stock_A_23...                PASS
# 4   pro_A_22 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
# 5   pro_A_23 = oth460_1l_m1r_1yf_spe_se;stock_A_23...                PASS
# 6   pro_A_20 = oth460_1l_m1r_1yf_spe_se;stock_A_20...                PASS
# 7   pro_A_23 = oth460_1l_m1r_1yf_spe_se;stock_A_23...                PASS
# 8   pro_A_21 = oth460_1l_fbds;stock_A_21 = ts_zsco...                PASS
# 9   pro_A_22 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
# 10  pro_A_20 = oth460_1l_m1r_1yf_spe_se;stock_A_20...                PASS
# 11  pro_A_22 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
# 12  pro_A_24 = oth460_1l_fbbs;stock_A_24 = ts_zsco...                PASS
# 13  pro_A_23 = oth460_1l_m1r_1yf_spe_se;stock_A_23...                PASS
# 14  pro_A_20 = oth460_1l_m1r_1yf_spe_se;stock_A_20...                PASS
# 15  pro_A_21 = oth460_1l_fbds;stock_A_21 = ts_zsco...                PASS
# 16  pro_A_24 = oth460_1l_fbbs;stock_A_24 = ts_zsco...                PASS
# 17  pro_A_21 = oth460_1l_fbds;stock_A_21 = ts_zsco...                PASS
# 18  pro_A_24 = oth460_1l_fbbs;stock_A_24 = ts_zsco...                PASS
# 19  pro_A_23 = oth460_1l_m1r_1yf_spe_se;stock_A_23...                PASS
# 20  pro_A_22 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
# 21  pro_A_21 = oth460_1l_fbds;stock_A_21 = ts_zsco...                PASS
# 22  pro_A_24 = oth460_1l_fbbs;stock_A_24 = ts_zsco...                PASS
# 23  pro_A_21 = oth460_1l_fbds;stock_A_21 = ts_zsco...                PASS
# 24  pro_A_24 = oth460_1l_fbbs;stock_A_24 = ts_zsco...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             PASS        PASS       PASS
# 1           PASS             PASS        PASS       PASS
# 2           PASS             PASS        PASS       PASS
# 3           PASS             PASS        PASS       PASS
# 4           PASS             PASS        PASS       PASS
# 5           PASS             PASS        PASS       PASS
# 6           PASS             PASS        PASS       PASS
# 7           PASS             PASS        PASS       PASS
# 8           PASS             PASS        PASS       PASS
# 9           PASS             PASS        PASS       PASS
# 10          PASS             PASS        PASS       PASS
# 11          PASS             PASS        PASS       PASS
# 12          PASS             PASS        PASS       PASS
# 13          PASS             PASS        PASS       PASS
# 14          FAIL             PASS        PASS       PASS
# 15          PASS             FAIL        PASS       PASS
# 16          PASS             PASS        PASS       PASS
# 17          PASS             FAIL        PASS       PASS
# 18          PASS             FAIL        PASS       PASS
# 19          PASS             FAIL        PASS       PASS
# 20          PASS             PASS        PASS       PASS
# 21          PASS             PASS        PASS       PASS
# 22          PASS             PASS        PASS       PASS
# 23          PASS             FAIL        PASS       PASS
# 24          PASS             FAIL        PASS       PASS
#
#    low_sub_universe_sharpe low_turnover
# 0                     PASS         PASS
# 1                     PASS         PASS
# 2                     PASS         PASS
# 3                     PASS         PASS
# 4                     PASS         PASS
# 5                     PASS         PASS
# 6                     PASS         PASS
# 7                     PASS         PASS
# 8                     PASS         PASS
# 9                     PASS         PASS
# 10                    PASS         PASS
# 11                    PASS         PASS
# 12                    PASS         PASS
# 13                    PASS         PASS
# 14                    PASS         PASS
# 15                    PASS         PASS
# 16                    PASS         PASS
# 17                    PASS         PASS
# 18                    PASS         PASS
# 19                    PASS         PASS
# 20                    PASS         PASS
# 21                    PASS         PASS
# 22                    PASS         PASS
# 23                    PASS         PASS
# 24                    PASS         PASS
#
# [25 rows x 21 columns]

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df.head()
# Out:
#   alpha_id endDate  limit                 name result startDate themes  \
# 0  LpvVgkv     NaN   1.58           LOW_SHARPE   PASS       NaN    NaN
# 1  LpvVgkv     NaN   1.00          LOW_FITNESS   PASS       NaN    NaN
# 2  LpvVgkv     NaN   0.01         LOW_TURNOVER   PASS       NaN    NaN
# 3  LpvVgkv     NaN   0.70        HIGH_TURNOVER   PASS       NaN    NaN
# 4  LpvVgkv     NaN    NaN  CONCENTRATED_WEIGHT   PASS       NaN    NaN
#
#     value  year
# 0  2.3000   NaN
# 1  1.1500   NaN
# 2  0.5916   NaN
# 3  0.5916   NaN
# 4     NaN   NaN

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['LpvVgkv' 'PpRQw17' 'oKb83K5' '7w57a18' 'WpZ1aGx' 'lVnp7JN' 'xxLOewb'
#  'Npdxb8L' 'MpEMG26' 'Gw21ljO' '6wWmlWP']
# Passed alphas:['jZpz6xe', 'xxLOPxw', 'EwjOlPP', '5wmnLRJ']

# %%
candidates = result['alpha_id']

# %%
#calling submit_alpha on all alphas that have passed the submission tests
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['Sep2024'])

# %%
for alpha_id in passed_alphas:
    print(ace.check_prod_corr_test(s, alpha_id))
# Out:
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.8  Opgx1lp
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    1.0  9wk7zao
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   PASS    0.7    0.7  9wk7zNd
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   PASS    0.7    0.7  k39ZXjP
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   PASS    0.7    0.7  k39ZXoO
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.8  ngr81zq
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   PASS    0.7    0.7  RpP1Rjg
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.8  RpP1Zw0
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.9  k39ZXVP
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   PASS    0.7    0.7  ZpNKYR1
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.9  27eNn0x
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.8  Gw9e07O
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   PASS    0.7    0.7  lV13KYe
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   PASS    0.7    0.7  bLAdWXR
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   PASS    0.7    0.7  075MKOk
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.9  7wln881
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   PASS    0.7    0.7  eOEx7kd
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   PASS    0.7    0.6  6wNeP6p

# %%
corr_pass = ['9wk7zNd', 'k39ZXjP', 'k39ZXoO', 'RpP1Rjg', 'ZpNKYR1', 'lV13KYe', 'bLAdWXR', '075MKOk', 'eOEx7kd', '6wNeP6p']

# %%
submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in candidates}
submit_result
# Out:
# {'ZpVprx1': False,
#  'wR7RjR2': False,
#  'PpLpvXq': False,
#  'ZpVp0NQ': False,
#  'jZkZjEk': False,
#  'RpxpVv1': False,
#  '1737Jak': False,
#  'lVwV8Ye': False,
#  'oKjKnl2': False,
#  'xx7xjkn': False,
#  '6w6wzxE': False,
#  'z979kMK': False,
#  'z979deR': False,
#  'z979gzE': False,
#  'jZkZ1mj': False,
#  'WprpNpO': False,
#  'NpEpP2p': True,
#  'eOMOn0N': False,
#  'RpxpeKe': False,
#  'QaRaOdX': False,
#  'Lpop7dn': False,
#  'OpdpoKv': False,
#  'p6b6x0v': False,
#  'AwXwl9W': False,
#  'ZpVpQMQ': False}

# %% [markdown]
# ## resimulation

# %%
temp = pd.read_csv('A_mixing_add_fin.csv')
temp
# Out:
#     Unnamed: 0         pnl   book_size  long_count  short_count  turnover  \
# 0          0.0  14787979.0  20000000.0       943.0        982.0    0.3519
# 1          1.0  14576358.0  20000000.0       935.0        989.0    0.3423
# 2          2.0  16908540.0  20000000.0      1029.0       1071.0    0.4707
# 3          3.0  17598017.0  20000000.0       808.0        823.0    0.4836
# 4          4.0  15752825.0  20000000.0       925.0        928.0    0.4829
# 5          5.0  15520980.0  20000000.0       935.0        933.0    0.4896
# 6          6.0  12149700.0  20000000.0       926.0        966.0    0.3474
# 7          7.0  14390032.0  20000000.0      1367.0       1441.0    0.3691
# 8          8.0  13539449.0  20000000.0      1318.0       1379.0    0.4359
# 9          9.0  14848188.0  20000000.0       841.0        905.0    0.3962
# 10        10.0  11785344.0  20000000.0      1400.0       1429.0    0.3973
# 11        11.0  14042107.0  20000000.0       802.0        883.0    0.5149
# 12        12.0  13131491.0  20000000.0      1052.0       1183.0    0.4751
# 13        13.0  10498886.0  20000000.0      1656.0       1832.0    0.3873
# 14        14.0  10368898.0  20000000.0      1272.0       1365.0    0.4312
# 15         NaN         NaN         NaN         NaN          NaN       NaN
# 16         NaN         NaN         NaN         NaN          NaN       NaN
# 17         NaN         NaN         NaN         NaN          NaN       NaN
# 18         NaN         NaN         NaN         NaN          NaN       NaN
# 19         NaN         NaN         NaN         NaN          NaN       NaN
# 20         NaN         NaN         NaN         NaN          NaN       NaN
# 21         NaN         NaN         NaN         NaN          NaN       NaN
# 22         NaN         NaN         NaN         NaN          NaN       NaN
# 23         NaN         NaN         NaN         NaN          NaN       NaN
#
#     returns  drawdown    margin  fitness  sharpe  start_date alpha_id  \
# 0    0.1428    0.0538  0.000812     1.70    2.67  2012-01-22  YpJom7l
# 1    0.1408    0.0578  0.000822     1.60    2.49  2012-01-22  roVMLl3
# 2    0.1633    0.0670  0.000694     1.48    2.51  2012-01-22  qA32a9A
# 3    0.1699    0.0791  0.000703     1.46    2.46  2012-01-22  xxW7pdN
# 4    0.1521    0.0636  0.000630     1.45    2.59  2012-01-22  jZxK0AZ
# 5    0.1499    0.0740  0.000612     1.45    2.62  2012-01-22  Awm8Y2l
# 6    0.1173    0.0677  0.000676     1.35    2.33  2012-01-22  ngQG5N3
# 7    0.1390    0.0878  0.000753     1.29    2.10  2012-01-22  076Z2wv
# 8    0.1307    0.0763  0.000600     1.25    2.29  2012-01-22  MpZvEOk
# 9    0.1434    0.0916  0.000724     1.24    2.06  2012-01-22  lV9nxJ8
# 10   0.1138    0.1044  0.000573     1.17    2.18  2012-01-22  lV9nxx8
# 11   0.1356    0.0770  0.000527     1.08    2.10  2012-01-22  375KdYe
# 12   0.1268    0.0751  0.000534     1.01    1.96  2012-01-22  Awmp6Yd
# 13   0.1014    0.0845  0.000523     0.95    1.85  2012-01-22  OpVLewY
# 14   0.1001    0.1109  0.000464     0.85    1.76  2012-01-22  9wmeog1
# 15      NaN       NaN       NaN      NaN     NaN         NaN      NaN
# 16      NaN       NaN       NaN      NaN     NaN         NaN      NaN
# 17      NaN       NaN       NaN      NaN     NaN         NaN      NaN
# 18      NaN       NaN       NaN      NaN     NaN         NaN      NaN
# 19      NaN       NaN       NaN      NaN     NaN         NaN      NaN
# 20      NaN       NaN       NaN      NaN     NaN         NaN      NaN
# 21      NaN       NaN       NaN      NaN     NaN         NaN      NaN
# 22      NaN       NaN       NaN      NaN     NaN         NaN      NaN
# 23      NaN       NaN       NaN      NaN     NaN         NaN      NaN
#
#                                            expression concentrated_weight  \
# 0   pro_A_0 = oth460_1l_acda;stock_A_0 = ts_zscore...                PASS
# 1   pro_A_2 = oth460_1l_ccns;stock_A_2 = ts_zscore...                PASS
# 2   pro_A_8 = oth460_es_ebit_fy1_d1m_l1;stock_A_8 ...                PASS
# 3   pro_A_12 = oth460_1l_m3r_mtn_spb_se;stock_A_12...                PASS
# 4   pro_A_6 = oth460_1l_m3r_mtn_spb_se;stock_A_6 =...                PASS
# 5   pro_A_4 = oth460_1l_m3r_mtn_spb_se;stock_A_4 =...                PASS
# 6   pro_A_14 = oth460_1l_acda;stock_A_14 = ts_zsco...                PASS
# 7   pro_A_16 = oth460_es_ebit_fy1_d1m_l1;stock_A_1...                PASS
# 8   pro_A_10 = oth460_1l_fbds;stock_A_10 = ts_zsco...                PASS
# 9   pro_A_18 = oth460_es_roe_fy1_d1m_l1;stock_A_18...                PASS
# 10  pro_A_24 = oth460_1l_fbbs;stock_A_24 = ts_zsco...                PASS
# 11  pro_A_20 = oth460_1l_m1r_1yf_spe_se;stock_A_20...                PASS
# 12  pro_A_22 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
# 13  pro_A_28 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
# 14  pro_A_26 = oth460_1l_fbbs;stock_A_26 = ts_zsco...                PASS
# 15                                                NaN                 NaN
# 16                                                NaN                 NaN
# 17                                                NaN                 NaN
# 18                                                NaN                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
# 23                                                NaN                 NaN
#
#    high_turnover low_fitness low_sharpe low_sub_universe_sharpe low_turnover
# 0           PASS        PASS       PASS                    PASS         PASS
# 1           PASS        PASS       PASS                    PASS         PASS
# 2           PASS        PASS       PASS                    PASS         PASS
# 3           PASS        PASS       PASS                    PASS         PASS
# 4           PASS        PASS       PASS                    PASS         PASS
# 5           PASS        PASS       PASS                    PASS         PASS
# 6           PASS        PASS       PASS                    PASS         PASS
# 7           PASS        PASS       PASS                    PASS         PASS
# 8           PASS        PASS       PASS                    PASS         PASS
# 9           PASS        PASS       PASS                    PASS         PASS
# 10          PASS        PASS       PASS                    PASS         PASS
# 11          PASS        PASS       PASS                    PASS         PASS
# 12          PASS        PASS       PASS                    PASS         PASS
# 13          PASS        FAIL       PASS                    PASS         PASS
# 14          PASS        FAIL       PASS                    PASS         PASS
# 15           NaN         NaN        NaN                     NaN          NaN
# 16           NaN         NaN        NaN                     NaN          NaN
# 17           NaN         NaN        NaN                     NaN          NaN
# 18           NaN         NaN        NaN                     NaN          NaN
# 19           NaN         NaN        NaN                     NaN          NaN
# 20           NaN         NaN        NaN                     NaN          NaN
# 21           NaN         NaN        NaN                     NaN          NaN
# 22           NaN         NaN        NaN                     NaN          NaN
# 23           NaN         NaN        NaN                     NaN          NaN

# %%
passed_expression = [temp.iloc[i]['expression'] for i in range(13)]

# %%
passed_expression
# Out:
# ['pro_A_0 = oth460_1l_acda;stock_A_0 = ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21);factor_A_0 = group_zscore(ts_ir(returns, 252), industry);alpha_A_0 = regression_neut(stock_A_0, factor_A_0);signal_A_0 = trade_when(pro_A_0<=0.5, alpha_A_0, pro_A_0>0.5);pro_A_1 = oth460_1l_ccns;stock_A_1 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_1 = group_zscore(ts_ir(returns, 252), industry);alpha_A_1 = regression_neut(stock_A_1, factor_A_1);signal_A_1 = trade_when(pro_A_1<=0.5, alpha_A_1, pro_A_1>0.5);zscore(add(signal_A_0, signal_A_1, filter = false))',
#  'pro_A_2 = oth460_1l_ccns;stock_A_2 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_2 = group_zscore(ts_ir(returns, 252), industry);alpha_A_2 = vector_neut(stock_A_2, factor_A_2);signal_A_2 = trade_when(pro_A_2<=0.5, alpha_A_2, pro_A_2>0.5);pro_A_3 = oth460_1l_acda;stock_A_3 = ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21);factor_A_3 = group_zscore(ts_ir(returns, 252), industry);alpha_A_3 = vector_neut(stock_A_3, factor_A_3);signal_A_3 = trade_when(pro_A_3<=0.5, alpha_A_3, pro_A_3>0.5);zscore(add(signal_A_2, signal_A_3, filter = false))',
#  'pro_A_8 = oth460_es_ebit_fy1_d1m_l1;stock_A_8 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_8 = group_zscore(ts_ir(returns, 252), industry);alpha_A_8 = regression_neut(stock_A_8, factor_A_8);signal_A_8 = trade_when(pro_A_8<=0.5, alpha_A_8, pro_A_8>0.5);pro_A_9 = oth460_1l_m3r_mtn_spb_se;stock_A_9 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_9 = group_zscore(ts_ir(returns, 252), industry);alpha_A_9 = regression_neut(stock_A_9, factor_A_9);signal_A_9 = trade_when(pro_A_9<=0.5, alpha_A_9, pro_A_9>0.5);zscore(add(signal_A_8, signal_A_9, filter = false))',
#  'pro_A_12 = oth460_1l_m3r_mtn_spb_se;stock_A_12 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_12 = group_zscore(ts_ir(returns, 252), industry);alpha_A_12 = vector_neut(stock_A_12, factor_A_12);signal_A_12 = trade_when(pro_A_12<=0.5, alpha_A_12, pro_A_12>0.5);pro_A_13 = oth460_1l_fbbs;stock_A_13 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_13 = group_zscore(ts_ir(returns, 252), industry);alpha_A_13 = vector_neut(stock_A_13, factor_A_13);signal_A_13 = trade_when(pro_A_13<=0.5, alpha_A_13, pro_A_13>0.5);zscore(add(signal_A_12, signal_A_13, filter = false))',
#  'pro_A_6 = oth460_1l_m3r_mtn_spb_se;stock_A_6 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_6 = group_zscore(ts_ir(returns, 252), industry);alpha_A_6 = vector_neut(stock_A_6, factor_A_6);signal_A_6 = trade_when(pro_A_6<=0.5, alpha_A_6, pro_A_6>0.5);pro_A_7 = oth460_1l_fbbs;stock_A_7 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_7 = group_zscore(ts_ir(returns, 252), industry);alpha_A_7 = regression_neut(stock_A_7, factor_A_7);signal_A_7 = trade_when(pro_A_7<=0.5, alpha_A_7, pro_A_7>0.5);zscore(add(signal_A_6, signal_A_7, filter = false))',
#  'pro_A_4 = oth460_1l_m3r_mtn_spb_se;stock_A_4 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_4 = group_zscore(ts_ir(returns, 252), industry);alpha_A_4 = regression_neut(stock_A_4, factor_A_4);signal_A_4 = trade_when(pro_A_4<=0.5, alpha_A_4, pro_A_4>0.5);pro_A_5 = oth460_1l_fbds;stock_A_5 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_5 = group_zscore(ts_ir(returns, 252), industry);alpha_A_5 = regression_neut(stock_A_5, factor_A_5);signal_A_5 = trade_when(pro_A_5<=0.5, alpha_A_5, pro_A_5>0.5);zscore(add(signal_A_4, signal_A_5, filter = false))',
#  'pro_A_14 = oth460_1l_acda;stock_A_14 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_14 = group_zscore(ts_ir(returns, 252), industry);alpha_A_14 = regression_neut(stock_A_14, factor_A_14);signal_A_14 = trade_when(pro_A_14<=0.5, alpha_A_14, pro_A_14>0.5);pro_A_15 = oth460_1l_ccns;stock_A_15 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_15 = group_zscore(ts_ir(returns, 252), industry);alpha_A_15 = regression_neut(stock_A_15, factor_A_15);signal_A_15 = trade_when(pro_A_15<=0.5, alpha_A_15, pro_A_15>0.5);zscore(add(signal_A_14, signal_A_15, filter = false))',
#  'pro_A_16 = oth460_es_ebit_fy1_d1m_l1;stock_A_16 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_16 = group_zscore(ts_ir(returns, 252), industry);alpha_A_16 = vector_neut(stock_A_16, factor_A_16);signal_A_16 = trade_when(pro_A_16<=0.5, alpha_A_16, pro_A_16>0.5);pro_A_17 = oth460_1l_acda;stock_A_17 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_17 = group_zscore(ts_ir(returns, 252), industry);alpha_A_17 = vector_neut(stock_A_17, factor_A_17);signal_A_17 = trade_when(pro_A_17<=0.5, alpha_A_17, pro_A_17>0.5);zscore(add(signal_A_16, signal_A_17, filter = false))',
#  'pro_A_10 = oth460_1l_fbds;stock_A_10 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_10 = group_zscore(ts_ir(returns, 252), industry);alpha_A_10 = vector_neut(stock_A_10, factor_A_10);signal_A_10 = trade_when(pro_A_10<=0.5, alpha_A_10, pro_A_10>0.5);pro_A_11 = oth460_es_roe_fy1_d1m_l1;stock_A_11 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_11 = group_zscore(ts_ir(returns, 252), industry);alpha_A_11 = regression_neut(stock_A_11, factor_A_11);signal_A_11 = trade_when(pro_A_11<=0.5, alpha_A_11, pro_A_11>0.5);zscore(add(signal_A_10, signal_A_11, filter = false))',
#  'pro_A_18 = oth460_es_roe_fy1_d1m_l1;stock_A_18 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_18 = group_zscore(ts_ir(returns, 252), industry);alpha_A_18 = vector_neut(stock_A_18, factor_A_18);signal_A_18 = trade_when(pro_A_18<=0.5, alpha_A_18, pro_A_18>0.5);pro_A_19 = oth460_1l_ccns;stock_A_19 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_19 = group_zscore(ts_ir(returns, 252), industry);alpha_A_19 = vector_neut(stock_A_19, factor_A_19);signal_A_19 = trade_when(pro_A_19<=0.5, alpha_A_19, pro_A_19>0.5);zscore(add(signal_A_18, signal_A_19, filter = false))',
#  'pro_A_24 = oth460_1l_fbbs;stock_A_24 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_24 = group_zscore(ts_ir(returns, 252), industry);alpha_A_24 = regression_neut(stock_A_24, factor_A_24);signal_A_24 = trade_when(pro_A_24<=0.5, alpha_A_24, pro_A_24>0.5);pro_A_25 = oth460_1l_fbds;stock_A_25 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_25 = group_zscore(ts_ir(returns, 252), industry);alpha_A_25 = vector_neut(stock_A_25, factor_A_25);signal_A_25 = trade_when(pro_A_25<=0.5, alpha_A_25, pro_A_25>0.5);zscore(add(signal_A_24, signal_A_25, filter = false))',
#  'pro_A_20 = oth460_1l_m1r_1yf_spe_se;stock_A_20 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_20 = group_zscore(ts_ir(returns, 252), industry);alpha_A_20 = regression_neut(stock_A_20, factor_A_20);signal_A_20 = trade_when(pro_A_20<=0.5, alpha_A_20, pro_A_20>0.5);pro_A_21 = oth460_1l_fbds;stock_A_21 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_21 = group_zscore(ts_ir(returns, 252), industry);alpha_A_21 = regression_neut(stock_A_21, factor_A_21);signal_A_21 = trade_when(pro_A_21<=0.5, alpha_A_21, pro_A_21>0.5);zscore(add(signal_A_20, signal_A_21, filter = false))',
#  'pro_A_22 = oth460_es_ebit_fy1_d1m_l1;stock_A_22 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_22 = group_zscore(ts_ir(returns, 252), industry);alpha_A_22 = regression_neut(stock_A_22, factor_A_22);signal_A_22 = trade_when(pro_A_22<=0.5, alpha_A_22, pro_A_22>0.5);pro_A_23 = oth460_1l_m1r_1yf_spe_se;stock_A_23 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_23 = group_zscore(ts_ir(returns, 252), industry);alpha_A_23 = vector_neut(stock_A_23, factor_A_23);signal_A_23 = trade_when(pro_A_23<=0.5, alpha_A_23, pro_A_23>0.5);zscore(add(signal_A_22, signal_A_23, filter = false))']

# %%
alpha_list = [ace.generate_alpha(x, region= "GLB", universe = "MINVOL1M", neutralization = 'MARKET', truncation = 0.02, decay = 5) for x in passed_expression]

alpha_list
# Out:
# [{'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_0 = oth460_1l_acda;stock_A_0 = ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21);factor_A_0 = group_zscore(ts_ir(returns, 252), industry);alpha_A_0 = regression_neut(stock_A_0, factor_A_0);signal_A_0 = trade_when(pro_A_0<=0.5, alpha_A_0, pro_A_0>0.5);pro_A_1 = oth460_1l_ccns;stock_A_1 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_1 = group_zscore(ts_ir(returns, 252), industry);alpha_A_1 = regression_neut(stock_A_1, factor_A_1);signal_A_1 = trade_when(pro_A_1<=0.5, alpha_A_1, pro_A_1>0.5);zscore(add(signal_A_0, signal_A_1, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_2 = oth460_1l_ccns;stock_A_2 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_2 = group_zscore(ts_ir(returns, 252), industry);alpha_A_2 = vector_neut(stock_A_2, factor_A_2);signal_A_2 = trade_when(pro_A_2<=0.5, alpha_A_2, pro_A_2>0.5);pro_A_3 = oth460_1l_acda;stock_A_3 = ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21);factor_A_3 = group_zscore(ts_ir(returns, 252), industry);alpha_A_3 = vector_neut(stock_A_3, factor_A_3);signal_A_3 = trade_when(pro_A_3<=0.5, alpha_A_3, pro_A_3>0.5);zscore(add(signal_A_2, signal_A_3, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_8 = oth460_es_ebit_fy1_d1m_l1;stock_A_8 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_8 = group_zscore(ts_ir(returns, 252), industry);alpha_A_8 = regression_neut(stock_A_8, factor_A_8);signal_A_8 = trade_when(pro_A_8<=0.5, alpha_A_8, pro_A_8>0.5);pro_A_9 = oth460_1l_m3r_mtn_spb_se;stock_A_9 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_9 = group_zscore(ts_ir(returns, 252), industry);alpha_A_9 = regression_neut(stock_A_9, factor_A_9);signal_A_9 = trade_when(pro_A_9<=0.5, alpha_A_9, pro_A_9>0.5);zscore(add(signal_A_8, signal_A_9, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_12 = oth460_1l_m3r_mtn_spb_se;stock_A_12 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_12 = group_zscore(ts_ir(returns, 252), industry);alpha_A_12 = vector_neut(stock_A_12, factor_A_12);signal_A_12 = trade_when(pro_A_12<=0.5, alpha_A_12, pro_A_12>0.5);pro_A_13 = oth460_1l_fbbs;stock_A_13 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_13 = group_zscore(ts_ir(returns, 252), industry);alpha_A_13 = vector_neut(stock_A_13, factor_A_13);signal_A_13 = trade_when(pro_A_13<=0.5, alpha_A_13, pro_A_13>0.5);zscore(add(signal_A_12, signal_A_13, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_6 = oth460_1l_m3r_mtn_spb_se;stock_A_6 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_6 = group_zscore(ts_ir(returns, 252), industry);alpha_A_6 = vector_neut(stock_A_6, factor_A_6);signal_A_6 = trade_when(pro_A_6<=0.5, alpha_A_6, pro_A_6>0.5);pro_A_7 = oth460_1l_fbbs;stock_A_7 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_7 = group_zscore(ts_ir(returns, 252), industry);alpha_A_7 = regression_neut(stock_A_7, factor_A_7);signal_A_7 = trade_when(pro_A_7<=0.5, alpha_A_7, pro_A_7>0.5);zscore(add(signal_A_6, signal_A_7, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_4 = oth460_1l_m3r_mtn_spb_se;stock_A_4 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_4 = group_zscore(ts_ir(returns, 252), industry);alpha_A_4 = regression_neut(stock_A_4, factor_A_4);signal_A_4 = trade_when(pro_A_4<=0.5, alpha_A_4, pro_A_4>0.5);pro_A_5 = oth460_1l_fbds;stock_A_5 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_5 = group_zscore(ts_ir(returns, 252), industry);alpha_A_5 = regression_neut(stock_A_5, factor_A_5);signal_A_5 = trade_when(pro_A_5<=0.5, alpha_A_5, pro_A_5>0.5);zscore(add(signal_A_4, signal_A_5, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_14 = oth460_1l_acda;stock_A_14 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_14 = group_zscore(ts_ir(returns, 252), industry);alpha_A_14 = regression_neut(stock_A_14, factor_A_14);signal_A_14 = trade_when(pro_A_14<=0.5, alpha_A_14, pro_A_14>0.5);pro_A_15 = oth460_1l_ccns;stock_A_15 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_15 = group_zscore(ts_ir(returns, 252), industry);alpha_A_15 = regression_neut(stock_A_15, factor_A_15);signal_A_15 = trade_when(pro_A_15<=0.5, alpha_A_15, pro_A_15>0.5);zscore(add(signal_A_14, signal_A_15, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_16 = oth460_es_ebit_fy1_d1m_l1;stock_A_16 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_16 = group_zscore(ts_ir(returns, 252), industry);alpha_A_16 = vector_neut(stock_A_16, factor_A_16);signal_A_16 = trade_when(pro_A_16<=0.5, alpha_A_16, pro_A_16>0.5);pro_A_17 = oth460_1l_acda;stock_A_17 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_17 = group_zscore(ts_ir(returns, 252), industry);alpha_A_17 = vector_neut(stock_A_17, factor_A_17);signal_A_17 = trade_when(pro_A_17<=0.5, alpha_A_17, pro_A_17>0.5);zscore(add(signal_A_16, signal_A_17, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_10 = oth460_1l_fbds;stock_A_10 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_10 = group_zscore(ts_ir(returns, 252), industry);alpha_A_10 = vector_neut(stock_A_10, factor_A_10);signal_A_10 = trade_when(pro_A_10<=0.5, alpha_A_10, pro_A_10>0.5);pro_A_11 = oth460_es_roe_fy1_d1m_l1;stock_A_11 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_11 = group_zscore(ts_ir(returns, 252), industry);alpha_A_11 = regression_neut(stock_A_11, factor_A_11);signal_A_11 = trade_when(pro_A_11<=0.5, alpha_A_11, pro_A_11>0.5);zscore(add(signal_A_10, signal_A_11, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_18 = oth460_es_roe_fy1_d1m_l1;stock_A_18 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_18 = group_zscore(ts_ir(returns, 252), industry);alpha_A_18 = vector_neut(stock_A_18, factor_A_18);signal_A_18 = trade_when(pro_A_18<=0.5, alpha_A_18, pro_A_18>0.5);pro_A_19 = oth460_1l_ccns;stock_A_19 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_19 = group_zscore(ts_ir(returns, 252), industry);alpha_A_19 = vector_neut(stock_A_19, factor_A_19);signal_A_19 = trade_when(pro_A_19<=0.5, alpha_A_19, pro_A_19>0.5);zscore(add(signal_A_18, signal_A_19, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_24 = oth460_1l_fbbs;stock_A_24 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_24 = group_zscore(ts_ir(returns, 252), industry);alpha_A_24 = regression_neut(stock_A_24, factor_A_24);signal_A_24 = trade_when(pro_A_24<=0.5, alpha_A_24, pro_A_24>0.5);pro_A_25 = oth460_1l_fbds;stock_A_25 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_25 = group_zscore(ts_ir(returns, 252), industry);alpha_A_25 = vector_neut(stock_A_25, factor_A_25);signal_A_25 = trade_when(pro_A_25<=0.5, alpha_A_25, pro_A_25>0.5);zscore(add(signal_A_24, signal_A_25, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_20 = oth460_1l_m1r_1yf_spe_se;stock_A_20 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_20 = group_zscore(ts_ir(returns, 252), industry);alpha_A_20 = regression_neut(stock_A_20, factor_A_20);signal_A_20 = trade_when(pro_A_20<=0.5, alpha_A_20, pro_A_20>0.5);pro_A_21 = oth460_1l_fbds;stock_A_21 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_21 = group_zscore(ts_ir(returns, 252), industry);alpha_A_21 = regression_neut(stock_A_21, factor_A_21);signal_A_21 = trade_when(pro_A_21<=0.5, alpha_A_21, pro_A_21>0.5);zscore(add(signal_A_20, signal_A_21, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'MARKET',
#    'truncation': 0.02,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'pro_A_22 = oth460_es_ebit_fy1_d1m_l1;stock_A_22 = ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21);factor_A_22 = group_zscore(ts_ir(returns, 252), industry);alpha_A_22 = regression_neut(stock_A_22, factor_A_22);signal_A_22 = trade_when(pro_A_22<=0.5, alpha_A_22, pro_A_22>0.5);pro_A_23 = oth460_1l_m1r_1yf_spe_se;stock_A_23 = ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21);factor_A_23 = group_zscore(ts_ir(returns, 252), industry);alpha_A_23 = vector_neut(stock_A_23, factor_A_23);signal_A_23 = trade_when(pro_A_23<=0.5, alpha_A_23, pro_A_23>0.5);zscore(add(signal_A_22, signal_A_23, filter = false))'}]

# %%
result = ace.simulate_alpha_list_multi(s, alpha_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [26:46<00:00, 321.34s/it]

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#          pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   13148568   20000000         941          984    0.2665   0.1270    0.0522
# 1   13116265   20000000         934          991    0.2611   0.1267    0.0557
# 2   14914371   20000000         925          928    0.4040   0.1440    0.0611
# 3   14701038   20000000         935          933    0.4092   0.1420    0.0654
# 4   16601812   20000000         806          825    0.4054   0.1603    0.0783
# 5   15633768   20000000        1025         1075    0.3874   0.1510    0.0625
# 6   10431152   20000000         923          969    0.2629   0.1007    0.0734
# 7   12854034   20000000        1362         1447    0.2862   0.1241    0.0948
# 8   12216787   20000000        1316         1382    0.3536   0.1180    0.0755
# 9   13017343   20000000         837          909    0.3110   0.1257    0.0909
# 10  10557441   20000000        1398         1432    0.3157   0.1019    0.1031
# 11  12596862   20000000         798          886    0.4237   0.1216    0.0739
# 12  11584851   20000000        1046         1191    0.3831   0.1119    0.0725
#
#       margin  fitness  sharpe  start_date alpha_id  \
# 0   0.000953     1.65    2.39  2012-01-22  MpZJEKn
# 1   0.000970     1.57    2.26  2012-01-22  xxWJLel
# 2   0.000713     1.46    2.44  2012-01-22  ngQLAox
# 3   0.000694     1.46    2.47  2012-01-22  QagwYlG
# 4   0.000791     1.45    2.31  2012-01-22  7wMeoq5
# 5   0.000779     1.44    2.30  2012-01-22  9wmNeJd
# 6   0.000766     1.24    2.00  2012-01-22  GwxZ2G5
# 7   0.000867     1.22    1.86  2012-01-22  9wmNeVV
# 8   0.000667     1.19    2.06  2012-01-22  3758KXN
# 9   0.000808     1.14    1.80  2012-01-22  eOvXP1M
# 10  0.000646     1.10    1.94  2012-01-22  Vp5ALZM
# 11  0.000574     1.01    1.89  2012-01-22  RpKGolz
# 12  0.000584     0.93    1.72  2012-01-22  p63qrqV
#
#                                            expression concentrated_weight  \
# 0   pro_A_0 = oth460_1l_acda;stock_A_0 = ts_zscore...                PASS
# 1   pro_A_2 = oth460_1l_ccns;stock_A_2 = ts_zscore...                PASS
# 2   pro_A_6 = oth460_1l_m3r_mtn_spb_se;stock_A_6 =...                PASS
# 3   pro_A_4 = oth460_1l_m3r_mtn_spb_se;stock_A_4 =...                PASS
# 4   pro_A_12 = oth460_1l_m3r_mtn_spb_se;stock_A_12...                PASS
# 5   pro_A_8 = oth460_es_ebit_fy1_d1m_l1;stock_A_8 ...                PASS
# 6   pro_A_14 = oth460_1l_acda;stock_A_14 = ts_zsco...                PASS
# 7   pro_A_16 = oth460_es_ebit_fy1_d1m_l1;stock_A_1...                PASS
# 8   pro_A_10 = oth460_1l_fbds;stock_A_10 = ts_zsco...                PASS
# 9   pro_A_18 = oth460_es_roe_fy1_d1m_l1;stock_A_18...                PASS
# 10  pro_A_24 = oth460_1l_fbbs;stock_A_24 = ts_zsco...                PASS
# 11  pro_A_20 = oth460_1l_m1r_1yf_spe_se;stock_A_20...                PASS
# 12  pro_A_22 = oth460_es_ebit_fy1_d1m_l1;stock_A_2...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             PASS        PASS       PASS
# 1           PASS             FAIL        PASS       PASS
# 2           PASS             PASS        PASS       PASS
# 3           PASS             PASS        PASS       PASS
# 4           PASS             PASS        PASS       PASS
# 5           PASS             PASS        PASS       PASS
# 6           PASS             FAIL        PASS       PASS
# 7           PASS             FAIL        PASS       PASS
# 8           PASS             FAIL        PASS       PASS
# 9           PASS             FAIL        PASS       PASS
# 10          PASS             FAIL        PASS       PASS
# 11          PASS             FAIL        PASS       PASS
# 12          PASS             FAIL        FAIL       PASS
#
#    low_sub_universe_sharpe low_turnover
# 0                     PASS         PASS
# 1                     PASS         PASS
# 2                     PASS         PASS
# 3                     PASS         PASS
# 4                     PASS         PASS
# 5                     PASS         PASS
# 6                     PASS         PASS
# 7                     PASS         PASS
# 8                     PASS         PASS
# 9                     PASS         PASS
# 10                    PASS         PASS
# 11                    PASS         PASS
# 12                    PASS         PASS

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df.head()
# Out:
#   alpha_id endDate  limit                 name result startDate   value  year
# 0  7wMeoq5     NaN   1.58           LOW_SHARPE   PASS       NaN  2.3100   NaN
# 1  7wMeoq5     NaN   1.00          LOW_FITNESS   PASS       NaN  1.4500   NaN
# 2  7wMeoq5     NaN   0.01         LOW_TURNOVER   PASS       NaN  0.4054   NaN
# 3  7wMeoq5     NaN   0.70        HIGH_TURNOVER   PASS       NaN  0.4054   NaN
# 4  7wMeoq5     NaN    NaN  CONCENTRATED_WEIGHT   PASS       NaN     NaN   NaN

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['eOvXP1M' 'Vp5ALZM' 'RpKGolz' 'xxWJLel' 'GwxZ2G5' '9wmNeVV' '3758KXN'
#  'p63qrqV']
# Passed alphas:['ngQLAox', 'QagwYlG', 'MpZJEKn', '7wMeoq5', '9wmNeJd']

# %%
for alpha_id in passed_alphas:
    print(ace.check_prod_corr_test(s, alpha_id))
# Out:
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.8  ngQLAox
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.8  QagwYlG
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.9  MpZJEKn
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    0.9  7wMeoq5
#                test result  limit  value alpha_id
# 0  PROD_CORRELATION   FAIL    0.7    1.0  9wmNeJd

# %%
submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas}

# %%
submit_result
# Out:
# {'xxW7pdN': False,
#  'YpJom7l': False,
#  'roVMLl3': False,
#  'qA32a9A': False,
#  'Awm8Y2l': False,
#  'jZxK0AZ': False}

# %%
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['summer_boot_camp_4조'])

# %%
ace.get_check_submission(s, passed_alphas[0])
# Out:
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.0200
# 1              LOW_FITNESS   PASS   1.00  1.1200
# 2             LOW_TURNOVER   PASS   0.01  0.3259
# 3            HIGH_TURNOVER   PASS   0.70  0.3259
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.87  0.9200
# 6         SELF_CORRELATION   PASS   0.70  0.4739
# 7         PROD_CORRELATION   PASS   0.70  0.6252
# 8       REGULAR_SUBMISSION   PASS   4.00  3.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  oKP2Wrl
# 1                                         NaN  oKP2Wrl
# 2                                         NaN  oKP2Wrl
# 3                                         NaN  oKP2Wrl
# 4                                         NaN  oKP2Wrl
# 5                                         NaN  oKP2Wrl
# 6                                         NaN  oKP2Wrl
# 7                                         NaN  oKP2Wrl
# 8                                         NaN  oKP2Wrl
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  oKP2Wrl

# %% [markdown]
# When you got a list of submittable alphas, you can call function submit_alpha()

# %%
#calling submit_alpha on all alphas that have passed the submission tests
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['summer_boot_camp_4조'])
submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas}

# %%
#submit_result will have return values from the submit_result function

submit_result
# Out:
# {'oKP2Wrl': True}

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance

# %%
ace.get_alpha_pnl(s, result[0]['alpha_id'])
# Out:
#                    Pnl alpha_id
# Date
# 2012-01-23         0.0  dx9ALqJ
# 2012-01-24     52190.0  dx9ALqJ
# 2012-01-25     32038.0  dx9ALqJ
# 2012-01-26     37403.0  dx9ALqJ
# 2012-01-27     53631.0  dx9ALqJ
# ...                ...      ...
# 2022-01-17  12935472.0  dx9ALqJ
# 2022-01-18  12935661.0  dx9ALqJ
# 2022-01-19  12967474.0  dx9ALqJ
# 2022-01-20  12966156.0  dx9ALqJ
# 2022-01-21  12958392.0  dx9ALqJ
#
# [2588 rows x 2 columns]
