# %% [markdown]
# ### Import library

# %%
import os
os.chdir('../..')
os.getcwd()
# Out:
# 'C:\\Users\\csia7\\OneDrive\\문서\\GitHub\\WQBrain_2024_API'

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px
import pygwalker as pyg
import glob
import re

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_mJXehjgCZxdsY6hU1neKzQNAxBrG

# %%
ace.check_session_timeout(s)
# Out:
# 14399.133222

# %% [markdown]
# ## Alpha Mixing Templates

# %% [markdown]
# ## Read all passed alphas

# %%
os.chdir('Results/signal')
file_direc = glob.glob('*')
file_direc
# Out:
# ['A_signalform.csv',
#  'B_signalform.csv',
#  'C_signalform.csv',
#  'D_signalform.csv',
#  'pre_signalform.csv',
#  'Sep03GLB_signalform.csv']

# %%
expressions = {}
for file in file_direc:
    expressions[file.split('_')[0]] = pd.read_csv(file)['expression']
#expressions

# %%
os.chdir('../..')

# %%
expressions.keys()
# Out:
# dict_keys(['A', 'B', 'C', 'D', 'pre', 'Sep03GLB'])

# %%
expressions['pre']
# Out:
# 0    sig_pre_0 = group_zscore(ts_zscore(ts_backfill...
# Name: expression, dtype: object

# %% [markdown]
# ## Template A & pre mixing
# use top 32 results

# %%
#region= "GLB", universe = "MINVOL1M", neutralization = 'MARKET', truncation = 0.01

# %%
B = expressions['B']
pre = expressions['pre']
#Sep03GLB = expressions['Sep03GLB']

# %%
alpha_list_Bpre = []

for i in range(40):
    alpha_list_Bpre += [ace.generate_alpha(f'{B[i]};{pre[0]};add(scale_down(signal_B_{i}), scale_down(signal_pre_{0}), filter = false)', region= "GLB", universe = "MINVOL1M", neutralization = x, truncation = 0.008, decay = 7) for x in ['COUNTRY', 'SECTOR']]

alpha_list_Bpre
# Out:
# [{'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_0 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_0 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_0 = entry_B_0 < 0.5;signal_B_0 =  trade_when(entry_B_0>0.55, maintenance_B_0, quit_B_0);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_0), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_0 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_0 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_0 = entry_B_0 < 0.5;signal_B_0 =  trade_when(entry_B_0>0.55, maintenance_B_0, quit_B_0);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_0), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_1 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_1 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_1 = entry_B_1 < 0.5;signal_B_1 =  trade_when(entry_B_1>0.55, maintenance_B_1, quit_B_1);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_1), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_1 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_1 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_1 = entry_B_1 < 0.5;signal_B_1 =  trade_when(entry_B_1>0.55, maintenance_B_1, quit_B_1);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_1), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_2 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_2 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_2 = entry_B_2 < 0.5;signal_B_2 =  trade_when(entry_B_2>0.55, maintenance_B_2, quit_B_2);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_2), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_2 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_2 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_2 = entry_B_2 < 0.5;signal_B_2 =  trade_when(entry_B_2>0.55, maintenance_B_2, quit_B_2);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_2), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_3 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_3 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_3 = entry_B_3 < 0.5;signal_B_3 =  trade_when(entry_B_3>0.55, maintenance_B_3, quit_B_3);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_3), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_3 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_3 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_3 = entry_B_3 < 0.5;signal_B_3 =  trade_when(entry_B_3>0.55, maintenance_B_3, quit_B_3);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_3), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_4 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_4 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_4 = entry_B_4 < 0.5;signal_B_4 =  trade_when(entry_B_4>0.55, maintenance_B_4, quit_B_4);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_4), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_4 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_4 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_4 = entry_B_4 < 0.5;signal_B_4 =  trade_when(entry_B_4>0.55, maintenance_B_4, quit_B_4);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_4), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_5 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_5 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_5 = entry_B_5 < 0.5;signal_B_5 =  trade_when(entry_B_5>0.55, maintenance_B_5, quit_B_5);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_5), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_5 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_5 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_5 = entry_B_5 < 0.5;signal_B_5 =  trade_when(entry_B_5>0.55, maintenance_B_5, quit_B_5);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_5), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_6 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_6 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_6 = entry_B_6 < 0.5;signal_B_6 =  trade_when(entry_B_6>0.55, maintenance_B_6, quit_B_6);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_6), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_6 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_6 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_6 = entry_B_6 < 0.5;signal_B_6 =  trade_when(entry_B_6>0.55, maintenance_B_6, quit_B_6);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_6), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_7 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_7 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_7 = entry_B_7 < 0.5;signal_B_7 =  trade_when(entry_B_7>0.55, maintenance_B_7, quit_B_7);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_7), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_7 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_7 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_7 = entry_B_7 < 0.5;signal_B_7 =  trade_when(entry_B_7>0.55, maintenance_B_7, quit_B_7);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_7), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_8 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_8 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_8 = entry_B_8 < 0.5;signal_B_8 =  trade_when(entry_B_8>0.55, maintenance_B_8, quit_B_8);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_8), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_8 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_8 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_8 = entry_B_8 < 0.5;signal_B_8 =  trade_when(entry_B_8>0.55, maintenance_B_8, quit_B_8);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_8), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_9 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_9 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_9 = entry_B_9 < 0.5;signal_B_9 =  trade_when(entry_B_9>0.55, maintenance_B_9, quit_B_9);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_9), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_9 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_9 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_9 = entry_B_9 < 0.5;signal_B_9 =  trade_when(entry_B_9>0.55, maintenance_B_9, quit_B_9);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_9), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_10 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_10 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_10 = entry_B_10 < 0.5;signal_B_10 =  trade_when(entry_B_10>0.55, maintenance_B_10, quit_B_10);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_10), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_10 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_10 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_10 = entry_B_10 < 0.5;signal_B_10 =  trade_when(entry_B_10>0.55, maintenance_B_10, quit_B_10);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_10), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_11 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_11 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_11 = entry_B_11 < 0.5;signal_B_11 =  trade_when(entry_B_11>0.55, maintenance_B_11, quit_B_11);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_11), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_11 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_11 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_11 = entry_B_11 < 0.5;signal_B_11 =  trade_when(entry_B_11>0.55, maintenance_B_11, quit_B_11);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_11), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_12 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_12 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_12 = entry_B_12 < 0.5;signal_B_12 =  trade_when(entry_B_12>0.55, maintenance_B_12, quit_B_12);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_12), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_12 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_12 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_12 = entry_B_12 < 0.5;signal_B_12 =  trade_when(entry_B_12>0.55, maintenance_B_12, quit_B_12);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_12), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_13 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_13 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_13 = entry_B_13 < 0.5;signal_B_13 =  trade_when(entry_B_13>0.55, maintenance_B_13, quit_B_13);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_13), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_13 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_13 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_13 = entry_B_13 < 0.5;signal_B_13 =  trade_when(entry_B_13>0.55, maintenance_B_13, quit_B_13);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_13), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_14 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_14 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_14 = entry_B_14 < 0.5;signal_B_14 =  trade_when(entry_B_14>0.55, maintenance_B_14, quit_B_14);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_14), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_14 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_14 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_14 = entry_B_14 < 0.5;signal_B_14 =  trade_when(entry_B_14>0.55, maintenance_B_14, quit_B_14);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_14), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_15 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_15 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_15 = entry_B_15 < 0.5;signal_B_15 =  trade_when(entry_B_15>0.55, maintenance_B_15, quit_B_15);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_15), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_15 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_15 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_15 = entry_B_15 < 0.5;signal_B_15 =  trade_when(entry_B_15>0.55, maintenance_B_15, quit_B_15);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_15), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_16 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_16 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_16 = entry_B_16 < 0.5;signal_B_16 =  trade_when(entry_B_16>0.55, maintenance_B_16, quit_B_16);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_16), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_16 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_16 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_16 = entry_B_16 < 0.5;signal_B_16 =  trade_when(entry_B_16>0.55, maintenance_B_16, quit_B_16);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_16), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_17 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_17 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_17 = entry_B_17 < 0.5;signal_B_17 =  trade_when(entry_B_17>0.55, maintenance_B_17, quit_B_17);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_17), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_17 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_17 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_17 = entry_B_17 < 0.5;signal_B_17 =  trade_when(entry_B_17>0.55, maintenance_B_17, quit_B_17);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_17), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_18 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_18 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_18 = entry_B_18 < 0.5;signal_B_18 =  trade_when(entry_B_18>0.55, maintenance_B_18, quit_B_18);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_18), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_18 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_18 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_18 = entry_B_18 < 0.5;signal_B_18 =  trade_when(entry_B_18>0.55, maintenance_B_18, quit_B_18);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_18), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_19 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_19 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_19 = entry_B_19 < 0.5;signal_B_19 =  trade_when(entry_B_19>0.55, maintenance_B_19, quit_B_19);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_19), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_19 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_19 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_19 = entry_B_19 < 0.5;signal_B_19 =  trade_when(entry_B_19>0.55, maintenance_B_19, quit_B_19);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_19), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_20 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_20 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_20 = entry_B_20 < 0.5;signal_B_20 =  trade_when(entry_B_20>0.55, maintenance_B_20, quit_B_20);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_20), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_20 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_20 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_20 = entry_B_20 < 0.5;signal_B_20 =  trade_when(entry_B_20>0.55, maintenance_B_20, quit_B_20);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_20), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_21 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_21 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_21 = entry_B_21 < 0.5;signal_B_21 =  trade_when(entry_B_21>0.55, maintenance_B_21, quit_B_21);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_21), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_21 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_21 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_21 = entry_B_21 < 0.5;signal_B_21 =  trade_when(entry_B_21>0.55, maintenance_B_21, quit_B_21);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_21), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_22 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_22 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_22 = entry_B_22 < 0.5;signal_B_22 =  trade_when(entry_B_22>0.55, maintenance_B_22, quit_B_22);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_22), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_22 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_22 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_22 = entry_B_22 < 0.5;signal_B_22 =  trade_when(entry_B_22>0.55, maintenance_B_22, quit_B_22);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_22), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_23 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_23 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_23 = entry_B_23 < 0.5;signal_B_23 =  trade_when(entry_B_23>0.55, maintenance_B_23, quit_B_23);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_23), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_23 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_23 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_23 = entry_B_23 < 0.5;signal_B_23 =  trade_when(entry_B_23>0.55, maintenance_B_23, quit_B_23);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_23), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
# ...
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_32 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_32 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_32 = entry_B_32 < 0.5;signal_B_32 =  trade_when(entry_B_32>0.55, maintenance_B_32, quit_B_32);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_32), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_32 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_32 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_32 = entry_B_32 < 0.5;signal_B_32 =  trade_when(entry_B_32>0.55, maintenance_B_32, quit_B_32);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_32), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_33 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_33 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_33 = entry_B_33 < 0.5;signal_B_33 =  trade_when(entry_B_33>0.55, maintenance_B_33, quit_B_33);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_33), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_33 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_33 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_33 = entry_B_33 < 0.5;signal_B_33 =  trade_when(entry_B_33>0.55, maintenance_B_33, quit_B_33);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_33), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_34 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_34 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_34 = entry_B_34 < 0.5;signal_B_34 =  trade_when(entry_B_34>0.55, maintenance_B_34, quit_B_34);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_34), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_34 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_34 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_34 = entry_B_34 < 0.5;signal_B_34 =  trade_when(entry_B_34>0.55, maintenance_B_34, quit_B_34);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_34), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_35 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_35 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_35 = entry_B_35 < 0.5;signal_B_35 =  trade_when(entry_B_35>0.55, maintenance_B_35, quit_B_35);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_35), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_35 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_35 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_35 = entry_B_35 < 0.5;signal_B_35 =  trade_when(entry_B_35>0.55, maintenance_B_35, quit_B_35);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_35), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_36 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_36 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_36 = entry_B_36 < 0.5;signal_B_36 =  trade_when(entry_B_36>0.55, maintenance_B_36, quit_B_36);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_36), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_36 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_36 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_36 = entry_B_36 < 0.5;signal_B_36 =  trade_when(entry_B_36>0.55, maintenance_B_36, quit_B_36);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_36), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_37 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_37 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_37 = entry_B_37 < 0.5;signal_B_37 =  trade_when(entry_B_37>0.55, maintenance_B_37, quit_B_37);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_37), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_37 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_37 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_37 = entry_B_37 < 0.5;signal_B_37 =  trade_when(entry_B_37>0.55, maintenance_B_37, quit_B_37);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_37), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_38 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_38 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_38 = entry_B_38 < 0.5;signal_B_38 =  trade_when(entry_B_38>0.55, maintenance_B_38, quit_B_38);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_38), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_38 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_38 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_38 = entry_B_38 < 0.5;signal_B_38 =  trade_when(entry_B_38>0.55, maintenance_B_38, quit_B_38);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_38), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_39 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_39 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_39 = entry_B_39 < 0.5;signal_B_39 =  trade_when(entry_B_39>0.55, maintenance_B_39, quit_B_39);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_39), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 7,
#    'neutralization': 'SECTOR',
#    'truncation': 0.008,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_39 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_39 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_39 = entry_B_39 < 0.5;signal_B_39 =  trade_when(entry_B_39>0.55, maintenance_B_39, quit_B_39);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_39), scale_down(signal_pre_0), filter = false)'}]

# %%
result = ace.simulate_alpha_list_multi(s, alpha_list_Bpre)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 27/27 [1:19:27<00:00, 176.59s/it]

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#          pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   19651997   20000000         714          657    0.5004   0.1898    0.0271
# 1   19528771   20000000         703          646    0.5018   0.1886    0.0239
# 2   24048515   20000000         649          609    0.4971   0.2322    0.0526
# 3   23714268   20000000         638          598    0.4985   0.2290    0.0495
# 4   18748359   20000000         631          594    0.4987   0.1810    0.0294
# ..       ...        ...         ...          ...       ...      ...       ...
# 75  12325613   20000000         470          453    0.3533   0.1190    0.0893
# 76  12559217   20000000         465          428    0.4512   0.1213    0.0915
# 77  12778223   20000000         362          341    0.3261   0.1234    0.1500
# 78  10399505   20000000         363          337    0.3569   0.1004    0.0898
# 79  10263432   20000000         618          594    0.3609   0.0991    0.0706
#
#       margin  fitness  sharpe  start_date alpha_id  \
# 0   0.000758     2.61    4.24  2012-01-22  plYK9Jq
# 1   0.000752     2.60    4.24  2012-01-22  P3QOkn7
# 2   0.000934     2.58    3.77  2012-01-22  5OnkGk1
# 3   0.000919     2.55    3.76  2012-01-22  mbwVjGK
# 4   0.000726     2.49    4.14  2012-01-22  Xnm8Npz
# ..       ...      ...     ...         ...      ...
# 75  0.000674     0.96    1.65  2012-01-22  QVZGNjr
# 76  0.000538     0.93    1.79  2012-01-22  wlKa7wY
# 77  0.000757     0.92    1.50  2012-01-22  xkON9Wg
# 78  0.000563     0.89    1.67  2012-01-22  717z0mL
# 79  0.000549     0.82    1.56  2012-01-22  zmKNWlE
#
#                                            expression concentrated_weight  \
# 0   entry_B_16 = ts_rank( ts_std_dev(oth460_1l_ccn...                PASS
# 1   entry_B_14 = ts_rank( ts_std_dev(oth460_1l_ccn...                PASS
# 2   entry_B_8 = ts_rank( ts_std_dev(oth460_veia_l2...                PASS
# 3   entry_B_3 = ts_rank( ts_std_dev(oth460_veia_l2...                PASS
# 4   entry_B_6 = ts_rank( ts_std_dev(oth460_1l_2dls...                PASS
# ..                                                ...                 ...
# 75  entry_B_35 = ts_rank( ts_std_dev(oth460_1l_aie...                PASS
# 76  entry_B_39 = ts_rank( ts_std_dev(oth460_1l_aie...                PASS
# 77  entry_B_24 = ts_rank( ts_std_dev(oth460_fprd_c...                FAIL
# 78  entry_B_24 = ts_rank( ts_std_dev(oth460_fprd_c...                PASS
# 79  entry_B_30 = ts_rank( ts_std_dev(oth460_1l_1dl...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             PASS        PASS       PASS
# 1           PASS             PASS        PASS       PASS
# 2           PASS             PASS        PASS       PASS
# 3           PASS             PASS        PASS       PASS
# 4           PASS             PASS        PASS       PASS
# ..           ...              ...         ...        ...
# 75          PASS             FAIL        FAIL       PASS
# 76          PASS             FAIL        FAIL       PASS
# 77          PASS             FAIL        FAIL       FAIL
# 78          PASS             FAIL        FAIL       PASS
# 79          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover
# 0                     PASS         PASS
# 1                     PASS         PASS
# 2                     PASS         PASS
# 3                     PASS         PASS
# 4                     PASS         PASS
# ..                     ...          ...
# 75                    PASS         PASS
# 76                    PASS         PASS
# 77                    PASS         PASS
# 78                    FAIL         PASS
# 79                    FAIL         PASS
#
# [80 rows x 20 columns]

# %%
path = 'Results/mixing'
result_st1.to_csv(path + '/B&pre_mixing_add_Sep11.csv')

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df.head()
# Out:
#   alpha_id date endDate  limit                 name result startDate themes  \
# 0  ZnPK71n  NaN     NaN   1.58           LOW_SHARPE   PASS       NaN    NaN
# 1  ZnPK71n  NaN     NaN   1.00          LOW_FITNESS   PASS       NaN    NaN
# 2  ZnPK71n  NaN     NaN   0.01         LOW_TURNOVER   PASS       NaN    NaN
# 3  ZnPK71n  NaN     NaN   0.70        HIGH_TURNOVER   PASS       NaN    NaN
# 4  ZnPK71n  NaN     NaN    NaN  CONCENTRATED_WEIGHT   PASS       NaN    NaN
#
#     value  year
# 0  3.5900   NaN
# 1  2.3100   NaN
# 2  0.5068   NaN
# 3  0.5068   NaN
# 4     NaN   NaN

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['mbwVNAp' '5Onp0LN' '9rZp1m1' 'VP1GJnb' '5OnpNrz' '717z0mL' 'xkON9Wg'
#  'llpWk9A' 'EEOGYdP' '0EOp8Y6' 'vlwNmAz' 'anj1Op1' 'zmKNWlE' 'd0kZR3Y'
#  'rlp2el9' 'QVZGK9w' 'd0kZKeE' 'JOMGWYx' 'QVZGNjr' 'plYN3wg' 'llpWwJl'
#  'wlKa7wY']
# Passed alphas:['3RQeOx0', 'Xnm8ObX', 'zmKRARo', 'VP1Gdn0', 'Xnm8OJX', '1dkzRmX', 'Y0LgRZo', 'wlKake6', 'vlwNR83', 'ql9656v', 'Y0LvopW', '2L8pN9P', 'EEOGRwG', 'L1VGOEe', '0EOMaXq', '5OnkGk1', 'k0EPrOg', '1dkp7YJ', 'vlwNmYz', 'K9lE7oj', '2L8prr5', 'ql9NrPE', 'GL1GAzQ', 'OZQGP5J', 'QVZ9wmG', 'plYK9Jq', 'Y0Lvqqo', 'JOMGP0E', '8Q5pxpa', 'mbwVjGK', 'anjE5N5', 'QVZ97RW', 'APj7LPg', 'd0kRPOK', 'VP137L5', 'Xnm8Npz', 'EEOe2pR', 'MQML7E8', 'GL1el7Z', '1dkzGdX', 'P3QOAgJ', 'GL1elRG', 'gMk8wnv', 'k0EPqxk', 'llpWXZn', '69mpoPE', 'Xnm8N8m', 'n2xNr1w', 'P3QOkn7', 'vlwNPRG', 'vlwNap3', '3RQelNQ', 'ZnPK71n', 'ZnPKXKQ', 'EEOe9qJ', '5OnkGO1', '717znG8', 'j0z6Wqe']

# %%
#calling submit_alpha on all alphas that have passed the submission tests
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['Sep11_mixing'])

# %%
submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas[:10]}
submit_result
# Out:
# {'3RQeOx0': True,
#  'Xnm8ObX': False,
#  'zmKRARo': False,
#  'VP1Gdn0': True,
#  'Xnm8OJX': False,
#  '1dkzRmX': False,
#  'Y0LgRZo': False,
#  'wlKake6': True,
#  'vlwNR83': False,
#  'ql9656v': False}

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance

# %%
ace.get_alpha_pnl(s, result[0]['alpha_id'])
# Out:
#                    Pnl alpha_id
# Date
# 2012-01-23         0.0  dx9ALqJ
# 2012-01-24     52190.0  dx9ALqJ
# 2012-01-25     32038.0  dx9ALqJ
# 2012-01-26     37403.0  dx9ALqJ
# 2012-01-27     53631.0  dx9ALqJ
# ...                ...      ...
# 2022-01-17  12935472.0  dx9ALqJ
# 2022-01-18  12935661.0  dx9ALqJ
# 2022-01-19  12967474.0  dx9ALqJ
# 2022-01-20  12966156.0  dx9ALqJ
# 2022-01-21  12958392.0  dx9ALqJ
#
# [2588 rows x 2 columns]
