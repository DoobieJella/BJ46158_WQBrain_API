# %% [markdown]
# ### Import library

# %%
import os
os.chdir('../..')
os.getcwd()
# Out:
# 'C:\\Users\\csia7\\OneDrive\\문서\\GitHub\\WQBrain_2024_API'

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px
import pygwalker as pyg
import glob
import re

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_46eCs2ZvxkqGRNtfKB6nCZZpKR8X

# %%
ace.check_session_timeout(s)
# Out:
# 14398.65292

# %% [markdown]
# ## Alpha Mixing Templates

# %% [markdown]
# ## Read all passed alphas

# %%
os.chdir('Results/signal')
file_direc = glob.glob('*')
file_direc
# Out:
# ['A_signalform.csv',
#  'B_signalform.csv',
#  'C_signalform.csv',
#  'D_signalform.csv',
#  'pre_signalform.csv',
#  'Sep03GLB_signalform.csv']

# %%
expressions = {}
for file in file_direc:
    expressions[file.split('_')[0]] = pd.read_csv(file)['expression']
#expressions

# %%
os.chdir('../..')

# %%
expressions.keys()
# Out:
# dict_keys(['A', 'B', 'C', 'D', 'pre', 'Sep03GLB'])

# %%
expressions['pre']
# Out:
# 0    sig_pre_0 = group_zscore(ts_zscore(ts_backfill...
# Name: expression, dtype: object

# %% [markdown]
# ## Template A & pre mixing
# use top 32 results

# %%
#region= "GLB", universe = "MINVOL1M", neutralization = 'MARKET', truncation = 0.01

# %%
B = expressions['B']
pre = expressions['pre']
#Sep03GLB = expressions['Sep03GLB']

# %%
alpha_list_Bpre = []

for i in range(20):
    alpha_list_Bpre += [ace.generate_alpha(f'{B[i]};{pre[0]};add(scale_down(signal_B_{i}), scale_down(signal_pre_{0}), filter = false)', region= "GLB", universe = "MINVOL1M", neutralization = x, truncation = 0.01, decay = 5) for x in ['COUNTRY', 'SECTOR']]

alpha_list_Bpre
# Out:
# [{'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_0 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_0 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_0 = entry_B_0 < 0.5;signal_B_0 =  trade_when(entry_B_0>0.55, maintenance_B_0, quit_B_0);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_0), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_0 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_0 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_0 = entry_B_0 < 0.5;signal_B_0 =  trade_when(entry_B_0>0.55, maintenance_B_0, quit_B_0);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_0), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_1 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_1 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_1 = entry_B_1 < 0.5;signal_B_1 =  trade_when(entry_B_1>0.55, maintenance_B_1, quit_B_1);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_1), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_1 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_1 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_1 = entry_B_1 < 0.5;signal_B_1 =  trade_when(entry_B_1>0.55, maintenance_B_1, quit_B_1);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_1), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_2 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_2 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_2 = entry_B_2 < 0.5;signal_B_2 =  trade_when(entry_B_2>0.55, maintenance_B_2, quit_B_2);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_2), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_2 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_2 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_2 = entry_B_2 < 0.5;signal_B_2 =  trade_when(entry_B_2>0.55, maintenance_B_2, quit_B_2);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_2), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_3 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_3 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_3 = entry_B_3 < 0.5;signal_B_3 =  trade_when(entry_B_3>0.55, maintenance_B_3, quit_B_3);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_3), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_3 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_3 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_3 = entry_B_3 < 0.5;signal_B_3 =  trade_when(entry_B_3>0.55, maintenance_B_3, quit_B_3);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_3), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_4 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_4 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_4 = entry_B_4 < 0.5;signal_B_4 =  trade_when(entry_B_4>0.55, maintenance_B_4, quit_B_4);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_4), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_4 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_4 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_4 = entry_B_4 < 0.5;signal_B_4 =  trade_when(entry_B_4>0.55, maintenance_B_4, quit_B_4);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_4), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_5 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_5 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_5 = entry_B_5 < 0.5;signal_B_5 =  trade_when(entry_B_5>0.55, maintenance_B_5, quit_B_5);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_5), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_5 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_5 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_5 = entry_B_5 < 0.5;signal_B_5 =  trade_when(entry_B_5>0.55, maintenance_B_5, quit_B_5);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_5), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_6 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_6 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_6 = entry_B_6 < 0.5;signal_B_6 =  trade_when(entry_B_6>0.55, maintenance_B_6, quit_B_6);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_6), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_6 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_6 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_6 = entry_B_6 < 0.5;signal_B_6 =  trade_when(entry_B_6>0.55, maintenance_B_6, quit_B_6);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_6), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_7 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_7 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_7 = entry_B_7 < 0.5;signal_B_7 =  trade_when(entry_B_7>0.55, maintenance_B_7, quit_B_7);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_7), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_7 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_7 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_7 = entry_B_7 < 0.5;signal_B_7 =  trade_when(entry_B_7>0.55, maintenance_B_7, quit_B_7);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_7), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_8 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_8 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_8 = entry_B_8 < 0.5;signal_B_8 =  trade_when(entry_B_8>0.55, maintenance_B_8, quit_B_8);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_8), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_8 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_8 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_8 = entry_B_8 < 0.5;signal_B_8 =  trade_when(entry_B_8>0.55, maintenance_B_8, quit_B_8);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_8), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_9 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_9 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_9 = entry_B_9 < 0.5;signal_B_9 =  trade_when(entry_B_9>0.55, maintenance_B_9, quit_B_9);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_9), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_9 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_9 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_9 = entry_B_9 < 0.5;signal_B_9 =  trade_when(entry_B_9>0.55, maintenance_B_9, quit_B_9);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_9), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_10 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_10 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_10 = entry_B_10 < 0.5;signal_B_10 =  trade_when(entry_B_10>0.55, maintenance_B_10, quit_B_10);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_10), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_10 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_10 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_10 = entry_B_10 < 0.5;signal_B_10 =  trade_when(entry_B_10>0.55, maintenance_B_10, quit_B_10);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_10), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_11 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_11 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_11 = entry_B_11 < 0.5;signal_B_11 =  trade_when(entry_B_11>0.55, maintenance_B_11, quit_B_11);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_11), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_11 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_11 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_11 = entry_B_11 < 0.5;signal_B_11 =  trade_when(entry_B_11>0.55, maintenance_B_11, quit_B_11);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_11), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_12 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_12 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_12 = entry_B_12 < 0.5;signal_B_12 =  trade_when(entry_B_12>0.55, maintenance_B_12, quit_B_12);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_12), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_12 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_12 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_12 = entry_B_12 < 0.5;signal_B_12 =  trade_when(entry_B_12>0.55, maintenance_B_12, quit_B_12);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_12), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_13 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_13 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_13 = entry_B_13 < 0.5;signal_B_13 =  trade_when(entry_B_13>0.55, maintenance_B_13, quit_B_13);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_13), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_13 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_13 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_13 = entry_B_13 < 0.5;signal_B_13 =  trade_when(entry_B_13>0.55, maintenance_B_13, quit_B_13);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_13), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_14 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_14 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_14 = entry_B_14 < 0.5;signal_B_14 =  trade_when(entry_B_14>0.55, maintenance_B_14, quit_B_14);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_14), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_14 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_14 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_14 = entry_B_14 < 0.5;signal_B_14 =  trade_when(entry_B_14>0.55, maintenance_B_14, quit_B_14);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_14), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_15 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_15 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_15 = entry_B_15 < 0.5;signal_B_15 =  trade_when(entry_B_15>0.55, maintenance_B_15, quit_B_15);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_15), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_15 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_15 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_15 = entry_B_15 < 0.5;signal_B_15 =  trade_when(entry_B_15>0.55, maintenance_B_15, quit_B_15);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_15), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_16 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_16 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_16 = entry_B_16 < 0.5;signal_B_16 =  trade_when(entry_B_16>0.55, maintenance_B_16, quit_B_16);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_16), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_16 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_16 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_16 = entry_B_16 < 0.5;signal_B_16 =  trade_when(entry_B_16>0.55, maintenance_B_16, quit_B_16);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_16), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_17 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_17 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_17 = entry_B_17 < 0.5;signal_B_17 =  trade_when(entry_B_17>0.55, maintenance_B_17, quit_B_17);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_17), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_17 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_17 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_17 = entry_B_17 < 0.5;signal_B_17 =  trade_when(entry_B_17>0.55, maintenance_B_17, quit_B_17);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_17), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_18 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_18 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_18 = entry_B_18 < 0.5;signal_B_18 =  trade_when(entry_B_18>0.55, maintenance_B_18, quit_B_18);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_18), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_18 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_18 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_18 = entry_B_18 < 0.5;signal_B_18 =  trade_when(entry_B_18>0.55, maintenance_B_18, quit_B_18);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_18), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'COUNTRY',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_19 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_19 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_19 = entry_B_19 < 0.5;signal_B_19 =  trade_when(entry_B_19>0.55, maintenance_B_19, quit_B_19);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_19), scale_down(signal_pre_0), filter = false)'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 5,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_19 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_19 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_19 = entry_B_19 < 0.5;signal_B_19 =  trade_when(entry_B_19>0.55, maintenance_B_19, quit_B_19);sig_pre_0 = group_zscore(ts_zscore(ts_backfill(anl69_epss_best_eeps_cur_yr, 21), 21), industry);factor_pre_0 = group_zscore(ts_ir(returns, 252), industry);value_pre_0 = floor(rank(fnd28_value_05480/close)*4.99);signal_pre_0 = group_neutralize(sig_pre_0, value_pre_0 *factor_pre_0);add(scale_down(signal_B_19), scale_down(signal_pre_0), filter = false)'}]

# %%
result = ace.simulate_alpha_list_multi(s, alpha_list_Bpre)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 14/14 [46:10<00:00, 197.92s/it]

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#          pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   25815099   20000000         647          611    0.5515   0.2493    0.0533
# 1   20773093   20000000         713          662    0.5521   0.2006    0.0279
# 2   20569680   20000000         698          648    0.5541   0.1986    0.0246
# 3   25468835   20000000         634          599    0.5537   0.2459    0.0511
# 4   19814618   20000000         629          596    0.5500   0.1913    0.0303
# 5   19714200   20000000         641          607    0.5482   0.1904    0.0306
# 6   25226900   20000000         716          661    0.5473   0.2436    0.0477
# 7   24924480   20000000         702          647    0.5498   0.2407    0.0449
# 8   19826093   20000000         644          611    0.5560   0.1914    0.0347
# 9   19577723   20000000         633          600    0.5578   0.1890    0.0335
# 10  24392480   20000000         643          607    0.5429   0.2355    0.0465
# 11  24302236   20000000         632          595    0.5452   0.2347    0.0463
# 12  24367866   20000000         685          648    0.6170   0.2353    0.0503
# 13  24133568   20000000         672          635    0.6206   0.2330    0.0508
# 14  24813402   20000000         628          593    0.5586   0.2396    0.0587
# 15  23230706   20000000         612          579    0.5600   0.2243    0.0453
# 16  19412765   20000000         683          648    0.6248   0.1875    0.0341
# 17  20628003   20000000         471          447    0.5643   0.1992    0.0358
# 18  20530609   20000000         463          439    0.5664   0.1982    0.0367
# 19  19231865   20000000         670          636    0.6280   0.1857    0.0323
# 20  22939238   20000000         624          591    0.5573   0.2215    0.0452
# 21  25351662   20000000         465          439    0.5617   0.2448    0.0885
# 22  23997776   20000000         611          578    0.6717   0.2317    0.0429
# 23  25167177   20000000         474          448    0.5589   0.2430    0.0876
# 24  18880086   20000000         623          590    0.5544   0.1823    0.0436
# 25  23809660   20000000         603          570    0.6747   0.2299    0.0426
# 26  18203402   20000000         610          580    0.5645   0.1758    0.0280
# 27  23350719   20000000         626          589    0.5502   0.2255    0.0535
# 28  23760904   20000000         666          629    0.6258   0.2294    0.0568
# 29  18755830   20000000         627          594    0.5618   0.1811    0.0339
# 30  18706733   20000000         609          578    0.6805   0.1806    0.0343
# 31  18610935   20000000         601          570    0.6830   0.1797    0.0339
# 32  17789102   20000000         621          591    0.5624   0.1718    0.0314
# 33  18458535   20000000         664          629    0.6323   0.1782    0.0405
# 34  24551387   20000000         459          433    0.5648   0.2371    0.0822
# 35  19808797   20000000         457          433    0.5690   0.1913    0.0455
# 36  24786707   20000000         358          331    0.5433   0.2393    0.0854
# 37  21603814   20000000         605          573    0.5651   0.2086    0.0485
# 38  16719259   20000000         603          573    0.5694   0.1614    0.0375
# 39  18664939   20000000         356          331    0.5537   0.1802    0.0531
#
#       margin  fitness  sharpe  ... self_correlation prod_correlation  \
# 0   0.000904     2.65    3.94  ...              NaN              NaN
# 1   0.000727     2.64    4.38  ...              NaN              NaN
# 2   0.000717     2.62    4.37  ...              NaN              NaN
# 3   0.000888     2.62    3.93  ...              NaN              NaN
# 4   0.000696     2.53    4.29  ...           0.6262           0.6262
# 5   0.000695     2.52    4.27  ...              NaN              NaN
# 6   0.000890     2.52    3.78  ...              NaN              NaN
# 7   0.000875     2.51    3.80  ...              NaN              NaN
# 8   0.000689     2.50    4.26  ...           0.5954           0.5954
# 9   0.000678     2.46    4.22  ...              NaN              NaN
# 10  0.000868     2.45    3.72  ...              NaN              NaN
# 11  0.000861     2.45    3.73  ...              NaN              NaN
# 12  0.000763     2.40    3.89  ...              NaN              NaN
# 13  0.000751     2.38    3.89  ...           0.6899           0.6899
# 14  0.000858     2.38    3.63  ...              NaN              NaN
# 15  0.000801     2.36    3.73  ...              NaN              NaN
# 16  0.000600     2.35    4.29  ...              NaN              NaN
# 17  0.000706     2.35    3.95  ...              NaN              NaN
# 18  0.000700     2.33    3.94  ...              NaN              NaN
# 19  0.000591     2.32    4.26  ...              NaN              NaN
# 20  0.000795     2.30    3.65  ...              NaN              NaN
# 21  0.000872     2.29    3.47  ...           0.6801           0.6801
# 22  0.000690     2.27    3.86  ...              NaN              NaN
# 23  0.000870     2.26    3.42  ...              NaN              NaN
# 24  0.000658     2.26    3.94  ...              NaN              NaN
# 25  0.000682     2.25    3.86  ...              NaN              NaN
# 26  0.000623     2.20    3.95  ...              NaN              NaN
# 27  0.000820     2.18    3.41  ...              NaN              NaN
# 28  0.000733     2.18    3.60  ...              NaN              NaN
# 29  0.000645     2.17    3.83  ...              NaN              NaN
# 30  0.000531     2.17    4.22  ...              NaN              NaN
# 31  0.000526     2.15    4.20  ...              NaN              NaN
# 32  0.000611     2.12    3.84  ...              NaN              NaN
# 33  0.000564     2.08    3.91  ...              NaN              NaN
# 34  0.000839     2.06    3.18  ...              NaN              NaN
# 35  0.000672     2.06    3.56  ...              NaN              NaN
# 36  0.000881     2.00    3.02  ...              NaN              NaN
# 37  0.000738     1.98    3.26  ...              NaN              NaN
# 38  0.000567     1.81    3.40  ...              NaN              NaN
# 39  0.000651     1.57    2.76  ...              NaN              NaN
#
#                                            expression  concentrated_weight  \
# 0   entry_B_8 = ts_rank( ts_std_dev(oth460_veia_l2...                 PASS
# 1   entry_B_16 = ts_rank( ts_std_dev(oth460_1l_ccn...                 PASS
# 2   entry_B_14 = ts_rank( ts_std_dev(oth460_1l_ccn...                 PASS
# 3   entry_B_3 = ts_rank( ts_std_dev(oth460_veia_l2...                 PASS
# 4   entry_B_6 = ts_rank( ts_std_dev(oth460_1l_2dls...                 PASS
# 5   entry_B_10 = ts_rank( ts_std_dev(oth460_1l_2dl...                 PASS
# 6   entry_B_16 = ts_rank( ts_std_dev(oth460_1l_ccn...                 PASS
# 7   entry_B_14 = ts_rank( ts_std_dev(oth460_1l_ccn...                 PASS
# 8   entry_B_8 = ts_rank( ts_std_dev(oth460_veia_l2...                 PASS
# 9   entry_B_3 = ts_rank( ts_std_dev(oth460_veia_l2...                 PASS
# 10  entry_B_10 = ts_rank( ts_std_dev(oth460_1l_2dl...                 PASS
# 11  entry_B_6 = ts_rank( ts_std_dev(oth460_1l_2dls...                 PASS
# 12  entry_B_4 = ts_rank( ts_std_dev(oth460_3l_vlc,...                 PASS
# 13  entry_B_0 = ts_rank( ts_std_dev(oth460_3l_vlc,...                 PASS
# 14  entry_B_13 = ts_rank( ts_std_dev(oth460_veia_l...                 PASS
# 15  entry_B_1 = ts_rank( ts_std_dev(oth460_1l_1dls...                 PASS
# 16  entry_B_4 = ts_rank( ts_std_dev(oth460_3l_vlc,...                 PASS
# 17  entry_B_15 = ts_rank( ts_std_dev(oth460_1l_aie...                 PASS
# 18  entry_B_2 = ts_rank( ts_std_dev(oth460_1l_aiec...                 PASS
# 19  entry_B_0 = ts_rank( ts_std_dev(oth460_3l_vlc,...                 PASS
# 20  entry_B_5 = ts_rank( ts_std_dev(oth460_1l_1dls...                 PASS
# 21  entry_B_2 = ts_rank( ts_std_dev(oth460_1l_aiec...                 PASS
# 22  entry_B_18 = ts_rank( ts_std_dev(oth460_clv_cl...                 PASS
# 23  entry_B_15 = ts_rank( ts_std_dev(oth460_1l_aie...                 PASS
# 24  entry_B_17 = ts_rank( ts_std_dev(oth460_1l_2dl...                 PASS
# 25  entry_B_11 = ts_rank( ts_std_dev(oth460_clv_cl...                 PASS
# 26  entry_B_1 = ts_rank( ts_std_dev(oth460_1l_1dls...                 PASS
# 27  entry_B_17 = ts_rank( ts_std_dev(oth460_1l_2dl...                 PASS
# 28  entry_B_7 = ts_rank( ts_std_dev(oth460_3l_vlc,...                 PASS
# 29  entry_B_13 = ts_rank( ts_std_dev(oth460_veia_l...                 PASS
# 30  entry_B_18 = ts_rank( ts_std_dev(oth460_clv_cl...                 PASS
# 31  entry_B_11 = ts_rank( ts_std_dev(oth460_clv_cl...                 PASS
# 32  entry_B_5 = ts_rank( ts_std_dev(oth460_1l_1dls...                 PASS
# 33  entry_B_7 = ts_rank( ts_std_dev(oth460_3l_vlc,...                 PASS
# 34  entry_B_19 = ts_rank( ts_std_dev(oth460_1l_aie...                 PASS
# 35  entry_B_19 = ts_rank( ts_std_dev(oth460_1l_aie...                 PASS
# 36  entry_B_9 = ts_rank( ts_std_dev(oth460_fprd_cl...                 FAIL
# 37  entry_B_12 = ts_rank( ts_std_dev(oth460_1l_1dl...                 PASS
# 38  entry_B_12 = ts_rank( ts_std_dev(oth460_1l_1dl...                 PASS
# 39  entry_B_9 = ts_rank( ts_std_dev(oth460_fprd_cl...                 PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             PASS        PASS       PASS
# 1           PASS             PASS        PASS       PASS
# 2           PASS             PASS        PASS       PASS
# 3           PASS             PASS        PASS       PASS
# 4           PASS             PASS        PASS       PASS
# 5           PASS             PASS        PASS       PASS
# 6           PASS             PASS        PASS       PASS
# 7           PASS             PASS        PASS       PASS
# 8           PASS             PASS        PASS       PASS
# 9           PASS             PASS        PASS       PASS
# 10          PASS             PASS        PASS       PASS
# 11          PASS             PASS        PASS       PASS
# 12          PASS             PASS        PASS       PASS
# 13          PASS             PASS        PASS       PASS
# 14          PASS             PASS        PASS       PASS
# 15          PASS             PASS        PASS       PASS
# 16          PASS             PASS        PASS       PASS
# 17          PASS             PASS        PASS       PASS
# 18          PASS             PASS        PASS       PASS
# 19          PASS             PASS        PASS       PASS
# 20          PASS             PASS        PASS       PASS
# 21          PASS             PASS        PASS       PASS
# 22          PASS             PASS        PASS       PASS
# 23          PASS             PASS        PASS       PASS
# 24          PASS             PASS        PASS       PASS
# 25          PASS             PASS        PASS       PASS
# 26          PASS             PASS        PASS       PASS
# 27          PASS             PASS        PASS       PASS
# 28          PASS             PASS        PASS       PASS
# 29          PASS             PASS        PASS       PASS
# 30          PASS             PASS        PASS       PASS
# 31          PASS             PASS        PASS       PASS
# 32          PASS             PASS        PASS       PASS
# 33          PASS             PASS        PASS       PASS
# 34          PASS             PASS        PASS       PASS
# 35          PASS             FAIL        PASS       PASS
# 36          PASS             PASS        PASS       PASS
# 37          PASS             PASS        PASS       PASS
# 38          PASS             PASS        PASS       PASS
# 39          PASS             FAIL        PASS       PASS
#
#    low_sub_universe_sharpe low_turnover
# 0                     PASS         PASS
# 1                     PASS         PASS
# 2                     PASS         PASS
# 3                     PASS         PASS
# 4                     PASS         PASS
# 5                     PASS         PASS
# 6                     PASS         PASS
# 7                     PASS         PASS
# 8                     PASS         PASS
# 9                     PASS         PASS
# 10                    PASS         PASS
# 11                    PASS         PASS
# 12                    PASS         PASS
# 13                    PASS         PASS
# 14                    PASS         PASS
# 15                    PASS         PASS
# 16                    PASS         PASS
# 17                    PASS         PASS
# 18                    PASS         PASS
# 19                    PASS         PASS
# 20                    PASS         PASS
# 21                    PASS         PASS
# 22                    PASS         PASS
# 23                    PASS         PASS
# 24                    PASS         PASS
# 25                    PASS         PASS
# 26                    PASS         PASS
# 27                    PASS         PASS
# 28                    PASS         PASS
# 29                    PASS         PASS
# 30                    PASS         PASS
# 31                    PASS         PASS
# 32                    PASS         PASS
# 33                    PASS         PASS
# 34                    PASS         PASS
# 35                    PASS         PASS
# 36                    PASS         PASS
# 37                    PASS         PASS
# 38                    PASS         PASS
# 39                    PASS         PASS
#
# [40 rows x 22 columns]

# %%
path = 'Results/mixing'
result_st1.to_csv(path + '/B&pre_mixing_add_2.csv')

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df.head()
# Out:
#   alpha_id date endDate  limit                 name result startDate themes  \
# 0  6w5Ln6E  NaN     NaN   1.58           LOW_SHARPE   PASS       NaN    NaN
# 1  6w5Ln6E  NaN     NaN   1.00          LOW_FITNESS   PASS       NaN    NaN
# 2  6w5Ln6E  NaN     NaN   0.01         LOW_TURNOVER   PASS       NaN    NaN
# 3  6w5Ln6E  NaN     NaN   0.70        HIGH_TURNOVER   PASS       NaN    NaN
# 4  6w5Ln6E  NaN     NaN    NaN  CONCENTRATED_WEIGHT   PASS       NaN    NaN
#
#    value  year
# 0   3.73   NaN
# 1   2.36   NaN
# 2   0.56   NaN
# 3   0.56   NaN
# 4    NaN   NaN

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['QawpmEQ' 'jZqKNg5' 'k0xVv8k']
# Passed alphas:['R8JVmRd', 'qlKWv9P', '9rzVpZd', 'gMYQaXQ', '8zMx1kW', 'e0l95Zp', 'gMYQeNv', 'JOVxpPm', '2L1O7wZ', 'APR0O6W', 'K9KObrj', 'mbPg9gK', 'llL8EAn', '273obEY', 'm8EWMk1', 'Y0j5nrW', 'QawpLe5', '6w5Ln6E', 'KbWMjRx', 'anrLM6W', 'ZnR0E53', 'Ppkmde7', 'eOXZlZz', 'lVoPLnn', 'Lp0YPva', '17rAQ6m', '3RM9oKZ', 'ad59v2O', 'xxJpKLg', 'QV135m5', 'k3z6qqk', 'qAQJMKA', 'Wpv2EZo', 'anrLeKv', 'K9KOwjx', '7weR901', '9wNOzNr']

# %%
#calling submit_alpha on all alphas that have passed the submission tests
for alpha_id in passed_alphas[9:]:
    hf.set_alpha_properties(s, alpha_id, tags = ['Sep09_mixing'])

# %%
submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas[8:10]}
submit_result
# Out:
# {'2L1O7wZ': True, 'APR0O6W': False}

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance

# %%
ace.get_alpha_pnl(s, result[0]['alpha_id'])
# Out:
#                    Pnl alpha_id
# Date
# 2012-01-23         0.0  dx9ALqJ
# 2012-01-24     52190.0  dx9ALqJ
# 2012-01-25     32038.0  dx9ALqJ
# 2012-01-26     37403.0  dx9ALqJ
# 2012-01-27     53631.0  dx9ALqJ
# ...                ...      ...
# 2022-01-17  12935472.0  dx9ALqJ
# 2022-01-18  12935661.0  dx9ALqJ
# 2022-01-19  12967474.0  dx9ALqJ
# 2022-01-20  12966156.0  dx9ALqJ
# 2022-01-21  12958392.0  dx9ALqJ
#
# [2588 rows x 2 columns]
