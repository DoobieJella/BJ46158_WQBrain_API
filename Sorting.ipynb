# %% [markdown]
# # Datafield Clustering

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ## 1. clustering with numerical values

# %%
df = pd.read_csv('datafield.csv')

# Select the relevant columns for variance analysis
data = df[['coverage', 'userCount', 'alphaCount']].dropna()

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Perform PCA to reduce dimensionality
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

# Perform KMeans clustering to identify groups of similar datafields
kmeans = KMeans(n_clusters=5)  
clusters = kmeans.fit_predict(pca_result)

df['PCA1'] = pca_result[:, 0]
df['PCA2'] = pca_result[:, 1]
df['Cluster'] = clusters

plt.figure(figsize=(10, 8))
plt.scatter(df['PCA1'], df['PCA2'], c=df['Cluster'], cmap='viridis')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Clusters of Datafields Based on Variance')
plt.colorbar()
plt.show()

# Sort and filter by highest alphaCount within clusters
sorted_df = df.sort_values(by=['Cluster', 'alphaCount'], ascending=[True, False])

sorted_df_filtered = sorted_df[['id', 'description', 'coverage', 'userCount', 'alphaCount', 'Cluster']]
sorted_df_filtered.head(20)  # Display the top 20 significant datafields
# Out:
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
#                                                   id  \
# 82                      fn_def_tax_assets_liab_net_a
# 0                                  fn_accrued_liab_a
# 16        fn_antidilutive_securities_excl_from_eps_a
# 8              fn_accum_oth_income_loss_net_of_tax_a
# 140                          fn_new_shares_options_a
# 209                                  fnd2_a_dfdtxava
# 9              fn_accum_oth_income_loss_net_of_tax_q
# 17        fn_antidilutive_securities_excl_from_eps_q
# 287                                      fnd2_ebitfr
# 58                          fn_comp_options_grants_a
# 1                             fn_accrued_liab_curr_a
# 50              fn_comp_options_exercisable_number_a
# 11   fn_allocated_share_based_compensation_expense_q
# 145                  fn_op_lease_min_pay_due_in_3y_a
# 72              fn_debt_instrument_carrying_amount_a
# 167                             fn_prepaid_expense_a
# 83                      fn_def_tax_assets_liab_net_q
# 114                          fn_income_tax_expense_a
# 177                                 fn_profit_loss_a
# 10   fn_allocated_share_based_compensation_expense_a
#
#                                            description  coverage  userCount  \
# 82   Amount, after allocation of valuation allowanc...    0.7058        304
# 0    Carrying value as of the balance sheet date of...    0.3934        359
# 16   Securities (including those issuable pursuant ...    0.6007        340
# 8    Accumulated change in equity from transactions...    0.6936        161
# 140  Number of share options (or share units) exerc...    0.6306        195
# 209  Amount of deferred tax assets for which it is ...    0.5993        222
# 9    Accumulated change in equity from transactions...    0.6597        253
# 17   Securities (including those issuable pursuant ...    0.5838        193
# 287                                      EBIT, Foreign    0.3948        189
# 58   Net number of share options (or share units) g...    0.6394        201
# 1    Carrying value as of the balance sheet date of...    0.3644        157
# 50   The number of shares into which fully or parti...    0.5859         85
# 11   Represents the expense recognized during the p...    0.6541        129
# 145  Amount of required minimum rental payments for...    0.6422        239
# 72                                Debt carrying amount    0.5667        184
# 167  Carrying amount for a unclassified balance she...    0.5118        184
# 83   Amount, after allocation of valuation allowanc...    0.5750        240
# 114                       Income Tax Expense (Benefit)    0.6933        124
# 177  The consolidated profit or loss for the period...    0.4085        176
# 10   Represents the expense recognized during the p...    0.6739        151
#
#      alphaCount  Cluster
# 82         1278        0
# 0          1052        0
# 16          883        0
# 8           741        0
# 140         732        0
# 209         696        0
# 9           680        0
# 17          624        0
# 287         619        0
# 58          618        0
# 1           610        0
# 50          585        0
# 11          575        0
# 145         565        0
# 72          538        0
# 167         538        0
# 83          535        0
# 114         527        0
# 177         516        0
# 10          510        0

# %%
sorted_df_filtered[]
# Out:
#                                              id  \
# 82                 fn_def_tax_assets_liab_net_a
# 0                             fn_accrued_liab_a
# 16   fn_antidilutive_securities_excl_from_eps_a
# 8         fn_accum_oth_income_loss_net_of_tax_a
# 140                     fn_new_shares_options_a
# ..                                          ...
# 189                          fn_taxes_payable_a
# 187               fn_repurchased_shares_value_a
# 259                           fnd2_currfedtxexp
# 298                     fnd2_propplteqmuflmeqmt
# 279                         fnd2_dfdlocalitxexp
#
#                                            description  coverage  userCount  \
# 82   Amount, after allocation of valuation allowanc...    0.7058        304
# 0    Carrying value as of the balance sheet date of...    0.3934        359
# 16   Securities (including those issuable pursuant ...    0.6007        340
# 8    Accumulated change in equity from transactions...    0.6936        161
# 140  Number of share options (or share units) exerc...    0.6306        195
# ..                                                 ...       ...        ...
# 189  Carrying value as of the balance sheet date of...    0.4462         36
# 187  Shares repurchased and either retired or put i...    0.4936         23
# 259              Income Tax Expense, Current - Federal    0.5661         28
# 298               PPE, Equipment, Useful Life, Minimum    0.4744         20
# 279                       Income Tax Expense, Deferred    0.5120         19
#
#      alphaCount  Cluster
# 82         1278        0
# 0          1052        0
# 16          883        0
# 8           741        0
# 140         732        0
# ..          ...      ...
# 189          86        4
# 187          84        4
# 259          80        4
# 298          80        4
# 279          72        4
#
# [318 rows x 6 columns]

# %% [markdown]
# ## 2. Clustering with text description

# %%
file_path = 'datafield.csv'
df = pd.read_csv(file_path)

descriptions = df['description']

for i in range(5):
    print(descriptions[i])
# Out:
# Carrying value as of the balance sheet date of obligations incurred and payable, pertaining to costs that are statutory in nature, are incurred on contractual obligations, or accumulate over time and for which invoices have not yet been received or will not be rendered.
# Carrying value as of the balance sheet date of obligations incurred and payable, pertaining to costs that are statutory in nature, are incurred on contractual obligations, or accumulate over time and for which invoices have not yet been received or will not be rendered.
# Carrying value as of the balance sheet date of obligations incurred and payable, pertaining to costs that are statutory in nature, are incurred on contractual obligations, or accumulate over time and for which invoices have not yet been received or will not be rendered.
# Carrying value as of the balance sheet date of obligations incurred and payable, pertaining to costs that are statutory in nature, are incurred on contractual obligations, or accumulate over time and for which invoices have not yet been received or will not be rendered.
# Amount of accumulated depreciation, depletion and amortization for physical assets used in the normal conduct of business to produce goods and services.

# %%
# Convert the text data into TF-IDF features
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(descriptions)

# %%
min_cluster, max_cluster = 2, 10

wcss = []
# iterate through certain numbers to observe optimal number for clusters
for i in range(min_cluster, max_cluster):
    # Perform KMeans clustering based on the TF-IDF features
    kmeans = KMeans(n_clusters=i, random_state=42) 
    kmeans.fit_predict(X)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(range(min_cluster, max_cluster), wcss, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Within-Cluster Sum of Squares (WCSS)')
plt.title('Elbow Method For Optimal Number of Clusters')
plt.show()

silhouette_scores = []
for i in range(min_cluster, max_cluster):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X)
    score = silhouette_score(X, kmeans.labels_)
    silhouette_scores.append(score)

plt.figure(figsize=(10, 6))
plt.plot(range(min_cluster, max_cluster), silhouette_scores, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score For Optimal Number of Clusters')
plt.show()
# Out:
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
kmeans = KMeans(n_clusters=5, random_state=42) 
clusters = kmeans.fit_predict(X)

df['Cluster'] = clusters

# Sort the dataframe by clusters and potentially by other metrics within the clusters
sorted_df = df.sort_values(by=['Cluster', 'alphaCount'], ascending=[True, False])

sorted_df[sorted_df['Cluster'] == 4]
# Out:
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#      Unnamed: 0                                                 id  \
# 157         157  fn_oth_income_loss_fx_transaction_and_tax_tran...
# 82           82                       fn_def_tax_assets_liab_net_a
# 8             8              fn_accum_oth_income_loss_net_of_tax_a
# 209         209                                    fnd2_a_dfdtxava
# 9             9              fn_accum_oth_income_loss_net_of_tax_q
# ..          ...                                                ...
# 268         268                          fnd2_dbplanchgbnfolintcst
# 264         264                               fnd2_dbplanartonplas
# 263         263                            fnd2_dbplanamtsrginblsh
# 314         314                    fnd2_unrgtxbnfdecresfsttwtxauth
# 213         213                      fnd2_a_excesstxbnffsbcpnoprat
#
#                                            description  \
# 157  Amount after tax and reclassification adjustme...
# 82   Amount, after allocation of valuation allowanc...
# 8    Accumulated change in equity from transactions...
# 209  Amount of deferred tax assets for which it is ...
# 9    Accumulated change in equity from transactions...
# ..                                                 ...
# 268  Defined Benefit Plan Change In Benefit Obligat...
# 264   Defined Benefit Plan, Benefits Paid, Plan Assets
# 263  The aggregate net amount recognized in the bal...
# 314  Amount of decrease in unrecognized tax benefit...
# 213  Amount of cash outflow for realized tax benefi...
#
#                                                dataset  \
# 157  {'id': 'fundamental2', 'name': 'Report Footnot...
# 82   {'id': 'fundamental2', 'name': 'Report Footnot...
# 8    {'id': 'fundamental2', 'name': 'Report Footnot...
# 209  {'id': 'fundamental2', 'name': 'Report Footnot...
# 9    {'id': 'fundamental2', 'name': 'Report Footnot...
# ..                                                 ...
# 268  {'id': 'fundamental2', 'name': 'Report Footnot...
# 264  {'id': 'fundamental2', 'name': 'Report Footnot...
# 263  {'id': 'fundamental2', 'name': 'Report Footnot...
# 314  {'id': 'fundamental2', 'name': 'Report Footnot...
# 213  {'id': 'fundamental2', 'name': 'Report Footnot...
#
#                                          category  \
# 157  {'id': 'fundamental', 'name': 'Fundamental'}
# 82   {'id': 'fundamental', 'name': 'Fundamental'}
# 8    {'id': 'fundamental', 'name': 'Fundamental'}
# 209  {'id': 'fundamental', 'name': 'Fundamental'}
# 9    {'id': 'fundamental', 'name': 'Fundamental'}
# ..                                            ...
# 268  {'id': 'fundamental', 'name': 'Fundamental'}
# 264  {'id': 'fundamental', 'name': 'Fundamental'}
# 263  {'id': 'fundamental', 'name': 'Fundamental'}
# 314  {'id': 'fundamental', 'name': 'Fundamental'}
# 213  {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                            subcategory region  delay universe  \
# 157  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 82   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 8    {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 209  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 9    {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# ..                                                 ...    ...    ...      ...
# 268  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 264  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 263  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 314  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 213  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
#
#        type  coverage  turnover  userCount  alphaCount themes  Cluster
# 157  MATRIX    0.4260       NaN       1149        1571     []        4
# 82   MATRIX    0.7058       NaN        304        1278     []        4
# 8    MATRIX    0.6936       NaN        161         741     []        4
# 209  MATRIX    0.5993       NaN        222         696     []        4
# 9    MATRIX    0.6597       NaN        253         680     []        4
# ..      ...       ...       ...        ...         ...    ...      ...
# 268  MATRIX    0.2593       NaN         11          60     []        4
# 264  MATRIX    0.2514       NaN         10          54     []        4
# 263  MATRIX    0.2521       NaN          6          51     []        4
# 314  MATRIX    0.3539       NaN         22          49     []        4
# 213  MATRIX    0.2565       NaN         13          29     []        4
#
# [85 rows x 16 columns]

# %%
top_entries_per_cluster = sorted_df.groupby('Cluster').head(2)

top_entries_per_cluster
#print(top_entries_per_cluster[['id', 'description', 'Cluster']].head(2))
# Out:
#      Unnamed: 0                                                 id  \
# 16           16         fn_antidilutive_securities_excl_from_eps_a
# 140         140                            fn_new_shares_options_a
# 0             0                                  fn_accrued_liab_a
# 287         287                                        fnd2_ebitfr
# 127         127                              fn_liab_fair_val_l1_a
# 18           18                               fn_assets_fair_val_a
# 145         145                    fn_op_lease_min_pay_due_in_3y_a
# 144         144                    fn_op_lease_min_pay_due_in_2y_a
# 157         157  fn_oth_income_loss_fx_transaction_and_tax_tran...
# 82           82                       fn_def_tax_assets_liab_net_a
#
#                                            description  \
# 16   Securities (including those issuable pursuant ...
# 140  Number of share options (or share units) exerc...
# 0    Carrying value as of the balance sheet date of...
# 287                                      EBIT, Foreign
# 127         Liabilities Fair Value, Recurring, Level 1
# 18                  Asset Fair Value, Recurring, Total
# 145  Amount of required minimum rental payments for...
# 144  Amount of required minimum rental payments for...
# 157  Amount after tax and reclassification adjustme...
# 82   Amount, after allocation of valuation allowanc...
#
#                                                dataset  \
# 16   {'id': 'fundamental2', 'name': 'Report Footnot...
# 140  {'id': 'fundamental2', 'name': 'Report Footnot...
# 0    {'id': 'fundamental2', 'name': 'Report Footnot...
# 287  {'id': 'fundamental2', 'name': 'Report Footnot...
# 127  {'id': 'fundamental2', 'name': 'Report Footnot...
# 18   {'id': 'fundamental2', 'name': 'Report Footnot...
# 145  {'id': 'fundamental2', 'name': 'Report Footnot...
# 144  {'id': 'fundamental2', 'name': 'Report Footnot...
# 157  {'id': 'fundamental2', 'name': 'Report Footnot...
# 82   {'id': 'fundamental2', 'name': 'Report Footnot...
#
#                                          category  \
# 16   {'id': 'fundamental', 'name': 'Fundamental'}
# 140  {'id': 'fundamental', 'name': 'Fundamental'}
# 0    {'id': 'fundamental', 'name': 'Fundamental'}
# 287  {'id': 'fundamental', 'name': 'Fundamental'}
# 127  {'id': 'fundamental', 'name': 'Fundamental'}
# 18   {'id': 'fundamental', 'name': 'Fundamental'}
# 145  {'id': 'fundamental', 'name': 'Fundamental'}
# 144  {'id': 'fundamental', 'name': 'Fundamental'}
# 157  {'id': 'fundamental', 'name': 'Fundamental'}
# 82   {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                            subcategory region  delay universe  \
# 16   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 140  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 0    {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 287  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 127  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 18   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 145  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 144  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 157  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 82   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
#
#        type  coverage  turnover  userCount  alphaCount themes  Cluster
# 16   MATRIX    0.6007       NaN        340         883     []        0
# 140  MATRIX    0.6306       NaN        195         732     []        0
# 0    MATRIX    0.3934       NaN        359        1052     []        1
# 287  MATRIX    0.3948       NaN        189         619     []        1
# 127  MATRIX    0.3604       NaN       2120        3183     []        2
# 18   MATRIX    0.3258       NaN        243         472     []        2
# 145  MATRIX    0.6422       NaN        239         565     []        3
# 144  MATRIX    0.6419       NaN        170         423     []        3
# 157  MATRIX    0.4260       NaN       1149        1571     []        4
# 82   MATRIX    0.7058       NaN        304        1278     []        4

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X.toarray())

plt.figure(figsize=(10, 8))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=clusters, cmap='viridis')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Clusters of Datafields Based on Text Descriptions')
plt.colorbar()
plt.show()

# %% [markdown]
# # 3. Clustering with ID

# %%
file_path = 'datafield.csv'
df = pd.read_csv(file_path)

# %%
descriptions = df['id']
descriptions = [x.replace('_', ' ') for x in descriptions]

for i in range(5):
    print(descriptions[i])
# Out:
# fn accrued liab a
# fn accrued liab curr a
# fn accrued liab curr q
# fn accrued liab q
# fn accum depr depletion and amortization ppne a

# %%
# Convert the text data into TF-IDF features
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(descriptions)

# %%
min_cluster, max_cluster = 2, 10

wcss = []
# iterate through certain numbers to observe optimal number for clusters
for i in range(min_cluster, max_cluster):
    # Perform KMeans clustering based on the TF-IDF features
    kmeans = KMeans(n_clusters=i, random_state=42) 
    kmeans.fit_predict(X)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(range(min_cluster, max_cluster), wcss, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Within-Cluster Sum of Squares (WCSS)')
plt.title('Elbow Method For Optimal Number of Clusters')
plt.show()

silhouette_scores = []
for i in range(min_cluster, max_cluster):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X)
    score = silhouette_score(X, kmeans.labels_)
    silhouette_scores.append(score)

plt.figure(figsize=(10, 6))
plt.plot(range(min_cluster, max_cluster), silhouette_scores, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score For Optimal Number of Clusters')
plt.show()
# Out:
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\csia7\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
kmeans = KMeans(n_clusters=5, random_state=42) 
clusters = kmeans.fit_predict(X)

df['Cluster'] = clusters

# Sort the dataframe by clusters and potentially by other metrics within the clusters
sorted_df = df.sort_values(by=['Cluster', 'alphaCount'], ascending=[True, False])

sorted_df[sorted_df['Cluster'] == 4]
# Out:
#      Unnamed: 0                                                 id  \
# 127         127                              fn_liab_fair_val_l1_a
# 0             0                                  fn_accrued_liab_a
# 1             1                             fn_accrued_liab_curr_a
# 3             3                                  fn_accrued_liab_q
# 2             2                             fn_accrued_liab_curr_q
# 18           18                               fn_assets_fair_val_a
# 130         130                              fn_liab_fair_val_l2_q
# 99           99                         fn_employee_related_liab_q
# 25           25                               fn_assets_fair_val_q
# 23           23                            fn_assets_fair_val_l3_a
# 98           98                         fn_employee_related_liab_a
# 21           21                            fn_assets_fair_val_l2_a
# 19           19                            fn_assets_fair_val_l1_a
# 22           22                            fn_assets_fair_val_l2_q
# 20           20                            fn_assets_fair_val_l1_q
# 132         132                              fn_liab_fair_val_l3_q
# 128         128                              fn_liab_fair_val_l1_q
# 24           24                            fn_assets_fair_val_l3_q
# 126         126                                 fn_liab_fair_val_a
# 90           90  fn_derivative_fair_value_of_derivative_liabili...
# 129         129                              fn_liab_fair_val_l2_a
# 131         131                              fn_liab_fair_val_l3_a
# 133         133                                 fn_liab_fair_val_q
# 89           89     fn_derivative_fair_value_of_derivative_asset_q
# 91           91  fn_derivative_fair_value_of_derivative_liabili...
# 88           88     fn_derivative_fair_value_of_derivative_asset_a
#
#                                            description  \
# 127         Liabilities Fair Value, Recurring, Level 1
# 0    Carrying value as of the balance sheet date of...
# 1    Carrying value as of the balance sheet date of...
# 3    Carrying value as of the balance sheet date of...
# 2    Carrying value as of the balance sheet date of...
# 18                  Asset Fair Value, Recurring, Total
# 130         Liabilities Fair Value, Recurring, Level 2
# 99   Total of the carrying values as of the balance...
# 25                  Asset Fair Value, Recurring, Total
# 23                Asset Fair Value, Recurring, Level 3
# 98   Total of the carrying values as of the balance...
# 21                Asset Fair Value, Recurring, Level 2
# 19                Asset Fair Value, Recurring, Level 1
# 22                Asset Fair Value, Recurring, Level 2
# 20                Asset Fair Value, Recurring, Level 1
# 132         Liabilities Fair Value, Recurring, Level 3
# 128         Liabilities Fair Value, Recurring, Level 1
# 24                Asset Fair Value, Recurring, Level 3
# 126           Liabilities Fair Value, Recurring, Total
# 90   Fair value, before effects of master netting a...
# 129         Liabilities Fair Value, Recurring, Level 2
# 131         Liabilities Fair Value, Recurring, Level 3
# 133           Liabilities Fair Value, Recurring, Total
# 89   Fair value, before effects of master netting a...
# 91   Fair value, before effects of master netting a...
# 88   Fair value, before effects of master netting a...
#
#                                                dataset  \
# 127  {'id': 'fundamental2', 'name': 'Report Footnot...
# 0    {'id': 'fundamental2', 'name': 'Report Footnot...
# 1    {'id': 'fundamental2', 'name': 'Report Footnot...
# 3    {'id': 'fundamental2', 'name': 'Report Footnot...
# 2    {'id': 'fundamental2', 'name': 'Report Footnot...
# 18   {'id': 'fundamental2', 'name': 'Report Footnot...
# 130  {'id': 'fundamental2', 'name': 'Report Footnot...
# 99   {'id': 'fundamental2', 'name': 'Report Footnot...
# 25   {'id': 'fundamental2', 'name': 'Report Footnot...
# 23   {'id': 'fundamental2', 'name': 'Report Footnot...
# 98   {'id': 'fundamental2', 'name': 'Report Footnot...
# 21   {'id': 'fundamental2', 'name': 'Report Footnot...
# 19   {'id': 'fundamental2', 'name': 'Report Footnot...
# 22   {'id': 'fundamental2', 'name': 'Report Footnot...
# 20   {'id': 'fundamental2', 'name': 'Report Footnot...
# 132  {'id': 'fundamental2', 'name': 'Report Footnot...
# 128  {'id': 'fundamental2', 'name': 'Report Footnot...
# 24   {'id': 'fundamental2', 'name': 'Report Footnot...
# 126  {'id': 'fundamental2', 'name': 'Report Footnot...
# 90   {'id': 'fundamental2', 'name': 'Report Footnot...
# 129  {'id': 'fundamental2', 'name': 'Report Footnot...
# 131  {'id': 'fundamental2', 'name': 'Report Footnot...
# 133  {'id': 'fundamental2', 'name': 'Report Footnot...
# 89   {'id': 'fundamental2', 'name': 'Report Footnot...
# 91   {'id': 'fundamental2', 'name': 'Report Footnot...
# 88   {'id': 'fundamental2', 'name': 'Report Footnot...
#
#                                          category  \
# 127  {'id': 'fundamental', 'name': 'Fundamental'}
# 0    {'id': 'fundamental', 'name': 'Fundamental'}
# 1    {'id': 'fundamental', 'name': 'Fundamental'}
# 3    {'id': 'fundamental', 'name': 'Fundamental'}
# 2    {'id': 'fundamental', 'name': 'Fundamental'}
# 18   {'id': 'fundamental', 'name': 'Fundamental'}
# 130  {'id': 'fundamental', 'name': 'Fundamental'}
# 99   {'id': 'fundamental', 'name': 'Fundamental'}
# 25   {'id': 'fundamental', 'name': 'Fundamental'}
# 23   {'id': 'fundamental', 'name': 'Fundamental'}
# 98   {'id': 'fundamental', 'name': 'Fundamental'}
# 21   {'id': 'fundamental', 'name': 'Fundamental'}
# 19   {'id': 'fundamental', 'name': 'Fundamental'}
# 22   {'id': 'fundamental', 'name': 'Fundamental'}
# 20   {'id': 'fundamental', 'name': 'Fundamental'}
# 132  {'id': 'fundamental', 'name': 'Fundamental'}
# 128  {'id': 'fundamental', 'name': 'Fundamental'}
# 24   {'id': 'fundamental', 'name': 'Fundamental'}
# 126  {'id': 'fundamental', 'name': 'Fundamental'}
# 90   {'id': 'fundamental', 'name': 'Fundamental'}
# 129  {'id': 'fundamental', 'name': 'Fundamental'}
# 131  {'id': 'fundamental', 'name': 'Fundamental'}
# 133  {'id': 'fundamental', 'name': 'Fundamental'}
# 89   {'id': 'fundamental', 'name': 'Fundamental'}
# 91   {'id': 'fundamental', 'name': 'Fundamental'}
# 88   {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                            subcategory region  delay universe  \
# 127  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 0    {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 1    {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 3    {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 2    {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 18   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 130  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 99   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 25   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 23   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 98   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 21   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 19   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 22   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 20   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 132  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 128  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 24   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 126  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 90   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 129  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 131  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 133  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 89   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 91   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 88   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
#
#        type  coverage  turnover  userCount  alphaCount themes  Cluster
# 127  MATRIX    0.3604       NaN       2120        3183     []        4
# 0    MATRIX    0.3934       NaN        359        1052     []        4
# 1    MATRIX    0.3644       NaN        157         610     []        4
# 3    MATRIX    0.3650       NaN        148         486     []        4
# 2    MATRIX    0.3403       NaN        129         478     []        4
# 18   MATRIX    0.3258       NaN        243         472     []        4
# 130  MATRIX    0.4041       NaN        188         430     []        4
# 99   MATRIX    0.3552       NaN        105         417     []        4
# 25   MATRIX    0.3347       NaN        200         414     []        4
# 23   MATRIX    0.3873       NaN        118         400     []        4
# 98   MATRIX    0.4928       NaN         69         355     []        4
# 21   MATRIX    0.3939       NaN        129         340     []        4
# 19   MATRIX    0.3965       NaN         83         262     []        4
# 22   MATRIX    0.3812       NaN        110         251     []        4
# 20   MATRIX    0.3838       NaN         73         244     []        4
# 132  MATRIX    0.2564       NaN         45         209     []        4
# 128  MATRIX    0.3624       NaN         75         175     []        4
# 24   MATRIX    0.3813       NaN         50         170     []        4
# 126  MATRIX    0.3258       NaN         66         168     []        4
# 90   MATRIX    0.4062       NaN         67         130     []        4
# 129  MATRIX    0.4012       NaN         66         129     []        4
# 131  MATRIX    0.2569       NaN         43         112     []        4
# 133  MATRIX    0.3161       NaN         34         110     []        4
# 89   MATRIX    0.3551       NaN         32          84     []        4
# 91   MATRIX    0.3972       NaN         22          75     []        4
# 88   MATRIX    0.3613       NaN         19          70     []        4

# %%
top_entries_per_cluster = sorted_df.groupby('Cluster').head(2)

top_entries_per_cluster
#print(top_entries_per_cluster[['id', 'description', 'Cluster']].head(2))
# Out:
#      Unnamed: 0                                                 id  \
# 16           16         fn_antidilutive_securities_excl_from_eps_a
# 140         140                            fn_new_shares_options_a
# 157         157  fn_oth_income_loss_fx_transaction_and_tax_tran...
# 82           82                       fn_def_tax_assets_liab_net_a
# 165         165                                    fn_ppne_gross_a
# 108         108            fn_finite_lived_intangible_assets_net_a
# 209         209                                    fnd2_a_dfdtxava
# 287         287                                        fnd2_ebitfr
# 127         127                              fn_liab_fair_val_l1_a
# 0             0                                  fn_accrued_liab_a
#
#                                            description  \
# 16   Securities (including those issuable pursuant ...
# 140  Number of share options (or share units) exerc...
# 157  Amount after tax and reclassification adjustme...
# 82   Amount, after allocation of valuation allowanc...
# 165  Amount before accumulated depreciation, deplet...
# 108                Finite Lived Intangible Assets, Net
# 209  Amount of deferred tax assets for which it is ...
# 287                                      EBIT, Foreign
# 127         Liabilities Fair Value, Recurring, Level 1
# 0    Carrying value as of the balance sheet date of...
#
#                                                dataset  \
# 16   {'id': 'fundamental2', 'name': 'Report Footnot...
# 140  {'id': 'fundamental2', 'name': 'Report Footnot...
# 157  {'id': 'fundamental2', 'name': 'Report Footnot...
# 82   {'id': 'fundamental2', 'name': 'Report Footnot...
# 165  {'id': 'fundamental2', 'name': 'Report Footnot...
# 108  {'id': 'fundamental2', 'name': 'Report Footnot...
# 209  {'id': 'fundamental2', 'name': 'Report Footnot...
# 287  {'id': 'fundamental2', 'name': 'Report Footnot...
# 127  {'id': 'fundamental2', 'name': 'Report Footnot...
# 0    {'id': 'fundamental2', 'name': 'Report Footnot...
#
#                                          category  \
# 16   {'id': 'fundamental', 'name': 'Fundamental'}
# 140  {'id': 'fundamental', 'name': 'Fundamental'}
# 157  {'id': 'fundamental', 'name': 'Fundamental'}
# 82   {'id': 'fundamental', 'name': 'Fundamental'}
# 165  {'id': 'fundamental', 'name': 'Fundamental'}
# 108  {'id': 'fundamental', 'name': 'Fundamental'}
# 209  {'id': 'fundamental', 'name': 'Fundamental'}
# 287  {'id': 'fundamental', 'name': 'Fundamental'}
# 127  {'id': 'fundamental', 'name': 'Fundamental'}
# 0    {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                            subcategory region  delay universe  \
# 16   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 140  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 157  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 82   {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 165  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 108  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 209  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 287  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 127  {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
# 0    {'id': 'fundamental-footnotes', 'name': 'Footn...    USA      1  TOP3000
#
#        type  coverage  turnover  userCount  alphaCount themes  Cluster
# 16   MATRIX    0.6007       NaN        340         883     []        0
# 140  MATRIX    0.6306       NaN        195         732     []        0
# 157  MATRIX    0.4260       NaN       1149        1571     []        1
# 82   MATRIX    0.7058       NaN        304        1278     []        1
# 165  MATRIX    0.5997       NaN         81         362     []        2
# 108  MATRIX    0.4505       NaN        191         341     []        2
# 209  MATRIX    0.5993       NaN        222         696     []        3
# 287  MATRIX    0.3948       NaN        189         619     []        3
# 127  MATRIX    0.3604       NaN       2120        3183     []        4
# 0    MATRIX    0.3934       NaN        359        1052     []        4

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X.toarray())

plt.figure(figsize=(10, 8))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=clusters, cmap='viridis')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Clusters of Datafields Based on Text Descriptions')
plt.colorbar()
plt.show()
