# %% [markdown]
# ### Import library

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px
import pygwalker as pyg
import glob
import re

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_eMoefDW2d5cFQQRSToWoqskNB6oi

# %%
ace.check_session_timeout(s)
# Out:
# 14399.521684

# %%
'''
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')

#calling submit_alpha on all alphas that have passed the submission tests
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['summer_boot_camp_4조'])
    
ace.get_check_submission(s, passed_alphas[3])

submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas}
'''
# Out:
# '\n#making a list of failed alphas\nfailed_alphas = is_tests_df.query(\'result=="FAIL"\')[\'alpha_id\'].unique()\n\n#making a list of passed alphas\npassed_alphas = list(set(is_tests_df[\'alpha_id\']).difference(failed_alphas))\n\nprint(f\'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}\')\n\n#calling submit_alpha on all alphas that have passed the submission tests\nfor alpha_id in passed_alphas:\n    hf.set_alpha_properties(s, alpha_id, tags = [\'summer_boot_camp_4조\'])\n    \nace.get_check_submission(s, passed_alphas[3])\n'

# %% [markdown]
# ## Scoring

# %%
def score(raw_data):
    score_data = raw_data[['test.turnover', 'test.returns', 'test.drawdown']]
    score = pd.DataFrame()
    score = 1.3673 + 0.1757*score_data['test.turnover'] + 0.6150*score_data['test.returns'] - 1.0816*score_data['test.drawdown']
    return score

# %% [markdown]
# ## Alpha Mixing Templates

# %%
'''
signal1 = scale_down(<cs_operator>(ts_backfill(<data1>,126)));

signal2 = scale_down(<cs_operator>(ts_backfill(<data2>,126)));

signal1 * (1 + signal2)
'''
# Out:
# '\nsignal1 = scale_down(<cs_operator>(ts_backfill(<data1>,126)));\n\nsignal2 = scale_down(<cs_operator>(ts_backfill(<data2>,126)));\n\nsignal1 * (1 + signal2)\n'

# %%
'''
signal1 = oth176_lmt_close_eq_score ;
signal2 = oth176_malta_eq_score ;
k = ts_corr(signal1, signal2, 30) ;
k*regression_neut(signal1, signal2)

[아이디어]
경향성이 비슷한 알파 활용하여 corr로 weight를 부여
'''
# Out:
# '\nsignal1 = oth176_lmt_close_eq_score ;\nsignal2 = oth176_malta_eq_score ;\nk = ts_corr(signal1, signal2, 30) ;\nk*regression_neut(signal1, signal2)\n\n[아이디어]\n경향성이 비슷한 알파 활용하여 corr로 weight를 부여\n'

# %% [markdown]
# ## Read all passed alphas

# %%
file_direc = glob.glob('Files/signal/signal_form/*')
file_direc
# Out:
# ['Files/signal/signal_form\\A_signalform.csv',
#  'Files/signal/signal_form\\B_signalform.csv',
#  'Files/signal/signal_form\\C_signalform.csv',
#  'Files/signal/signal_form\\D_signalform.csv']

# %%
expressions = {}
expressions['A'] = pd.read_csv(file_direc[0])['expression']
expressions['B'] = pd.read_csv(file_direc[1])['expression']
expressions['C'] = pd.read_csv(file_direc[2])['expression']
expressions['D'] = pd.read_csv(file_direc[3])['expression']

# %% [markdown]
# ## Template B mixing
# use top 24 results

# %%
#region= "GLB", universe = "MINVOL1M", neutralization = 'SECTOR', truncation = 0.01, decay = 3

# %%
b = expressions['B'][:24]
b
# Out:
# 0     entry_B_0 = ts_rank( ts_std_dev(oth460_3l_vlc,...
# 1     entry_B_1 = ts_rank( ts_std_dev(oth460_1l_1dls...
# 2     entry_B_2 = ts_rank( ts_std_dev(oth460_1l_aiec...
# 3     entry_B_3 = ts_rank( ts_std_dev(oth460_veia_l2...
# 4     entry_B_4 = ts_rank( ts_std_dev(oth460_3l_vlc,...
#                             ...
# 67    entry_B_67 = ts_rank( ts_std_dev(oth460_1l_aie...
# 68    entry_B_68 = ts_rank( ts_std_dev(oth460_1l_1dl...
# 69    entry_B_69 = ts_rank( ts_std_dev(oth460_1l_2dl...
# 70    entry_B_70 = ts_rank( ts_std_dev(oth460_clv_cl...
# 71    entry_B_71 = ts_rank( ts_std_dev(oth460_3l_vlc...
# Name: expression, Length: 72, dtype: object

# %%
'''
signal1 = scale_down(<cs_operator>(ts_backfill(<data1>,126)));

signal2 = scale_down(<cs_operator>(ts_backfill(<data2>,126)));

signal1 * (1 + signal2)
'''

# %% [markdown]
# ### add

# %%
alpha_list = []

for i in range(13):
    alpha_list.append(ace.generate_alpha(f'{b[2*i]};{b[2*i+1]};sqrt(add(signal_B_{2*i}, signal_B_{2*i+1}, filter = false))', region= "GLB", universe = "MINVOL1M", neutralization = 'SECTOR', truncation = 0.01, decay = 15))

alpha_list
# Out:
# [{'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_0 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_0 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_0 = entry_B_0 < 0.5;signal_B_0 =  trade_when(entry_B_0>0.55, maintenance_B_0, quit_B_0);entry_B_1 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_1 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_1 = entry_B_1 < 0.5;signal_B_1 =  trade_when(entry_B_1>0.55, maintenance_B_1, quit_B_1);sqrt(add(signal_B_0, signal_B_1, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_2 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_2 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_2 = entry_B_2 < 0.5;signal_B_2 =  trade_when(entry_B_2>0.55, maintenance_B_2, quit_B_2);entry_B_3 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_3 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_3 = entry_B_3 < 0.5;signal_B_3 =  trade_when(entry_B_3>0.55, maintenance_B_3, quit_B_3);sqrt(add(signal_B_2, signal_B_3, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_4 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_4 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_4 = entry_B_4 < 0.5;signal_B_4 =  trade_when(entry_B_4>0.55, maintenance_B_4, quit_B_4);entry_B_5 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_5 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_5 = entry_B_5 < 0.5;signal_B_5 =  trade_when(entry_B_5>0.55, maintenance_B_5, quit_B_5);sqrt(add(signal_B_4, signal_B_5, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_6 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_6 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_6 = entry_B_6 < 0.5;signal_B_6 =  trade_when(entry_B_6>0.55, maintenance_B_6, quit_B_6);entry_B_7 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_7 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_7 = entry_B_7 < 0.5;signal_B_7 =  trade_when(entry_B_7>0.55, maintenance_B_7, quit_B_7);sqrt(add(signal_B_6, signal_B_7, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_8 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_8 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_8 = entry_B_8 < 0.5;signal_B_8 =  trade_when(entry_B_8>0.55, maintenance_B_8, quit_B_8);entry_B_9 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_9 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_9 = entry_B_9 < 0.5;signal_B_9 =  trade_when(entry_B_9>0.55, maintenance_B_9, quit_B_9);sqrt(add(signal_B_8, signal_B_9, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_10 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_10 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_10 = entry_B_10 < 0.5;signal_B_10 =  trade_when(entry_B_10>0.55, maintenance_B_10, quit_B_10);entry_B_11 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_11 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_11 = entry_B_11 < 0.5;signal_B_11 =  trade_when(entry_B_11>0.55, maintenance_B_11, quit_B_11);sqrt(add(signal_B_10, signal_B_11, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_12 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_12 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_12 = entry_B_12 < 0.5;signal_B_12 =  trade_when(entry_B_12>0.55, maintenance_B_12, quit_B_12);entry_B_13 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_13 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_13 = entry_B_13 < 0.5;signal_B_13 =  trade_when(entry_B_13>0.55, maintenance_B_13, quit_B_13);sqrt(add(signal_B_12, signal_B_13, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_14 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_14 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_14 = entry_B_14 < 0.5;signal_B_14 =  trade_when(entry_B_14>0.55, maintenance_B_14, quit_B_14);entry_B_15 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_15 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_15 = entry_B_15 < 0.5;signal_B_15 =  trade_when(entry_B_15>0.55, maintenance_B_15, quit_B_15);sqrt(add(signal_B_14, signal_B_15, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_16 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_16 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_16 = entry_B_16 < 0.5;signal_B_16 =  trade_when(entry_B_16>0.55, maintenance_B_16, quit_B_16);entry_B_17 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_17 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_17 = entry_B_17 < 0.5;signal_B_17 =  trade_when(entry_B_17>0.55, maintenance_B_17, quit_B_17);sqrt(add(signal_B_16, signal_B_17, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_18 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_18 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_18 = entry_B_18 < 0.5;signal_B_18 =  trade_when(entry_B_18>0.55, maintenance_B_18, quit_B_18);entry_B_19 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_19 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_19 = entry_B_19 < 0.5;signal_B_19 =  trade_when(entry_B_19>0.55, maintenance_B_19, quit_B_19);sqrt(add(signal_B_18, signal_B_19, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_20 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_20 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_20 = entry_B_20 < 0.5;signal_B_20 =  trade_when(entry_B_20>0.55, maintenance_B_20, quit_B_20);entry_B_21 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_21 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_21 = entry_B_21 < 0.5;signal_B_21 =  trade_when(entry_B_21>0.55, maintenance_B_21, quit_B_21);sqrt(add(signal_B_20, signal_B_21, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_22 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_22 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_22 = entry_B_22 < 0.5;signal_B_22 =  trade_when(entry_B_22>0.55, maintenance_B_22, quit_B_22);entry_B_23 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_23 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_23 = entry_B_23 < 0.5;signal_B_23 =  trade_when(entry_B_23>0.55, maintenance_B_23, quit_B_23);sqrt(add(signal_B_22, signal_B_23, filter = false))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 15,
#    'neutralization': 'SECTOR',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'entry_B_24 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_24 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_24 = entry_B_24 < 0.5;signal_B_24 =  trade_when(entry_B_24>0.55, maintenance_B_24, quit_B_24);entry_B_25 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_25 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_25 = entry_B_25 < 0.5;signal_B_25 =  trade_when(entry_B_25>0.55, maintenance_B_25, quit_B_25);sqrt(add(signal_B_24, signal_B_25, filter = false))'}]

# %%
result = ace.simulate_alpha_list_multi(s, alpha_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [16:29<00:00, 197.85s/it]

# %%
result
# Out:
# [{'alpha_id': 'JprVg7j',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_0 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_0 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_0 = entry_B_0 < 0.5;signal_B_0 =  trade_when(entry_B_0>0.55, maintenance_B_0, quit_B_0);entry_B_1 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_1 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_1 = entry_B_1 < 0.5;signal_B_1 =  trade_when(entry_B_1>0.55, maintenance_B_1, quit_B_1);sqrt(multiply(signal_B_0, signal_B_1, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0 -5427983  20000000        680         926    0.6695  -0.0524    0.6578
#
#        margin  fitness  sharpe   startDate alpha_id
#   0 -0.000157    -0.16   -0.58  2012-01-22  JprVg7j  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58 -0.5800   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00 -0.1600   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.6695   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.6695   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS  -0.20 -0.0600   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58 -0.3200   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  JprVg7j
#   1          NaN  JprVg7j
#   2          NaN  JprVg7j
#   3          NaN  JprVg7j
#   4          NaN  JprVg7j
#   5          NaN  JprVg7j
#   6          NaN  JprVg7j
#   7          NaN  JprVg7j
#   8          NaN  JprVg7j
#   9          NaN  JprVg7j
#   10  2020-01-25  JprVg7j  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'WpJEaPk',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_2 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_2 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_2 = entry_B_2 < 0.5;signal_B_2 =  trade_when(entry_B_2>0.55, maintenance_B_2, quit_B_2);entry_B_3 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_3 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_3 = entry_B_3 < 0.5;signal_B_3 =  trade_when(entry_B_3>0.55, maintenance_B_3, quit_B_3);sqrt(multiply(signal_B_2, signal_B_3, filter = false))'},
#   'is_stats':       pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  928328  20000000        586         774    0.5667    0.009    0.2451
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000032     0.01    0.09  2012-01-22  WpJEaPk  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  0.0900   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.0100   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.5667   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.5667   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS   0.03  0.2800   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  0.4600   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  WpJEaPk
#   1          NaN  WpJEaPk
#   2          NaN  WpJEaPk
#   3          NaN  WpJEaPk
#   4          NaN  WpJEaPk
#   5          NaN  WpJEaPk
#   6          NaN  WpJEaPk
#   7          NaN  WpJEaPk
#   8          NaN  WpJEaPk
#   9          NaN  WpJEaPk
#   10  2020-01-25  WpJEaPk  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'Np8Xgag',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_4 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_4 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_4 = entry_B_4 < 0.5;signal_B_4 =  trade_when(entry_B_4>0.55, maintenance_B_4, quit_B_4);entry_B_5 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_5 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_5 = entry_B_5 < 0.5;signal_B_5 =  trade_when(entry_B_5>0.55, maintenance_B_5, quit_B_5);sqrt(multiply(signal_B_4, signal_B_5, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0 -5857815  20000000        747        1017    0.6631  -0.0566    0.7139
#
#        margin  fitness  sharpe   startDate alpha_id
#   0 -0.000171    -0.18   -0.61  2012-01-22  Np8Xgag  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58 -0.6100   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00 -0.1800   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.6631   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.6631   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS  -0.21  0.0100   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58 -0.4100   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  Np8Xgag
#   1          NaN  Np8Xgag
#   2          NaN  Np8Xgag
#   3          NaN  Np8Xgag
#   4          NaN  Np8Xgag
#   5          NaN  Np8Xgag
#   6          NaN  Np8Xgag
#   7          NaN  Np8Xgag
#   8          NaN  Np8Xgag
#   9          NaN  Np8Xgag
#   10  2020-01-25  Np8Xgag  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'k39xQ3k',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_6 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_6 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_6 = entry_B_6 < 0.5;signal_B_6 =  trade_when(entry_B_6>0.55, maintenance_B_6, quit_B_6);entry_B_7 = ts_rank( ts_std_dev(oth460_3l_vlc, 21), 252 ); maintenance_B_7 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_7 = entry_B_7 < 0.5;signal_B_7 =  trade_when(entry_B_7>0.55, maintenance_B_7, quit_B_7);sqrt(multiply(signal_B_6, signal_B_7, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0 -3754198  20000000        636         864    0.7248  -0.0363     0.462
#
#      margin  fitness  sharpe   startDate alpha_id
#   0 -0.0001    -0.09   -0.39  2012-01-22  k39xQ3k  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58 -0.3900   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00 -0.0900   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.7248   NaN         NaN
#   3             HIGH_TURNOVER     FAIL   0.70  0.7248   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS  -0.14  0.1600   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58 -0.1500   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  k39xQ3k
#   1          NaN  k39xQ3k
#   2          NaN  k39xQ3k
#   3          NaN  k39xQ3k
#   4          NaN  k39xQ3k
#   5          NaN  k39xQ3k
#   6          NaN  k39xQ3k
#   7          NaN  k39xQ3k
#   8          NaN  k39xQ3k
#   9          NaN  k39xQ3k
#   10  2020-01-25  k39xQ3k  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'PpKJv3q',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_8 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_8 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_8 = entry_B_8 < 0.5;signal_B_8 =  trade_when(entry_B_8>0.55, maintenance_B_8, quit_B_8);entry_B_9 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_9 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_9 = entry_B_9 < 0.5;signal_B_9 =  trade_when(entry_B_9>0.55, maintenance_B_9, quit_B_9);sqrt(multiply(signal_B_8, signal_B_9, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0 -2657871  20000000        355         469    0.6219  -0.0257      0.46
#
#        margin  fitness  sharpe   startDate alpha_id
#   0 -0.000083    -0.05   -0.23  2012-01-22  PpKJv3q  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit     value        date  year  \
#   0                LOW_SHARPE     FAIL   1.58 -0.230000         NaN   NaN
#   1               LOW_FITNESS     FAIL   1.00 -0.050000         NaN   NaN
#   2              LOW_TURNOVER     PASS   0.01  0.621900         NaN   NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.621900         NaN   NaN
#   4       CONCENTRATED_WEIGHT     FAIL   0.10  0.113939  2012-01-23   NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS  -0.08  0.160000         NaN   NaN
#   6          SELF_CORRELATION  PENDING    NaN       NaN         NaN   NaN
#   7            DATA_DIVERSITY  PENDING    NaN       NaN         NaN   NaN
#   8          PROD_CORRELATION  PENDING    NaN       NaN         NaN   NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN       NaN         NaN   NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  0.070000         NaN   2.0
#
#        startDate     endDate alpha_id
#   0          NaN         NaN  PpKJv3q
#   1          NaN         NaN  PpKJv3q
#   2          NaN         NaN  PpKJv3q
#   3          NaN         NaN  PpKJv3q
#   4          NaN         NaN  PpKJv3q
#   5          NaN         NaN  PpKJv3q
#   6          NaN         NaN  PpKJv3q
#   7          NaN         NaN  PpKJv3q
#   8          NaN         NaN  PpKJv3q
#   9          NaN         NaN  PpKJv3q
#   10  2022-01-24  2020-01-25  PpKJv3q  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': '6wNnzeP',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_10 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_10 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_10 = entry_B_10 < 0.5;signal_B_10 =  trade_when(entry_B_10>0.55, maintenance_B_10, quit_B_10);entry_B_11 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_11 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_11 = entry_B_11 < 0.5;signal_B_11 =  trade_when(entry_B_11>0.55, maintenance_B_11, quit_B_11);sqrt(multiply(signal_B_10, signal_B_11, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0 -5359146  20000000        584         809    0.7996  -0.0517    0.6331
#
#        margin  fitness  sharpe   startDate alpha_id
#   0 -0.000129    -0.16   -0.62  2012-01-22  6wNnzeP  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58 -0.6200   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00 -0.1600   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.7996   NaN         NaN
#   3             HIGH_TURNOVER     FAIL   0.70  0.7996   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS  -0.22  0.3000   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58 -0.3800   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  6wNnzeP
#   1          NaN  6wNnzeP
#   2          NaN  6wNnzeP
#   3          NaN  6wNnzeP
#   4          NaN  6wNnzeP
#   5          NaN  6wNnzeP
#   6          NaN  6wNnzeP
#   7          NaN  6wNnzeP
#   8          NaN  6wNnzeP
#   9          NaN  6wNnzeP
#   10  2020-01-25  6wNnzeP  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'AwERkzw',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_12 = ts_rank( ts_std_dev(oth460_1l_1dls, 21), 252 ); maintenance_B_12 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_12 = entry_B_12 < 0.5;signal_B_12 =  trade_when(entry_B_12>0.55, maintenance_B_12, quit_B_12);entry_B_13 = ts_rank( ts_std_dev(oth460_veia_l2, 21), 252 ); maintenance_B_13 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_13 = entry_B_13 < 0.5;signal_B_13 =  trade_when(entry_B_13>0.55, maintenance_B_13, quit_B_13);sqrt(multiply(signal_B_12, signal_B_13, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0 -2643853  20000000        787        1079    0.5681  -0.0255    0.4118
#
#       margin  fitness  sharpe   startDate alpha_id
#   0 -0.00009    -0.05   -0.23  2012-01-22  AwERkzw  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58 -0.2300   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00 -0.0500   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.5681   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.5681   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS  -0.08  0.2200   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58 -0.1400   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  AwERkzw
#   1          NaN  AwERkzw
#   2          NaN  AwERkzw
#   3          NaN  AwERkzw
#   4          NaN  AwERkzw
#   5          NaN  AwERkzw
#   6          NaN  AwERkzw
#   7          NaN  AwERkzw
#   8          NaN  AwERkzw
#   9          NaN  AwERkzw
#   10  2020-01-25  AwERkzw  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': '27e1JWZ',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_14 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_14 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_14 = entry_B_14 < 0.5;signal_B_14 =  trade_when(entry_B_14>0.55, maintenance_B_14, quit_B_14);entry_B_15 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_15 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_15 = entry_B_15 < 0.5;signal_B_15 =  trade_when(entry_B_15>0.55, maintenance_B_15, quit_B_15);sqrt(multiply(signal_B_14, signal_B_15, filter = false))'},
#   'is_stats':       pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  707901  20000000        530         711    0.6605   0.0068    0.1853
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000021     0.01    0.06  2012-01-22  27e1JWZ  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  0.0600   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.0100   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.6605   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.6605   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS   0.02  0.2800   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58 -0.1100   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  27e1JWZ
#   1          NaN  27e1JWZ
#   2          NaN  27e1JWZ
#   3          NaN  27e1JWZ
#   4          NaN  27e1JWZ
#   5          NaN  27e1JWZ
#   6          NaN  27e1JWZ
#   7          NaN  27e1JWZ
#   8          NaN  27e1JWZ
#   9          NaN  27e1JWZ
#   10  2020-01-25  27e1JWZ  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'AwERkEw',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_16 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_16 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_16 = entry_B_16 < 0.5;signal_B_16 =  trade_when(entry_B_16>0.55, maintenance_B_16, quit_B_16);entry_B_17 = ts_rank( ts_std_dev(oth460_1l_2dls, 21), 252 ); maintenance_B_17 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_17 = entry_B_17 < 0.5;signal_B_17 =  trade_when(entry_B_17>0.55, maintenance_B_17, quit_B_17);sqrt(multiply(signal_B_16, signal_B_17, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0 -2226796  20000000        675         923    0.6569  -0.0215    0.3438
#
#        margin  fitness  sharpe   startDate alpha_id
#   0 -0.000065    -0.04    -0.2  2012-01-22  AwERkEw  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58 -0.2000   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00 -0.0400   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.6569   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.6569   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS  -0.07  0.3400   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58 -0.6500   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  AwERkEw
#   1          NaN  AwERkEw
#   2          NaN  AwERkEw
#   3          NaN  AwERkEw
#   4          NaN  AwERkEw
#   5          NaN  AwERkEw
#   6          NaN  AwERkEw
#   7          NaN  AwERkEw
#   8          NaN  AwERkEw
#   9          NaN  AwERkEw
#   10  2020-01-25  AwERkEw  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'Lp3PGmm',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'testPeriod': 'P0Y0M0D',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_24 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_24 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_24 = entry_B_24 < 0.5;signal_B_24 =  trade_when(entry_B_24>0.55, maintenance_B_24, quit_B_24);entry_B_25 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_25 = -ts_regression(rsk70_mfm2_gemtrd_size, ts_delay(rsk70_mfm2_gemtrd_anlystsn, 1), 252); quit_B_25 = entry_B_25 < 0.5;signal_B_25 =  trade_when(entry_B_25>0.55, maintenance_B_25, quit_B_25);sqrt(multiply(signal_B_24, signal_B_25, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  2250116  20000000        473        1050     0.196   0.0217    0.4003
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000222     0.06    0.19  2012-01-22  Lp3PGmm  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit  value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  0.190   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.060   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.196   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.196   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN    NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     FAIL   0.07 -0.250   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN    NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN    NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN    NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN    NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  0.570   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  Lp3PGmm
#   1          NaN  Lp3PGmm
#   2          NaN  Lp3PGmm
#   3          NaN  Lp3PGmm
#   4          NaN  Lp3PGmm
#   5          NaN  Lp3PGmm
#   6          NaN  Lp3PGmm
#   7          NaN  Lp3PGmm
#   8          NaN  Lp3PGmm
#   9          NaN  Lp3PGmm
#   10  2020-01-25  Lp3PGmm  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'AwER0Qw',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_18 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_18 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_18 = entry_B_18 < 0.5;signal_B_18 =  trade_when(entry_B_18>0.55, maintenance_B_18, quit_B_18);entry_B_19 = ts_rank( ts_std_dev(oth460_1l_aiec, 21), 252 ); maintenance_B_19 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_19 = entry_B_19 < 0.5;signal_B_19 =  trade_when(entry_B_19>0.55, maintenance_B_19, quit_B_19);sqrt(multiply(signal_B_18, signal_B_19, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0 -2573277  20000000        443         596    0.8189  -0.0248    0.3503
#
#        margin  fitness  sharpe   startDate alpha_id
#   0 -0.000061    -0.05   -0.27  2012-01-22  AwER0Qw  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58 -0.2700   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00 -0.0500   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.8189   NaN         NaN
#   3             HIGH_TURNOVER     FAIL   0.70  0.8189   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS  -0.09  0.2400   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58 -0.4000   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  AwER0Qw
#   1          NaN  AwER0Qw
#   2          NaN  AwER0Qw
#   3          NaN  AwER0Qw
#   4          NaN  AwER0Qw
#   5          NaN  AwER0Qw
#   6          NaN  AwER0Qw
#   7          NaN  AwER0Qw
#   8          NaN  AwER0Qw
#   9          NaN  AwER0Qw
#   10  2020-01-25  AwER0Qw  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'XpMjW91',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_20 = ts_rank( ts_std_dev(oth460_clv_class, 21), 252 ); maintenance_B_20 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_20 = entry_B_20 < 0.5;signal_B_20 =  trade_when(entry_B_20>0.55, maintenance_B_20, quit_B_20);entry_B_21 = ts_rank( ts_std_dev(oth460_1l_ccns, 21), 252 ); maintenance_B_21 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_21 = entry_B_21 < 0.5;signal_B_21 =  trade_when(entry_B_21>0.55, maintenance_B_21, quit_B_21);sqrt(multiply(signal_B_20, signal_B_21, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0 -3763968  20000000        613         847    0.7501  -0.0363    0.4782
#
#        margin  fitness  sharpe   startDate alpha_id
#   0 -0.000097    -0.09   -0.39  2012-01-22  XpMjW91  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58 -0.3900   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00 -0.0900   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.7501   NaN         NaN
#   3             HIGH_TURNOVER     FAIL   0.70  0.7501   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS  -0.14  0.1700   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58 -0.6500   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  XpMjW91
#   1          NaN  XpMjW91
#   2          NaN  XpMjW91
#   3          NaN  XpMjW91
#   4          NaN  XpMjW91
#   5          NaN  XpMjW91
#   6          NaN  XpMjW91
#   7          NaN  XpMjW91
#   8          NaN  XpMjW91
#   9          NaN  XpMjW91
#   10  2020-01-25  XpMjW91  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'qAVKW7E',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 15,
#     'neutralization': 'SECTOR',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'entry_B_22 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_22 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_srtindcnt, 1), 252); quit_B_22 = entry_B_22 < 0.5;signal_B_22 =  trade_when(entry_B_22>0.55, maintenance_B_22, quit_B_22);entry_B_23 = ts_rank( ts_std_dev(oth460_fprd_class, 21), 252 ); maintenance_B_23 = -ts_regression(rsk70_mfm2_gemtrd_srtindcnt, ts_delay(rsk70_mfm2_gemtrd_size, 1), 252); quit_B_23 = entry_B_23 < 0.5;signal_B_23 =  trade_when(entry_B_23>0.55, maintenance_B_23, quit_B_23);sqrt(multiply(signal_B_22, signal_B_23, filter = false))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0 -2659326  20000000        737         981    0.5059  -0.0257    0.4459
#
#        margin  fitness  sharpe   startDate alpha_id
#   0 -0.000102    -0.05   -0.23  2012-01-22  qAVKW7E  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58 -0.2300   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00 -0.0500   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.5059   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.5059   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS  -0.08 -0.0300   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58 -0.1900   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  qAVKW7E
#   1          NaN  qAVKW7E
#   2          NaN  qAVKW7E
#   3          NaN  qAVKW7E
#   4          NaN  qAVKW7E
#   5          NaN  qAVKW7E
#   6          NaN  qAVKW7E
#   7          NaN  qAVKW7E
#   8          NaN  qAVKW7E
#   9          NaN  qAVKW7E
#   10  2020-01-25  qAVKW7E  ,
#   'train': None,
#   'test': None}]

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#          pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   10539393   20000000         404          455    1.3883   0.1018    0.1348
# 1   11094456   20000000         326          365    1.3561   0.1071    0.1296
# 2   11601660   20000000         215          237    1.3561   0.1120    0.1324
# 3    9845797   20000000         392          442    1.3881   0.0951    0.1256
# 4   10650254   20000000         369          419    1.4078   0.1028    0.1653
# 5    9031770   20000000         445          500    1.3679   0.0872    0.1494
# 6    9862173   20000000         463          529    1.3714   0.0952    0.1503
# 7    5910956   20000000         392          521    0.2379   0.0571    0.2520
# 8    9655958   20000000         418          476    1.3573   0.0932    0.1554
# 9    9650807   20000000         432          487    1.3410   0.0932    0.1982
# 10   8924600   20000000         340          381    1.3671   0.0862    0.2147
# 11   7654677   20000000         366          414    1.3953   0.0739    0.1917
# 12   8231072   20000000         277          307    1.3991   0.0795    0.1868
#
#       margin  fitness  sharpe  start_date alpha_id  \
# 0   0.000147     0.33    1.22  2012-01-22  p63wO7j
# 1   0.000158     0.31    1.10  2012-01-22  adGk3O9
# 2   0.000165     0.31    1.09  2012-01-22  ro8Kko9
# 3   0.000137     0.30    1.13  2012-01-22  ZpNYZod
# 4   0.000146     0.30    1.12  2012-01-22  YpYPpw6
# 5   0.000128     0.26    1.02  2012-01-22  Np819RL
# 6   0.000139     0.26    0.99  2012-01-22  wRWpVL2
# 7   0.000480     0.25    0.52  2012-01-22  6wNXqlL
# 8   0.000137     0.24    0.93  2012-01-22  AwE1dPY
# 9   0.000139     0.24    0.92  2012-01-22  YpYPpn6
# 10  0.000126     0.23    0.91  2012-01-22  Ewx5JEJ
# 11  0.000106     0.21    0.90  2012-01-22  ZpNYZKY
# 12  0.000114     0.21    0.86  2012-01-22  Opg0peb
#
#                                            expression concentrated_weight  \
# 0   entry_B_0 = ts_rank( ts_std_dev(oth460_3l_vlc,...                PASS
# 1   entry_B_14 = ts_rank( ts_std_dev(oth460_1l_ccn...                PASS
# 2   entry_B_8 = ts_rank( ts_std_dev(oth460_veia_l2...                FAIL
# 3   entry_B_6 = ts_rank( ts_std_dev(oth460_1l_2dls...                PASS
# 4   entry_B_20 = ts_rank( ts_std_dev(oth460_clv_cl...                PASS
# 5   entry_B_4 = ts_rank( ts_std_dev(oth460_3l_vlc,...                PASS
# 6   entry_B_12 = ts_rank( ts_std_dev(oth460_1l_1dl...                PASS
# 7   entry_B_24 = ts_rank( ts_std_dev(oth460_fprd_c...                PASS
# 8   entry_B_16 = ts_rank( ts_std_dev(oth460_1l_ccn...                PASS
# 9   entry_B_22 = ts_rank( ts_std_dev(oth460_fprd_c...                PASS
# 10  entry_B_2 = ts_rank( ts_std_dev(oth460_1l_aiec...                FAIL
# 11  entry_B_10 = ts_rank( ts_std_dev(oth460_1l_2dl...                PASS
# 12  entry_B_18 = ts_rank( ts_std_dev(oth460_clv_cl...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           FAIL             FAIL        FAIL       FAIL
# 1           FAIL             FAIL        FAIL       FAIL
# 2           FAIL             FAIL        FAIL       FAIL
# 3           FAIL             FAIL        FAIL       FAIL
# 4           FAIL             FAIL        FAIL       FAIL
# 5           FAIL             FAIL        FAIL       FAIL
# 6           FAIL             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           FAIL             FAIL        FAIL       FAIL
# 9           FAIL             FAIL        FAIL       FAIL
# 10          FAIL             FAIL        FAIL       FAIL
# 11          FAIL             FAIL        FAIL       FAIL
# 12          FAIL             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover
# 0                     PASS         PASS
# 1                     PASS         PASS
# 2                     PASS         PASS
# 3                     PASS         PASS
# 4                     PASS         PASS
# 5                     PASS         PASS
# 6                     PASS         PASS
# 7                     FAIL         PASS
# 8                     PASS         PASS
# 9                     PASS         PASS
# 10                    PASS         PASS
# 11                    PASS         PASS
# 12                    PASS         PASS

# %%
result_st1.to_csv('A_mixing_add.csv')

# %% [markdown]
# ### mult

# %%
'''
signal1 = scale_down(<cs_operator>(ts_backfill(<data1>,126)));

signal2 = scale_down(<cs_operator>(ts_backfill(<data2>,126)));

signal1 * (1 + signal2)
'''
# Out:
# '\nsignal1 = scale_down(<cs_operator>(ts_backfill(<data1>,126)));\n\nsignal2 = scale_down(<cs_operator>(ts_backfill(<data2>,126)));\n\nsignal1 * (1 + signal2)\n'

# %%
alpha_list = []

for i in range(10):
    alpha_list.append(ace.generate_alpha(f'{a[2*i]}*(1+ {a[2*i+1]})', region= "GLB", universe = "MINVOL1M", neutralization = 'MARKET', truncation = 0.01))

alpha_list
# Out:
# [{'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'trade_when(oth460_1l_acda<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5)*(1+ trade_when(oth460_1l_ccns<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'trade_when(oth460_1l_ccns<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5)*(1+ trade_when(oth460_1l_acda<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5)*(1+ trade_when(oth460_1l_fbds<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbds>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5)*(1+ trade_when(oth460_1l_fbbs<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbbs>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'trade_when(oth460_es_ebit_fy1_d1m_l1<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_ebit_fy1_d1m_l1>0.5)*(1+ trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'trade_when(oth460_1l_fbds<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbds>0.5)*(1+ trade_when(oth460_es_roe_fy1_d1m_l1<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_roe_fy1_d1m_l1>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5)*(1+ trade_when(oth460_1l_fbbs<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbbs>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'trade_when(oth460_1l_acda<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5)*(1+ trade_when(oth460_1l_ccns<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'trade_when(oth460_es_ebit_fy1_d1m_l1<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_ebit_fy1_d1m_l1>0.5)*(1+ trade_when(oth460_1l_acda<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'trade_when(oth460_es_roe_fy1_d1m_l1<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_roe_fy1_d1m_l1>0.5)*(1+ trade_when(oth460_1l_ccns<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5))'}]

# %%
result = ace.simulate_alpha_list_multi(s, alpha_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [22:51<00:00, 342.85s/it]

# %% [markdown]
# ### corr

# %%
alpha_list = []

for i in range(10):
    alpha_list.append(ace.generate_alpha(f'k = ts_corr({a[i]}, {a[i+1]}, 30);k*regression_neut({a[i]}, {a[i+1]})', region= "GLB", universe = "MINVOL1M", neutralization = 'MARKET', truncation = 0.01))

alpha_list
# Out:
# [{'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'k = ts_corr(trade_when(oth460_1l_acda<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5), trade_when(oth460_1l_ccns<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5), 30);k*regression_neut(trade_when(oth460_1l_acda<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5), trade_when(oth460_1l_ccns<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'k = ts_corr(trade_when(oth460_1l_ccns<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5), trade_when(oth460_1l_ccns<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5), 30);k*regression_neut(trade_when(oth460_1l_ccns<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5), trade_when(oth460_1l_ccns<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'k = ts_corr(trade_when(oth460_1l_ccns<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5), trade_when(oth460_1l_acda<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5), 30);k*regression_neut(trade_when(oth460_1l_ccns<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5), trade_when(oth460_1l_acda<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'k = ts_corr(trade_when(oth460_1l_acda<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5), trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5), 30);k*regression_neut(trade_when(oth460_1l_acda<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5), trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'k = ts_corr(trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5), trade_when(oth460_1l_fbds<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbds>0.5), 30);k*regression_neut(trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5), trade_when(oth460_1l_fbds<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbds>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'k = ts_corr(trade_when(oth460_1l_fbds<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbds>0.5), trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5), 30);k*regression_neut(trade_when(oth460_1l_fbds<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbds>0.5), trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'k = ts_corr(trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5), trade_when(oth460_1l_fbbs<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbbs>0.5), 30);k*regression_neut(trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5), trade_when(oth460_1l_fbbs<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbbs>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'k = ts_corr(trade_when(oth460_1l_fbbs<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbbs>0.5), trade_when(oth460_es_ebit_fy1_d1m_l1<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_ebit_fy1_d1m_l1>0.5), 30);k*regression_neut(trade_when(oth460_1l_fbbs<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbbs>0.5), trade_when(oth460_es_ebit_fy1_d1m_l1<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_ebit_fy1_d1m_l1>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'k = ts_corr(trade_when(oth460_es_ebit_fy1_d1m_l1<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_ebit_fy1_d1m_l1>0.5), trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5), 30);k*regression_neut(trade_when(oth460_es_ebit_fy1_d1m_l1<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_ebit_fy1_d1m_l1>0.5), trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5))'},
#  {'type': 'REGULAR',
#   'settings': {'instrumentType': 'EQUITY',
#    'region': 'GLB',
#    'universe': 'MINVOL1M',
#    'delay': 1,
#    'decay': 0,
#    'neutralization': 'MARKET',
#    'truncation': 0.01,
#    'pasteurization': 'ON',
#    'testPeriod': 'P0Y0M0D',
#    'unitHandling': 'VERIFY',
#    'nanHandling': 'OFF',
#    'language': 'FASTEXPR',
#    'visualization': False},
#   'regular': 'k = ts_corr(trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5), trade_when(oth460_1l_fbds<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbds>0.5), 30);k*regression_neut(trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5), trade_when(oth460_1l_fbds<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbds>0.5))'}]

# %%
result = ace.simulate_alpha_list_multi(s, alpha_list)
# Out:
#  25%|████████████████████▊                                                              | 1/4 [03:07<09:22, 187.53s/it]
# An error occurred
#  50%|█████████████████████████████████████████▌                                         | 2/4 [04:58<04:45, 142.54s/it]
# An error occurred
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [05:34<01:33, 93.81s/it]
# An error occurred
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [19:01<00:00, 285.34s/it]
# An error occurred
# Your simulation has been running too long. If you are running simulations in batch, consider to reduce number of concurrent simulations.

# %%
result
# Out:
# [{'alpha_id': 'RpKKkxa',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 0,
#     'neutralization': 'MARKET',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5)*(1+ trade_when(oth460_1l_fbbs<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbbs>0.5))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  5634660  20000000        570        1060    0.6559   0.0544    0.1309
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000166     0.26    0.91  2012-01-22  RpKKkxa  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  0.9100   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.2600   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.6559   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.6559   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     FAIL   0.32  0.2000   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  0.5700   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  RpKKkxa
#   1          NaN  RpKKkxa
#   2          NaN  RpKKkxa
#   3          NaN  RpKKkxa
#   4          NaN  RpKKkxa
#   5          NaN  RpKKkxa
#   6          NaN  RpKKkxa
#   7          NaN  RpKKkxa
#   8          NaN  RpKKkxa
#   9          NaN  RpKKkxa
#   10  2020-01-25  RpKKkxa  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'Pp88XLL',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 0,
#     'neutralization': 'MARKET',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'trade_when(oth460_1l_acda<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5)*(1+ trade_when(oth460_1l_ccns<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  4842543  20000000        574        1318    0.5459   0.0468    0.1084
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000171     0.26    0.88  2012-01-22  Pp88XLL  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  0.8800   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.2600   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.5459   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.5459   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     FAIL   0.31  0.2400   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  0.4800   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  Pp88XLL
#   1          NaN  Pp88XLL
#   2          NaN  Pp88XLL
#   3          NaN  Pp88XLL
#   4          NaN  Pp88XLL
#   5          NaN  Pp88XLL
#   6          NaN  Pp88XLL
#   7          NaN  Pp88XLL
#   8          NaN  Pp88XLL
#   9          NaN  Pp88XLL
#   10  2020-01-25  Pp88XLL  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'AwmmOpw',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 0,
#     'neutralization': 'MARKET',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'trade_when(oth460_es_ebit_fy1_d1m_l1<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_ebit_fy1_d1m_l1>0.5)*(1+ trade_when(oth460_1l_acda<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  5656042  20000000        942        1866    0.5911   0.0546     0.116
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000185      0.3     1.0  2012-01-22  AwmmOpw  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  1.0000   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.3000   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.5911   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.5911   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     FAIL   0.35  0.1900   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  0.7200   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  AwmmOpw
#   1          NaN  AwmmOpw
#   2          NaN  AwmmOpw
#   3          NaN  AwmmOpw
#   4          NaN  AwmmOpw
#   5          NaN  AwmmOpw
#   6          NaN  AwmmOpw
#   7          NaN  AwmmOpw
#   8          NaN  AwmmOpw
#   9          NaN  AwmmOpw
#   10  2020-01-25  AwmmOpw  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'vL66dAQ',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 0,
#     'neutralization': 'MARKET',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5)*(1+ trade_when(oth460_1l_fbbs<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbbs>0.5))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  7457729  20000000        569        1283    0.6729    0.072    0.0921
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000214     0.39     1.2  2012-01-22  vL66dAQ  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  1.2000   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.3900   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.6729   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.6729   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS   0.42  0.5100   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  1.3200   3.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  vL66dAQ
#   1          NaN  vL66dAQ
#   2          NaN  vL66dAQ
#   3          NaN  vL66dAQ
#   4          NaN  vL66dAQ
#   5          NaN  vL66dAQ
#   6          NaN  vL66dAQ
#   7          NaN  vL66dAQ
#   8          NaN  vL66dAQ
#   9          NaN  vL66dAQ
#   10  2019-01-25  vL66dAQ  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'Xpee1Nx',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 0,
#     'neutralization': 'MARKET',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'trade_when(oth460_es_ebit_fy1_d1m_l1<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_ebit_fy1_d1m_l1>0.5)*(1+ trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  7029477  20000000        688        1413    0.6486   0.0679    0.0926
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000209     0.38    1.18  2012-01-22  Xpee1Nx  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  1.1800   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.3800   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.6486   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.6486   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     FAIL   0.41  0.1600   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  1.0700   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  Xpee1Nx
#   1          NaN  Xpee1Nx
#   2          NaN  Xpee1Nx
#   3          NaN  Xpee1Nx
#   4          NaN  Xpee1Nx
#   5          NaN  Xpee1Nx
#   6          NaN  Xpee1Nx
#   7          NaN  Xpee1Nx
#   8          NaN  Xpee1Nx
#   9          NaN  Xpee1Nx
#   10  2020-01-25  Xpee1Nx  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': '5weeMrJ',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 0,
#     'neutralization': 'MARKET',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'trade_when(oth460_1l_fbds<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbds>0.5)*(1+ trade_when(oth460_es_roe_fy1_d1m_l1<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_roe_fy1_d1m_l1>0.5))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  7219126  20000000        813        1885    0.6375   0.0697    0.1073
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000219     0.39    1.17  2012-01-22  5weeMrJ  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  1.1700   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.3900   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.6375   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.6375   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS   0.41  0.4100   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  1.0100   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  5weeMrJ
#   1          NaN  5weeMrJ
#   2          NaN  5weeMrJ
#   3          NaN  5weeMrJ
#   4          NaN  5weeMrJ
#   5          NaN  5weeMrJ
#   6          NaN  5weeMrJ
#   7          NaN  5weeMrJ
#   8          NaN  5weeMrJ
#   9          NaN  5weeMrJ
#   10  2020-01-25  5weeMrJ  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': '27WWKaZ',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 0,
#     'neutralization': 'MARKET',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'trade_when(oth460_1l_acda<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5)*(1+ trade_when(oth460_1l_ccns<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  5795140  20000000        579        1344     0.548    0.056    0.0858
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000204     0.33    1.02  2012-01-22  27WWKaZ  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit  value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  1.020   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.330   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.548   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.548   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN    NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS   0.36  0.510   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN    NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN    NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN    NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN    NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  1.060   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  27WWKaZ
#   1          NaN  27WWKaZ
#   2          NaN  27WWKaZ
#   3          NaN  27WWKaZ
#   4          NaN  27WWKaZ
#   5          NaN  27WWKaZ
#   6          NaN  27WWKaZ
#   7          NaN  27WWKaZ
#   8          NaN  27WWKaZ
#   9          NaN  27WWKaZ
#   10  2020-01-25  27WWKaZ  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': '6wJJEzO',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 0,
#     'neutralization': 'MARKET',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'trade_when(oth460_1l_ccns<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5)*(1+ trade_when(oth460_1l_acda<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_acda>0.5))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  5490512  20000000        588        1337    0.5688    0.053    0.1044
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000186     0.29    0.95  2012-01-22  6wJJEzO  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  0.9500   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.2900   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.5688   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.5688   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS   0.33  0.5700   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  1.0400   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  6wJJEzO
#   1          NaN  6wJJEzO
#   2          NaN  6wJJEzO
#   3          NaN  6wJJEzO
#   4          NaN  6wJJEzO
#   5          NaN  6wJJEzO
#   6          NaN  6wJJEzO
#   7          NaN  6wJJEzO
#   8          NaN  6wJJEzO
#   9          NaN  6wJJEzO
#   10  2020-01-25  6wJJEzO  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'dxooQdv',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 0,
#     'neutralization': 'MARKET',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_m3r_mtn_spb_se>0.5)*(1+ trade_when(oth460_1l_fbds<=0.5, regression_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_fbds>0.5))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  7170607  20000000        568        1299    0.6671   0.0692    0.0998
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000208     0.38    1.18  2012-01-22  dxooQdv  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  1.1800   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.3800   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.6671   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.6671   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS   0.41  0.4200   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  1.3400   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  dxooQdv
#   1          NaN  dxooQdv
#   2          NaN  dxooQdv
#   3          NaN  dxooQdv
#   4          NaN  dxooQdv
#   5          NaN  dxooQdv
#   6          NaN  dxooQdv
#   7          NaN  dxooQdv
#   8          NaN  dxooQdv
#   9          NaN  dxooQdv
#   10  2020-01-25  dxooQdv  ,
#   'train': None,
#   'test': None},
#  {'alpha_id': 'vL66NAd',
#   'simulate_data': {'type': 'REGULAR',
#    'settings': {'instrumentType': 'EQUITY',
#     'region': 'GLB',
#     'universe': 'MINVOL1M',
#     'delay': 1,
#     'decay': 0,
#     'neutralization': 'MARKET',
#     'truncation': 0.01,
#     'pasteurization': 'ON',
#     'testPeriod': 'P0Y0M0D',
#     'unitHandling': 'VERIFY',
#     'nanHandling': 'OFF',
#     'language': 'FASTEXPR',
#     'visualization': False},
#    'regular': 'trade_when(oth460_es_roe_fy1_d1m_l1<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cpss_best_eeps_nxt_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_es_roe_fy1_d1m_l1>0.5)*(1+ trade_when(oth460_1l_ccns<=0.5, vector_neut(ts_zscore(ts_backfill(anl69_cps_best_eeps_cur_yr, 21),21), group_zscore(ts_ir(returns, 252), industry)), oth460_1l_ccns>0.5))'},
#   'is_stats':        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
#   0  5620094  20000000        587        1159    0.5987   0.0543    0.1137
#
#        margin  fitness  sharpe   startDate alpha_id
#   0  0.000181     0.27    0.89  2012-01-22  vL66NAd  ,
#   'pnl': None,
#   'stats': None,
#   'is_tests':                        name   result  limit   value  year   startDate  \
#   0                LOW_SHARPE     FAIL   1.58  0.8900   NaN         NaN
#   1               LOW_FITNESS     FAIL   1.00  0.2700   NaN         NaN
#   2              LOW_TURNOVER     PASS   0.01  0.5987   NaN         NaN
#   3             HIGH_TURNOVER     PASS   0.70  0.5987   NaN         NaN
#   4       CONCENTRATED_WEIGHT     PASS    NaN     NaN   NaN         NaN
#   5   LOW_SUB_UNIVERSE_SHARPE     PASS   0.31  0.3900   NaN         NaN
#   6          SELF_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   7            DATA_DIVERSITY  PENDING    NaN     NaN   NaN         NaN
#   8          PROD_CORRELATION  PENDING    NaN     NaN   NaN         NaN
#   9        REGULAR_SUBMISSION  PENDING    NaN     NaN   NaN         NaN
#   10         IS_LADDER_SHARPE     FAIL   1.58  0.7100   2.0  2022-01-24
#
#          endDate alpha_id
#   0          NaN  vL66NAd
#   1          NaN  vL66NAd
#   2          NaN  vL66NAd
#   3          NaN  vL66NAd
#   4          NaN  vL66NAd
#   5          NaN  vL66NAd
#   6          NaN  vL66NAd
#   7          NaN  vL66NAd
#   8          NaN  vL66NAd
#   9          NaN  vL66NAd
#   10  2020-01-25  vL66NAd  ,
#   'train': None,
#   'test': None}]

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  7457729   20000000         569         1283    0.6729   0.0720    0.0921
# 1  7219126   20000000         813         1885    0.6375   0.0697    0.1073
# 2  7029477   20000000         688         1413    0.6486   0.0679    0.0926
# 3  7170607   20000000         568         1299    0.6671   0.0692    0.0998
# 4  5795140   20000000         579         1344    0.5480   0.0560    0.0858
# 5  5656042   20000000         942         1866    0.5911   0.0546    0.1160
# 6  5490512   20000000         588         1337    0.5688   0.0530    0.1044
# 7  5620094   20000000         587         1159    0.5987   0.0543    0.1137
# 8  5634660   20000000         570         1060    0.6559   0.0544    0.1309
# 9  4842543   20000000         574         1318    0.5459   0.0468    0.1084
#
#      margin  fitness  sharpe  start_date alpha_id  \
# 0  0.000214     0.39    1.20  2012-01-22  vL66dAQ
# 1  0.000219     0.39    1.17  2012-01-22  5weeMrJ
# 2  0.000209     0.38    1.18  2012-01-22  Xpee1Nx
# 3  0.000208     0.38    1.18  2012-01-22  dxooQdv
# 4  0.000204     0.33    1.02  2012-01-22  27WWKaZ
# 5  0.000185     0.30    1.00  2012-01-22  AwmmOpw
# 6  0.000186     0.29    0.95  2012-01-22  6wJJEzO
# 7  0.000181     0.27    0.89  2012-01-22  vL66NAd
# 8  0.000166     0.26    0.91  2012-01-22  RpKKkxa
# 9  0.000171     0.26    0.88  2012-01-22  Pp88XLL
#
#                                           expression concentrated_weight  \
# 0  trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, vect...                PASS
# 1  trade_when(oth460_1l_fbds<=0.5, vector_neut(ts...                PASS
# 2  trade_when(oth460_es_ebit_fy1_d1m_l1<=0.5, reg...                PASS
# 3  trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, regr...                PASS
# 4  trade_when(oth460_1l_acda<=0.5, regression_neu...                PASS
# 5  trade_when(oth460_es_ebit_fy1_d1m_l1<=0.5, vec...                PASS
# 6  trade_when(oth460_1l_ccns<=0.5, vector_neut(ts...                PASS
# 7  trade_when(oth460_es_roe_fy1_d1m_l1<=0.5, vect...                PASS
# 8  trade_when(oth460_1l_m3r_mtn_spb_se<=0.5, vect...                PASS
# 9  trade_when(oth460_1l_acda<=0.5, regression_neu...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
# 5          PASS             FAIL        FAIL       FAIL
# 6          PASS             FAIL        FAIL       FAIL
# 7          PASS             FAIL        FAIL       FAIL
# 8          PASS             FAIL        FAIL       FAIL
# 9          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover
# 0                    PASS         PASS
# 1                    PASS         PASS
# 2                    FAIL         PASS
# 3                    PASS         PASS
# 4                    PASS         PASS
# 5                    FAIL         PASS
# 6                    PASS         PASS
# 7                    PASS         PASS
# 8                    FAIL         PASS
# 9                    FAIL         PASS

# %%
result_st1.to_csv('A_mixing_add.csv')

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(result)
is_tests_df.head()
# Out:
#   alpha_id endDate  limit                 name result startDate   value  year
# 0  Vp55RVY     NaN   1.58           LOW_SHARPE   PASS       NaN  2.1900   NaN
# 1  Vp55RVY     NaN   1.00          LOW_FITNESS   PASS       NaN  1.4900   NaN
# 2  Vp55RVY     NaN   0.01         LOW_TURNOVER   PASS       NaN  0.2594   NaN
# 3  Vp55RVY     NaN   0.70        HIGH_TURNOVER   PASS       NaN  0.2594   NaN
# 4  Vp55RVY     NaN    NaN  CONCENTRATED_WEIGHT   PASS       NaN     NaN   NaN

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['Vp55RVY' 'roVVn3j']
# Passed alphas:[]

# %%
#calling submit_alpha on all alphas that have passed the submission tests
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['summer_boot_camp_4조'])

# %%
ace.get_check_submission(s, passed_alphas[3])
# Out:
#                       name   result  limit   value  \
# 0               LOW_SHARPE     PASS   1.25  2.6200
# 1              LOW_FITNESS     PASS   1.00  1.5400
# 2             LOW_TURNOVER     PASS   0.01  0.4315
# 3            HIGH_TURNOVER     PASS   0.70  0.4315
# 4      CONCENTRATED_WEIGHT     PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE     PASS   0.92  1.2600
# 6         SELF_CORRELATION     FAIL   0.70  0.8117
# 7         PROD_CORRELATION  PENDING   0.70     NaN
# 8       REGULAR_SUBMISSION     PASS   4.00  0.0000
# 9      MATCHES_COMPETITION     PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  roV9mgo
# 1                                         NaN  roV9mgo
# 2                                         NaN  roV9mgo
# 3                                         NaN  roV9mgo
# 4                                         NaN  roV9mgo
# 5                                         NaN  roV9mgo
# 6                                         NaN  roV9mgo
# 7                                         NaN  roV9mgo
# 8                                         NaN  roV9mgo
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  roV9mgo

# %%
submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas}

# %% [markdown]
# ## Template C Mixing

# %%
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['summer_boot_camp_4조'])

# %%
ace.get_check_submission(s, passed_alphas[0])
# Out:
#                       name result  limit   value  \
# 0               LOW_SHARPE   PASS   1.25  2.0200
# 1              LOW_FITNESS   PASS   1.00  1.1200
# 2             LOW_TURNOVER   PASS   0.01  0.3259
# 3            HIGH_TURNOVER   PASS   0.70  0.3259
# 4      CONCENTRATED_WEIGHT   PASS    NaN     NaN
# 5  LOW_SUB_UNIVERSE_SHARPE   PASS   0.87  0.9200
# 6         SELF_CORRELATION   PASS   0.70  0.4739
# 7         PROD_CORRELATION   PASS   0.70  0.6252
# 8       REGULAR_SUBMISSION   PASS   4.00  3.0000
# 9      MATCHES_COMPETITION   PASS    NaN     NaN
#
#                                  competitions alpha_id
# 0                                         NaN  oKP2Wrl
# 1                                         NaN  oKP2Wrl
# 2                                         NaN  oKP2Wrl
# 3                                         NaN  oKP2Wrl
# 4                                         NaN  oKP2Wrl
# 5                                         NaN  oKP2Wrl
# 6                                         NaN  oKP2Wrl
# 7                                         NaN  oKP2Wrl
# 8                                         NaN  oKP2Wrl
# 9  [{'id': 'challenge', 'name': 'Challenge'}]  oKP2Wrl

# %% [markdown]
# When you got a list of submittable alphas, you can call function submit_alpha()

# %%
#calling submit_alpha on all alphas that have passed the submission tests
for alpha_id in passed_alphas:
    hf.set_alpha_properties(s, alpha_id, tags = ['summer_boot_camp_4조'])
submit_result = {alpha_id: ace.submit_alpha(s, alpha_id) for alpha_id in passed_alphas}

# %%
#submit_result will have return values from the submit_result function

submit_result
# Out:
# {'oKP2Wrl': True}

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance

# %%
ace.get_alpha_pnl(s, result[0]['alpha_id'])
# Out:
#                    Pnl alpha_id
# Date
# 2012-01-23         0.0  dx9ALqJ
# 2012-01-24     52190.0  dx9ALqJ
# 2012-01-25     32038.0  dx9ALqJ
# 2012-01-26     37403.0  dx9ALqJ
# 2012-01-27     53631.0  dx9ALqJ
# ...                ...      ...
# 2022-01-17  12935472.0  dx9ALqJ
# 2022-01-18  12935661.0  dx9ALqJ
# 2022-01-19  12967474.0  dx9ALqJ
# 2022-01-20  12966156.0  dx9ALqJ
# 2022-01-21  12958392.0  dx9ALqJ
#
# [2588 rows x 2 columns]
